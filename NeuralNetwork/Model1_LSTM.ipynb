# %% [markdown]
# # LSTM_model1

# %% [markdown]
# LSTM_model1 uses a simple layer of LSTM with N=100 times steps, Nh=150 hidden units.
# Dataset can be downloaded in http://www.montefiore.ulg.ac.be/services/acous/STSI/downloads.php

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
"""lstm for guitar signal"""
import os
import sys
sys.path.append('Codes')
import tensorflow as tf
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import pickle
from dataShaping import *
from savePerf import *
import scipy.io.wavfile
import time
from tensorflow.contrib.layers import fully_connected
from tensorflow.contrib.rnn import *
from saveTransformedGraph import optimizeGraph

modelName = "LSTM_model1"

#############################
# Directory experiment
#############################
date = time.strftime("%Y-%m-%d-%H-%M")
path = os.path.join("Experiments",date)
if not os.path.isdir(path):
    os.makedirs(path)
    #experiment/"date"/temp will contain the backuped model parameters
    pathTemp = os.path.join(path,'temp')
    os.makedirs(pathTemp)
    # if you run the file two time in a minute
else :
    date = date+'(2)'
    path = os.path.join("Experiments",date)
    os.makedirs(path)
    pathTemp = os.path.join(path,'temp')
    os.makedirs(pathTemp)

# directory that will contain tensorboard information
pathLog = 'Tf_logs'
if not os.path.isdir(pathLog):
    os.makedirs(pathLog)
pathLog = "{}/run-{}/".format(pathLog,date)

version = tf.__version__
print ("version {} of tensorflow".format(version))

#############################
# Model parameters
#############################
trainTestRatio = 0.8
maxSize = 0
num_step = 100
num_hidden = 150
num_out = 1
num_feature = 1
batch_size = 1000
num_epoch = 10000                                      
trainDuration = 60*60*15                             
                                      
amplifierName = 'EnglDisto'
fileNameTrain = 'Datasets/training'+amplifierName+'.mat' #dataset train/test path
fileNameTest = 'Datasets/test'+amplifierName+'.mat'     # dataset validation path
fileNameValidation = 'Datasets/val'+amplifierName+'.mat'

#############################
# Loading data
#############################
matrix = sio.loadmat(fileNameTrain)
matrixTrain = matrix['train']
matrix = sio.loadmat(fileNameTest)
matrixTest = matrix['test']
if maxSize ==0:
    maxSize = len(matrixTrain)
    print("maxSize = {}".format(maxSize))

train_input,train_output,test_input,test_output = loadInputOutputSeq(matrixTrain,matrixTest,num_step,maxSize)
print("shape input train {}".format(np.shape(train_input)))
numTrain = len(train_output)
print ("Data loaded")

#######################
# Graph Construction
#######################
G = tf.Graph()
with G.as_default():
    with tf.name_scope("placeHolder"):
        data = tf.placeholder(tf.float32, [None, num_step], name ="data") 
        target = tf.placeholder(tf.float32, [None, num_out],name = "target")
        dataShaped = tf.reshape(data,[tf.shape(data)[0],tf.shape(data)[1],num_feature])
        dataShaped = tf.transpose(dataShaped,[1,0,2])
    
    with tf.name_scope("LSTMLayer"):
        fusedCell = tf.contrib.rnn.LSTMBlockFusedCell(num_hidden,use_peephole=False)
        val, state = fusedCell(dataShaped,dtype=tf.float32) 
        
    with tf.name_scope("extractLastCelloftheLSTMLayer"):
        last_index = tf.shape(val)[0] - 1
        lastState = tf.gather(val,last_index)
    
    prediction = fully_connected(lastState,int(target.get_shape()[1]),activation_fn=tf.nn.tanh,weights_regularizer=None,scope="FCPred")
    
##############################
# Cost function
##############################
    MSE = tf.reduce_mean(tf.square(prediction-target))
    EnergyTarget = tf.reduce_mean(tf.square(target)) 
    optimizer = tf.train.AdamOptimizer()
    minimize = optimizer.minimize(MSE)
    # Create summary view for tensorboard
    mse_summary = tf.summary.scalar('RMSE',tf.sqrt(MSE))
    summary_op = tf.summary.merge_all()
    #Create an init op to initialize variable
    init_op = tf.global_variables_initializer()
    saver = tf.train.Saver() 

##############################
# Graph execution
##############################
    
with tf.Session(graph=G) as sess:
    #restorePath = os.path.join('2017-09-11-18-07','temp','my_model.ckpt')
    #saver.restore(sess,restorePath)
    sess.run(init_op)
    train_writer = tf.summary.FileWriter(pathLog+'train',graph =tf.get_default_graph())
    test_writer = tf.summary.FileWriter(pathLog+'test')
    
    no_of_batches = int(np.floor((numTrain)/batch_size)) 
    no_of_batchesTest = int(np.floor((len(test_input))/batch_size))
    tStart = time.clock()
    epoch =0
    NRMSETest = 1
    bestNRMSETest = 1    
    # train until the number of epochs or the training time is reached
    for epoch in range(num_epoch):
        tEpoch = time.clock()
        if (time.clock()-tStart < trainDuration) :
            ptr = 0
            if epoch % 20==0 : # each twenty epochs save the model
                tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myGraph.pb',as_text=False)
                save_path = saver.save(sess,os.path.join(pathTemp,'myModel.ckpt'))
            
            pMSETrain=0
            pEnergyTarget=0
            for j in range(no_of_batches):
                inp, out = train_input[ptr:ptr+batch_size],train_output[ptr:ptr+batch_size]
                ptr+=batch_size
                
                if j % np.floor(numTrain/len(test_input)) ==0 : # This is to have a train summary and a test summary of the same size
                    _,summary_str,pMSETrainTemp,pEnergyTargetTemp = sess.run([minimize,summary_op,MSE,EnergyTarget],{data: inp, target: out})
                    pMSETrain += pMSETrainTemp
                    pEnergyTarget += pEnergyTargetTemp
                    step = epoch*no_of_batches+j
                    # save the training RMSE for tensorboard
                    train_writer.add_summary(summary_str,step)                   

                else :
                    _,pMSETrainTemp,pEnergyTargetTemp = sess.run([minimize,MSE,EnergyTarget],{data: inp, target: out})
                    pMSETrain += pMSETrainTemp
                    pEnergyTarget += pEnergyTargetTemp
            # compute an estimation of the RMSE for this epoch       
            MSETrain = pMSETrain/no_of_batches
            EnergyTargetTrain = pEnergyTarget/no_of_batches
            NRMSETrain = np.sqrt(MSETrain/EnergyTargetTrain)
            print ("Epoch -{} calculated in {:5.2f} s ".format(epoch,time.clock()-tEpoch))
            # evaluate the model on the test set 
            pMSE = 0
            ptr2 = 0
            pEnergyTarget = 0
            for k in range(no_of_batchesTest):
                pMSETemp,pEnergyTargetTemp,summary_str = sess.run([MSE,EnergyTarget,summary_op],{data: test_input[ptr2:ptr2+batch_size] , target: test_output[ptr2:ptr2+batch_size]})
                pMSE += pMSETemp
                ptr2 += batch_size
                pEnergyTarget+=pEnergyTargetTemp
                step = epoch*no_of_batchesTest+k
                test_writer.add_summary(summary_str,step*np.floor(numTrain/len(test_input)))
            MSETest = pMSE/no_of_batchesTest
            EnergyTargetTest = pEnergyTarget/no_of_batchesTest
            NRMSETest = np.sqrt(MSETest/EnergyTargetTest)
            if NRMSETest<bestNRMSETest:
                bestNRMSETest=NRMSETest
                tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myBestGraph.pbtxt',as_text=True)
                save_path = saver.save(sess,os.path.join(pathTemp,'myBestModel.ckpt'))
            print("Epoch {}, NRMSE Test/best: {:.5f}/{:.5f}, Training NRMSE: {:.5f}, deviation of {:.2f}%".format(epoch,NRMSETest,bestNRMSETest,NRMSETrain,100*np.sqrt((NRMSETrain-NRMSETest)**2)/NRMSETrain))
        else : break # break the while loop if number of epoch is reached
    tStop = time.clock()
    trainTime = time.strftime("%d:%H:%M:%S ", time.gmtime(tStop-tStart))
    
    ################################################################
    # Save Graph variable and information about the running session
    ################################################################
    # save graph model
    tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myFinalGraph.pbtxt',as_text=True)
    # Save checkpoint variables
    save_path = saver.save(sess,os.path.join(pathTemp,'myFinalModel.ckpt'))
    print ("Training duration {}".format(trainTime))
    totalParameters =np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.trainable_variables()])
    print("Number of training variable {}".format(totalParameters))
    # log
    infoLog={}
    infoLog["path"] = path
    infoLog["MSE"] = bestNRMSETest
    infoLog["num_step"] = num_step
    infoLog["num_hidden"] = num_hidden
    infoLog["num_epoch"] = epoch
    infoLog["batch_size"] = batch_size
    infoLog["maxSize"] = maxSize
    infoLog["duration"] = trainTime
    infoLog["totalParameters"] = totalParameters
    infoLog["version"] = version
    infoLog["n_layer"] = 1
    infoLog["trainDropout"] = 0
    infoLog["nameModel"] = modelName
    infoLog["conv_chan"] = [0]
    infoLog["strides"] = 0
    infoLog["conv_size"] = 0
    infoLog["amplifierName"]=amplifierName
    logPerf(infoLog)
    input_nodes=["placeHolder/data"]
    output_nodes=["FCPred/Tanh"]
    optimizeGraph(pathTemp,input_nodes,output_nodes) 
    
    ################################################
    #   Validation
    ################################################
    restorePath = os.path.join(pathTemp,'myBestModel.ckpt') # restore the best model
    saver.restore(sess,restorePath)
    matrixVal = sio.loadmat(fileNameValidation)
    matrixVal = matrixVal['val']  
    valSize = 0
    if valSize == 0 :
        valSize = len(matrixVal)
    # shape validation testpLast
    val_input,val_output = loadValidationSeq(matrixVal,num_step,valSize)
    lPrediction = []
    lTarget = []
    ptr3 = 0
    no_of_batchesVal = int(np.floor((len(val_input))/batch_size))
    for k in range(no_of_batchesVal):
        pPrediction,pTarget = sess.run([prediction,target],{data: val_input[ptr3:ptr3+batch_size], target: val_output[ptr3:ptr3+batch_size]}) 
        lPrediction.append(pPrediction)
        lTarget.append(pTarget)   
        ptr3+=batch_size
    #plt.show()scree
    predictionArray = np.array(lPrediction,dtype=np.float32).ravel()
    targetArray = np.array(lTarget,dtype=np.float32).ravel()
    scipy.io.wavfile.write(os.path.join(path,'prediction.wav'),44100,predictionArray)
    scipy.io.wavfile.write(os.path.join(path,'target.wav'),44100,targetArray)

    # save emulation in a pickle format
    ax = plt.subplot(111)
    ax.plot(predictionArray[6000+num_step:6700+num_step],label='prediction')
    ax.plot(targetArray[6000+num_step:6700+num_step],label='target')
    ax.legend()
    plt.xlabel('sample n')
    plt.ylabel('Amplitude y[n]')
    nameFigEstimation = os.path.join(path,"targetVsPrediction.pickle")
    pickle.dump(ax,open(nameFigEstimation, 'wb'))
print ("done, good job kids")
# Out:
# version 1.13.1 of tensorflow
# maxSize = 6726407
# shape input train (6726308, 100)
# Data loaded
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/rnn/python/ops/lstm_ops.py:694: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch -0 calculated in 242.53 s
# Epoch 0, NRMSE Test/best: 0.87148/0.87148, Training NRMSE: 0.62956, deviation of 38.43%
# Epoch -1 calculated in 242.70 s
# Epoch 1, NRMSE Test/best: 1.10016/0.87148, Training NRMSE: 0.50131, deviation of 119.45%
# Epoch -2 calculated in 242.63 s
# Epoch 2, NRMSE Test/best: 0.98675/0.87148, Training NRMSE: 0.46363, deviation of 112.83%
# Epoch -3 calculated in 242.59 s
# Epoch 3, NRMSE Test/best: 0.80054/0.80054, Training NRMSE: 0.42364, deviation of 88.97%
# Epoch -4 calculated in 242.81 s
# Epoch 4, NRMSE Test/best: 1.01279/0.80054, Training NRMSE: 0.40830, deviation of 148.05%
# Epoch -5 calculated in 242.60 s
# Epoch 5, NRMSE Test/best: 0.63509/0.63509, Training NRMSE: 0.40895, deviation of 55.30%
# Epoch -6 calculated in 242.45 s
# Epoch 6, NRMSE Test/best: 0.60500/0.60500, Training NRMSE: 0.38948, deviation of 55.33%
# Epoch -7 calculated in 243.09 s
# Epoch 7, NRMSE Test/best: 0.60895/0.60500, Training NRMSE: 0.38476, deviation of 58.27%
# Epoch -8 calculated in 242.37 s
# Epoch 8, NRMSE Test/best: 0.68731/0.60500, Training NRMSE: 0.38024, deviation of 80.76%
# Epoch -9 calculated in 242.62 s
# Epoch 9, NRMSE Test/best: 0.69752/0.60500, Training NRMSE: 0.37729, deviation of 84.88%
# Epoch -10 calculated in 242.53 s
# Epoch 10, NRMSE Test/best: 0.59905/0.59905, Training NRMSE: 0.37375, deviation of 60.28%
# Epoch -11 calculated in 242.95 s
# Epoch 11, NRMSE Test/best: 0.60816/0.59905, Training NRMSE: 0.36987, deviation of 64.42%
# Epoch -12 calculated in 242.99 s
# Epoch 12, NRMSE Test/best: 0.64712/0.59905, Training NRMSE: 0.36737, deviation of 76.15%
# Epoch -13 calculated in 242.39 s
# Epoch 13, NRMSE Test/best: 0.65982/0.59905, Training NRMSE: 0.36571, deviation of 80.42%
# Epoch -14 calculated in 242.67 s
# Epoch 14, NRMSE Test/best: 0.60002/0.59905, Training NRMSE: 0.36395, deviation of 64.86%
# Epoch -15 calculated in 242.82 s
# Epoch 15, NRMSE Test/best: 0.61852/0.59905, Training NRMSE: 0.36217, deviation of 70.78%
# Epoch -16 calculated in 242.40 s
# Epoch 16, NRMSE Test/best: 0.60842/0.59905, Training NRMSE: 0.36084, deviation of 68.61%
# Epoch -17 calculated in 242.43 s
# Epoch 17, NRMSE Test/best: 0.58873/0.58873, Training NRMSE: 0.35972, deviation of 63.66%
# Epoch -18 calculated in 242.65 s
# Epoch 18, NRMSE Test/best: 0.56988/0.56988, Training NRMSE: 0.35841, deviation of 59.00%
# Epoch -19 calculated in 242.29 s
# Epoch 19, NRMSE Test/best: 0.56514/0.56514, Training NRMSE: 0.35710, deviation of 58.26%
# Epoch -20 calculated in 242.82 s
# Epoch 20, NRMSE Test/best: 0.52481/0.52481, Training NRMSE: 0.35601, deviation of 47.42%
# Epoch -21 calculated in 242.13 s
# Epoch 21, NRMSE Test/best: 0.54659/0.52481, Training NRMSE: 0.35475, deviation of 54.08%
# Epoch -22 calculated in 242.77 s
# Epoch 22, NRMSE Test/best: 0.53681/0.52481, Training NRMSE: 0.35406, deviation of 51.62%
# Epoch -23 calculated in 242.51 s
# Epoch 23, NRMSE Test/best: 0.53105/0.52481, Training NRMSE: 0.35319, deviation of 50.36%
# Epoch -24 calculated in 242.70 s
# Epoch 24, NRMSE Test/best: 0.52584/0.52481, Training NRMSE: 0.35231, deviation of 49.26%
# Epoch -25 calculated in 242.80 s
# Epoch 25, NRMSE Test/best: 0.51413/0.51413, Training NRMSE: 0.35145, deviation of 46.29%
# Epoch -26 calculated in 243.05 s
# Epoch 26, NRMSE Test/best: 0.50201/0.50201, Training NRMSE: 0.35059, deviation of 43.19%
# Epoch -27 calculated in 242.74 s
# Epoch 27, NRMSE Test/best: 0.49910/0.49910, Training NRMSE: 0.34970, deviation of 42.72%
# Epoch -28 calculated in 242.62 s
# Epoch 28, NRMSE Test/best: 0.50332/0.49910, Training NRMSE: 0.34917, deviation of 44.15%
# Epoch -29 calculated in 243.02 s
# Epoch 29, NRMSE Test/best: 0.49396/0.49396, Training NRMSE: 0.34834, deviation of 41.81%
# Epoch -30 calculated in 242.53 s
# Epoch 30, NRMSE Test/best: 0.49560/0.49396, Training NRMSE: 0.34772, deviation of 42.53%
# Epoch -31 calculated in 242.50 s
# Epoch 31, NRMSE Test/best: 0.48069/0.48069, Training NRMSE: 0.34717, deviation of 38.46%
# Epoch -32 calculated in 242.42 s
# Epoch 32, NRMSE Test/best: 0.46513/0.46513, Training NRMSE: 0.34644, deviation of 34.26%
# Epoch -33 calculated in 242.17 s
# Epoch 33, NRMSE Test/best: 0.47098/0.46513, Training NRMSE: 0.34585, deviation of 36.18%
# Epoch -34 calculated in 242.95 s
# Epoch 34, NRMSE Test/best: 0.46497/0.46497, Training NRMSE: 0.34519, deviation of 34.70%
# Epoch -35 calculated in 242.96 s
# Epoch 35, NRMSE Test/best: 0.46471/0.46471, Training NRMSE: 0.34461, deviation of 34.85%
# Epoch -36 calculated in 242.82 s
# Epoch 36, NRMSE Test/best: 0.46443/0.46443, Training NRMSE: 0.34397, deviation of 35.02%
# Epoch -37 calculated in 242.77 s
# Epoch 37, NRMSE Test/best: 0.46081/0.46081, Training NRMSE: 0.34337, deviation of 34.20%
# Epoch -38 calculated in 242.34 s
# Epoch 38, NRMSE Test/best: 0.46153/0.46081, Training NRMSE: 0.34282, deviation of 34.63%
# Epoch -39 calculated in 243.48 s
# Epoch 39, NRMSE Test/best: 0.46245/0.46081, Training NRMSE: 0.34216, deviation of 35.15%
# Epoch -40 calculated in 242.59 s
# Epoch 40, NRMSE Test/best: 0.45715/0.45715, Training NRMSE: 0.34163, deviation of 33.81%
# Epoch -41 calculated in 242.73 s
# Epoch 41, NRMSE Test/best: 0.44873/0.44873, Training NRMSE: 0.34109, deviation of 31.56%
# Epoch -42 calculated in 242.71 s
# Epoch 42, NRMSE Test/best: 0.45349/0.44873, Training NRMSE: 0.34036, deviation of 33.24%
# Epoch -43 calculated in 242.84 s
# Epoch 43, NRMSE Test/best: 0.44822/0.44822, Training NRMSE: 0.33993, deviation of 31.86%
# Epoch -44 calculated in 242.78 s
# Epoch 44, NRMSE Test/best: 0.45129/0.44822, Training NRMSE: 0.33943, deviation of 32.96%
# Epoch -45 calculated in 242.55 s
# Epoch 45, NRMSE Test/best: 0.48611/0.44822, Training NRMSE: 0.34050, deviation of 42.76%
# Epoch -46 calculated in 242.79 s
# Epoch 46, NRMSE Test/best: 0.43797/0.43797, Training NRMSE: 0.33856, deviation of 29.36%
# Epoch -47 calculated in 242.74 s
# Epoch 47, NRMSE Test/best: 0.44276/0.43797, Training NRMSE: 0.33788, deviation of 31.04%
# Epoch -48 calculated in 243.01 s
# Epoch 48, NRMSE Test/best: 0.49891/0.43797, Training NRMSE: 0.34115, deviation of 46.25%
# Epoch -49 calculated in 242.57 s
# Epoch 49, NRMSE Test/best: 0.49535/0.43797, Training NRMSE: 0.33961, deviation of 45.86%
# Epoch -50 calculated in 242.55 s
# Epoch 50, NRMSE Test/best: 0.43833/0.43797, Training NRMSE: 0.33791, deviation of 29.72%
# Epoch -51 calculated in 242.53 s
# Epoch 51, NRMSE Test/best: 0.46929/0.43797, Training NRMSE: 0.33787, deviation of 38.90%
# Epoch -52 calculated in 242.90 s
# Epoch 52, NRMSE Test/best: 0.44572/0.43797, Training NRMSE: 0.33604, deviation of 32.64%
# Epoch -53 calculated in 242.24 s
# Epoch 53, NRMSE Test/best: 0.44259/0.43797, Training NRMSE: 0.33556, deviation of 31.90%
# Epoch -54 calculated in 242.53 s
# Epoch 54, NRMSE Test/best: 0.43773/0.43773, Training NRMSE: 0.33516, deviation of 30.61%
# Epoch -55 calculated in 242.44 s
# Epoch 55, NRMSE Test/best: 0.45928/0.43773, Training NRMSE: 0.33458, deviation of 37.27%
# Epoch -56 calculated in 242.72 s
# Epoch 56, NRMSE Test/best: 0.44228/0.43773, Training NRMSE: 0.33417, deviation of 32.35%
# Epoch -57 calculated in 242.75 s
# Epoch 57, NRMSE Test/best: 0.44989/0.43773, Training NRMSE: 0.33397, deviation of 34.71%
# Epoch -58 calculated in 243.08 s
# Epoch 58, NRMSE Test/best: 0.44367/0.43773, Training NRMSE: 0.33350, deviation of 33.03%
# Epoch -59 calculated in 242.20 s
# Epoch 59, NRMSE Test/best: 0.41931/0.41931, Training NRMSE: 0.33842, deviation of 23.90%
# Epoch -60 calculated in 242.48 s
# Epoch 60, NRMSE Test/best: 0.45520/0.41931, Training NRMSE: 0.33440, deviation of 36.12%
# Epoch -61 calculated in 242.85 s
# Epoch 61, NRMSE Test/best: 0.45861/0.41931, Training NRMSE: 0.33320, deviation of 37.64%
# Epoch -62 calculated in 242.47 s
# Epoch 62, NRMSE Test/best: 0.44790/0.41931, Training NRMSE: 0.33268, deviation of 34.63%
# Epoch -63 calculated in 242.84 s
# Epoch 63, NRMSE Test/best: 0.43009/0.41931, Training NRMSE: 0.33222, deviation of 29.46%
# Epoch -64 calculated in 242.63 s
# Epoch 64, NRMSE Test/best: 0.65244/0.41931, Training NRMSE: 0.47915, deviation of 36.17%
# Epoch -65 calculated in 242.31 s
# Epoch 65, NRMSE Test/best: 0.82037/0.41931, Training NRMSE: 0.64090, deviation of 28.00%
# Epoch -66 calculated in 242.22 s
# Epoch 66, NRMSE Test/best: 0.73567/0.41931, Training NRMSE: 0.65567, deviation of 12.20%
# Epoch -67 calculated in 243.03 s
# Epoch 67, NRMSE Test/best: 0.72187/0.41931, Training NRMSE: 0.60376, deviation of 19.56%
# Epoch -68 calculated in 242.39 s
# Epoch 68, NRMSE Test/best: 0.72730/0.41931, Training NRMSE: 0.60353, deviation of 20.51%
# Epoch -69 calculated in 242.57 s
# Epoch 69, NRMSE Test/best: 0.75089/0.41931, Training NRMSE: 0.61306, deviation of 22.48%
# Epoch -70 calculated in 242.57 s
# Epoch 70, NRMSE Test/best: 1.02971/0.41931, Training NRMSE: 0.73687, deviation of 39.74%
# Epoch -71 calculated in 243.03 s
# Epoch 71, NRMSE Test/best: 1.05832/0.41931, Training NRMSE: 0.84260, deviation of 25.60%
# Epoch -72 calculated in 242.65 s
# Epoch 72, NRMSE Test/best: 1.02834/0.41931, Training NRMSE: 0.90585, deviation of 13.52%
# Epoch -73 calculated in 242.72 s
# Epoch 73, NRMSE Test/best: 1.04448/0.41931, Training NRMSE: 0.91688, deviation of 13.92%
# Epoch -74 calculated in 242.23 s
# Epoch 74, NRMSE Test/best: 1.00425/0.41931, Training NRMSE: 0.91632, deviation of 9.60%
# Epoch -75 calculated in 242.91 s
# Epoch 75, NRMSE Test/best: 1.03604/0.41931, Training NRMSE: 0.91456, deviation of 13.28%
# Epoch -76 calculated in 242.72 s
# Epoch 76, NRMSE Test/best: 1.07822/0.41931, Training NRMSE: 0.92866, deviation of 16.10%
# Epoch -77 calculated in 242.95 s
# Epoch 77, NRMSE Test/best: 1.18340/0.41931, Training NRMSE: 0.90942, deviation of 30.13%
# Epoch -78 calculated in 242.63 s
# Epoch 78, NRMSE Test/best: 1.01703/0.41931, Training NRMSE: 0.94732, deviation of 7.36%
# Epoch -79 calculated in 242.65 s
# Epoch 79, NRMSE Test/best: 1.01255/0.41931, Training NRMSE: 0.93971, deviation of 7.75%
# Epoch -80 calculated in 242.64 s
# Epoch 80, NRMSE Test/best: 1.04548/0.41931, Training NRMSE: 0.96088, deviation of 8.80%
# Epoch -81 calculated in 242.44 s
# Epoch 81, NRMSE Test/best: 1.11360/0.41931, Training NRMSE: 0.94647, deviation of 17.66%
# Epoch -82 calculated in 242.29 s
# Epoch 82, NRMSE Test/best: 1.01787/0.41931, Training NRMSE: 0.94486, deviation of 7.73%
# Epoch -83 calculated in 242.57 s
# Epoch 83, NRMSE Test/best: 1.10002/0.41931, Training NRMSE: 0.94263, deviation of 16.70%
# Epoch -84 calculated in 242.69 s
# Epoch 84, NRMSE Test/best: 1.04526/0.41931, Training NRMSE: 0.92251, deviation of 13.31%
# Epoch -85 calculated in 242.13 s
# Epoch 85, NRMSE Test/best: 0.94081/0.41931, Training NRMSE: 0.91766, deviation of 2.52%
# Epoch -86 calculated in 242.66 s
# Epoch 86, NRMSE Test/best: 0.95167/0.41931, Training NRMSE: 0.92375, deviation of 3.02%
# Epoch -87 calculated in 242.73 s
# Epoch 87, NRMSE Test/best: 1.05577/0.41931, Training NRMSE: 0.92757, deviation of 13.82%
# Epoch -88 calculated in 242.55 s
# Epoch 88, NRMSE Test/best: 1.04848/0.41931, Training NRMSE: 0.91880, deviation of 14.11%
# Epoch -89 calculated in 242.27 s
# Epoch 89, NRMSE Test/best: 1.19098/0.41931, Training NRMSE: 0.90185, deviation of 32.06%
# Epoch -90 calculated in 242.55 s
# Epoch 90, NRMSE Test/best: 0.98999/0.41931, Training NRMSE: 0.94645, deviation of 4.60%
# Epoch -91 calculated in 242.08 s
# Epoch 91, NRMSE Test/best: 1.01059/0.41931, Training NRMSE: 0.94713, deviation of 6.70%
# Epoch -92 calculated in 242.96 s
# Epoch 92, NRMSE Test/best: 0.97762/0.41931, Training NRMSE: 0.91693, deviation of 6.62%
# Epoch -93 calculated in 242.18 s
# Epoch 93, NRMSE Test/best: 0.95335/0.41931, Training NRMSE: 0.93099, deviation of 2.40%
# Epoch -94 calculated in 242.31 s
# Epoch 94, NRMSE Test/best: 1.01420/0.41931, Training NRMSE: 0.94120, deviation of 7.76%
# Epoch -95 calculated in 242.56 s
# Epoch 95, NRMSE Test/best: 1.02398/0.41931, Training NRMSE: 0.93107, deviation of 9.98%
# Epoch -96 calculated in 242.58 s
# Epoch 96, NRMSE Test/best: 0.96885/0.41931, Training NRMSE: 0.94840, deviation of 2.16%
# Epoch -97 calculated in 242.71 s
# Epoch 97, NRMSE Test/best: 0.95735/0.41931, Training NRMSE: 0.92700, deviation of 3.27%
# Epoch -98 calculated in 242.73 s
# Epoch 98, NRMSE Test/best: 0.95153/0.41931, Training NRMSE: 0.91490, deviation of 4.00%
# Epoch -99 calculated in 242.12 s
# Epoch 99, NRMSE Test/best: 0.95983/0.41931, Training NRMSE: 0.93256, deviation of 2.92%
# Epoch -100 calculated in 242.61 s
# Epoch 100, NRMSE Test/best: 0.94470/0.41931, Training NRMSE: 0.91663, deviation of 3.06%
# Epoch -101 calculated in 242.53 s
# Epoch 101, NRMSE Test/best: 0.94073/0.41931, Training NRMSE: 0.90775, deviation of 3.63%
# Epoch -102 calculated in 242.54 s
# Epoch 102, NRMSE Test/best: 1.02273/0.41931, Training NRMSE: 0.89092, deviation of 14.79%
# Epoch -103 calculated in 242.91 s
# Epoch 103, NRMSE Test/best: 1.07783/0.41931, Training NRMSE: 1.21476, deviation of 11.27%
# Epoch -104 calculated in 242.79 s
# Epoch 104, NRMSE Test/best: 0.99456/0.41931, Training NRMSE: 0.96424, deviation of 3.14%
# Epoch -105 calculated in 242.44 s
# Epoch 105, NRMSE Test/best: 0.97508/0.41931, Training NRMSE: 0.93624, deviation of 4.15%
# Epoch -106 calculated in 242.52 s
# Epoch 106, NRMSE Test/best: 1.00601/0.41931, Training NRMSE: 0.92861, deviation of 8.33%
# Epoch -107 calculated in 242.42 s
# Epoch 107, NRMSE Test/best: 1.15216/0.41931, Training NRMSE: 0.92599, deviation of 24.43%
# Epoch -108 calculated in 242.09 s
# Epoch 108, NRMSE Test/best: 1.02789/0.41931, Training NRMSE: 0.91736, deviation of 12.05%
# Epoch -109 calculated in 242.48 s
# Epoch 109, NRMSE Test/best: 1.02316/0.41931, Training NRMSE: 0.89907, deviation of 13.80%
# Epoch -110 calculated in 242.46 s
# Epoch 110, NRMSE Test/best: 1.02571/0.41931, Training NRMSE: 0.89536, deviation of 14.56%
# Epoch -111 calculated in 242.52 s
# Epoch 111, NRMSE Test/best: 0.93876/0.41931, Training NRMSE: 0.90224, deviation of 4.05%
# Epoch -112 calculated in 242.20 s
# Epoch 112, NRMSE Test/best: 0.96672/0.41931, Training NRMSE: 0.94058, deviation of 2.78%
# Epoch -113 calculated in 242.86 s
# Epoch 113, NRMSE Test/best: 1.02210/0.41931, Training NRMSE: 0.93568, deviation of 9.24%
# Epoch -114 calculated in 242.87 s
# Epoch 114, NRMSE Test/best: 1.01726/0.41931, Training NRMSE: 0.87366, deviation of 16.44%
# Epoch -115 calculated in 242.74 s
# Epoch 115, NRMSE Test/best: 0.97000/0.41931, Training NRMSE: 0.85023, deviation of 14.09%
# Epoch -116 calculated in 242.83 s
# Epoch 116, NRMSE Test/best: 1.21587/0.41931, Training NRMSE: 0.76831, deviation of 58.25%
# Epoch -117 calculated in 242.60 s
# Epoch 117, NRMSE Test/best: 1.13164/0.41931, Training NRMSE: 0.71589, deviation of 58.08%
# Epoch -118 calculated in 242.19 s
# Epoch 118, NRMSE Test/best: 0.96714/0.41931, Training NRMSE: 0.64579, deviation of 49.76%
# Epoch -119 calculated in 242.92 s
# Epoch 119, NRMSE Test/best: 0.75674/0.41931, Training NRMSE: 0.59361, deviation of 27.48%
# Epoch -120 calculated in 242.80 s
# Epoch 120, NRMSE Test/best: 2.32811/0.41931, Training NRMSE: 0.66764, deviation of 248.71%
# Epoch -121 calculated in 242.49 s
# Epoch 121, NRMSE Test/best: 1.00175/0.41931, Training NRMSE: 0.68090, deviation of 47.12%
# Epoch -122 calculated in 242.85 s
# Epoch 122, NRMSE Test/best: 0.71017/0.41931, Training NRMSE: 0.57177, deviation of 24.21%
# Epoch -123 calculated in 243.00 s
# Epoch 123, NRMSE Test/best: 0.72612/0.41931, Training NRMSE: 0.56017, deviation of 29.62%
# Epoch -124 calculated in 242.55 s
# Epoch 124, NRMSE Test/best: 0.99221/0.41931, Training NRMSE: 0.64833, deviation of 53.04%
# Epoch -125 calculated in 243.21 s
# Epoch 125, NRMSE Test/best: 0.92966/0.41931, Training NRMSE: 0.61978, deviation of 50.00%
# Epoch -126 calculated in 242.83 s
# Epoch 126, NRMSE Test/best: 0.93695/0.41931, Training NRMSE: 0.54434, deviation of 72.12%
# Epoch -127 calculated in 242.66 s
# Epoch 127, NRMSE Test/best: 0.86004/0.41931, Training NRMSE: 0.55239, deviation of 55.69%
# Epoch -128 calculated in 242.84 s
# Epoch 128, NRMSE Test/best: 0.92621/0.41931, Training NRMSE: 0.50799, deviation of 82.33%
# Epoch -129 calculated in 242.50 s
# Epoch 129, NRMSE Test/best: 0.73249/0.41931, Training NRMSE: 0.50292, deviation of 45.65%
# Epoch -130 calculated in 242.51 s
# Epoch 130, NRMSE Test/best: 0.77043/0.41931, Training NRMSE: 0.58370, deviation of 31.99%
# Epoch -131 calculated in 242.17 s
# Epoch 131, NRMSE Test/best: 0.75082/0.41931, Training NRMSE: 0.47640, deviation of 57.60%
# Epoch -132 calculated in 241.99 s
# Epoch 132, NRMSE Test/best: 0.73778/0.41931, Training NRMSE: 0.46389, deviation of 59.04%
# Epoch -133 calculated in 242.72 s
# Epoch 133, NRMSE Test/best: 0.72536/0.41931, Training NRMSE: 0.46018, deviation of 57.62%
# Epoch -134 calculated in 242.60 s
# Epoch 134, NRMSE Test/best: 0.83364/0.41931, Training NRMSE: 0.45441, deviation of 83.46%
# Epoch -135 calculated in 242.64 s
# Epoch 135, NRMSE Test/best: 0.70931/0.41931, Training NRMSE: 0.44300, deviation of 60.12%
# Epoch -136 calculated in 242.87 s
# Epoch 136, NRMSE Test/best: 0.86425/0.41931, Training NRMSE: 0.47446, deviation of 82.16%
# Epoch -137 calculated in 242.65 s
# Epoch 137, NRMSE Test/best: 0.80276/0.41931, Training NRMSE: 0.62824, deviation of 27.78%
# Epoch -138 calculated in 242.73 s
# Epoch 138, NRMSE Test/best: 0.83694/0.41931, Training NRMSE: 0.50826, deviation of 64.67%
# Epoch -139 calculated in 242.20 s
# Epoch 139, NRMSE Test/best: 0.65592/0.41931, Training NRMSE: 0.47362, deviation of 38.49%
# Epoch -140 calculated in 242.80 s
# Epoch 140, NRMSE Test/best: 0.59719/0.41931, Training NRMSE: 0.45183, deviation of 32.17%
# Epoch -141 calculated in 242.50 s
# Epoch 141, NRMSE Test/best: 0.58465/0.41931, Training NRMSE: 0.44169, deviation of 32.37%
# Epoch -142 calculated in 242.99 s
# Epoch 142, NRMSE Test/best: 0.71870/0.41931, Training NRMSE: 0.43328, deviation of 65.88%
# Epoch -143 calculated in 242.38 s
# Epoch 143, NRMSE Test/best: 0.64524/0.41931, Training NRMSE: 0.43165, deviation of 49.48%
# Epoch -144 calculated in 242.41 s
# Epoch 144, NRMSE Test/best: 0.63215/0.41931, Training NRMSE: 0.42802, deviation of 47.69%
# Epoch -145 calculated in 242.30 s
# Epoch 145, NRMSE Test/best: 0.60282/0.41931, Training NRMSE: 0.42633, deviation of 41.40%
# Epoch -146 calculated in 242.33 s
# Epoch 146, NRMSE Test/best: 0.59024/0.41931, Training NRMSE: 0.42575, deviation of 38.64%
# Epoch -147 calculated in 242.62 s
# Epoch 147, NRMSE Test/best: 0.58149/0.41931, Training NRMSE: 0.42066, deviation of 38.23%
# Epoch -148 calculated in 243.01 s
# Epoch 148, NRMSE Test/best: 0.56738/0.41931, Training NRMSE: 0.41651, deviation of 36.22%
# Epoch -149 calculated in 242.72 s
# Epoch 149, NRMSE Test/best: 0.56445/0.41931, Training NRMSE: 0.41806, deviation of 35.02%
# Epoch -150 calculated in 242.66 s
# Epoch 150, NRMSE Test/best: 0.60192/0.41931, Training NRMSE: 0.44262, deviation of 35.99%
# Epoch -151 calculated in 242.49 s
# Epoch 151, NRMSE Test/best: 0.57805/0.41931, Training NRMSE: 0.41621, deviation of 38.89%
# Epoch -152 calculated in 242.38 s
# Epoch 152, NRMSE Test/best: 0.58300/0.41931, Training NRMSE: 0.41680, deviation of 39.88%
# Epoch -153 calculated in 242.18 s
# Epoch 153, NRMSE Test/best: 0.57327/0.41931, Training NRMSE: 0.41351, deviation of 38.64%
# Epoch -154 calculated in 242.19 s
# Epoch 154, NRMSE Test/best: 0.57572/0.41931, Training NRMSE: 0.41489, deviation of 38.76%
# Epoch -155 calculated in 242.65 s
# Epoch 155, NRMSE Test/best: 0.57550/0.41931, Training NRMSE: 0.41331, deviation of 39.24%
# Epoch -156 calculated in 242.69 s
# Epoch 156, NRMSE Test/best: 0.57298/0.41931, Training NRMSE: 0.41165, deviation of 39.19%
# Epoch -157 calculated in 242.36 s
# Epoch 157, NRMSE Test/best: 0.57356/0.41931, Training NRMSE: 0.41201, deviation of 39.21%
# Epoch -158 calculated in 242.69 s
# Epoch 158, NRMSE Test/best: 0.55176/0.41931, Training NRMSE: 0.40997, deviation of 34.58%
# Epoch -159 calculated in 242.58 s
# Epoch 159, NRMSE Test/best: 0.54529/0.41931, Training NRMSE: 0.41033, deviation of 32.89%
# Epoch -160 calculated in 242.87 s
# Epoch 160, NRMSE Test/best: 0.55002/0.41931, Training NRMSE: 0.40984, deviation of 34.20%
# Epoch -161 calculated in 242.76 s
# Epoch 161, NRMSE Test/best: 0.52341/0.41931, Training NRMSE: 0.40963, deviation of 27.78%
# Epoch -162 calculated in 242.85 s
# Epoch 162, NRMSE Test/best: 0.54207/0.41931, Training NRMSE: 0.40696, deviation of 33.20%
# Epoch -163 calculated in 242.49 s
# Epoch 163, NRMSE Test/best: 0.62332/0.41931, Training NRMSE: 0.41480, deviation of 50.27%
# Epoch -164 calculated in 242.20 s
# Epoch 164, NRMSE Test/best: 0.59894/0.41931, Training NRMSE: 0.40766, deviation of 46.92%
# Epoch -165 calculated in 242.80 s
# Epoch 165, NRMSE Test/best: 0.61050/0.41931, Training NRMSE: 0.40620, deviation of 50.30%
# Epoch -166 calculated in 242.57 s
# Epoch 166, NRMSE Test/best: 0.53408/0.41931, Training NRMSE: 0.40567, deviation of 31.66%
# Epoch -167 calculated in 243.01 s
# Epoch 167, NRMSE Test/best: 0.57791/0.41931, Training NRMSE: 0.40374, deviation of 43.14%
# Epoch -168 calculated in 242.34 s
# Epoch 168, NRMSE Test/best: 0.55066/0.41931, Training NRMSE: 0.40296, deviation of 36.65%
# Epoch -169 calculated in 242.61 s
# Epoch 169, NRMSE Test/best: 0.55683/0.41931, Training NRMSE: 0.40156, deviation of 38.67%
# Epoch -170 calculated in 242.58 s
# Epoch 170, NRMSE Test/best: 0.55075/0.41931, Training NRMSE: 0.40250, deviation of 36.83%
# Epoch -171 calculated in 242.43 s
# Epoch 171, NRMSE Test/best: 0.56866/0.41931, Training NRMSE: 0.40323, deviation of 41.03%
# Epoch -172 calculated in 242.21 s
# Epoch 172, NRMSE Test/best: 0.59003/0.41931, Training NRMSE: 0.40506, deviation of 45.66%
# Epoch -173 calculated in 242.75 s
# Epoch 173, NRMSE Test/best: 0.55140/0.41931, Training NRMSE: 0.40239, deviation of 37.03%
# Epoch -174 calculated in 242.32 s
# Epoch 174, NRMSE Test/best: 0.55936/0.41931, Training NRMSE: 0.40120, deviation of 39.42%
# Epoch -175 calculated in 242.93 s
# Epoch 175, NRMSE Test/best: 0.56516/0.41931, Training NRMSE: 0.40104, deviation of 40.92%
# Epoch -176 calculated in 242.65 s
# Epoch 176, NRMSE Test/best: 0.57147/0.41931, Training NRMSE: 0.40061, deviation of 42.65%
# Epoch -177 calculated in 242.67 s
# Epoch 177, NRMSE Test/best: 0.56800/0.41931, Training NRMSE: 0.41639, deviation of 36.41%
# Epoch -178 calculated in 242.75 s
# Epoch 178, NRMSE Test/best: 0.58256/0.41931, Training NRMSE: 0.39989, deviation of 45.68%
# Epoch -179 calculated in 242.69 s
# Epoch 179, NRMSE Test/best: 0.58023/0.41931, Training NRMSE: 0.39819, deviation of 45.72%
# Epoch -180 calculated in 243.03 s
# Epoch 180, NRMSE Test/best: 0.57929/0.41931, Training NRMSE: 0.39902, deviation of 45.18%
# Epoch -181 calculated in 242.35 s
# Epoch 181, NRMSE Test/best: 0.57024/0.41931, Training NRMSE: 0.40013, deviation of 42.51%
# Epoch -182 calculated in 242.40 s
# Epoch 182, NRMSE Test/best: 0.60452/0.41931, Training NRMSE: 0.39889, deviation of 51.55%
# Epoch -183 calculated in 242.29 s
# Epoch 183, NRMSE Test/best: 0.65059/0.41931, Training NRMSE: 0.40238, deviation of 61.69%
# Epoch -184 calculated in 242.63 s
# Epoch 184, NRMSE Test/best: 0.64195/0.41931, Training NRMSE: 0.39684, deviation of 61.77%
# Epoch -185 calculated in 242.29 s
# Epoch 185, NRMSE Test/best: 0.65287/0.41931, Training NRMSE: 0.39847, deviation of 63.84%
# Epoch -186 calculated in 242.81 s
# Epoch 186, NRMSE Test/best: 0.67888/0.41931, Training NRMSE: 0.39991, deviation of 69.76%
# Epoch -187 calculated in 242.66 s
# Epoch 187, NRMSE Test/best: 0.68164/0.41931, Training NRMSE: 0.39828, deviation of 71.15%
# Epoch -188 calculated in 242.63 s
# Epoch 188, NRMSE Test/best: 0.68311/0.41931, Training NRMSE: 0.39924, deviation of 71.10%
# Epoch -189 calculated in 242.50 s
# Epoch 189, NRMSE Test/best: 0.58512/0.41931, Training NRMSE: 0.40179, deviation of 45.63%
# Epoch -190 calculated in 242.54 s
# Epoch 190, NRMSE Test/best: 0.68031/0.41931, Training NRMSE: 0.39656, deviation of 71.55%
# Epoch -191 calculated in 242.98 s
# Epoch 191, NRMSE Test/best: 0.64676/0.41931, Training NRMSE: 0.39766, deviation of 62.64%
# Epoch -192 calculated in 242.27 s
# Epoch 192, NRMSE Test/best: 0.62074/0.41931, Training NRMSE: 0.39753, deviation of 56.15%
# Epoch -193 calculated in 242.80 s
# Epoch 193, NRMSE Test/best: 0.59695/0.41931, Training NRMSE: 0.39520, deviation of 51.05%
# Epoch -194 calculated in 242.40 s
# Epoch 194, NRMSE Test/best: 0.59294/0.41931, Training NRMSE: 0.40263, deviation of 47.27%
# Epoch -195 calculated in 242.63 s
# Epoch 195, NRMSE Test/best: 0.60180/0.41931, Training NRMSE: 0.39506, deviation of 52.33%
# Epoch -196 calculated in 242.52 s
# Epoch 196, NRMSE Test/best: 0.61946/0.41931, Training NRMSE: 0.39635, deviation of 56.29%
# Epoch -197 calculated in 242.83 s
# Epoch 197, NRMSE Test/best: 0.57534/0.41931, Training NRMSE: 0.39382, deviation of 46.09%
# Epoch -198 calculated in 242.92 s
# Epoch 198, NRMSE Test/best: 0.55603/0.41931, Training NRMSE: 0.39527, deviation of 40.67%
# Epoch -199 calculated in 242.40 s
# Epoch 199, NRMSE Test/best: 0.62548/0.41931, Training NRMSE: 0.39417, deviation of 58.68%
# Epoch -200 calculated in 242.33 s
# Epoch 200, NRMSE Test/best: 0.91938/0.41931, Training NRMSE: 0.70433, deviation of 30.53%
# Epoch -201 calculated in 242.61 s
# Epoch 201, NRMSE Test/best: 1.51050/0.41931, Training NRMSE: 0.76140, deviation of 98.39%
# Epoch -202 calculated in 242.27 s
# Epoch 202, NRMSE Test/best: 1.31187/0.41931, Training NRMSE: 0.70689, deviation of 85.58%
# Epoch -203 calculated in 242.36 s
# Epoch 203, NRMSE Test/best: 1.06214/0.41931, Training NRMSE: 0.68947, deviation of 54.05%
# Epoch -204 calculated in 242.74 s
# Epoch 204, NRMSE Test/best: 1.45666/0.41931, Training NRMSE: 0.60948, deviation of 139.00%
# Epoch -205 calculated in 242.46 s
# Epoch 205, NRMSE Test/best: 1.56185/0.41931, Training NRMSE: 0.73296, deviation of 113.09%
# Epoch -206 calculated in 242.68 s
# Epoch 206, NRMSE Test/best: 1.11872/0.41931, Training NRMSE: 0.67360, deviation of 66.08%
# Epoch -207 calculated in 242.78 s
# Epoch 207, NRMSE Test/best: 0.94965/0.41931, Training NRMSE: 0.58993, deviation of 60.98%
# Epoch -208 calculated in 242.51 s
# Epoch 208, NRMSE Test/best: 0.83921/0.41931, Training NRMSE: 0.53903, deviation of 55.69%
# Epoch -209 calculated in 242.26 s
# Epoch 209, NRMSE Test/best: 0.99515/0.41931, Training NRMSE: 0.60420, deviation of 64.71%
# Epoch -210 calculated in 242.72 s
# Epoch 210, NRMSE Test/best: 0.80607/0.41931, Training NRMSE: 0.58687, deviation of 37.35%
# Training duration 01:15:00:26
# Number of training variable 91351
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/freeze_graph.py:249: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from Experiments/2019-05-04-19-03/temp/myFinalModel.ckpt
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/freeze_graph.py:232: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.convert_variables_to_constants
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/graph_util_impl.py:245: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph
# INFO:tensorflow:Froze 4 variables.
# INFO:tensorflow:Converted 4 variables to const ops.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/optimize_for_inference_lib.py:113: remove_training_nodes (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.remove_training_nodes
# INFO:tensorflow:Restoring parameters from Experiments/2019-05-04-19-03/temp/myBestModel.ckpt
# done, good job kids

# %%
from show import *
# %matplotlib notebook
showPickle(nameFigEstimation)
# Out:
# <img src="data:image/png;base64,..." width="640">
