# %% [markdown]
# # LSTM_model3

# %% [markdown]
# LSTM_model3 uses 1 layer of LSTM with N=100 times steps, Nh=150 hidden units with a sequence to sequence output.
# Dataset can be downloaded in http://www.montefiore.ulg.ac.be/services/acous/STSI/downloads.php

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
"""lstm for guitar signal"""
import os
import sys
sys.path.append('Codes')
import tensorflow as tf
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import pickle
from dataShapingSeq import *
from savePerf import *
import scipy.io.wavfile
import time
from tensorflow.contrib.layers import fully_connected
from tensorflow.contrib.rnn import *
from saveTransformedGraph import optimizeGraph

modelName = "LSTM_model3"

#############################
# Directory experiment
#############################
date = time.strftime("%Y-%m-%d-%H-%M")
path = os.path.join("Experiments",date)
if not os.path.isdir(path):
    os.makedirs(path)
    #experiment/"date"/temp will contain the backuped model parameters
    pathTemp = os.path.join(path,'temp')
    os.makedirs(pathTemp)
    # if you run the file two time in a minute
else :
    date = date+'(2)'
    path = os.path.join("Experiments",date)
    os.makedirs(path)
    pathTemp = os.path.join(path,'temp')
    os.makedirs(pathTemp)

# directory that will contain tensorboard information
pathLog = 'Tf_logs'
if not os.path.isdir(pathLog):
    os.makedirs(pathLog)
pathLog = "{}/run-{}/".format(pathLog,date)

version = tf.__version__
print ("version {} of tensorflow".format(version))

#############################
# Model parameters
#############################
trainTestRatio = 0.8
maxSize = 0
num_step = 100
num_hidden = 150
num_out = 5
num_feature = 1
batch_size = 1000
num_epoch = 10000                                  
trainDuration = 60*60*15                             
                                      
amplifierName = 'EnglDisto'
fileNameTrain = 'Datasets/training'+amplifierName+'.mat' # dataset train/test path
fileNameTest = 'Datasets/test'+amplifierName+'.mat'      # dataset validation path
fileNameValidation = 'Datasets/val'+amplifierName+'.mat'

#############################
# Loading data
#############################
matrix = sio.loadmat(fileNameTrain)
matrixTrain = matrix['train']
matrix = sio.loadmat(fileNameTest)
matrixTest = matrix['test']
if maxSize ==0:
    maxSize = len(matrixTrain)
    print("maxSize = {}".format(maxSize))

train_input,train_output,test_input,test_output = loadTrainTest(matrixTrain,matrixTest,num_step,num_out,maxSize)
print("shape input train {}".format(np.shape(train_input)))
numTrain = len(train_output)
print ("Data loaded")

#######################
# Graph Construction
#######################
G = tf.Graph()
with G.as_default():
    with tf.name_scope("placeHolder"):
        data = tf.placeholder(tf.float32, [None, num_step], name ="data")
        target = tf.placeholder(tf.float32, [None, num_out],name = "target") 
        dataShaped = tf.reshape(data,[tf.shape(data)[0],tf.shape(data)[1],num_feature])
        dataShaped = tf.transpose(dataShaped,[1,0,2])
    
    with tf.name_scope("LSTMLayer1"):
        fusedCell1 = tf.contrib.rnn.LSTMBlockFusedCell(num_hidden,use_peephole=False)
        val, state = fusedCell1(dataShaped,dtype=tf.float32) 
        last_index = tf.shape(val)[0]-1
        lastVals = tf.gather(val,tf.range(last_index-num_out,last_index))
    with tf.name_scope("ReshapeOutputofLSTMSeq"):
        stacked_val = tf.reshape(tf.transpose(lastVals,[1,0,2]),[-1,num_hidden]) 
        stacked_out = fully_connected(stacked_val,1,activation_fn=tf.nn.tanh,weights_regularizer=None,scope="stackedPred")
    
    prediction = tf.reshape(stacked_out,[-1,num_out],name="FCPred")
    
##############################
# Cost function
##############################
    MSE = tf.reduce_mean(tf.square(prediction-target))
    EnergyTarget = tf.reduce_mean(tf.square(target)) 
    optimizer = tf.train.AdamOptimizer()
    minimize = optimizer.minimize(MSE)
    # Create summary view for tensorboard
    mse_summary = tf.summary.scalar('RMSE',tf.sqrt(MSE))
    summary_op = tf.summary.merge_all()
    #Create an init op to initialize variable
    init_op = tf.global_variables_initializer()
    saver = tf.train.Saver() 
    
##############################
# Graph execution
##############################
    
with tf.Session(graph=G) as sess:
    sess.run(init_op)
    train_writer = tf.summary.FileWriter(pathLog+'train',graph =tf.get_default_graph())
    test_writer = tf.summary.FileWriter(pathLog+'test')
    
    no_of_batches = int(np.floor((numTrain)/batch_size)) 
    no_of_batchesTest = int(np.floor((len(test_input))/batch_size))
    tStart = time.clock()
    epoch =0
    NRMSETest = 1
    bestNRMSETest = 10    
    # train until the number of epoch or the training time is reached
    for epoch in range(num_epoch):
        tEpoch = time.clock()
        if (time.clock()-tStart < trainDuration) :
            ptr = 0
            if epoch % 20==0 : # each twenty epochs save the model
                tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myGraph.pb',as_text=False)
                save_path = saver.save(sess,os.path.join(pathTemp,'myModel.ckpt'))
            
            pMSETrain=0
            pEnergyTarget=0
            for j in range(no_of_batches):
                inp, out = train_input[ptr:ptr+batch_size],train_output[ptr:ptr+batch_size]
                ptr+=batch_size
                
                if j % np.floor(numTrain/len(test_input)) ==0 : # This is to have a train summary and a test summary of the same size
                    _,summary_str,pMSETrainTemp,pEnergyTargetTemp = sess.run([minimize,summary_op,MSE,EnergyTarget],{data: inp, target: out})
                    pMSETrain += pMSETrainTemp
                    pEnergyTarget += pEnergyTargetTemp
                    step = epoch*no_of_batches+j
                    # save the training RMSE for tensorboard
                    train_writer.add_summary(summary_str,step)                   

                else :
                    _,pMSETrainTemp,pEnergyTargetTemp = sess.run([minimize,MSE,EnergyTarget],{data: inp, target: out})
                    pMSETrain += pMSETrainTemp
                    pEnergyTarget += pEnergyTargetTemp
                    
            # compute an estimation of the RMSE for this epoch       
            MSETrain = pMSETrain/no_of_batches
            EnergyTargetTrain = pEnergyTarget/no_of_batches
            NRMSETrain = np.sqrt(MSETrain/EnergyTargetTrain)
            print ("Epoch -{} calculated in {:5.2f} s ".format(epoch,time.clock()-tEpoch))
            # evaluate the model on the test set 
            pMSE = 0
            ptr2 = 0
            pEnergyTarget = 0
            for k in range(no_of_batchesTest):
                pMSETemp,pEnergyTargetTemp,summary_str = sess.run([MSE,EnergyTarget,summary_op],{data: test_input[ptr2:ptr2+batch_size] , target: test_output[ptr2:ptr2+batch_size]})
                pMSE += pMSETemp
                ptr2 += batch_size
                pEnergyTarget+=pEnergyTargetTemp
                step = epoch*no_of_batchesTest+k
                test_writer.add_summary(summary_str,step*np.floor(numTrain/len(test_input)))
            MSETest = pMSE/no_of_batchesTest
            EnergyTargetTest = pEnergyTarget/no_of_batchesTest
            NRMSETest = np.sqrt(MSETest/EnergyTargetTest)
            if NRMSETest<bestNRMSETest:
                bestNRMSETest=NRMSETest
                tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myBestGraph.pbtxt',as_text=True)
                save_path = saver.save(sess,os.path.join(pathTemp,'myBestModel.ckpt'))
            print("Epoch {}, NRMSE Test/best: {:.5f}/{:.5f}, Training NRMSE: {:.5f}, deviation of {:.2f}%".format(epoch,NRMSETest,bestNRMSETest,NRMSETrain,100*np.sqrt((NRMSETrain-NRMSETest)**2)/NRMSETrain))
        else : break # break the while loop if number of epoch is reached
    tStop = time.clock()
    trainTime = time.strftime("%d:%H:%M:%S ", time.gmtime(tStop-tStart))
    
    ################################################################
    # Save Graph variable and information about the running session
    ################################################################
    # save graph model
    tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myFinalGraph.pbtxt',as_text=True)
    # Save checkpoint variables
    save_path = saver.save(sess,os.path.join(pathTemp,'myFinalModel.ckpt'))
    print ("Training duration {}".format(trainTime))
    totalParameters =np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.trainable_variables()])
    print("Number of training variable {}".format(totalParameters))
    # log
    infoLog={}
    infoLog["path"] = path
    infoLog["MSE"] = bestNRMSETest
    infoLog["num_step"] = num_step
    infoLog["num_hidden"] = num_hidden
    infoLog["num_epoch"] = epoch
    infoLog["batch_size"] = batch_size
    infoLog["maxSize"] = maxSize
    infoLog["duration"] = trainTime
    infoLog["totalParameters"] = totalParameters
    infoLog["version"] = version
    infoLog["n_layer"] = 1
    infoLog["trainDropout"] = 0
    infoLog["nameModel"] = modelName
    infoLog["conv_chan"] = [0]
    infoLog["strides"] = 0
    infoLog["conv_size"] = 0
    infoLog["amplifierName"]=amplifierName
    logPerf(infoLog)
    input_nodes=["placeHolder/data"]
    output_nodes=["FCPred"]
    optimizeGraph(pathTemp,input_nodes,output_nodes) 
    
    ################################################
    #   Validation
    ################################################

    restorePath = os.path.join(pathTemp,'myBestModel.ckpt') # restore the best model
    saver.restore(sess,restorePath)
    matrixVal = sio.loadmat(fileNameValidation)
    matrixVal = matrixVal['val']  
    valSize = 44100*5
    if valSize == 0 :
        valSize = len(matrixVal)
    val_input,val_output = loadValidationSeq(matrixVal,num_step,valSize,num_out)
    
    lPrediction = []
    lTarget = []
    ptr3 = 0
    no_of_batches_val = int(np.floor(len(val_input)/batch_size))
    for k in range(no_of_batches_val):
        pPrediction = sess.run(prediction,{data: val_input[ptr3:ptr3+batch_size]}).ravel()
        pTarget = val_output[ptr3:ptr3+batch_size].ravel()
        lPrediction.append(pPrediction)
        lTarget.append(pTarget)   
        ptr3+=batch_size

    predictionArray = np.array(lPrediction,dtype=np.float32).ravel()
    targetArray = np.array(lTarget,dtype=np.float32).ravel()
    scipy.io.wavfile.write(os.path.join(path,'prediction.wav'),44100,predictionArray)
    scipy.io.wavfile.write(os.path.join(path,'target.wav'),44100,targetArray)

    # save emulation in a pickle format
    ax = plt.subplot(111)
    ax.plot(predictionArray[6000+num_out:6700+num_out],label='prediction')
    ax.plot(targetArray[6000+num_out:6700+num_out],label='target')
    ax.legend()
    plt.xlabel('sample n')
    plt.ylabel('Amplitude y[n]')
    nameFigEstimation = os.path.join(path,"targetVsPrediction.pickle")
    pickle.dump(ax,open(nameFigEstimation, 'wb'))
print ("done, good job kids")
# Out:
# version 1.13.1 of tensorflow
# maxSize = 6726407
# shape input train (6726308, 100)
# Data loaded
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/rnn/python/ops/lstm_ops.py:694: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch -0 calculated in 253.20 s
# Epoch 0, NRMSE Test/best: 1.36372/1.36372, Training NRMSE: 0.63532, deviation of 114.65%
# Epoch -1 calculated in 252.85 s
# Epoch 1, NRMSE Test/best: 1.06727/1.06727, Training NRMSE: 0.47250, deviation of 125.88%
# Epoch -2 calculated in 254.08 s
# Epoch 2, NRMSE Test/best: 0.90451/0.90451, Training NRMSE: 0.46364, deviation of 95.09%
# Epoch -3 calculated in 253.80 s
# Epoch 3, NRMSE Test/best: 0.79331/0.79331, Training NRMSE: 0.42132, deviation of 88.29%
# Epoch -4 calculated in 254.40 s
# Epoch 4, NRMSE Test/best: 0.77923/0.77923, Training NRMSE: 0.41056, deviation of 89.80%
# Epoch -5 calculated in 254.11 s
# Epoch 5, NRMSE Test/best: 0.75056/0.75056, Training NRMSE: 0.40585, deviation of 84.94%
# Epoch -6 calculated in 254.13 s
# Epoch 6, NRMSE Test/best: 0.68727/0.68727, Training NRMSE: 0.39290, deviation of 74.92%
# Epoch -7 calculated in 253.95 s
# Epoch 7, NRMSE Test/best: 0.66199/0.66199, Training NRMSE: 0.38184, deviation of 73.37%
# Epoch -8 calculated in 254.26 s
# Epoch 8, NRMSE Test/best: 0.64633/0.64633, Training NRMSE: 0.37728, deviation of 71.31%
# Epoch -9 calculated in 254.27 s
# Epoch 9, NRMSE Test/best: 0.61739/0.61739, Training NRMSE: 0.37412, deviation of 65.02%
# Epoch -10 calculated in 254.01 s
# Epoch 10, NRMSE Test/best: 0.58697/0.58697, Training NRMSE: 0.37164, deviation of 57.94%
# Epoch -11 calculated in 253.75 s
# Epoch 11, NRMSE Test/best: 0.58066/0.58066, Training NRMSE: 0.36825, deviation of 57.68%
# Epoch -12 calculated in 254.08 s
# Epoch 12, NRMSE Test/best: 0.57849/0.57849, Training NRMSE: 0.36522, deviation of 58.39%
# Epoch -13 calculated in 253.98 s
# Epoch 13, NRMSE Test/best: 0.57398/0.57398, Training NRMSE: 0.36325, deviation of 58.01%
# Epoch -14 calculated in 254.49 s
# Epoch 14, NRMSE Test/best: 0.56662/0.56662, Training NRMSE: 0.36183, deviation of 56.60%
# Epoch -15 calculated in 254.31 s
# Epoch 15, NRMSE Test/best: 0.56393/0.56393, Training NRMSE: 0.36063, deviation of 56.37%
# Epoch -16 calculated in 254.11 s
# Epoch 16, NRMSE Test/best: 0.55375/0.55375, Training NRMSE: 0.35927, deviation of 54.13%
# Epoch -17 calculated in 254.32 s
# Epoch 17, NRMSE Test/best: 0.54190/0.54190, Training NRMSE: 0.35802, deviation of 51.36%
# Epoch -18 calculated in 254.25 s
# Epoch 18, NRMSE Test/best: 0.53319/0.53319, Training NRMSE: 0.35700, deviation of 49.35%
# Epoch -19 calculated in 254.37 s
# Epoch 19, NRMSE Test/best: 0.52253/0.52253, Training NRMSE: 0.35583, deviation of 46.85%
# Epoch -20 calculated in 254.19 s
# Epoch 20, NRMSE Test/best: 0.51169/0.51169, Training NRMSE: 0.35463, deviation of 44.29%
# Epoch -21 calculated in 253.84 s
# Epoch 21, NRMSE Test/best: 0.50448/0.50448, Training NRMSE: 0.35346, deviation of 42.73%
# Epoch -22 calculated in 253.83 s
# Epoch 22, NRMSE Test/best: 0.49679/0.49679, Training NRMSE: 0.35228, deviation of 41.02%
# Epoch -23 calculated in 254.41 s
# Epoch 23, NRMSE Test/best: 0.49068/0.49068, Training NRMSE: 0.35109, deviation of 39.76%
# Epoch -24 calculated in 254.11 s
# Epoch 24, NRMSE Test/best: 0.48719/0.48719, Training NRMSE: 0.35015, deviation of 39.14%
# Epoch -25 calculated in 254.09 s
# Epoch 25, NRMSE Test/best: 0.48496/0.48496, Training NRMSE: 0.34925, deviation of 38.86%
# Epoch -26 calculated in 253.81 s
# Epoch 26, NRMSE Test/best: 0.49229/0.48496, Training NRMSE: 0.34813, deviation of 41.41%
# Epoch -27 calculated in 253.98 s
# Epoch 27, NRMSE Test/best: 0.49151/0.48496, Training NRMSE: 0.34734, deviation of 41.51%
# Epoch -28 calculated in 254.05 s
# Epoch 28, NRMSE Test/best: 0.49463/0.48496, Training NRMSE: 0.34655, deviation of 42.73%
# Epoch -29 calculated in 254.24 s
# Epoch 29, NRMSE Test/best: 0.47174/0.47174, Training NRMSE: 0.34576, deviation of 36.43%
# Epoch -30 calculated in 254.14 s
# Epoch 30, NRMSE Test/best: 0.48834/0.47174, Training NRMSE: 0.34497, deviation of 41.56%
# Epoch -31 calculated in 253.93 s
# Epoch 31, NRMSE Test/best: 0.46970/0.46970, Training NRMSE: 0.34447, deviation of 36.35%
# Epoch -32 calculated in 254.36 s
# Epoch 32, NRMSE Test/best: 0.47154/0.46970, Training NRMSE: 0.34370, deviation of 37.20%
# Epoch -33 calculated in 254.20 s
# Epoch 33, NRMSE Test/best: 0.47678/0.46970, Training NRMSE: 0.34309, deviation of 38.97%
# Epoch -34 calculated in 253.76 s
# Epoch 34, NRMSE Test/best: 0.49240/0.46970, Training NRMSE: 0.34268, deviation of 43.69%
# Epoch -35 calculated in 253.91 s
# Epoch 35, NRMSE Test/best: 0.48174/0.46970, Training NRMSE: 0.34203, deviation of 40.85%
# Epoch -36 calculated in 253.87 s
# Epoch 36, NRMSE Test/best: 0.46283/0.46283, Training NRMSE: 0.34138, deviation of 35.58%
# Epoch -37 calculated in 254.24 s
# Epoch 37, NRMSE Test/best: 0.45083/0.45083, Training NRMSE: 0.34087, deviation of 32.26%
# Epoch -38 calculated in 254.16 s
# Epoch 38, NRMSE Test/best: 0.45501/0.45083, Training NRMSE: 0.34031, deviation of 33.71%
# Epoch -39 calculated in 254.28 s
# Epoch 39, NRMSE Test/best: 0.44816/0.44816, Training NRMSE: 0.33972, deviation of 31.92%
# Epoch -40 calculated in 254.38 s
# Epoch 40, NRMSE Test/best: 0.46407/0.44816, Training NRMSE: 0.33898, deviation of 36.90%
# Epoch -41 calculated in 254.30 s
# Epoch 41, NRMSE Test/best: 0.45934/0.44816, Training NRMSE: 0.33855, deviation of 35.68%
# Epoch -42 calculated in 253.65 s
# Epoch 42, NRMSE Test/best: 0.45406/0.44816, Training NRMSE: 0.33795, deviation of 34.36%
# Epoch -43 calculated in 254.69 s
# Epoch 43, NRMSE Test/best: 0.44371/0.44371, Training NRMSE: 0.33748, deviation of 31.48%
# Epoch -44 calculated in 253.97 s
# Epoch 44, NRMSE Test/best: 0.44912/0.44371, Training NRMSE: 0.33686, deviation of 33.32%
# Epoch -45 calculated in 254.51 s
# Epoch 45, NRMSE Test/best: 0.43948/0.43948, Training NRMSE: 0.33630, deviation of 30.68%
# Epoch -46 calculated in 253.64 s
# Epoch 46, NRMSE Test/best: 0.44332/0.43948, Training NRMSE: 0.33588, deviation of 31.99%
# Epoch -47 calculated in 254.23 s
# Epoch 47, NRMSE Test/best: 0.44446/0.43948, Training NRMSE: 0.33535, deviation of 32.53%
# Epoch -48 calculated in 254.39 s
# Epoch 48, NRMSE Test/best: 0.43846/0.43846, Training NRMSE: 0.33499, deviation of 30.89%
# Epoch -49 calculated in 254.04 s
# Epoch 49, NRMSE Test/best: 0.42173/0.42173, Training NRMSE: 0.33522, deviation of 25.81%
# Epoch -50 calculated in 254.00 s
# Epoch 50, NRMSE Test/best: 0.43920/0.42173, Training NRMSE: 0.33747, deviation of 30.14%
# Epoch -51 calculated in 254.29 s
# Epoch 51, NRMSE Test/best: 0.43761/0.42173, Training NRMSE: 0.33426, deviation of 30.92%
# Epoch -52 calculated in 254.41 s
# Epoch 52, NRMSE Test/best: 0.43650/0.42173, Training NRMSE: 0.33353, deviation of 30.87%
# Epoch -53 calculated in 253.63 s
# Epoch 53, NRMSE Test/best: 0.42859/0.42173, Training NRMSE: 0.33334, deviation of 28.57%
# Epoch -54 calculated in 254.50 s
# Epoch 54, NRMSE Test/best: 0.43359/0.42173, Training NRMSE: 0.33280, deviation of 30.29%
# Epoch -55 calculated in 253.63 s
# Epoch 55, NRMSE Test/best: 0.42608/0.42173, Training NRMSE: 0.33282, deviation of 28.02%
# Epoch -56 calculated in 254.15 s
# Epoch 56, NRMSE Test/best: 0.43545/0.42173, Training NRMSE: 0.33227, deviation of 31.05%
# Epoch -57 calculated in 253.81 s
# Epoch 57, NRMSE Test/best: 0.43110/0.42173, Training NRMSE: 0.33205, deviation of 29.83%
# Epoch -58 calculated in 254.07 s
# Epoch 58, NRMSE Test/best: 0.43285/0.42173, Training NRMSE: 0.33169, deviation of 30.50%
# Epoch -59 calculated in 254.07 s
# Epoch 59, NRMSE Test/best: 0.42922/0.42173, Training NRMSE: 0.33112, deviation of 29.63%
# Epoch -60 calculated in 254.23 s
# Epoch 60, NRMSE Test/best: 0.44577/0.42173, Training NRMSE: 0.33116, deviation of 34.61%
# Epoch -61 calculated in 253.94 s
# Epoch 61, NRMSE Test/best: 0.43095/0.42173, Training NRMSE: 0.33098, deviation of 30.21%
# Epoch -62 calculated in 254.20 s
# Epoch 62, NRMSE Test/best: 0.43549/0.42173, Training NRMSE: 0.33127, deviation of 31.46%
# Epoch -63 calculated in 254.21 s
# Epoch 63, NRMSE Test/best: 0.43504/0.42173, Training NRMSE: 0.33065, deviation of 31.57%
# Epoch -64 calculated in 254.18 s
# Epoch 64, NRMSE Test/best: 0.43153/0.42173, Training NRMSE: 0.33019, deviation of 30.69%
# Epoch -65 calculated in 254.31 s
# Epoch 65, NRMSE Test/best: 0.43206/0.42173, Training NRMSE: 0.33001, deviation of 30.92%
# Epoch -66 calculated in 253.95 s
# Epoch 66, NRMSE Test/best: 0.43879/0.42173, Training NRMSE: 0.32969, deviation of 33.09%
# Epoch -67 calculated in 254.47 s
# Epoch 67, NRMSE Test/best: 0.43894/0.42173, Training NRMSE: 0.32942, deviation of 33.24%
# Epoch -68 calculated in 253.92 s
# Epoch 68, NRMSE Test/best: 0.42957/0.42173, Training NRMSE: 0.32923, deviation of 30.47%
# Epoch -69 calculated in 254.09 s
# Epoch 69, NRMSE Test/best: 0.40294/0.40294, Training NRMSE: 0.33408, deviation of 20.61%
# Epoch -70 calculated in 254.10 s
# Epoch 70, NRMSE Test/best: 0.45075/0.40294, Training NRMSE: 0.32965, deviation of 36.74%
# Epoch -71 calculated in 254.29 s
# Epoch 71, NRMSE Test/best: 0.42931/0.40294, Training NRMSE: 0.32888, deviation of 30.54%
# Epoch -72 calculated in 253.85 s
# Epoch 72, NRMSE Test/best: 0.44849/0.40294, Training NRMSE: 0.33041, deviation of 35.74%
# Epoch -73 calculated in 254.30 s
# Epoch 73, NRMSE Test/best: 0.52217/0.40294, Training NRMSE: 0.33046, deviation of 58.01%
# Epoch -74 calculated in 254.11 s
# Epoch 74, NRMSE Test/best: 0.42788/0.40294, Training NRMSE: 0.33087, deviation of 29.32%
# Epoch -75 calculated in 254.46 s
# Epoch 75, NRMSE Test/best: 0.44127/0.40294, Training NRMSE: 0.32836, deviation of 34.39%
# Epoch -76 calculated in 254.28 s
# Epoch 76, NRMSE Test/best: 0.42480/0.40294, Training NRMSE: 0.32863, deviation of 29.26%
# Epoch -77 calculated in 253.93 s
# Epoch 77, NRMSE Test/best: 0.46157/0.40294, Training NRMSE: 0.32964, deviation of 40.02%
# Epoch -78 calculated in 254.20 s
# Epoch 78, NRMSE Test/best: 0.41979/0.40294, Training NRMSE: 0.32882, deviation of 27.67%
# Epoch -79 calculated in 254.07 s
# Epoch 79, NRMSE Test/best: 0.42885/0.40294, Training NRMSE: 0.32844, deviation of 30.57%
# Epoch -80 calculated in 254.68 s
# Epoch 80, NRMSE Test/best: 0.45718/0.40294, Training NRMSE: 0.32821, deviation of 39.30%
# Epoch -81 calculated in 254.17 s
# Epoch 81, NRMSE Test/best: 0.44039/0.40294, Training NRMSE: 0.32739, deviation of 34.52%
# Epoch -82 calculated in 254.10 s
# Epoch 82, NRMSE Test/best: 0.43741/0.40294, Training NRMSE: 0.32903, deviation of 32.94%
# Epoch -83 calculated in 254.39 s
# Epoch 83, NRMSE Test/best: 0.43454/0.40294, Training NRMSE: 0.32751, deviation of 32.68%
# Epoch -84 calculated in 253.91 s
# Epoch 84, NRMSE Test/best: 0.49041/0.40294, Training NRMSE: 0.36725, deviation of 33.54%
# Epoch -85 calculated in 253.80 s
# Epoch 85, NRMSE Test/best: 0.39523/0.39523, Training NRMSE: 0.40634, deviation of 2.73%
# Epoch -86 calculated in 254.39 s
# Epoch 86, NRMSE Test/best: 0.42759/0.39523, Training NRMSE: 0.34624, deviation of 23.50%
# Epoch -87 calculated in 253.93 s
# Epoch 87, NRMSE Test/best: 0.43314/0.39523, Training NRMSE: 0.32988, deviation of 31.31%
# Epoch -88 calculated in 254.09 s
# Epoch 88, NRMSE Test/best: 0.58154/0.39523, Training NRMSE: 0.40925, deviation of 42.10%
# Epoch -89 calculated in 254.13 s
# Epoch 89, NRMSE Test/best: 0.51928/0.39523, Training NRMSE: 0.49653, deviation of 4.58%
# Epoch -90 calculated in 254.25 s
# Epoch 90, NRMSE Test/best: 0.49472/0.39523, Training NRMSE: 0.42260, deviation of 17.07%
# Epoch -91 calculated in 254.15 s
# Epoch 91, NRMSE Test/best: 0.43069/0.39523, Training NRMSE: 0.40014, deviation of 7.64%
# Epoch -92 calculated in 254.37 s
# Epoch 92, NRMSE Test/best: 0.41503/0.39523, Training NRMSE: 0.37509, deviation of 10.65%
# Epoch -93 calculated in 254.10 s
# Epoch 93, NRMSE Test/best: 0.43903/0.39523, Training NRMSE: 0.34660, deviation of 26.67%
# Epoch -94 calculated in 253.95 s
# Epoch 94, NRMSE Test/best: 0.44007/0.39523, Training NRMSE: 0.33353, deviation of 31.94%
# Epoch -95 calculated in 254.20 s
# Epoch 95, NRMSE Test/best: 0.52147/0.39523, Training NRMSE: 0.42753, deviation of 21.97%
# Epoch -96 calculated in 254.27 s
# Epoch 96, NRMSE Test/best: 0.51829/0.39523, Training NRMSE: 0.45339, deviation of 14.31%
# Epoch -97 calculated in 254.16 s
# Epoch 97, NRMSE Test/best: 0.51641/0.39523, Training NRMSE: 0.45074, deviation of 14.57%
# Epoch -98 calculated in 254.39 s
# Epoch 98, NRMSE Test/best: 0.45795/0.39523, Training NRMSE: 0.42105, deviation of 8.76%
# Epoch -99 calculated in 254.00 s
# Epoch 99, NRMSE Test/best: 0.42478/0.39523, Training NRMSE: 0.35441, deviation of 19.86%
# Epoch -100 calculated in 254.54 s
# Epoch 100, NRMSE Test/best: 0.43164/0.39523, Training NRMSE: 0.33299, deviation of 29.63%
# Epoch -101 calculated in 253.95 s
# Epoch 101, NRMSE Test/best: 0.37474/0.37474, Training NRMSE: 0.33532, deviation of 11.76%
# Epoch -102 calculated in 254.57 s
# Epoch 102, NRMSE Test/best: 0.39745/0.37474, Training NRMSE: 0.33378, deviation of 19.07%
# Epoch -103 calculated in 254.06 s
# Epoch 103, NRMSE Test/best: 0.43478/0.37474, Training NRMSE: 0.32738, deviation of 32.81%
# Epoch -104 calculated in 254.37 s
# Epoch 104, NRMSE Test/best: 0.51824/0.37474, Training NRMSE: 0.38468, deviation of 34.72%
# Epoch -105 calculated in 254.59 s
# Epoch 105, NRMSE Test/best: 0.49830/0.37474, Training NRMSE: 0.44751, deviation of 11.35%
# Epoch -106 calculated in 254.29 s
# Epoch 106, NRMSE Test/best: 0.47810/0.37474, Training NRMSE: 0.43097, deviation of 10.94%
# Epoch -107 calculated in 253.89 s
# Epoch 107, NRMSE Test/best: 0.41607/0.37474, Training NRMSE: 0.39470, deviation of 5.41%
# Epoch -108 calculated in 254.09 s
# Epoch 108, NRMSE Test/best: 0.39992/0.37474, Training NRMSE: 0.35193, deviation of 13.64%
# Epoch -109 calculated in 254.15 s
# Epoch 109, NRMSE Test/best: 0.45725/0.37474, Training NRMSE: 0.33352, deviation of 37.10%
# Epoch -110 calculated in 253.94 s
# Epoch 110, NRMSE Test/best: 0.50709/0.37474, Training NRMSE: 0.37568, deviation of 34.98%
# Epoch -111 calculated in 253.86 s
# Epoch 111, NRMSE Test/best: 0.46129/0.37474, Training NRMSE: 0.41923, deviation of 10.03%
# Epoch -112 calculated in 253.89 s
# Epoch 112, NRMSE Test/best: 0.43018/0.37474, Training NRMSE: 0.35707, deviation of 20.48%
# Epoch -113 calculated in 253.89 s
# Epoch 113, NRMSE Test/best: 0.45062/0.37474, Training NRMSE: 0.33383, deviation of 34.99%
# Epoch -114 calculated in 254.34 s
# Epoch 114, NRMSE Test/best: 0.39825/0.37474, Training NRMSE: 0.33095, deviation of 20.34%
# Epoch -115 calculated in 254.18 s
# Epoch 115, NRMSE Test/best: 0.44884/0.37474, Training NRMSE: 0.32852, deviation of 36.63%
# Epoch -116 calculated in 254.29 s
# Epoch 116, NRMSE Test/best: 0.43826/0.37474, Training NRMSE: 0.32786, deviation of 33.67%
# Epoch -117 calculated in 254.08 s
# Epoch 117, NRMSE Test/best: 0.45302/0.37474, Training NRMSE: 0.32700, deviation of 38.54%
# Epoch -118 calculated in 253.93 s
# Epoch 118, NRMSE Test/best: 0.66154/0.37474, Training NRMSE: 0.38477, deviation of 71.93%
# Epoch -119 calculated in 253.90 s
# Epoch 119, NRMSE Test/best: 0.64176/0.37474, Training NRMSE: 0.45471, deviation of 41.14%
# Epoch -120 calculated in 254.37 s
# Epoch 120, NRMSE Test/best: 0.64956/0.37474, Training NRMSE: 0.44897, deviation of 44.68%
# Epoch -121 calculated in 253.84 s
# Epoch 121, NRMSE Test/best: 0.60217/0.37474, Training NRMSE: 0.48848, deviation of 23.27%
# Epoch -122 calculated in 254.28 s
# Epoch 122, NRMSE Test/best: 0.58391/0.37474, Training NRMSE: 0.52905, deviation of 10.37%
# Epoch -123 calculated in 254.17 s
# Epoch 123, NRMSE Test/best: 0.70886/0.37474, Training NRMSE: 0.55731, deviation of 27.19%
# Epoch -124 calculated in 254.39 s
# Epoch 124, NRMSE Test/best: 0.63022/0.37474, Training NRMSE: 0.58364, deviation of 7.98%
# Epoch -125 calculated in 253.98 s
# Epoch 125, NRMSE Test/best: 0.65625/0.37474, Training NRMSE: 0.58919, deviation of 11.38%
# Epoch -126 calculated in 254.33 s
# Epoch 126, NRMSE Test/best: 0.63682/0.37474, Training NRMSE: 0.59122, deviation of 7.71%
# Epoch -127 calculated in 254.47 s
# Epoch 127, NRMSE Test/best: 0.63168/0.37474, Training NRMSE: 0.58565, deviation of 7.86%
# Epoch -128 calculated in 254.01 s
# Epoch 128, NRMSE Test/best: 0.70095/0.37474, Training NRMSE: 0.61589, deviation of 13.81%
# Epoch -129 calculated in 254.12 s
# Epoch 129, NRMSE Test/best: 0.68329/0.37474, Training NRMSE: 0.64407, deviation of 6.09%
# Epoch -130 calculated in 254.14 s
# Epoch 130, NRMSE Test/best: 0.67843/0.37474, Training NRMSE: 0.63225, deviation of 7.30%
# Epoch -131 calculated in 254.25 s
# Epoch 131, NRMSE Test/best: 0.68357/0.37474, Training NRMSE: 0.65304, deviation of 4.68%
# Epoch -132 calculated in 253.84 s
# Epoch 132, NRMSE Test/best: 0.69420/0.37474, Training NRMSE: 0.63976, deviation of 8.51%
# Epoch -133 calculated in 253.96 s
# Epoch 133, NRMSE Test/best: 0.77940/0.37474, Training NRMSE: 0.71338, deviation of 9.25%
# Epoch -134 calculated in 253.88 s
# Epoch 134, NRMSE Test/best: 0.82684/0.37474, Training NRMSE: 0.71498, deviation of 15.64%
# Epoch -135 calculated in 253.96 s
# Epoch 135, NRMSE Test/best: 0.89646/0.37474, Training NRMSE: 0.78737, deviation of 13.86%
# Epoch -136 calculated in 254.21 s
# Epoch 136, NRMSE Test/best: 0.92975/0.37474, Training NRMSE: 0.79661, deviation of 16.71%
# Epoch -137 calculated in 254.28 s
# Epoch 137, NRMSE Test/best: 0.92744/0.37474, Training NRMSE: 0.81466, deviation of 13.84%
# Epoch -138 calculated in 254.02 s
# Epoch 138, NRMSE Test/best: 0.96294/0.37474, Training NRMSE: 0.82829, deviation of 16.26%
# Epoch -139 calculated in 254.46 s
# Epoch 139, NRMSE Test/best: 1.03615/0.37474, Training NRMSE: 0.87574, deviation of 18.32%
# Epoch -140 calculated in 254.16 s
# Epoch 140, NRMSE Test/best: 1.00298/0.37474, Training NRMSE: 0.89907, deviation of 11.56%
# Epoch -141 calculated in 254.27 s
# Epoch 141, NRMSE Test/best: 1.04594/0.37474, Training NRMSE: 0.91539, deviation of 14.26%
# Epoch -142 calculated in 253.96 s
# Epoch 142, NRMSE Test/best: 1.01647/0.37474, Training NRMSE: 0.93468, deviation of 8.75%
# Epoch -143 calculated in 253.99 s
# Epoch 143, NRMSE Test/best: 1.00274/0.37474, Training NRMSE: 0.94095, deviation of 6.57%
# Epoch -144 calculated in 254.35 s
# Epoch 144, NRMSE Test/best: 0.99137/0.37474, Training NRMSE: 0.94720, deviation of 4.66%
# Epoch -145 calculated in 254.15 s
# Epoch 145, NRMSE Test/best: 1.02554/0.37474, Training NRMSE: 0.94278, deviation of 8.78%
# Epoch -146 calculated in 253.89 s
# Epoch 146, NRMSE Test/best: 1.03683/0.37474, Training NRMSE: 0.93826, deviation of 10.51%
# Epoch -147 calculated in 254.22 s
# Epoch 147, NRMSE Test/best: 1.01052/0.37474, Training NRMSE: 0.94875, deviation of 6.51%
# Epoch -148 calculated in 254.18 s
# Epoch 148, NRMSE Test/best: 1.00923/0.37474, Training NRMSE: 0.95448, deviation of 5.74%
# Epoch -149 calculated in 254.03 s
# Epoch 149, NRMSE Test/best: 0.99328/0.37474, Training NRMSE: 0.95483, deviation of 4.03%
# Epoch -150 calculated in 253.91 s
# Epoch 150, NRMSE Test/best: 0.96706/0.37474, Training NRMSE: 0.95399, deviation of 1.37%
# Epoch -151 calculated in 254.15 s
# Epoch 151, NRMSE Test/best: 0.96571/0.37474, Training NRMSE: 0.93420, deviation of 3.37%
# Epoch -152 calculated in 254.03 s
# Epoch 152, NRMSE Test/best: 0.96671/0.37474, Training NRMSE: 0.92718, deviation of 4.26%
# Epoch -153 calculated in 254.13 s
# Epoch 153, NRMSE Test/best: 0.98057/0.37474, Training NRMSE: 0.92738, deviation of 5.73%
# Epoch -154 calculated in 254.12 s
# Epoch 154, NRMSE Test/best: 0.98887/0.37474, Training NRMSE: 0.92891, deviation of 6.45%
# Epoch -155 calculated in 254.19 s
# Epoch 155, NRMSE Test/best: 1.02732/0.37474, Training NRMSE: 0.94132, deviation of 9.14%
# Epoch -156 calculated in 254.00 s
# Epoch 156, NRMSE Test/best: 0.99035/0.37474, Training NRMSE: 0.93830, deviation of 5.55%
# Epoch -157 calculated in 254.29 s
# Epoch 157, NRMSE Test/best: 0.97619/0.37474, Training NRMSE: 0.93250, deviation of 4.69%
# Epoch -158 calculated in 254.21 s
# Epoch 158, NRMSE Test/best: 0.98421/0.37474, Training NRMSE: 0.93330, deviation of 5.45%
# Epoch -159 calculated in 254.07 s
# Epoch 159, NRMSE Test/best: 0.95047/0.37474, Training NRMSE: 0.91957, deviation of 3.36%
# Epoch -160 calculated in 253.61 s
# Epoch 160, NRMSE Test/best: 0.96297/0.37474, Training NRMSE: 0.92197, deviation of 4.45%
# Epoch -161 calculated in 254.10 s
# Epoch 161, NRMSE Test/best: 1.00430/0.37474, Training NRMSE: 0.91365, deviation of 9.92%
# Epoch -162 calculated in 254.16 s
# Epoch 162, NRMSE Test/best: 0.92697/0.37474, Training NRMSE: 0.91772, deviation of 1.01%
# Epoch -163 calculated in 253.64 s
# Epoch 163, NRMSE Test/best: 0.96955/0.37474, Training NRMSE: 0.92359, deviation of 4.98%
# Epoch -164 calculated in 254.18 s
# Epoch 164, NRMSE Test/best: 0.97538/0.37474, Training NRMSE: 0.90868, deviation of 7.34%
# Epoch -165 calculated in 254.20 s
# Epoch 165, NRMSE Test/best: 0.96958/0.37474, Training NRMSE: 0.90702, deviation of 6.90%
# Epoch -166 calculated in 254.03 s
# Epoch 166, NRMSE Test/best: 0.96977/0.37474, Training NRMSE: 0.90991, deviation of 6.58%
# Epoch -167 calculated in 253.84 s
# Epoch 167, NRMSE Test/best: 0.97380/0.37474, Training NRMSE: 0.91914, deviation of 5.95%
# Epoch -168 calculated in 253.85 s
# Epoch 168, NRMSE Test/best: 0.93855/0.37474, Training NRMSE: 0.91708, deviation of 2.34%
# Epoch -169 calculated in 253.99 s
# Epoch 169, NRMSE Test/best: 0.97400/0.37474, Training NRMSE: 0.88661, deviation of 9.86%
# Epoch -170 calculated in 254.01 s
# Epoch 170, NRMSE Test/best: 1.04671/0.37474, Training NRMSE: 0.93338, deviation of 12.14%
# Epoch -171 calculated in 254.03 s
# Epoch 171, NRMSE Test/best: 0.95480/0.37474, Training NRMSE: 0.94183, deviation of 1.38%
# Epoch -172 calculated in 253.98 s
# Epoch 172, NRMSE Test/best: 0.94273/0.37474, Training NRMSE: 0.91473, deviation of 3.06%
# Epoch -173 calculated in 254.36 s
# Epoch 173, NRMSE Test/best: 1.00103/0.37474, Training NRMSE: 0.92441, deviation of 8.29%
# Epoch -174 calculated in 253.90 s
# Epoch 174, NRMSE Test/best: 0.92864/0.37474, Training NRMSE: 0.91694, deviation of 1.28%
# Epoch -175 calculated in 254.18 s
# Epoch 175, NRMSE Test/best: 0.92520/0.37474, Training NRMSE: 0.89863, deviation of 2.96%
# Epoch -176 calculated in 253.82 s
# Epoch 176, NRMSE Test/best: 0.93836/0.37474, Training NRMSE: 0.89210, deviation of 5.19%
# Epoch -177 calculated in 254.05 s
# Epoch 177, NRMSE Test/best: 1.07124/0.37474, Training NRMSE: 0.81614, deviation of 31.26%
# Epoch -178 calculated in 253.97 s
# Epoch 178, NRMSE Test/best: 1.31574/0.37474, Training NRMSE: 0.73695, deviation of 78.54%
# Epoch -179 calculated in 253.84 s
# Epoch 179, NRMSE Test/best: 0.90730/0.37474, Training NRMSE: 0.65944, deviation of 37.59%
# Epoch -180 calculated in 254.19 s
# Epoch 180, NRMSE Test/best: 0.75446/0.37474, Training NRMSE: 0.53286, deviation of 41.59%
# Epoch -181 calculated in 254.01 s
# Epoch 181, NRMSE Test/best: 0.74756/0.37474, Training NRMSE: 0.54516, deviation of 37.13%
# Epoch -182 calculated in 254.13 s
# Epoch 182, NRMSE Test/best: 0.72730/0.37474, Training NRMSE: 0.51754, deviation of 40.53%
# Epoch -183 calculated in 253.89 s
# Epoch 183, NRMSE Test/best: 0.71439/0.37474, Training NRMSE: 0.47120, deviation of 51.61%
# Epoch -184 calculated in 254.37 s
# Epoch 184, NRMSE Test/best: 0.63924/0.37474, Training NRMSE: 0.46109, deviation of 38.64%
# Epoch -185 calculated in 254.42 s
# Epoch 185, NRMSE Test/best: 1.05947/0.37474, Training NRMSE: 0.45119, deviation of 134.81%
# Epoch -186 calculated in 254.27 s
# Epoch 186, NRMSE Test/best: 0.57496/0.37474, Training NRMSE: 0.44801, deviation of 28.34%
# Epoch -187 calculated in 253.90 s
# Epoch 187, NRMSE Test/best: 0.63094/0.37474, Training NRMSE: 0.43301, deviation of 45.71%
# Epoch -188 calculated in 253.97 s
# Epoch 188, NRMSE Test/best: 0.87971/0.37474, Training NRMSE: 0.57467, deviation of 53.08%
# Epoch -189 calculated in 253.79 s
# Epoch 189, NRMSE Test/best: 0.71079/0.37474, Training NRMSE: 0.61194, deviation of 16.15%
# Epoch -190 calculated in 254.17 s
# Epoch 190, NRMSE Test/best: 0.95344/0.37474, Training NRMSE: 0.70468, deviation of 35.30%
# Epoch -191 calculated in 254.02 s
# Epoch 191, NRMSE Test/best: 0.78730/0.37474, Training NRMSE: 0.59512, deviation of 32.29%
# Epoch -192 calculated in 254.19 s
# Epoch 192, NRMSE Test/best: 0.70440/0.37474, Training NRMSE: 0.51301, deviation of 37.31%
# Epoch -193 calculated in 253.93 s
# Epoch 193, NRMSE Test/best: 0.66800/0.37474, Training NRMSE: 0.47477, deviation of 40.70%
# Epoch -194 calculated in 254.41 s
# Epoch 194, NRMSE Test/best: 0.69311/0.37474, Training NRMSE: 0.44513, deviation of 55.71%
# Epoch -195 calculated in 254.11 s
# Epoch 195, NRMSE Test/best: 0.70009/0.37474, Training NRMSE: 0.45073, deviation of 55.32%
# Epoch -196 calculated in 254.15 s
# Epoch 196, NRMSE Test/best: 0.60538/0.37474, Training NRMSE: 0.42456, deviation of 42.59%
# Epoch -197 calculated in 254.59 s
# Epoch 197, NRMSE Test/best: 0.63707/0.37474, Training NRMSE: 0.41921, deviation of 51.97%
# Epoch -198 calculated in 254.27 s
# Epoch 198, NRMSE Test/best: 0.68613/0.37474, Training NRMSE: 0.41415, deviation of 65.67%
# Epoch -199 calculated in 254.09 s
# Epoch 199, NRMSE Test/best: 0.67780/0.37474, Training NRMSE: 0.41021, deviation of 65.23%
# Epoch -200 calculated in 253.99 s
# Epoch 200, NRMSE Test/best: 0.73566/0.37474, Training NRMSE: 0.45296, deviation of 62.41%
# Epoch -201 calculated in 254.29 s
# Epoch 201, NRMSE Test/best: 0.65271/0.37474, Training NRMSE: 0.40903, deviation of 59.57%
# Epoch -202 calculated in 254.08 s
# Epoch 202, NRMSE Test/best: 0.69302/0.37474, Training NRMSE: 0.40729, deviation of 70.15%
# Training duration 01:15:03:46
# Number of training variable 91351
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/freeze_graph.py:249: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from Experiments/2019-05-13-10-41/temp/myFinalModel.ckpt
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/freeze_graph.py:232: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.convert_variables_to_constants
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/graph_util_impl.py:245: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph
# INFO:tensorflow:Froze 4 variables.
# INFO:tensorflow:Converted 4 variables to const ops.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/optimize_for_inference_lib.py:113: remove_training_nodes (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.remove_training_nodes
# INFO:tensorflow:Restoring parameters from Experiments/2019-05-13-10-41/temp/myBestModel.ckpt
# done, good job kids

# %%
from show import *
# %matplotlib notebook
showPickle(nameFigEstimation)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
valInput=np.arange(44100)
num_step = 100
num_class=5
my_indices = np.arange(num_step-1,valSize,num_class)
indices = (my_indices[:,np.newaxis]-np.arange(num_class-1,-1,-1))
print(indices)
# Out:
# [[    95     96     97     98     99]
#  [   100    101    102    103    104]
#  [   105    106    107    108    109]
#  ...
#  [220485 220486 220487 220488 220489]
#  [220490 220491 220492 220493 220494]
#  [220495 220496 220497 220498 220499]]
