# %% [markdown]
# # Learn simple layer of LSTM

# %% [markdown]
# smaller model parameters than in conv 10

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
import os
import sys
sys.path.append('Codes')
import tensorflow as tf
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import pickle
from dataShaping import *
from savePerf import *
from saveTransformedGraph import optimizeGraph
import scipy.io.wavfile
import time
from tensorflow.contrib.layers import fully_connected
from tensorflow.contrib.rnn import *




modelName = "LSTM31"
# create directory experiment
date = time.strftime("%Y-%m-%d-%H-%M")
path = os.path.join("Experiments",date)
if not os.path.isdir(path):
    os.makedirs(path)
    #experiment/"date"/temp will contain the backuped model parameters
    pathTemp = os.path.join(path,'temp')
    os.makedirs(pathTemp)
    # if you run the file two time in a minute
else :
    date = date+'(2)'
    path = os.path.join("Experiments",date)
    os.makedirs(path)
    pathTemp = os.path.join(path,'temp')
    os.makedirs(pathTemp)

# directory that will contain tensorboard information
pathLog = 'Tf_logs'
if not os.path.isdir(pathLog):
    os.makedirs(pathLog)
pathLog = "{}/run-{}/".format(pathLog,date)

version = tf.__version__
print ("version {} of tensorflow".format(version))

#############################
# Model parameters
#############################
trainTestRatio = 0.8
#if you cannot load all the data set in Ram specify wich part you want to load (0 means all the dataset)
maxSize = 0
num_step = 100                                       # time step before reduction
#num_LSTM = 10                                         # num LSTM (time step after reduction)
conv_chan = [35]                                         #number of kernel for convolution
conv_strides = 3#int(np.ceil(num_step/num_LSTM))                  #decay between two convolution
conv_size = 12                                         #filter size for the convolution
size_poll = 4
reg_scale = 0
l1l2Prop = 0.4  # 1 =>l1, 0=> l2
reg_scale_l1 = l1l2Prop*reg_scale
reg_scale_l2 = ((1-l1l2Prop)/2)*reg_scale
num_hidden = 100                                      #num of hidden units
num_class = 1                                          #size of the output
num_feature = 1                                        # size of the input
batch_size = 2500                                   # number of sequence taken before to compute the gradient
n_layer = 1                                             #num_layer

#num_hidden = num_hidden/keep_prob
num_epoch = 10000                                      # process all the datas num_epoch times
trainDuration = 60*60*5                             # or during a determined duration(second)
                                      
amplifierName = 'MesaMarkVDisto'
fileNameTrain = 'Datasets/training'+amplifierName+'.mat'             #dataset train/test path
fileNameTest = 'Datasets/test'+amplifierName+'.mat' # dataset validation path
fileNameValidation = 'Datasets/val'+amplifierName+'.mat'

#############################
# Loading data
#############################
matrix = sio.loadmat(fileNameTrain)
matrixTrain = matrix['train']
matrix = sio.loadmat(fileNameTest)
matrixTest = matrix['test']
if maxSize ==0:
    maxSize = len(matrixTrain)
    print("maxSize = {}".format(maxSize))
# to do shuffle matrix by num_step length

#train_input,train_output,test_input,test_output = loadInputOutput(matrixTrain,matrixTest,num_step,maxSize)

#print("train input {}".format(matrixTrain[:10,0]))
#print("matrix output {}".format(matrixTrain[num_step-1:num_step-1+10,1]))
#print("1er method output {}".format(train_output[:10]))
train_input,train_output,test_input,test_output = loadInputOutputSeq(matrixTrain,matrixTest,num_step,maxSize)

#print("seq method output {}".format(train_output[:10]))
print("shape input train {}".format(np.shape(train_input)))
numTrain = len(train_output)
print ("Data loaded")
#######################
#Graph
#######################

G = tf.Graph()
with G.as_default():
    with tf.name_scope("placeHolder"):
        data = tf.placeholder(tf.float32, [None, num_step], name ="data") #Number of examples, number of input step (time step), dimension of each input
        target = tf.placeholder(tf.float32, [None, num_class],name = "target") # batchSize, nbClass

    dataShaped = tf.reshape(data,[tf.shape(data)[0],num_step,1,1]) # batchSize, num_step num_feature
    with tf.variable_scope("ConvLayers"):
        regularizerC1 = tf.contrib.layers.l1_l2_regularizer(scale_l1=reg_scale_l1,scale_l2=reg_scale_l2,scope="regC1")
        dataReduced = tf.layers.conv2d(inputs = dataShaped,filters = conv_chan[0],
                                       kernel_size = (conv_size,1),strides=(4,1),
                                       padding = "same",activation=tf.nn.elu,kernel_regularizer=regularizerC1,name="C1")#batch_size num_Lstm num_channel
        regularizerC2 = tf.contrib.layers.l1_l2_regularizer(scale_l1=reg_scale_l1,scale_l2=reg_scale_l2,scope="regC2")
        dataReduced = tf.layers.conv2d(inputs = dataReduced,filters = conv_chan[0],
                                       kernel_size = (conv_size,1),strides=(5,1),
                                       padding = "same",activation=tf.nn.elu,kernel_regularizer=regularizerC2,name="C2")#batch_size num_Lstm num_channel
        #regularizerC3 = tf.contrib.layers.l1_l2_regularizer(scale_l1=reg_scale_l1,scale_l2=reg_scale_l2,scope="regC3")
        #dataReduced = tf.layers.conv2d(inputs = dataReduced,filters = conv_chan,
        #                               kernel_size = (conv_size,1),strides=(2,1),
        #                               padding = "same",activation=tf.nn.elu,kernel_regularizer=regularizerC3,name="C3")#batch_size num_Lstm num_channel
    dataReduced = tf.reshape(dataReduced,[tf.shape(data)[0],tf.shape(dataReduced)[1],conv_chan[0]])
    
    fusedCell = tf.contrib.rnn.LSTMBlockFusedCell(num_hidden,use_peephole=False)
 
    dataReduced = tf.transpose(dataReduced,[1,0,2])

    with tf.name_scope("extractLastValueLSTM"):
        #val, state = fusedCell(dataReduced) #for cudnn_rnn.cudnnLSTM
        val, state = fusedCell(dataReduced,dtype=tf.float32) #for LSTMblockFusedCell
        #val, state = fusedCell(dataReduced,initial_state=None,dtype=tf.float32) # val dim is [num_step,batch_size, numhidden]
    # Let's first fetch the last index of seq length
    # last_index would have a scalar value
        last_index = tf.shape(val)[0] - 1
    # Then let's reshape the output to [sequence_length,batch_size,numhidden]
    # for convenience
        #val = tf.transpose(val,[1,0,2])
    # Last state of all batches
        #last = tf.nn.embedding_lookup(val,last_index) # tensor [batchsize,numhidden]
        last = tf.gather(val,last_index)

    prediction = fully_connected(last,int(target.get_shape()[1]),activation_fn=tf.nn.tanh,weights_regularizer=None,scope="FCPred")
    
    #Compute the mean square error
    MSE = tf.reduce_mean(tf.square(prediction-target))
    EnergyTarget = tf.reduce_mean(tf.square(target)) 
    
    #get regularizer
    reg_losses = tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES)
    MSEReg = tf.add_n([MSE]+reg_losses,name="MSEReg")
    # create optimizer
    optimizer = tf.train.AdamOptimizer()
    #Compute gradient and apply backpropagation
    minimize = optimizer.minimize(MSEReg)

    # Create summary view for tensorboard
    mse_summary = tf.summary.scalar('RMSE',tf.sqrt(MSE))
    #kernels = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES,'ConvLayers/C1/kernel')[0]
    #kernels1 = tf.reshape(tf.slice(kernels,[0,0,0,0],[12,1,1,1]),[-1])
    #kernels2 = tf.reshape(kernels,[1,12,30,1])
    #imag_summary=tf.summary.image('kernels',kernels2,max_outputs=1)
    #histogram_summary = tf.summary.histogram('kernelC1',kernels1)
    summary_op = tf.summary.merge_all()
    
    #Create an init op to initialize variable
    init_op = tf.global_variables_initializer()
    saver = tf.train.Saver() # save variable, use saver.restore(sess,"date/tmp/my_model.ckpt") instead of sess.run(init_op)

##############################
# Execution du graphe
##############################
    
with tf.Session(graph=G) as sess:
    #restorePath = os.path.join('2017-09-11-18-07','temp','my_model.ckpt') # example for restore a previous model
    #saver.restore(sess,restorePath)
    sess.run(init_op)
    train_writer = tf.summary.FileWriter(pathLog+'train',graph =tf.get_default_graph())
    test_writer = tf.summary.FileWriter(pathLog+'test')

    no_of_batches = int(np.floor((numTrain)/batch_size)) # numtrain -numstep ?
    no_of_batchesTest = int(np.floor((len(test_input))/batch_size))
    tStart = time.clock()
    epoch =0
    RMSENorm = 1
    bestRMSE = 1
    
    for epoch in range(num_epoch):
        tEpoch = time.clock()
        if (time.clock()-tStart < trainDuration) :
            ptr = 0
            if epoch % 20==0 : # each ten epoch save the model
                tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myGraph.pb',as_text=False)
                save_path = saver.save(sess,os.path.join(pathTemp,'myModel.ckpt'))
            pMSETrain=0
            
            for j in range(no_of_batches):
                inp, out = train_input[ptr:ptr+batch_size],train_output[ptr:ptr+batch_size]
                ptr+=batch_size
                
                if j % np.floor(numTrain/len(test_input)) ==0 : # This is to have a train summary and a test summary of the same size
                    _,summary_str,pMSETrainTemp,pLast = sess.run([minimize,summary_op,MSE,last],{data: inp, target: out})
                    
                    #print("shape:{}".format(numTrain/len(test_input)))
                    #print("Kernels1:{}".format(pKernels1))
                    #print("Kernels2:{}".format(pKernels2))
                    pMSETrain += pMSETrainTemp
                    step = epoch*no_of_batches+j
                    train_writer.add_summary(summary_str,step)                   

                else :
                    sess.run([minimize],{data: inp, target: out})
                    #[print(n.name) for n in tf.get_default_graph().as_graph_def().node]
                   
            RMSETrain = np.sqrt(pMSETrain/no_of_batchesTest)
            print ("Epoch -{} calculated in {:5.2f} s ".format(epoch,time.clock()-tEpoch))
            # evaluate the model on the test set (compute the mean of the MSE)
            pMSE = 0
            ptr2 = 0
            pEnergyTarget = 0
            for k in range(no_of_batchesTest):
                pMSETemp,pEnergyTargetTemp,summary_str = sess.run([MSE,EnergyTarget,summary_op],{data: test_input[ptr2:ptr2+batch_size] , target: test_output[ptr2:ptr2+batch_size]})
                pMSE += pMSETemp
                ptr2 += batch_size
                pEnergyTarget+=pEnergyTargetTemp
                step = epoch*no_of_batchesTest+k
                test_writer.add_summary(summary_str,step*np.floor(numTrain/len(test_input)))
            RMSETest = np.sqrt(pMSE/no_of_batchesTest)
            RMSENorm = np.sqrt(pMSE/pEnergyTarget)
            if RMSENorm<bestRMSE:
                bestRMSE=RMSENorm
                tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myBestGraph.pbtxt',as_text=True)
                save_path = saver.save(sess,os.path.join(pathTemp,'myBestModel.ckpt'))
            print("Epoch {}, RMSENorm: {:.5}/{:.5} on test set with deviation of {:.2f}%".format(epoch,RMSENorm,bestRMSE,100*np.sqrt((RMSETrain-RMSETest)**2)/RMSETrain))
        else : break # break the while loop if number of epoch is reached
    tStop = time.clock()
    trainTime = time.strftime("%d:%H:%M:%S ", time.gmtime(tStop-tStart))
    
    #######################
    # Save Graph variable and information about the running session
    #######################
    # save graph model
    tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myFinalGraph.pbtxt',as_text=True)
    # Save checkpoint variables
    save_path = saver.save(sess,os.path.join(pathTemp,'myFinalModel.ckpt'))
    print ("Training duration {}".format(trainTime))
    totalParameters =np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.trainable_variables()])
    print("Number of training variable {}".format(totalParameters))
    # log
    infoLog={}
    infoLog["path"] = path
    infoLog["MSE"] = bestRMSE
    infoLog["num_step"] = num_step
    infoLog["num_hidden"] = num_hidden
    infoLog["num_epoch"] = epoch
    infoLog["batch_size"] = batch_size
    infoLog["maxSize"] = maxSize
    infoLog["duration"] = trainTime
    infoLog["totalParameters"] = totalParameters
    infoLog["version"] = version
    infoLog["n_layer"] = n_layer
    infoLog["trainDropout"] = 0
    infoLog["nameModel"] = modelName
    infoLog["conv_chan"] = conv_chan
    infoLog["strides"] = conv_strides
    infoLog["conv_size"] = conv_size
    infoLog["amplifierName"]=amplifierName
    logPerf(infoLog)
    input_nodes=["placeHolder/data"]
    output_nodes=["FCPred/Tanh"]
    optimizeGraph(pathTemp,input_nodes,output_nodes)
    
    
                                                 
    
    ###############################
    #   validation dataset and emulate guitar signal
    ###############################
    restorePath = os.path.join(pathTemp,'myBestModel.ckpt') # example for restore a previous model
    saver.restore(sess,restorePath)
    matrixVal = sio.loadmat(fileNameValidation)
    matrixVal = matrixVal['val']  
    valSize = 0
    if valSize == 0 :
        valSize = len(matrixVal)
    # shape validation test
    val_input,val_output = loadValidationSeq(matrixVal,num_step,valSize)
    lPrediction = []
    lTarget = []
    ptr3 = 0
    no_of_batchesVal = int(np.floor((len(val_input))/batch_size))
    for k in range(no_of_batchesVal):
        pPrediction,pTarget = sess.run([prediction,target],{data: val_input[ptr3:ptr3+batch_size], target: val_output[ptr3:ptr3+batch_size]}) 
        lPrediction.append(pPrediction)
        lTarget.append(pTarget)   
        ptr3+=batch_size
    #plt.show()scree
    predictionArray = np.array(lPrediction,dtype=np.float32).ravel()
    targetArray = np.array(lTarget,dtype=np.float32).ravel()
    scipy.io.wavfile.write(os.path.join(path,'prediction.wav'),44100,predictionArray)
    scipy.io.wavfile.write(os.path.join(path,'target.wav'),44100,targetArray)

    # save emulation in a pickle format
    ax = plt.subplot(111)
    ax.plot(predictionArray[:10000],label='prediction')
    ax.plot(targetArray[:10000],label='target')
    ax.legend()
    nameFigEstimation = os.path.join(path,"targetVsPrediction.pickle")
    pickle.dump(ax,open(nameFigEstimation, 'wb'))
print ("done, good job kids")
# Out:
# version 1.10.1 of tensorflow
# maxSize = 6726407
# shape input train (6726308, 100)
# Data loaded
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# /home/totovai/.local/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch -0 calculated in 25.17 s
# Epoch 0, RMSENorm: 0.39015/0.39015 on test set with deviation of 8.49%
# Epoch -1 calculated in 24.35 s
# Epoch 1, RMSENorm: 0.35898/0.35898 on test set with deviation of 28.21%
# Epoch -2 calculated in 24.64 s
# Epoch 2, RMSENorm: 0.34122/0.34122 on test set with deviation of 31.55%
# Epoch -3 calculated in 24.34 s
# Epoch 3, RMSENorm: 0.33068/0.33068 on test set with deviation of 33.30%
# Epoch -4 calculated in 24.38 s
# Epoch 4, RMSENorm: 0.32201/0.32201 on test set with deviation of 33.34%
# Epoch -5 calculated in 24.24 s
# Epoch 5, RMSENorm: 0.31913/0.31913 on test set with deviation of 34.63%
# Epoch -6 calculated in 24.52 s
# Epoch 6, RMSENorm: 0.31384/0.31384 on test set with deviation of 32.91%
# Epoch -7 calculated in 24.38 s
# Epoch 7, RMSENorm: 0.30897/0.30897 on test set with deviation of 33.23%
# Epoch -8 calculated in 24.63 s
# Epoch 8, RMSENorm: 0.30826/0.30826 on test set with deviation of 33.39%
# Epoch -9 calculated in 24.30 s
# Epoch 9, RMSENorm: 0.3022/0.3022 on test set with deviation of 32.54%
# Epoch -10 calculated in 24.40 s
# Epoch 10, RMSENorm: 0.30095/0.30095 on test set with deviation of 32.39%
# Epoch -11 calculated in 24.29 s
# Epoch 11, RMSENorm: 0.29878/0.29878 on test set with deviation of 32.19%
# Epoch -12 calculated in 24.44 s
# Epoch 12, RMSENorm: 0.29689/0.29689 on test set with deviation of 32.57%
# Epoch -13 calculated in 24.48 s
# Epoch 13, RMSENorm: 0.29387/0.29387 on test set with deviation of 31.47%
# Epoch -14 calculated in 24.29 s
# Epoch 14, RMSENorm: 0.29413/0.29387 on test set with deviation of 32.02%
# Epoch -15 calculated in 24.26 s
# Epoch 15, RMSENorm: 0.29018/0.29018 on test set with deviation of 31.00%
# Epoch -16 calculated in 24.34 s
# Epoch 16, RMSENorm: 0.28746/0.28746 on test set with deviation of 30.39%
# Epoch -17 calculated in 24.46 s
# Epoch 17, RMSENorm: 0.28405/0.28405 on test set with deviation of 29.16%
# Epoch -18 calculated in 24.33 s
# Epoch 18, RMSENorm: 0.28511/0.28405 on test set with deviation of 30.46%
# Epoch -19 calculated in 23.71 s
# Epoch 19, RMSENorm: 0.28447/0.28405 on test set with deviation of 30.72%
# Epoch -20 calculated in 24.42 s
# Epoch 20, RMSENorm: 0.28591/0.28405 on test set with deviation of 32.40%
# Epoch -21 calculated in 24.24 s
# Epoch 21, RMSENorm: 0.28506/0.28405 on test set with deviation of 31.92%
# Epoch -22 calculated in 24.46 s
# Epoch 22, RMSENorm: 0.28504/0.28405 on test set with deviation of 32.98%
# Epoch -23 calculated in 24.51 s
# Epoch 23, RMSENorm: 0.28396/0.28396 on test set with deviation of 32.22%
# Epoch -24 calculated in 24.62 s
# Epoch 24, RMSENorm: 0.28541/0.28396 on test set with deviation of 33.53%
# Epoch -25 calculated in 24.37 s
# Epoch 25, RMSENorm: 0.28582/0.28396 on test set with deviation of 34.38%
# Epoch -26 calculated in 24.55 s
# Epoch 26, RMSENorm: 0.28363/0.28363 on test set with deviation of 33.26%
# Epoch -27 calculated in 24.43 s
# Epoch 27, RMSENorm: 0.28519/0.28363 on test set with deviation of 33.48%
# Epoch -28 calculated in 24.29 s
# Epoch 28, RMSENorm: 0.28369/0.28363 on test set with deviation of 34.27%
# Epoch -29 calculated in 24.67 s
# Epoch 29, RMSENorm: 0.28432/0.28363 on test set with deviation of 34.23%
# Epoch -30 calculated in 24.21 s
# Epoch 30, RMSENorm: 0.28392/0.28363 on test set with deviation of 35.14%
# Epoch -31 calculated in 24.43 s
# Epoch 31, RMSENorm: 0.28232/0.28232 on test set with deviation of 34.42%
# Epoch -32 calculated in 24.49 s
# Epoch 32, RMSENorm: 0.28291/0.28232 on test set with deviation of 35.40%
# Epoch -33 calculated in 24.36 s
# Epoch 33, RMSENorm: 0.28149/0.28149 on test set with deviation of 34.35%
# Epoch -34 calculated in 24.39 s
# Epoch 34, RMSENorm: 0.27975/0.27975 on test set with deviation of 33.66%
# Epoch -35 calculated in 24.46 s
# Epoch 35, RMSENorm: 0.28292/0.27975 on test set with deviation of 36.25%
# Epoch -36 calculated in 24.32 s
# Epoch 36, RMSENorm: 0.27928/0.27928 on test set with deviation of 34.56%
# Epoch -37 calculated in 24.31 s
# Epoch 37, RMSENorm: 0.2824/0.27928 on test set with deviation of 35.49%
# Epoch -38 calculated in 24.32 s
# Epoch 38, RMSENorm: 0.28393/0.27928 on test set with deviation of 37.27%
# Epoch -39 calculated in 24.40 s
# Epoch 39, RMSENorm: 0.27942/0.27928 on test set with deviation of 35.70%
# Epoch -40 calculated in 24.44 s
# Epoch 40, RMSENorm: 0.28277/0.27928 on test set with deviation of 37.87%
# Epoch -41 calculated in 24.49 s
# Epoch 41, RMSENorm: 0.27944/0.27928 on test set with deviation of 35.95%
# Epoch -42 calculated in 24.54 s
# Epoch 42, RMSENorm: 0.28031/0.27928 on test set with deviation of 37.00%
# Epoch -43 calculated in 24.34 s
# Epoch 43, RMSENorm: 0.27934/0.27928 on test set with deviation of 36.29%
# Epoch -44 calculated in 24.27 s
# Epoch 44, RMSENorm: 0.2784/0.2784 on test set with deviation of 36.07%
# Epoch -45 calculated in 24.32 s
# Epoch 45, RMSENorm: 0.28195/0.2784 on test set with deviation of 37.87%
# Epoch -46 calculated in 24.31 s
# Epoch 46, RMSENorm: 0.27616/0.27616 on test set with deviation of 35.31%
# Epoch -47 calculated in 24.33 s
# Epoch 47, RMSENorm: 0.27472/0.27472 on test set with deviation of 35.53%
# Epoch -48 calculated in 24.55 s
# Epoch 48, RMSENorm: 0.27398/0.27398 on test set with deviation of 35.22%
# Epoch -49 calculated in 24.61 s
# Epoch 49, RMSENorm: 0.27464/0.27398 on test set with deviation of 35.57%
# Epoch -50 calculated in 24.47 s
# Epoch 50, RMSENorm: 0.27434/0.27398 on test set with deviation of 35.62%
# Epoch -51 calculated in 24.49 s
# Epoch 51, RMSENorm: 0.27142/0.27142 on test set with deviation of 34.58%
# Epoch -52 calculated in 24.32 s
# Epoch 52, RMSENorm: 0.2702/0.2702 on test set with deviation of 33.31%
# Epoch -53 calculated in 24.37 s
# Epoch 53, RMSENorm: 0.27245/0.2702 on test set with deviation of 34.46%
# Epoch -54 calculated in 24.39 s
# Epoch 54, RMSENorm: 0.27099/0.2702 on test set with deviation of 34.96%
# Epoch -55 calculated in 24.28 s
# Epoch 55, RMSENorm: 0.26876/0.26876 on test set with deviation of 34.09%
# Epoch -56 calculated in 24.44 s
# Epoch 56, RMSENorm: 0.26948/0.26876 on test set with deviation of 33.83%
# Epoch -57 calculated in 24.50 s
# Epoch 57, RMSENorm: 0.26892/0.26876 on test set with deviation of 34.18%
# Epoch -58 calculated in 24.47 s
# Epoch 58, RMSENorm: 0.27051/0.26876 on test set with deviation of 34.97%
# Epoch -59 calculated in 24.63 s
# Epoch 59, RMSENorm: 0.26908/0.26876 on test set with deviation of 34.31%
# Epoch -60 calculated in 24.38 s
# Epoch 60, RMSENorm: 0.27018/0.26876 on test set with deviation of 35.66%
# Epoch -61 calculated in 24.46 s
# Epoch 61, RMSENorm: 0.27021/0.26876 on test set with deviation of 35.18%
# Epoch -62 calculated in 24.45 s
# Epoch 62, RMSENorm: 0.27124/0.26876 on test set with deviation of 36.03%
# Epoch -63 calculated in 24.32 s
# Epoch 63, RMSENorm: 0.27037/0.26876 on test set with deviation of 34.71%
# Epoch -64 calculated in 24.56 s
# Epoch 64, RMSENorm: 0.26993/0.26876 on test set with deviation of 35.85%
# Epoch -65 calculated in 24.47 s
# Epoch 65, RMSENorm: 0.26905/0.26876 on test set with deviation of 35.59%
# Epoch -66 calculated in 24.15 s
# Epoch 66, RMSENorm: 0.26984/0.26876 on test set with deviation of 35.83%
# Epoch -67 calculated in 24.32 s
# Epoch 67, RMSENorm: 0.27194/0.26876 on test set with deviation of 37.04%
# Epoch -68 calculated in 24.58 s
# Epoch 68, RMSENorm: 0.26954/0.26876 on test set with deviation of 36.05%
# Epoch -69 calculated in 24.34 s
# Epoch 69, RMSENorm: 0.27242/0.26876 on test set with deviation of 37.38%
# Epoch -70 calculated in 24.37 s
# Epoch 70, RMSENorm: 0.27233/0.26876 on test set with deviation of 38.13%
# Epoch -71 calculated in 24.45 s
# Epoch 71, RMSENorm: 0.27208/0.26876 on test set with deviation of 38.04%
# Epoch -72 calculated in 24.49 s
# Epoch 72, RMSENorm: 0.27175/0.26876 on test set with deviation of 37.91%
# Epoch -73 calculated in 24.46 s
# Epoch 73, RMSENorm: 0.27073/0.26876 on test set with deviation of 37.50%
# Epoch -74 calculated in 24.32 s
# Epoch 74, RMSENorm: 0.27242/0.26876 on test set with deviation of 38.14%
# Epoch -75 calculated in 24.24 s
# Epoch 75, RMSENorm: 0.27195/0.26876 on test set with deviation of 37.74%
# Epoch -76 calculated in 24.44 s
# Epoch 76, RMSENorm: 0.27305/0.26876 on test set with deviation of 38.23%
# Epoch -77 calculated in 24.32 s
# Epoch 77, RMSENorm: 0.27301/0.26876 on test set with deviation of 38.66%
# Epoch -78 calculated in 24.52 s
# Epoch 78, RMSENorm: 0.27276/0.26876 on test set with deviation of 38.99%
# Epoch -79 calculated in 24.43 s
# Epoch 79, RMSENorm: 0.27093/0.26876 on test set with deviation of 37.83%
# Epoch -80 calculated in 24.40 s
# Epoch 80, RMSENorm: 0.26989/0.26876 on test set with deviation of 37.14%
# Epoch -81 calculated in 24.44 s
# Epoch 81, RMSENorm: 0.27353/0.26876 on test set with deviation of 39.55%
# Epoch -82 calculated in 24.43 s
# Epoch 82, RMSENorm: 0.27193/0.26876 on test set with deviation of 38.60%
# Epoch -83 calculated in 24.15 s
# Epoch 83, RMSENorm: 0.27305/0.26876 on test set with deviation of 39.73%
# Epoch -84 calculated in 24.54 s
# Epoch 84, RMSENorm: 0.27428/0.26876 on test set with deviation of 40.67%
# Epoch -85 calculated in 24.40 s
# Epoch 85, RMSENorm: 0.27146/0.26876 on test set with deviation of 39.37%
# Epoch -86 calculated in 24.43 s
# Epoch 86, RMSENorm: 0.27262/0.26876 on test set with deviation of 39.90%
# Epoch -87 calculated in 24.49 s
# Epoch 87, RMSENorm: 0.27319/0.26876 on test set with deviation of 39.49%
# Epoch -88 calculated in 24.37 s
# Epoch 88, RMSENorm: 0.27176/0.26876 on test set with deviation of 39.07%
# Epoch -89 calculated in 24.48 s
# Epoch 89, RMSENorm: 0.27211/0.26876 on test set with deviation of 39.85%
# Epoch -90 calculated in 24.49 s
# Epoch 90, RMSENorm: 0.27478/0.26876 on test set with deviation of 40.70%
# Epoch -91 calculated in 24.34 s
# Epoch 91, RMSENorm: 0.27014/0.26876 on test set with deviation of 39.48%
# Epoch -92 calculated in 24.46 s
# Epoch 92, RMSENorm: 0.27139/0.26876 on test set with deviation of 39.84%
# Epoch -93 calculated in 24.30 s
# Epoch 93, RMSENorm: 0.26989/0.26876 on test set with deviation of 38.73%
# Epoch -94 calculated in 24.25 s
# Epoch 94, RMSENorm: 0.2691/0.26876 on test set with deviation of 38.65%
# Epoch -95 calculated in 24.45 s
# Epoch 95, RMSENorm: 0.2695/0.26876 on test set with deviation of 38.56%
# Epoch -96 calculated in 24.51 s
# Epoch 96, RMSENorm: 0.27081/0.26876 on test set with deviation of 39.91%
# Epoch -97 calculated in 24.45 s
# Epoch 97, RMSENorm: 0.27077/0.26876 on test set with deviation of 39.66%
# Epoch -98 calculated in 24.50 s
# Epoch 98, RMSENorm: 0.27148/0.26876 on test set with deviation of 39.52%
# Epoch -99 calculated in 24.49 s
# Epoch 99, RMSENorm: 0.27032/0.26876 on test set with deviation of 39.88%
# Epoch -100 calculated in 24.28 s
# Epoch 100, RMSENorm: 0.27167/0.26876 on test set with deviation of 39.70%
# Epoch -101 calculated in 24.34 s
# Epoch 101, RMSENorm: 0.27163/0.26876 on test set with deviation of 40.12%
# Epoch -102 calculated in 24.52 s
# Epoch 102, RMSENorm: 0.26702/0.26702 on test set with deviation of 38.30%
# Epoch -103 calculated in 24.45 s
# Epoch 103, RMSENorm: 0.26886/0.26702 on test set with deviation of 38.22%
# Epoch -104 calculated in 23.94 s
# Epoch 104, RMSENorm: 0.27067/0.26702 on test set with deviation of 40.93%
# Epoch -105 calculated in 24.27 s
# Epoch 105, RMSENorm: 0.27077/0.26702 on test set with deviation of 41.10%
# Epoch -106 calculated in 24.57 s
# Epoch 106, RMSENorm: 0.2721/0.26702 on test set with deviation of 41.76%
# Epoch -107 calculated in 24.48 s
# Epoch 107, RMSENorm: 0.26695/0.26695 on test set with deviation of 37.74%
# Epoch -108 calculated in 24.25 s
# Epoch 108, RMSENorm: 0.26778/0.26695 on test set with deviation of 39.33%
# Epoch -109 calculated in 24.62 s
# Epoch 109, RMSENorm: 0.26988/0.26695 on test set with deviation of 41.00%
# Epoch -110 calculated in 24.31 s
# Epoch 110, RMSENorm: 0.26759/0.26695 on test set with deviation of 39.12%
# Epoch -111 calculated in 24.20 s
# Epoch 111, RMSENorm: 0.26781/0.26695 on test set with deviation of 40.33%
# Epoch -112 calculated in 24.25 s
# Epoch 112, RMSENorm: 0.26751/0.26695 on test set with deviation of 38.18%
# Epoch -113 calculated in 24.41 s
# Epoch 113, RMSENorm: 0.26661/0.26661 on test set with deviation of 38.79%
# Epoch -114 calculated in 24.32 s
# Epoch 114, RMSENorm: 0.26602/0.26602 on test set with deviation of 38.88%
# Epoch -115 calculated in 24.37 s
# Epoch 115, RMSENorm: 0.2632/0.2632 on test set with deviation of 37.23%
# Epoch -116 calculated in 24.42 s
# Epoch 116, RMSENorm: 0.26463/0.2632 on test set with deviation of 38.55%
# Epoch -117 calculated in 24.46 s
# Epoch 117, RMSENorm: 0.26325/0.2632 on test set with deviation of 37.85%
# Epoch -118 calculated in 24.48 s
# Epoch 118, RMSENorm: 0.26372/0.2632 on test set with deviation of 37.55%
# Epoch -119 calculated in 24.53 s
# Epoch 119, RMSENorm: 0.26373/0.2632 on test set with deviation of 38.90%
# Epoch -120 calculated in 24.30 s
# Epoch 120, RMSENorm: 0.26982/0.2632 on test set with deviation of 39.26%
# Epoch -121 calculated in 24.19 s
# Epoch 121, RMSENorm: 0.26524/0.2632 on test set with deviation of 38.71%
# Epoch -122 calculated in 24.42 s
# Epoch 122, RMSENorm: 0.26524/0.2632 on test set with deviation of 39.46%
# Epoch -123 calculated in 24.49 s
# Epoch 123, RMSENorm: 0.26543/0.2632 on test set with deviation of 39.57%
# Epoch -124 calculated in 24.31 s
# Epoch 124, RMSENorm: 0.26695/0.2632 on test set with deviation of 39.97%
# Epoch -125 calculated in 24.53 s
# Epoch 125, RMSENorm: 0.26357/0.2632 on test set with deviation of 38.52%
# Epoch -126 calculated in 24.41 s
# Epoch 126, RMSENorm: 0.26422/0.2632 on test set with deviation of 38.62%
# Epoch -127 calculated in 24.34 s
# Epoch 127, RMSENorm: 0.26767/0.2632 on test set with deviation of 39.48%
# Epoch -128 calculated in 24.44 s
# Epoch 128, RMSENorm: 0.26717/0.2632 on test set with deviation of 40.10%
# Epoch -129 calculated in 24.39 s
# Epoch 129, RMSENorm: 0.26456/0.2632 on test set with deviation of 38.86%
# Epoch -130 calculated in 24.46 s
# Epoch 130, RMSENorm: 0.26323/0.2632 on test set with deviation of 37.79%
# Epoch -131 calculated in 24.47 s
# Epoch 131, RMSENorm: 0.26657/0.2632 on test set with deviation of 40.52%
# Epoch -132 calculated in 24.40 s
# Epoch 132, RMSENorm: 0.26659/0.2632 on test set with deviation of 40.06%
# Epoch -133 calculated in 24.45 s
# Epoch 133, RMSENorm: 0.26461/0.2632 on test set with deviation of 38.83%
# Epoch -134 calculated in 24.45 s
# Epoch 134, RMSENorm: 0.26416/0.2632 on test set with deviation of 37.06%
# Epoch -135 calculated in 24.62 s
# Epoch 135, RMSENorm: 0.26715/0.2632 on test set with deviation of 40.96%
# Epoch -136 calculated in 24.19 s
# Epoch 136, RMSENorm: 0.26598/0.2632 on test set with deviation of 41.01%
# Epoch -137 calculated in 24.41 s
# Epoch 137, RMSENorm: 0.27083/0.2632 on test set with deviation of 43.65%
# Epoch -138 calculated in 24.13 s
# Epoch 138, RMSENorm: 0.26772/0.2632 on test set with deviation of 40.98%
# Epoch -139 calculated in 24.18 s
# Epoch 139, RMSENorm: 0.26988/0.2632 on test set with deviation of 40.86%
# Epoch -140 calculated in 24.65 s
# Epoch 140, RMSENorm: 0.26279/0.26279 on test set with deviation of 38.67%
# Epoch -141 calculated in 24.26 s
# Epoch 141, RMSENorm: 0.26246/0.26246 on test set with deviation of 39.07%
# Epoch -142 calculated in 24.32 s
# Epoch 142, RMSENorm: 0.26156/0.26156 on test set with deviation of 37.47%
# Epoch -143 calculated in 24.27 s
# Epoch 143, RMSENorm: 0.26316/0.26156 on test set with deviation of 38.65%
# Epoch -144 calculated in 24.56 s
# Epoch 144, RMSENorm: 0.26533/0.26156 on test set with deviation of 41.13%
# Epoch -145 calculated in 24.47 s
# Epoch 145, RMSENorm: 0.26403/0.26156 on test set with deviation of 40.33%
# Epoch -146 calculated in 24.55 s
# Epoch 146, RMSENorm: 0.26369/0.26156 on test set with deviation of 39.20%
# Epoch -147 calculated in 24.14 s
# Epoch 147, RMSENorm: 0.26438/0.26156 on test set with deviation of 40.55%
# Epoch -148 calculated in 24.46 s
# Epoch 148, RMSENorm: 0.26368/0.26156 on test set with deviation of 40.17%
# Epoch -149 calculated in 24.46 s
# Epoch 149, RMSENorm: 0.26292/0.26156 on test set with deviation of 39.37%
# Epoch -150 calculated in 24.53 s
# Epoch 150, RMSENorm: 0.26586/0.26156 on test set with deviation of 39.48%
# Epoch -151 calculated in 24.41 s
# Epoch 151, RMSENorm: 0.2678/0.26156 on test set with deviation of 42.68%
# Epoch -152 calculated in 24.53 s
# Epoch 152, RMSENorm: 0.26297/0.26156 on test set with deviation of 39.60%
# Epoch -153 calculated in 24.17 s
# Epoch 153, RMSENorm: 0.26594/0.26156 on test set with deviation of 41.55%
# Epoch -154 calculated in 24.29 s
# Epoch 154, RMSENorm: 0.2632/0.26156 on test set with deviation of 39.37%
# Epoch -155 calculated in 24.40 s
# Epoch 155, RMSENorm: 0.2629/0.26156 on test set with deviation of 40.11%
# Epoch -156 calculated in 24.51 s
# Epoch 156, RMSENorm: 0.26084/0.26084 on test set with deviation of 38.97%
# Epoch -157 calculated in 24.51 s
# Epoch 157, RMSENorm: 0.26667/0.26084 on test set with deviation of 40.04%
# Epoch -158 calculated in 24.55 s
# Epoch 158, RMSENorm: 0.26344/0.26084 on test set with deviation of 39.15%
# Epoch -159 calculated in 24.52 s
# Epoch 159, RMSENorm: 0.26393/0.26084 on test set with deviation of 39.55%
# Epoch -160 calculated in 24.32 s
# Epoch 160, RMSENorm: 0.26294/0.26084 on test set with deviation of 40.10%
# Epoch -161 calculated in 24.42 s
# Epoch 161, RMSENorm: 0.26493/0.26084 on test set with deviation of 40.50%
# Epoch -162 calculated in 24.22 s
# Epoch 162, RMSENorm: 0.26854/0.26084 on test set with deviation of 42.10%
# Epoch -163 calculated in 24.45 s
# Epoch 163, RMSENorm: 0.26221/0.26084 on test set with deviation of 39.68%
# Epoch -164 calculated in 24.35 s
# Epoch 164, RMSENorm: 0.26367/0.26084 on test set with deviation of 40.59%
# Epoch -165 calculated in 24.61 s
# Epoch 165, RMSENorm: 0.26276/0.26084 on test set with deviation of 39.06%
# Epoch -166 calculated in 24.48 s
# Epoch 166, RMSENorm: 0.26417/0.26084 on test set with deviation of 40.69%
# Epoch -167 calculated in 24.33 s
# Epoch 167, RMSENorm: 0.26196/0.26084 on test set with deviation of 39.67%
# Epoch -168 calculated in 24.30 s
# Epoch 168, RMSENorm: 0.2638/0.26084 on test set with deviation of 39.65%
# Epoch -169 calculated in 24.35 s
# Epoch 169, RMSENorm: 0.263/0.26084 on test set with deviation of 40.43%
# Epoch -170 calculated in 24.46 s
# Epoch 170, RMSENorm: 0.26338/0.26084 on test set with deviation of 39.84%
# Epoch -171 calculated in 24.43 s
# Epoch 171, RMSENorm: 0.26514/0.26084 on test set with deviation of 41.51%
# Epoch -172 calculated in 24.28 s
# Epoch 172, RMSENorm: 0.26169/0.26084 on test set with deviation of 40.48%
# Epoch -173 calculated in 24.30 s
# Epoch 173, RMSENorm: 0.27211/0.26084 on test set with deviation of 43.65%
# Epoch -174 calculated in 24.28 s
# Epoch 174, RMSENorm: 0.26409/0.26084 on test set with deviation of 39.92%
# Epoch -175 calculated in 24.11 s
# Epoch 175, RMSENorm: 0.26485/0.26084 on test set with deviation of 41.52%
# Epoch -176 calculated in 24.44 s
# Epoch 176, RMSENorm: 0.26405/0.26084 on test set with deviation of 41.50%
# Epoch -177 calculated in 24.56 s
# Epoch 177, RMSENorm: 0.26264/0.26084 on test set with deviation of 40.19%
# Epoch -178 calculated in 24.46 s
# Epoch 178, RMSENorm: 0.26384/0.26084 on test set with deviation of 40.89%
# Epoch -179 calculated in 24.19 s
# Epoch 179, RMSENorm: 0.25975/0.25975 on test set with deviation of 38.36%
# Epoch -180 calculated in 24.48 s
# Epoch 180, RMSENorm: 0.26557/0.25975 on test set with deviation of 41.70%
# Epoch -181 calculated in 24.40 s
# Epoch 181, RMSENorm: 0.26283/0.25975 on test set with deviation of 41.21%
# Epoch -182 calculated in 24.36 s
# Epoch 182, RMSENorm: 0.26337/0.25975 on test set with deviation of 41.31%
# Epoch -183 calculated in 24.45 s
# Epoch 183, RMSENorm: 0.26467/0.25975 on test set with deviation of 40.57%
# Epoch -184 calculated in 24.49 s
# Epoch 184, RMSENorm: 0.26383/0.25975 on test set with deviation of 41.49%
# Epoch -185 calculated in 24.56 s
# Epoch 185, RMSENorm: 0.26151/0.25975 on test set with deviation of 41.11%
# Epoch -186 calculated in 24.49 s
# Epoch 186, RMSENorm: 0.26406/0.25975 on test set with deviation of 41.19%
# Epoch -187 calculated in 24.45 s
# Epoch 187, RMSENorm: 0.26571/0.25975 on test set with deviation of 42.16%
# Epoch -188 calculated in 24.20 s
# Epoch 188, RMSENorm: 0.26269/0.25975 on test set with deviation of 40.88%
# Epoch -189 calculated in 24.58 s
# Epoch 189, RMSENorm: 0.26248/0.25975 on test set with deviation of 41.19%
# Epoch -190 calculated in 23.92 s
# Epoch 190, RMSENorm: 0.26341/0.25975 on test set with deviation of 41.35%
# Epoch -191 calculated in 24.59 s
# Epoch 191, RMSENorm: 0.26807/0.25975 on test set with deviation of 42.51%
# Epoch -192 calculated in 24.42 s
# Epoch 192, RMSENorm: 0.26312/0.25975 on test set with deviation of 41.20%
# Epoch -193 calculated in 24.30 s
# Epoch 193, RMSENorm: 0.26463/0.25975 on test set with deviation of 41.38%
# Epoch -194 calculated in 24.31 s
# Epoch 194, RMSENorm: 0.26322/0.25975 on test set with deviation of 41.41%
# Epoch -195 calculated in 24.36 s
# Epoch 195, RMSENorm: 0.26273/0.25975 on test set with deviation of 42.00%
# Epoch -196 calculated in 24.14 s
# Epoch 196, RMSENorm: 0.26331/0.25975 on test set with deviation of 40.16%
# Epoch -197 calculated in 24.39 s
# Epoch 197, RMSENorm: 0.262/0.25975 on test set with deviation of 40.69%
# Epoch -198 calculated in 24.24 s
# Epoch 198, RMSENorm: 0.26192/0.25975 on test set with deviation of 41.62%
# Epoch -199 calculated in 24.14 s
# Epoch 199, RMSENorm: 0.26266/0.25975 on test set with deviation of 41.40%
# Epoch -200 calculated in 24.52 s
# Epoch 200, RMSENorm: 0.26345/0.25975 on test set with deviation of 40.38%
# Epoch -201 calculated in 24.37 s
# Epoch 201, RMSENorm: 0.26332/0.25975 on test set with deviation of 42.21%
# Epoch -202 calculated in 24.45 s
# Epoch 202, RMSENorm: 0.26254/0.25975 on test set with deviation of 42.05%
# Epoch -203 calculated in 24.19 s
# Epoch 203, RMSENorm: 0.26233/0.25975 on test set with deviation of 41.05%
# Epoch -204 calculated in 24.21 s
# Epoch 204, RMSENorm: 0.26237/0.25975 on test set with deviation of 41.92%
# Epoch -205 calculated in 24.16 s
# Epoch 205, RMSENorm: 0.26428/0.25975 on test set with deviation of 41.55%
# Epoch -206 calculated in 24.44 s
# Epoch 206, RMSENorm: 0.26187/0.25975 on test set with deviation of 40.83%
# Epoch -207 calculated in 24.33 s
# Epoch 207, RMSENorm: 0.2633/0.25975 on test set with deviation of 41.46%
# Epoch -208 calculated in 24.37 s
# Epoch 208, RMSENorm: 0.26212/0.25975 on test set with deviation of 41.20%
# Epoch -209 calculated in 24.38 s
# Epoch 209, RMSENorm: 0.2624/0.25975 on test set with deviation of 41.07%
# Epoch -210 calculated in 24.55 s
# Epoch 210, RMSENorm: 0.26373/0.25975 on test set with deviation of 41.88%
# Epoch -211 calculated in 24.43 s
# Epoch 211, RMSENorm: 0.26504/0.25975 on test set with deviation of 43.05%
# Epoch -212 calculated in 24.37 s
# Epoch 212, RMSENorm: 0.26388/0.25975 on test set with deviation of 42.61%
# Epoch -213 calculated in 24.24 s
# Epoch 213, RMSENorm: 0.26243/0.25975 on test set with deviation of 41.76%
# Epoch -214 calculated in 24.52 s
# Epoch 214, RMSENorm: 0.26391/0.25975 on test set with deviation of 42.80%
# Epoch -215 calculated in 24.17 s
# Epoch 215, RMSENorm: 0.26528/0.25975 on test set with deviation of 42.76%
# Epoch -216 calculated in 24.37 s
# Epoch 216, RMSENorm: 0.26475/0.25975 on test set with deviation of 42.52%
# Epoch -217 calculated in 24.27 s
# Epoch 217, RMSENorm: 0.26493/0.25975 on test set with deviation of 41.87%
# Epoch -218 calculated in 24.41 s
# Epoch 218, RMSENorm: 0.26457/0.25975 on test set with deviation of 43.03%
# Epoch -219 calculated in 24.37 s
# Epoch 219, RMSENorm: 0.26431/0.25975 on test set with deviation of 43.07%
# Epoch -220 calculated in 24.62 s
# Epoch 220, RMSENorm: 0.26472/0.25975 on test set with deviation of 43.28%
# Epoch -221 calculated in 24.45 s
# Epoch 221, RMSENorm: 0.26553/0.25975 on test set with deviation of 43.79%
# Epoch -222 calculated in 24.22 s
# Epoch 222, RMSENorm: 0.26582/0.25975 on test set with deviation of 43.29%
# Epoch -223 calculated in 24.56 s
# Epoch 223, RMSENorm: 0.26285/0.25975 on test set with deviation of 41.99%
# Epoch -224 calculated in 24.31 s
# Epoch 224, RMSENorm: 0.26584/0.25975 on test set with deviation of 43.84%
# Epoch -225 calculated in 24.59 s
# Epoch 225, RMSENorm: 0.26506/0.25975 on test set with deviation of 44.11%
# Epoch -226 calculated in 24.47 s
# Epoch 226, RMSENorm: 0.26401/0.25975 on test set with deviation of 42.59%
# Epoch -227 calculated in 24.37 s
# Epoch 227, RMSENorm: 0.26571/0.25975 on test set with deviation of 42.21%
# Epoch -228 calculated in 24.41 s
# Epoch 228, RMSENorm: 0.2699/0.25975 on test set with deviation of 46.37%
# Epoch -229 calculated in 24.23 s
# Epoch 229, RMSENorm: 0.26552/0.25975 on test set with deviation of 43.65%
# Epoch -230 calculated in 24.52 s
# Epoch 230, RMSENorm: 0.26819/0.25975 on test set with deviation of 43.90%
# Epoch -231 calculated in 24.26 s
# Epoch 231, RMSENorm: 0.26745/0.25975 on test set with deviation of 45.01%
# Epoch -232 calculated in 24.35 s
# Epoch 232, RMSENorm: 0.26979/0.25975 on test set with deviation of 45.58%
# Epoch -233 calculated in 24.39 s
# Epoch 233, RMSENorm: 0.27209/0.25975 on test set with deviation of 45.89%
# Epoch -234 calculated in 24.53 s
# Epoch 234, RMSENorm: 0.26963/0.25975 on test set with deviation of 46.00%
# Epoch -235 calculated in 24.53 s
# Epoch 235, RMSENorm: 0.26902/0.25975 on test set with deviation of 44.96%
# Epoch -236 calculated in 24.32 s
# Epoch 236, RMSENorm: 0.27348/0.25975 on test set with deviation of 48.23%
# Epoch -237 calculated in 24.40 s
# Epoch 237, RMSENorm: 0.27032/0.25975 on test set with deviation of 46.59%
# Epoch -238 calculated in 24.57 s
# Epoch 238, RMSENorm: 0.26752/0.25975 on test set with deviation of 45.04%
# Epoch -239 calculated in 24.26 s
# Epoch 239, RMSENorm: 0.26655/0.25975 on test set with deviation of 43.30%
# Epoch -240 calculated in 24.44 s
# Epoch 240, RMSENorm: 0.26434/0.25975 on test set with deviation of 43.86%
# Epoch -241 calculated in 24.44 s
# Epoch 241, RMSENorm: 0.26726/0.25975 on test set with deviation of 44.68%
# Epoch -242 calculated in 24.68 s
# Epoch 242, RMSENorm: 0.26885/0.25975 on test set with deviation of 45.65%
# Epoch -243 calculated in 24.43 s
# Epoch 243, RMSENorm: 0.267/0.25975 on test set with deviation of 45.43%
# Epoch -244 calculated in 24.39 s
# Epoch 244, RMSENorm: 0.26926/0.25975 on test set with deviation of 44.90%
# Epoch -245 calculated in 24.66 s
# Epoch 245, RMSENorm: 0.26395/0.25975 on test set with deviation of 43.39%
# Epoch -246 calculated in 24.33 s
# Epoch 246, RMSENorm: 0.26701/0.25975 on test set with deviation of 44.33%
# Epoch -247 calculated in 24.19 s
# Epoch 247, RMSENorm: 0.26763/0.25975 on test set with deviation of 45.94%
# Epoch -248 calculated in 24.43 s
# Epoch 248, RMSENorm: 0.26548/0.25975 on test set with deviation of 43.22%
# Epoch -249 calculated in 24.33 s
# Epoch 249, RMSENorm: 0.26552/0.25975 on test set with deviation of 44.39%
# Epoch -250 calculated in 24.35 s
# Epoch 250, RMSENorm: 0.26226/0.25975 on test set with deviation of 43.05%
# Epoch -251 calculated in 24.51 s
# Epoch 251, RMSENorm: 0.26756/0.25975 on test set with deviation of 45.63%
# Epoch -252 calculated in 24.57 s
# Epoch 252, RMSENorm: 0.2646/0.25975 on test set with deviation of 42.99%
# Epoch -253 calculated in 24.43 s
# Epoch 253, RMSENorm: 0.26612/0.25975 on test set with deviation of 44.94%
# Epoch -254 calculated in 24.14 s
# Epoch 254, RMSENorm: 0.26543/0.25975 on test set with deviation of 43.56%
# Epoch -255 calculated in 23.98 s
# Epoch 255, RMSENorm: 0.26786/0.25975 on test set with deviation of 45.53%
# Epoch -256 calculated in 24.24 s
# Epoch 256, RMSENorm: 0.26429/0.25975 on test set with deviation of 43.87%
# Epoch -257 calculated in 24.37 s
# Epoch 257, RMSENorm: 0.26449/0.25975 on test set with deviation of 44.54%
# Epoch -258 calculated in 24.50 s
# Epoch 258, RMSENorm: 0.2664/0.25975 on test set with deviation of 44.66%
# Epoch -259 calculated in 24.40 s
# Epoch 259, RMSENorm: 0.26433/0.25975 on test set with deviation of 42.40%
# Epoch -260 calculated in 24.39 s
# Epoch 260, RMSENorm: 0.2654/0.25975 on test set with deviation of 44.11%
# Epoch -261 calculated in 24.16 s
# Epoch 261, RMSENorm: 0.27006/0.25975 on test set with deviation of 46.27%
# Epoch -262 calculated in 24.36 s
# Epoch 262, RMSENorm: 0.26962/0.25975 on test set with deviation of 46.17%
# Epoch -263 calculated in 24.16 s
# Epoch 263, RMSENorm: 0.26763/0.25975 on test set with deviation of 45.33%
# Epoch -264 calculated in 24.21 s
# Epoch 264, RMSENorm: 0.26484/0.25975 on test set with deviation of 44.70%
# Epoch -265 calculated in 24.23 s
# Epoch 265, RMSENorm: 0.26612/0.25975 on test set with deviation of 44.15%
# Epoch -266 calculated in 24.48 s
# Epoch 266, RMSENorm: 0.26435/0.25975 on test set with deviation of 43.64%
# Epoch -267 calculated in 24.49 s
# Epoch 267, RMSENorm: 0.26492/0.25975 on test set with deviation of 43.88%
# Epoch -268 calculated in 24.25 s
# Epoch 268, RMSENorm: 0.26617/0.25975 on test set with deviation of 44.66%
# Epoch -269 calculated in 24.35 s
# Epoch 269, RMSENorm: 0.26545/0.25975 on test set with deviation of 44.37%
# Epoch -270 calculated in 24.60 s
# Epoch 270, RMSENorm: 0.26531/0.25975 on test set with deviation of 43.86%
# Epoch -271 calculated in 24.38 s
# Epoch 271, RMSENorm: 0.26595/0.25975 on test set with deviation of 45.35%
# Epoch -272 calculated in 24.20 s
# Epoch 272, RMSENorm: 0.26524/0.25975 on test set with deviation of 43.70%
# Epoch -273 calculated in 23.73 s
# Epoch 273, RMSENorm: 0.26476/0.25975 on test set with deviation of 44.13%
# Epoch -274 calculated in 24.18 s
# Epoch 274, RMSENorm: 0.26651/0.25975 on test set with deviation of 44.98%
# Epoch -275 calculated in 24.33 s
# Epoch 275, RMSENorm: 0.26586/0.25975 on test set with deviation of 45.26%
# Epoch -276 calculated in 24.31 s
# Epoch 276, RMSENorm: 0.26547/0.25975 on test set with deviation of 44.46%
# Epoch -277 calculated in 24.35 s
# Epoch 277, RMSENorm: 0.26437/0.25975 on test set with deviation of 44.40%
# Epoch -278 calculated in 24.63 s
# Epoch 278, RMSENorm: 0.26831/0.25975 on test set with deviation of 45.28%
# Epoch -279 calculated in 24.34 s
# Epoch 279, RMSENorm: 0.26528/0.25975 on test set with deviation of 43.89%
# Epoch -280 calculated in 24.33 s
# Epoch 280, RMSENorm: 0.26414/0.25975 on test set with deviation of 43.52%
# Epoch -281 calculated in 24.40 s
# Epoch 281, RMSENorm: 0.26377/0.25975 on test set with deviation of 40.94%
# Epoch -282 calculated in 24.35 s
# Epoch 282, RMSENorm: 0.2627/0.25975 on test set with deviation of 43.32%
# Epoch -283 calculated in 24.44 s
# Epoch 283, RMSENorm: 0.26425/0.25975 on test set with deviation of 44.02%
# Epoch -284 calculated in 24.27 s
# Epoch 284, RMSENorm: 0.26531/0.25975 on test set with deviation of 45.80%
# Epoch -285 calculated in 24.61 s
# Epoch 285, RMSENorm: 0.2633/0.25975 on test set with deviation of 43.53%
# Epoch -286 calculated in 24.46 s
# Epoch 286, RMSENorm: 0.26396/0.25975 on test set with deviation of 42.97%
# Epoch -287 calculated in 24.61 s
# Epoch 287, RMSENorm: 0.26352/0.25975 on test set with deviation of 43.74%
# Epoch -288 calculated in 24.23 s
# Epoch 288, RMSENorm: 0.26387/0.25975 on test set with deviation of 42.48%
# Epoch -289 calculated in 24.41 s
# Epoch 289, RMSENorm: 0.26375/0.25975 on test set with deviation of 42.23%
# Epoch -290 calculated in 24.49 s
# Epoch 290, RMSENorm: 0.26298/0.25975 on test set with deviation of 43.55%
# Epoch -291 calculated in 24.38 s
# Epoch 291, RMSENorm: 0.26307/0.25975 on test set with deviation of 43.35%
# Epoch -292 calculated in 24.44 s
# Epoch 292, RMSENorm: 0.26454/0.25975 on test set with deviation of 44.75%
# Epoch -293 calculated in 24.18 s
# Epoch 293, RMSENorm: 0.26571/0.25975 on test set with deviation of 44.08%
# Epoch -294 calculated in 24.35 s
# Epoch 294, RMSENorm: 0.26244/0.25975 on test set with deviation of 43.04%
# Epoch -295 calculated in 24.54 s
# Epoch 295, RMSENorm: 0.2631/0.25975 on test set with deviation of 44.24%
# Epoch -296 calculated in 24.35 s
# Epoch 296, RMSENorm: 0.26469/0.25975 on test set with deviation of 44.67%
# Epoch -297 calculated in 24.38 s
# Epoch 297, RMSENorm: 0.26312/0.25975 on test set with deviation of 42.65%
# Epoch -298 calculated in 24.40 s
# Epoch 298, RMSENorm: 0.26547/0.25975 on test set with deviation of 44.87%
# Epoch -299 calculated in 24.23 s
# Epoch 299, RMSENorm: 0.26568/0.25975 on test set with deviation of 45.39%
# Epoch -300 calculated in 24.61 s
# Epoch 300, RMSENorm: 0.26413/0.25975 on test set with deviation of 42.81%
# Epoch -301 calculated in 24.39 s
# Epoch 301, RMSENorm: 0.26399/0.25975 on test set with deviation of 44.19%
# Epoch -302 calculated in 24.37 s
# Epoch 302, RMSENorm: 0.26352/0.25975 on test set with deviation of 43.67%
# Epoch -303 calculated in 24.50 s
# Epoch 303, RMSENorm: 0.26378/0.25975 on test set with deviation of 43.37%
# Epoch -304 calculated in 24.48 s
# Epoch 304, RMSENorm: 0.26342/0.25975 on test set with deviation of 42.87%
# Epoch -305 calculated in 24.57 s
# Epoch 305, RMSENorm: 0.26405/0.25975 on test set with deviation of 44.29%
# Epoch -306 calculated in 24.34 s
# Epoch 306, RMSENorm: 0.26466/0.25975 on test set with deviation of 44.94%
# Epoch -307 calculated in 24.58 s
# Epoch 307, RMSENorm: 0.26457/0.25975 on test set with deviation of 44.52%
# Epoch -308 calculated in 24.56 s
# Epoch 308, RMSENorm: 0.26609/0.25975 on test set with deviation of 44.65%
# Epoch -309 calculated in 24.26 s
# Epoch 309, RMSENorm: 0.26381/0.25975 on test set with deviation of 44.20%
# Epoch -310 calculated in 24.38 s
# Epoch 310, RMSENorm: 0.26397/0.25975 on test set with deviation of 43.64%
# Epoch -311 calculated in 24.21 s
# Epoch 311, RMSENorm: 0.26251/0.25975 on test set with deviation of 43.58%
# Epoch -312 calculated in 24.45 s
# Epoch 312, RMSENorm: 0.26825/0.25975 on test set with deviation of 44.80%
# Epoch -313 calculated in 24.52 s
# Epoch 313, RMSENorm: 0.26305/0.25975 on test set with deviation of 42.84%
# Epoch -314 calculated in 24.37 s
# Epoch 314, RMSENorm: 0.26369/0.25975 on test set with deviation of 44.99%
# Epoch -315 calculated in 24.25 s
# Epoch 315, RMSENorm: 0.26418/0.25975 on test set with deviation of 44.73%
# Epoch -316 calculated in 24.45 s
# Epoch 316, RMSENorm: 0.26523/0.25975 on test set with deviation of 45.08%
# Epoch -317 calculated in 24.08 s
# Epoch 317, RMSENorm: 0.26303/0.25975 on test set with deviation of 43.86%
# Epoch -318 calculated in 24.37 s
# Epoch 318, RMSENorm: 0.26245/0.25975 on test set with deviation of 44.12%
# Epoch -319 calculated in 24.55 s
# Epoch 319, RMSENorm: 0.26253/0.25975 on test set with deviation of 44.08%
# Epoch -320 calculated in 24.40 s
# Epoch 320, RMSENorm: 0.26665/0.25975 on test set with deviation of 45.11%
# Epoch -321 calculated in 24.33 s
# Epoch 321, RMSENorm: 0.26339/0.25975 on test set with deviation of 43.93%
# Epoch -322 calculated in 24.43 s
# Epoch 322, RMSENorm: 0.26421/0.25975 on test set with deviation of 44.52%
# Epoch -323 calculated in 24.53 s
# Epoch 323, RMSENorm: 0.26389/0.25975 on test set with deviation of 45.87%
# Epoch -324 calculated in 24.33 s
# Epoch 324, RMSENorm: 0.26449/0.25975 on test set with deviation of 44.38%
# Epoch -325 calculated in 24.54 s
# Epoch 325, RMSENorm: 0.26521/0.25975 on test set with deviation of 46.34%
# Epoch -326 calculated in 24.62 s
# Epoch 326, RMSENorm: 0.2655/0.25975 on test set with deviation of 45.92%
# Epoch -327 calculated in 24.38 s
# Epoch 327, RMSENorm: 0.26575/0.25975 on test set with deviation of 44.90%
# Epoch -328 calculated in 24.62 s
# Epoch 328, RMSENorm: 0.26362/0.25975 on test set with deviation of 44.37%
# Epoch -329 calculated in 24.60 s
# Epoch 329, RMSENorm: 0.26625/0.25975 on test set with deviation of 45.23%
# Epoch -330 calculated in 24.23 s
# Epoch 330, RMSENorm: 0.26723/0.25975 on test set with deviation of 47.11%
# Epoch -331 calculated in 24.41 s
# Epoch 331, RMSENorm: 0.26374/0.25975 on test set with deviation of 43.79%
# Epoch -332 calculated in 24.39 s
# Epoch 332, RMSENorm: 0.26587/0.25975 on test set with deviation of 43.65%
# Epoch -333 calculated in 24.12 s
# Epoch 333, RMSENorm: 0.26451/0.25975 on test set with deviation of 45.13%
# Epoch -334 calculated in 24.46 s
# Epoch 334, RMSENorm: 0.26527/0.25975 on test set with deviation of 46.00%
# Epoch -335 calculated in 24.37 s
# Epoch 335, RMSENorm: 0.26583/0.25975 on test set with deviation of 45.28%
# Epoch -336 calculated in 24.36 s
# Epoch 336, RMSENorm: 0.26382/0.25975 on test set with deviation of 44.58%
# Epoch -337 calculated in 24.38 s
# Epoch 337, RMSENorm: 0.26533/0.25975 on test set with deviation of 45.31%
# Epoch -338 calculated in 24.39 s
# Epoch 338, RMSENorm: 0.2643/0.25975 on test set with deviation of 45.03%
# Epoch -339 calculated in 24.18 s
# Epoch 339, RMSENorm: 0.26467/0.25975 on test set with deviation of 45.62%
# Epoch -340 calculated in 24.41 s
# Epoch 340, RMSENorm: 0.26576/0.25975 on test set with deviation of 46.66%
# Epoch -341 calculated in 24.59 s
# Epoch 341, RMSENorm: 0.26592/0.25975 on test set with deviation of 46.21%
# Epoch -342 calculated in 24.44 s
# Epoch 342, RMSENorm: 0.26352/0.25975 on test set with deviation of 44.95%
# Epoch -343 calculated in 24.40 s
# Epoch 343, RMSENorm: 0.26478/0.25975 on test set with deviation of 45.93%
# Epoch -344 calculated in 24.25 s
# Epoch 344, RMSENorm: 0.26523/0.25975 on test set with deviation of 44.44%
# Epoch -345 calculated in 24.53 s
# Epoch 345, RMSENorm: 0.26462/0.25975 on test set with deviation of 45.13%
# Epoch -346 calculated in 24.38 s
# Epoch 346, RMSENorm: 0.26468/0.25975 on test set with deviation of 44.65%
# Epoch -347 calculated in 24.36 s
# Epoch 347, RMSENorm: 0.26608/0.25975 on test set with deviation of 46.05%
# Epoch -348 calculated in 24.58 s
# Epoch 348, RMSENorm: 0.26711/0.25975 on test set with deviation of 46.20%
# Epoch -349 calculated in 24.37 s
# Epoch 349, RMSENorm: 0.26673/0.25975 on test set with deviation of 46.69%
# Epoch -350 calculated in 24.19 s
# Epoch 350, RMSENorm: 0.26665/0.25975 on test set with deviation of 45.58%
# Epoch -351 calculated in 24.39 s
# Epoch 351, RMSENorm: 0.26539/0.25975 on test set with deviation of 45.92%
# Epoch -352 calculated in 24.58 s
# Epoch 352, RMSENorm: 0.26774/0.25975 on test set with deviation of 47.11%
# Epoch -353 calculated in 24.41 s
# Epoch 353, RMSENorm: 0.26489/0.25975 on test set with deviation of 45.29%
# Epoch -354 calculated in 24.56 s
# Epoch 354, RMSENorm: 0.26534/0.25975 on test set with deviation of 45.01%
# Epoch -355 calculated in 24.13 s
# Epoch 355, RMSENorm: 0.26638/0.25975 on test set with deviation of 45.40%
# Epoch -356 calculated in 24.43 s
# Epoch 356, RMSENorm: 0.26566/0.25975 on test set with deviation of 46.27%
# Epoch -357 calculated in 23.97 s
# Epoch 357, RMSENorm: 0.26564/0.25975 on test set with deviation of 45.33%
# Epoch -358 calculated in 24.56 s
# Epoch 358, RMSENorm: 0.26479/0.25975 on test set with deviation of 45.45%
# Epoch -359 calculated in 24.41 s
# Epoch 359, RMSENorm: 0.2665/0.25975 on test set with deviation of 45.49%
# Epoch -360 calculated in 24.37 s
# Epoch 360, RMSENorm: 0.26437/0.25975 on test set with deviation of 45.73%
# Epoch -361 calculated in 24.40 s
# Epoch 361, RMSENorm: 0.26627/0.25975 on test set with deviation of 47.10%
# Epoch -362 calculated in 24.42 s
# Epoch 362, RMSENorm: 0.26583/0.25975 on test set with deviation of 46.22%
# Epoch -363 calculated in 24.35 s
# Epoch 363, RMSENorm: 0.26963/0.25975 on test set with deviation of 48.92%
# Epoch -364 calculated in 24.48 s
# Epoch 364, RMSENorm: 0.26837/0.25975 on test set with deviation of 47.80%
# Epoch -365 calculated in 24.32 s
# Epoch 365, RMSENorm: 0.26893/0.25975 on test set with deviation of 47.97%
# Epoch -366 calculated in 24.24 s
# Epoch 366, RMSENorm: 0.26938/0.25975 on test set with deviation of 48.24%
# Epoch -367 calculated in 24.37 s
# Epoch 367, RMSENorm: 0.26779/0.25975 on test set with deviation of 47.49%
# Epoch -368 calculated in 24.51 s
# Epoch 368, RMSENorm: 0.26932/0.25975 on test set with deviation of 47.27%
# Epoch -369 calculated in 24.64 s
# Epoch 369, RMSENorm: 0.26861/0.25975 on test set with deviation of 47.04%
# Epoch -370 calculated in 24.41 s
# Epoch 370, RMSENorm: 0.26613/0.25975 on test set with deviation of 46.52%
# Epoch -371 calculated in 24.16 s
# Epoch 371, RMSENorm: 0.26763/0.25975 on test set with deviation of 47.24%
# Epoch -372 calculated in 24.26 s
# Epoch 372, RMSENorm: 0.2668/0.25975 on test set with deviation of 46.42%
# Epoch -373 calculated in 24.44 s
# Epoch 373, RMSENorm: 0.26883/0.25975 on test set with deviation of 47.91%
# Epoch -374 calculated in 24.27 s
# Epoch 374, RMSENorm: 0.2687/0.25975 on test set with deviation of 48.38%
# Epoch -375 calculated in 24.56 s
# Epoch 375, RMSENorm: 0.26628/0.25975 on test set with deviation of 44.82%
# Epoch -376 calculated in 24.45 s
# Epoch 376, RMSENorm: 0.26678/0.25975 on test set with deviation of 46.76%
# Epoch -377 calculated in 24.69 s
# Epoch 377, RMSENorm: 0.26701/0.25975 on test set with deviation of 46.94%
# Epoch -378 calculated in 24.50 s
# Epoch 378, RMSENorm: 0.26738/0.25975 on test set with deviation of 46.43%
# Epoch -379 calculated in 24.38 s
# Epoch 379, RMSENorm: 0.26633/0.25975 on test set with deviation of 45.14%
# Epoch -380 calculated in 24.32 s
# Epoch 380, RMSENorm: 0.26633/0.25975 on test set with deviation of 45.42%
# Epoch -381 calculated in 24.21 s
# Epoch 381, RMSENorm: 0.26727/0.25975 on test set with deviation of 46.44%
# Epoch -382 calculated in 24.38 s
# Epoch 382, RMSENorm: 0.26798/0.25975 on test set with deviation of 47.94%
# Epoch -383 calculated in 24.25 s
# Epoch 383, RMSENorm: 0.26758/0.25975 on test set with deviation of 46.23%
# Epoch -384 calculated in 24.48 s
# Epoch 384, RMSENorm: 0.26588/0.25975 on test set with deviation of 46.57%
# Epoch -385 calculated in 24.57 s
# Epoch 385, RMSENorm: 0.26647/0.25975 on test set with deviation of 46.27%
# Epoch -386 calculated in 24.60 s
# Epoch 386, RMSENorm: 0.26554/0.25975 on test set with deviation of 45.71%
# Epoch -387 calculated in 24.30 s
# Epoch 387, RMSENorm: 0.26792/0.25975 on test set with deviation of 46.53%
# Epoch -388 calculated in 24.53 s
# Epoch 388, RMSENorm: 0.26716/0.25975 on test set with deviation of 46.63%
# Epoch -389 calculated in 24.46 s
# Epoch 389, RMSENorm: 0.26738/0.25975 on test set with deviation of 46.91%
# Epoch -390 calculated in 24.47 s
# Epoch 390, RMSENorm: 0.26388/0.25975 on test set with deviation of 44.49%
# Epoch -391 calculated in 24.21 s
# Epoch 391, RMSENorm: 0.26609/0.25975 on test set with deviation of 46.32%
# Epoch -392 calculated in 24.69 s
# Epoch 392, RMSENorm: 0.26701/0.25975 on test set with deviation of 47.07%
# Epoch -393 calculated in 24.37 s
# Epoch 393, RMSENorm: 0.26827/0.25975 on test set with deviation of 48.13%
# Epoch -394 calculated in 24.43 s
# Epoch 394, RMSENorm: 0.26527/0.25975 on test set with deviation of 45.61%
# Epoch -395 calculated in 24.32 s
# Epoch 395, RMSENorm: 0.26884/0.25975 on test set with deviation of 47.19%
# Epoch -396 calculated in 24.21 s
# Epoch 396, RMSENorm: 0.26855/0.25975 on test set with deviation of 47.00%
# Epoch -397 calculated in 24.23 s
# Epoch 397, RMSENorm: 0.26943/0.25975 on test set with deviation of 48.47%
# Epoch -398 calculated in 24.43 s
# Epoch 398, RMSENorm: 0.272/0.25975 on test set with deviation of 48.59%
# Epoch -399 calculated in 24.33 s
# Epoch 399, RMSENorm: 0.27005/0.25975 on test set with deviation of 48.95%
# Epoch -400 calculated in 24.40 s
# Epoch 400, RMSENorm: 0.26943/0.25975 on test set with deviation of 48.99%
# Epoch -401 calculated in 24.52 s
# Epoch 401, RMSENorm: 0.27244/0.25975 on test set with deviation of 49.88%
# Epoch -402 calculated in 24.38 s
# Epoch 402, RMSENorm: 0.26873/0.25975 on test set with deviation of 48.33%
# Epoch -403 calculated in 24.36 s
# Epoch 403, RMSENorm: 0.26979/0.25975 on test set with deviation of 49.00%
# Epoch -404 calculated in 24.49 s
# Epoch 404, RMSENorm: 0.27411/0.25975 on test set with deviation of 51.28%
# Epoch -405 calculated in 24.48 s
# Epoch 405, RMSENorm: 0.2699/0.25975 on test set with deviation of 46.46%
# Epoch -406 calculated in 24.55 s
# Epoch 406, RMSENorm: 0.2709/0.25975 on test set with deviation of 50.43%
# Epoch -407 calculated in 24.32 s
# Epoch 407, RMSENorm: 0.26999/0.25975 on test set with deviation of 48.16%
# Epoch -408 calculated in 24.32 s
# Epoch 408, RMSENorm: 0.27033/0.25975 on test set with deviation of 49.33%
# Epoch -409 calculated in 24.36 s
# Epoch 409, RMSENorm: 0.26992/0.25975 on test set with deviation of 49.22%
# Epoch -410 calculated in 24.39 s
# Epoch 410, RMSENorm: 0.26921/0.25975 on test set with deviation of 47.81%
# Epoch -411 calculated in 24.44 s
# Epoch 411, RMSENorm: 0.26708/0.25975 on test set with deviation of 45.67%
# Epoch -412 calculated in 24.21 s
# Epoch 412, RMSENorm: 0.27093/0.25975 on test set with deviation of 48.67%
# Epoch -413 calculated in 24.62 s
# Epoch 413, RMSENorm: 0.26933/0.25975 on test set with deviation of 48.59%
# Epoch -414 calculated in 24.40 s
# Epoch 414, RMSENorm: 0.27132/0.25975 on test set with deviation of 50.02%
# Epoch -415 calculated in 24.26 s
# Epoch 415, RMSENorm: 0.27013/0.25975 on test set with deviation of 48.76%
# Epoch -416 calculated in 24.29 s
# Epoch 416, RMSENorm: 0.26657/0.25975 on test set with deviation of 46.40%
# Epoch -417 calculated in 24.35 s
# Epoch 417, RMSENorm: 0.27053/0.25975 on test set with deviation of 49.64%
# Epoch -418 calculated in 24.54 s
# Epoch 418, RMSENorm: 0.26707/0.25975 on test set with deviation of 48.03%
# Epoch -419 calculated in 24.46 s
# Epoch 419, RMSENorm: 0.26954/0.25975 on test set with deviation of 47.68%
# Epoch -420 calculated in 24.59 s
# Epoch 420, RMSENorm: 0.26917/0.25975 on test set with deviation of 47.89%
# Epoch -421 calculated in 24.19 s
# Epoch 421, RMSENorm: 0.26952/0.25975 on test set with deviation of 48.27%
# Epoch -422 calculated in 24.42 s
# Epoch 422, RMSENorm: 0.26998/0.25975 on test set with deviation of 50.02%
# Epoch -423 calculated in 23.94 s
# Epoch 423, RMSENorm: 0.27021/0.25975 on test set with deviation of 49.02%
# Epoch -424 calculated in 24.46 s
# Epoch 424, RMSENorm: 0.27177/0.25975 on test set with deviation of 49.47%
# Epoch -425 calculated in 24.41 s
# Epoch 425, RMSENorm: 0.26933/0.25975 on test set with deviation of 48.45%
# Epoch -426 calculated in 24.23 s
# Epoch 426, RMSENorm: 0.26976/0.25975 on test set with deviation of 48.31%
# Epoch -427 calculated in 24.44 s
# Epoch 427, RMSENorm: 0.271/0.25975 on test set with deviation of 49.73%
# Epoch -428 calculated in 24.48 s
# Epoch 428, RMSENorm: 0.26909/0.25975 on test set with deviation of 47.78%
# Epoch -429 calculated in 24.52 s
# Epoch 429, RMSENorm: 0.26792/0.25975 on test set with deviation of 47.76%
# Epoch -430 calculated in 24.32 s
# Epoch 430, RMSENorm: 0.27249/0.25975 on test set with deviation of 51.28%
# Epoch -431 calculated in 24.55 s
# Epoch 431, RMSENorm: 0.27043/0.25975 on test set with deviation of 50.72%
# Epoch -432 calculated in 24.36 s
# Epoch 432, RMSENorm: 0.27022/0.25975 on test set with deviation of 48.91%
# Epoch -433 calculated in 24.36 s
# Epoch 433, RMSENorm: 0.27211/0.25975 on test set with deviation of 51.07%
# Epoch -434 calculated in 24.44 s
# Epoch 434, RMSENorm: 0.26968/0.25975 on test set with deviation of 49.47%
# Epoch -435 calculated in 24.58 s
# Epoch 435, RMSENorm: 0.27026/0.25975 on test set with deviation of 50.11%
# Epoch -436 calculated in 24.15 s
# Epoch 436, RMSENorm: 0.27143/0.25975 on test set with deviation of 48.71%
# Epoch -437 calculated in 24.27 s
# Epoch 437, RMSENorm: 0.26885/0.25975 on test set with deviation of 48.83%
# Epoch -438 calculated in 24.24 s
# Epoch 438, RMSENorm: 0.2676/0.25975 on test set with deviation of 48.01%
# Epoch -439 calculated in 24.69 s
# Epoch 439, RMSENorm: 0.27174/0.25975 on test set with deviation of 49.77%
# Epoch -440 calculated in 24.43 s
# Epoch 440, RMSENorm: 0.27098/0.25975 on test set with deviation of 48.20%
# Epoch -441 calculated in 24.35 s
# Epoch 441, RMSENorm: 0.26724/0.25975 on test set with deviation of 47.30%
# Epoch -442 calculated in 24.19 s
# ...
# Epoch 487, RMSENorm: 0.26653/0.25975 on test set with deviation of 47.97%
# Epoch -488 calculated in 24.60 s
# Epoch 488, RMSENorm: 0.26788/0.25975 on test set with deviation of 49.31%
# Epoch -489 calculated in 24.41 s
# Epoch 489, RMSENorm: 0.26956/0.25975 on test set with deviation of 48.44%
# Epoch -490 calculated in 24.37 s
# Epoch 490, RMSENorm: 0.26743/0.25975 on test set with deviation of 48.37%
# Epoch -491 calculated in 24.33 s
# Epoch 491, RMSENorm: 0.26865/0.25975 on test set with deviation of 50.24%
# Epoch -492 calculated in 24.51 s
# Epoch 492, RMSENorm: 0.26908/0.25975 on test set with deviation of 48.97%
# Epoch -493 calculated in 24.29 s
# Epoch 493, RMSENorm: 0.2682/0.25975 on test set with deviation of 49.58%
# Epoch -494 calculated in 24.42 s
# Epoch 494, RMSENorm: 0.26716/0.25975 on test set with deviation of 46.89%
# Epoch -495 calculated in 24.37 s
# Epoch 495, RMSENorm: 0.26777/0.25975 on test set with deviation of 48.46%
# Epoch -496 calculated in 24.35 s
# Epoch 496, RMSENorm: 0.26687/0.25975 on test set with deviation of 49.09%
# Epoch -497 calculated in 24.17 s
# Epoch 497, RMSENorm: 0.26894/0.25975 on test set with deviation of 49.68%
# Epoch -498 calculated in 24.44 s
# Epoch 498, RMSENorm: 0.26837/0.25975 on test set with deviation of 48.56%
# Epoch -499 calculated in 24.47 s
# Epoch 499, RMSENorm: 0.27012/0.25975 on test set with deviation of 50.15%
# Epoch -500 calculated in 24.50 s
# Epoch 500, RMSENorm: 0.26755/0.25975 on test set with deviation of 48.23%
# Epoch -501 calculated in 24.31 s
# Epoch 501, RMSENorm: 0.26982/0.25975 on test set with deviation of 48.10%
# Epoch -502 calculated in 24.51 s
# Epoch 502, RMSENorm: 0.269/0.25975 on test set with deviation of 48.36%
# Epoch -503 calculated in 24.41 s
# Epoch 503, RMSENorm: 0.26685/0.25975 on test set with deviation of 48.43%
# Epoch -504 calculated in 24.40 s
# Epoch 504, RMSENorm: 0.26755/0.25975 on test set with deviation of 49.03%
# Epoch -505 calculated in 24.33 s
# Epoch 505, RMSENorm: 0.26908/0.25975 on test set with deviation of 49.15%
# Epoch -506 calculated in 24.23 s
# Epoch 506, RMSENorm: 0.26603/0.25975 on test set with deviation of 44.74%
# Epoch -507 calculated in 24.52 s
# Epoch 507, RMSENorm: 0.26744/0.25975 on test set with deviation of 48.71%
# Epoch -508 calculated in 24.34 s
# Epoch 508, RMSENorm: 0.26675/0.25975 on test set with deviation of 47.04%
# Epoch -509 calculated in 24.48 s
# Epoch 509, RMSENorm: 0.26957/0.25975 on test set with deviation of 49.84%
# Epoch -510 calculated in 24.39 s
# Epoch 510, RMSENorm: 0.26795/0.25975 on test set with deviation of 48.37%
# Epoch -511 calculated in 24.47 s
# Epoch 511, RMSENorm: 0.2691/0.25975 on test set with deviation of 50.25%
# Epoch -512 calculated in 24.34 s
# Epoch 512, RMSENorm: 0.26566/0.25975 on test set with deviation of 47.95%
# Epoch -513 calculated in 24.48 s
# Epoch 513, RMSENorm: 0.26998/0.25975 on test set with deviation of 49.75%
# Epoch -514 calculated in 24.21 s
# Epoch 514, RMSENorm: 0.2672/0.25975 on test set with deviation of 48.33%
# Epoch -515 calculated in 24.41 s
# Epoch 515, RMSENorm: 0.26889/0.25975 on test set with deviation of 49.43%
# Epoch -516 calculated in 24.62 s
# Epoch 516, RMSENorm: 0.2675/0.25975 on test set with deviation of 47.77%
# Epoch -517 calculated in 24.37 s
# Epoch 517, RMSENorm: 0.26662/0.25975 on test set with deviation of 48.09%
# Epoch -518 calculated in 24.39 s
# Epoch 518, RMSENorm: 0.26929/0.25975 on test set with deviation of 49.03%
# Epoch -519 calculated in 24.41 s
# Epoch 519, RMSENorm: 0.27168/0.25975 on test set with deviation of 51.57%
# Epoch -520 calculated in 24.54 s
# Epoch 520, RMSENorm: 0.26883/0.25975 on test set with deviation of 48.84%
# Epoch -521 calculated in 24.37 s
# Epoch 521, RMSENorm: 0.26839/0.25975 on test set with deviation of 46.96%
# Epoch -522 calculated in 24.21 s
# Epoch 522, RMSENorm: 0.26816/0.25975 on test set with deviation of 47.99%
# Epoch -523 calculated in 24.54 s
# Epoch 523, RMSENorm: 0.26939/0.25975 on test set with deviation of 49.37%
# Epoch -524 calculated in 24.18 s
# Epoch 524, RMSENorm: 0.26833/0.25975 on test set with deviation of 49.28%
# Epoch -525 calculated in 24.37 s
# Epoch 525, RMSENorm: 0.26999/0.25975 on test set with deviation of 50.54%
# Epoch -526 calculated in 24.58 s
# Epoch 526, RMSENorm: 0.26977/0.25975 on test set with deviation of 50.42%
# Epoch -527 calculated in 24.38 s
# Epoch 527, RMSENorm: 0.26964/0.25975 on test set with deviation of 50.15%
# Epoch -528 calculated in 24.28 s
# Epoch 528, RMSENorm: 0.26911/0.25975 on test set with deviation of 48.30%
# Epoch -529 calculated in 24.39 s
# Epoch 529, RMSENorm: 0.27231/0.25975 on test set with deviation of 49.39%
# Epoch -530 calculated in 24.53 s
# Epoch 530, RMSENorm: 0.26624/0.25975 on test set with deviation of 47.31%
# Epoch -531 calculated in 24.26 s
# Epoch 531, RMSENorm: 0.26849/0.25975 on test set with deviation of 49.07%
# Epoch -532 calculated in 24.53 s
# Epoch 532, RMSENorm: 0.27376/0.25975 on test set with deviation of 52.97%
# Epoch -533 calculated in 24.49 s
# Epoch 533, RMSENorm: 0.27168/0.25975 on test set with deviation of 51.77%
# Epoch -534 calculated in 24.38 s
# Epoch 534, RMSENorm: 0.26963/0.25975 on test set with deviation of 50.50%
# Epoch -535 calculated in 24.37 s
# Epoch 535, RMSENorm: 0.26711/0.25975 on test set with deviation of 48.12%
# Epoch -536 calculated in 24.30 s
# Epoch 536, RMSENorm: 0.26969/0.25975 on test set with deviation of 50.19%
# Epoch -537 calculated in 24.54 s
# Epoch 537, RMSENorm: 0.27182/0.25975 on test set with deviation of 51.18%
# Epoch -538 calculated in 24.49 s
# Epoch 538, RMSENorm: 0.27091/0.25975 on test set with deviation of 51.20%
# Epoch -539 calculated in 24.49 s
# Epoch 539, RMSENorm: 0.27084/0.25975 on test set with deviation of 51.65%
# Epoch -540 calculated in 24.47 s
# Epoch 540, RMSENorm: 0.27121/0.25975 on test set with deviation of 50.53%
# Epoch -541 calculated in 24.31 s
# Epoch 541, RMSENorm: 0.26939/0.25975 on test set with deviation of 47.47%
# Epoch -542 calculated in 24.47 s
# Epoch 542, RMSENorm: 0.27019/0.25975 on test set with deviation of 50.56%
# Epoch -543 calculated in 24.39 s
# Epoch 543, RMSENorm: 0.26916/0.25975 on test set with deviation of 49.09%
# Epoch -544 calculated in 24.34 s
# Epoch 544, RMSENorm: 0.26734/0.25975 on test set with deviation of 48.27%
# Epoch -545 calculated in 24.57 s
# Epoch 545, RMSENorm: 0.26914/0.25975 on test set with deviation of 49.71%
# Epoch -546 calculated in 24.35 s
# Epoch 546, RMSENorm: 0.27272/0.25975 on test set with deviation of 50.27%
# Epoch -547 calculated in 24.26 s
# Epoch 547, RMSENorm: 0.27058/0.25975 on test set with deviation of 50.13%
# Epoch -548 calculated in 24.39 s
# Epoch 548, RMSENorm: 0.27101/0.25975 on test set with deviation of 49.28%
# Epoch -549 calculated in 24.57 s
# Epoch 549, RMSENorm: 0.27363/0.25975 on test set with deviation of 51.73%
# Epoch -550 calculated in 24.41 s
# Epoch 550, RMSENorm: 0.27349/0.25975 on test set with deviation of 52.20%
# Epoch -551 calculated in 24.11 s
# Epoch 551, RMSENorm: 0.27201/0.25975 on test set with deviation of 50.40%
# Epoch -552 calculated in 24.29 s
# Epoch 552, RMSENorm: 0.27381/0.25975 on test set with deviation of 52.67%
# Epoch -553 calculated in 24.29 s
# Epoch 553, RMSENorm: 0.2715/0.25975 on test set with deviation of 51.31%
# Epoch -554 calculated in 24.53 s
# Epoch 554, RMSENorm: 0.27196/0.25975 on test set with deviation of 49.63%
# Epoch -555 calculated in 24.30 s
# Epoch 555, RMSENorm: 0.27045/0.25975 on test set with deviation of 50.37%
# Epoch -556 calculated in 24.19 s
# Epoch 556, RMSENorm: 0.26802/0.25975 on test set with deviation of 48.30%
# Epoch -557 calculated in 24.64 s
# Epoch 557, RMSENorm: 0.26979/0.25975 on test set with deviation of 49.77%
# Epoch -558 calculated in 24.30 s
# Epoch 558, RMSENorm: 0.26993/0.25975 on test set with deviation of 50.39%
# Epoch -559 calculated in 24.25 s
# Epoch 559, RMSENorm: 0.27105/0.25975 on test set with deviation of 50.55%
# Epoch -560 calculated in 24.22 s
# Epoch 560, RMSENorm: 0.2688/0.25975 on test set with deviation of 48.72%
# Epoch -561 calculated in 24.20 s
# Epoch 561, RMSENorm: 0.27027/0.25975 on test set with deviation of 50.20%
# Epoch -562 calculated in 24.32 s
# Epoch 562, RMSENorm: 0.26909/0.25975 on test set with deviation of 50.30%
# Epoch -563 calculated in 24.13 s
# Epoch 563, RMSENorm: 0.27107/0.25975 on test set with deviation of 50.91%
# Epoch -564 calculated in 24.21 s
# Epoch 564, RMSENorm: 0.27135/0.25975 on test set with deviation of 51.19%
# Epoch -565 calculated in 24.46 s
# Epoch 565, RMSENorm: 0.26874/0.25975 on test set with deviation of 49.62%
# Epoch -566 calculated in 24.46 s
# Epoch 566, RMSENorm: 0.2692/0.25975 on test set with deviation of 48.36%
# Epoch -567 calculated in 24.68 s
# Epoch 567, RMSENorm: 0.26848/0.25975 on test set with deviation of 48.43%
# Epoch -568 calculated in 24.33 s
# Epoch 568, RMSENorm: 0.27104/0.25975 on test set with deviation of 47.99%
# Epoch -569 calculated in 24.44 s
# Epoch 569, RMSENorm: 0.2693/0.25975 on test set with deviation of 49.93%
# Epoch -570 calculated in 24.50 s
# Epoch 570, RMSENorm: 0.27106/0.25975 on test set with deviation of 50.43%
# Epoch -571 calculated in 24.51 s
# Epoch 571, RMSENorm: 0.27047/0.25975 on test set with deviation of 50.41%
# Epoch -572 calculated in 24.24 s
# Epoch 572, RMSENorm: 0.26997/0.25975 on test set with deviation of 50.68%
# Epoch -573 calculated in 24.38 s
# Epoch 573, RMSENorm: 0.26906/0.25975 on test set with deviation of 50.55%
# Epoch -574 calculated in 24.51 s
# Epoch 574, RMSENorm: 0.26973/0.25975 on test set with deviation of 49.22%
# Epoch -575 calculated in 24.48 s
# Epoch 575, RMSENorm: 0.27106/0.25975 on test set with deviation of 50.36%
# Epoch -576 calculated in 24.41 s
# Epoch 576, RMSENorm: 0.26763/0.25975 on test set with deviation of 49.22%
# Epoch -577 calculated in 24.33 s
# Epoch 577, RMSENorm: 0.26955/0.25975 on test set with deviation of 50.17%
# Epoch -578 calculated in 24.48 s
# Epoch 578, RMSENorm: 0.26813/0.25975 on test set with deviation of 49.40%
# Epoch -579 calculated in 24.48 s
# Epoch 579, RMSENorm: 0.26775/0.25975 on test set with deviation of 49.39%
# Epoch -580 calculated in 24.59 s
# Epoch 580, RMSENorm: 0.27023/0.25975 on test set with deviation of 51.01%
# Epoch -581 calculated in 24.39 s
# Epoch 581, RMSENorm: 0.26885/0.25975 on test set with deviation of 48.97%
# Epoch -582 calculated in 24.54 s
# Epoch 582, RMSENorm: 0.26893/0.25975 on test set with deviation of 48.82%
# Epoch -583 calculated in 24.42 s
# Epoch 583, RMSENorm: 0.26925/0.25975 on test set with deviation of 50.36%
# Epoch -584 calculated in 24.42 s
# Epoch 584, RMSENorm: 0.26914/0.25975 on test set with deviation of 50.11%
# Epoch -585 calculated in 24.30 s
# Epoch 585, RMSENorm: 0.27237/0.25975 on test set with deviation of 50.47%
# Epoch -586 calculated in 24.39 s
# Epoch 586, RMSENorm: 0.26919/0.25975 on test set with deviation of 50.25%
# Epoch -587 calculated in 24.48 s
# Epoch 587, RMSENorm: 0.2695/0.25975 on test set with deviation of 50.60%
# Epoch -588 calculated in 24.43 s
# Epoch 588, RMSENorm: 0.26936/0.25975 on test set with deviation of 50.75%
# Epoch -589 calculated in 24.51 s
# Epoch 589, RMSENorm: 0.26955/0.25975 on test set with deviation of 49.94%
# Epoch -590 calculated in 24.29 s
# Epoch 590, RMSENorm: 0.26708/0.25975 on test set with deviation of 47.45%
# Epoch -591 calculated in 24.26 s
# Epoch 591, RMSENorm: 0.26849/0.25975 on test set with deviation of 48.51%
# Epoch -592 calculated in 24.48 s
# Epoch 592, RMSENorm: 0.26701/0.25975 on test set with deviation of 47.94%
# Epoch -593 calculated in 24.35 s
# Epoch 593, RMSENorm: 0.27059/0.25975 on test set with deviation of 50.12%
# Epoch -594 calculated in 24.33 s
# Epoch 594, RMSENorm: 0.26972/0.25975 on test set with deviation of 48.69%
# Epoch -595 calculated in 24.45 s
# Epoch 595, RMSENorm: 0.2705/0.25975 on test set with deviation of 49.82%
# Epoch -596 calculated in 24.50 s
# Epoch 596, RMSENorm: 0.26708/0.25975 on test set with deviation of 48.37%
# Epoch -597 calculated in 24.49 s
# Epoch 597, RMSENorm: 0.26809/0.25975 on test set with deviation of 50.20%
# Epoch -598 calculated in 24.47 s
# Epoch 598, RMSENorm: 0.27065/0.25975 on test set with deviation of 50.65%
# Epoch -599 calculated in 24.44 s
# Epoch 599, RMSENorm: 0.26731/0.25975 on test set with deviation of 47.94%
# Epoch -600 calculated in 24.59 s
# Epoch 600, RMSENorm: 0.26616/0.25975 on test set with deviation of 45.06%
# Epoch -601 calculated in 24.32 s
# Epoch 601, RMSENorm: 0.26793/0.25975 on test set with deviation of 49.93%
# Epoch -602 calculated in 24.39 s
# Epoch 602, RMSENorm: 0.26855/0.25975 on test set with deviation of 47.32%
# Epoch -603 calculated in 24.33 s
# Epoch 603, RMSENorm: 0.26692/0.25975 on test set with deviation of 47.07%
# Epoch -604 calculated in 24.58 s
# Epoch 604, RMSENorm: 0.27093/0.25975 on test set with deviation of 50.78%
# Epoch -605 calculated in 24.32 s
# Epoch 605, RMSENorm: 0.27013/0.25975 on test set with deviation of 49.93%
# Epoch -606 calculated in 24.46 s
# Epoch 606, RMSENorm: 0.26717/0.25975 on test set with deviation of 47.40%
# Epoch -607 calculated in 24.48 s
# Epoch 607, RMSENorm: 0.26833/0.25975 on test set with deviation of 48.28%
# Epoch -608 calculated in 24.48 s
# Epoch 608, RMSENorm: 0.26743/0.25975 on test set with deviation of 49.08%
# Epoch -609 calculated in 24.39 s
# Epoch 609, RMSENorm: 0.26943/0.25975 on test set with deviation of 50.38%
# Epoch -610 calculated in 24.25 s
# Epoch 610, RMSENorm: 0.26944/0.25975 on test set with deviation of 50.65%
# Epoch -611 calculated in 24.35 s
# Epoch 611, RMSENorm: 0.27163/0.25975 on test set with deviation of 51.24%
# Epoch -612 calculated in 24.39 s
# Epoch 612, RMSENorm: 0.26953/0.25975 on test set with deviation of 50.88%
# Epoch -613 calculated in 24.37 s
# Epoch 613, RMSENorm: 0.2711/0.25975 on test set with deviation of 51.08%
# Epoch -614 calculated in 23.88 s
# Epoch 614, RMSENorm: 0.2709/0.25975 on test set with deviation of 50.84%
# Epoch -615 calculated in 24.36 s
# Epoch 615, RMSENorm: 0.26967/0.25975 on test set with deviation of 50.33%
# Epoch -616 calculated in 24.45 s
# Epoch 616, RMSENorm: 0.27027/0.25975 on test set with deviation of 50.08%
# Epoch -617 calculated in 24.32 s
# Epoch 617, RMSENorm: 0.26997/0.25975 on test set with deviation of 50.03%
# Epoch -618 calculated in 24.26 s
# Epoch 618, RMSENorm: 0.27004/0.25975 on test set with deviation of 50.01%
# Epoch -619 calculated in 24.24 s
# Epoch 619, RMSENorm: 0.2728/0.25975 on test set with deviation of 52.57%
# Epoch -620 calculated in 24.27 s
# Epoch 620, RMSENorm: 0.27125/0.25975 on test set with deviation of 51.07%
# Epoch -621 calculated in 24.36 s
# Epoch 621, RMSENorm: 0.26856/0.25975 on test set with deviation of 49.20%
# Epoch -622 calculated in 24.25 s
# Epoch 622, RMSENorm: 0.2707/0.25975 on test set with deviation of 50.54%
# Epoch -623 calculated in 24.38 s
# Epoch 623, RMSENorm: 0.27031/0.25975 on test set with deviation of 50.67%
# Epoch -624 calculated in 24.26 s
# Epoch 624, RMSENorm: 0.27224/0.25975 on test set with deviation of 52.61%
# Epoch -625 calculated in 24.39 s
# Epoch 625, RMSENorm: 0.2708/0.25975 on test set with deviation of 51.15%
# Epoch -626 calculated in 24.35 s
# Epoch 626, RMSENorm: 0.27211/0.25975 on test set with deviation of 51.00%
# Epoch -627 calculated in 24.61 s
# Epoch 627, RMSENorm: 0.27031/0.25975 on test set with deviation of 49.52%
# Epoch -628 calculated in 24.36 s
# Epoch 628, RMSENorm: 0.26947/0.25975 on test set with deviation of 50.46%
# Epoch -629 calculated in 24.40 s
# Epoch 629, RMSENorm: 0.27319/0.25975 on test set with deviation of 53.28%
# Epoch -630 calculated in 24.37 s
# Epoch 630, RMSENorm: 0.26943/0.25975 on test set with deviation of 49.36%
# Epoch -631 calculated in 24.43 s
# Epoch 631, RMSENorm: 0.26955/0.25975 on test set with deviation of 49.34%
# Training duration 01:05:00:13
# Number of training variable 69691
# INFO:tensorflow:Restoring parameters from Experiments/2019-01-06-18-52/temp/myFinalModel.ckpt
# INFO:tensorflow:Froze 8 variables.
# INFO:tensorflow:Converted 8 variables to const ops.
# INFO:tensorflow:Restoring parameters from Experiments/2019-01-06-18-52/temp/myBestModel.ckpt
# done, good job kids

# %%
from show import *
# %matplotlib notebook
showPickle(nameFigEstimation)
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
