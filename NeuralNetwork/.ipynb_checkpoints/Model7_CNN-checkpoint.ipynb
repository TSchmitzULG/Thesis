# %% [markdown]
# # Learn CNN

# %% [markdown]
# CNN_model7 uses 2 convolutional layers .
# Dataset can be downloaded in http://www.montefiore.ulg.ac.be/services/acous/STSI/downloads.php

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
import os
import sys
sys.path.append('Codes')
import tensorflow as tf
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import pickle
from dataShaping import *
from savePerf import *
from saveTransformedGraph import optimizeGraph
import scipy.io.wavfile
import time
from tensorflow.contrib.layers import fully_connected
from tensorflow.contrib.rnn import *


modelName = "CNN1"
# create directory experiment
date = time.strftime("%Y-%m-%d-%H-%M")
path = os.path.join("Experiments",date)
if not os.path.isdir(path):
    os.makedirs(path)
    #experiment/"date"/temp will contain the backuped model parameters
    pathTemp = os.path.join(path,'temp')
    os.makedirs(pathTemp)
    # if you run the file two time in a minute
else :
    date = date+'(2)'
    path = os.path.join("Experiments",date)
    os.makedirs(path)
    pathTemp = os.path.join(path,'temp')
    os.makedirs(pathTemp)

# directory that will contain tensorboard information
pathLog = 'Tf_logs'
if not os.path.isdir(pathLog):
    os.makedirs(pathLog)
pathLog = "{}/run-{}/".format(pathLog,date)

version = tf.__version__
print ("version {} of tensorflow".format(version))

#############################
# Model parameters
#############################
trainTestRatio = 0.8
#if you cannot load all the data set in Ram specify wich part you want to load (0 means all the dataset)
maxSize = 0
num_step = 150                                       # time step before reduction
conv_chan = [35 , 70]                                # number of kernels for convolution
conv_strides = 3                                     # delay between two convolution
conv_size = 12                                       # filter size for the convolution
size_poll = 4
reg_scale = 0
l1l2Prop = 0.4  
reg_scale_l1 = l1l2Prop*reg_scale
reg_scale_l2 = ((1-l1l2Prop)/2)*reg_scale
num_hidden = 1000                                    # num of hidden units
num_class = 1                                        # size of the output
num_feature = 1                                      # size of the input
batch_size = 1000                                    # number of sequence taken before to compute the gradient
n_layer = 2                                          

#num_hidden = num_hidden/keep_prob
num_epoch = 10000                                    # process all the datas num_epoch times
trainDuration = 60*60*15                              # or during a determined duration(second)
amplifierName = 'EnglDisto'
fileNameTrain = 'Datasets/training'+amplifierName+'.mat'             #dataset train/test path
fileNameTest = 'Datasets/test'+amplifierName+'.mat' # dataset validation path
fileNameValidation = 'Datasets/val'+amplifierName+'.mat'

#############################
# Loading data
#############################
matrix = sio.loadmat(fileNameTrain)
matrixTrain = matrix['train']
matrix = sio.loadmat(fileNameTest)
matrixTest = matrix['test']
if maxSize ==0:
    maxSize = len(matrixTrain)
    print("maxSize = {}".format(maxSize))

train_input,train_output,test_input,test_output = loadInputOutputSeq(matrixTrain,matrixTest,num_step,maxSize)

print("shape input train {}".format(np.shape(train_input)))
numTrain = len(train_output)
print ("Data loaded")

#######################
# Graph Construction
#######################

G = tf.Graph()
with G.as_default():
    with tf.name_scope("placeHolder"):
        data = tf.placeholder(tf.float32, [None, num_step], name ="data")
        target = tf.placeholder(tf.float32, [None, num_class],name = "target") 
     
    dataShaped = tf.reshape(data,[tf.shape(data)[0],num_step,1,1])
    dataShaped = tf.transpose(dataShaped,[0,3,1,2]) 
    
    with tf.variable_scope("ConvLayers"):
        regularizerC1 = tf.contrib.layers.l1_l2_regularizer(scale_l1=reg_scale_l1,scale_l2=reg_scale_l2,scope="regC1")
        conv1 = tf.layers.conv2d(inputs = dataShaped,filters = conv_chan[0],
                                       kernel_size = (conv_size,1),strides=(3,1),
                                       padding = "same",activation=tf.nn.relu,kernel_regularizer=regularizerC1,
                                       data_format='channels_first',name="conv1")
        
        # pool1
        pool1 = tf.nn.max_pool(conv1, ksize=[1, 1, 3, 1], strides=[1, 1, 2, 1],data_format='NCHW',padding='SAME', name='pool1')  
        regularizerC2 = tf.contrib.layers.l1_l2_regularizer(scale_l1=reg_scale_l1,scale_l2=reg_scale_l2,scope="regC2")
        conv2 = tf.layers.conv2d(inputs = pool1,filters = conv_chan[1],
                                       kernel_size = (conv_size/2,1),strides=(1,1),
                                       padding = "same",activation=tf.nn.relu,kernel_regularizer=regularizerC1,
                                       data_format='channels_first',name="conv2")
        

        # pool2
        pool2 = tf.nn.max_pool(conv2, ksize=[1, 1, 3, 1], strides=[1, 1, 2, 1],data_format='NCHW',padding='SAME', name='pool2')
        
    # reshape pool 2 cnn to make a fully connected layer entry
    dataShape = int(np.prod(pool2.get_shape()[1:]))
    dataReshaped = tf.reshape(pool2, [-1, dataShape])
    FC1 = fully_connected(dataReshaped,1000,activation_fn=tf.nn.relu,weights_regularizer=None,scope="FC1")

    intermediate = FC1
    prediction = fully_connected(FC1,int(target.get_shape()[1]),activation_fn=tf.nn.tanh,weights_regularizer=None,scope="FCPred")

    #Compute the mean square error
    MSE = tf.reduce_mean(tf.square(prediction-target))
    EnergyTarget = tf.reduce_mean(tf.square(target)) 
    
    #get regularizer
    reg_losses = tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES)
    MSEReg = tf.add_n([MSE]+reg_losses,name="MSEReg")
    # create optimizer
    optimizer = tf.train.AdamOptimizer()
    #Compute gradient and apply backpropagation
    minimize = optimizer.minimize(MSEReg)

    # Create summary view for tensorboard
    mse_summary = tf.summary.scalar('RMSE',tf.sqrt(MSE))
    
    summary_op = tf.summary.merge_all()
    
    #Create an init op to initialize variable
    init_op = tf.global_variables_initializer()
    saver = tf.train.Saver() 
    
##############################
# Graph execution
##############################
    
with tf.Session(graph=G) as sess:

    sess.run(init_op)
    train_writer = tf.summary.FileWriter(pathLog+'train',graph =tf.get_default_graph())
    test_writer = tf.summary.FileWriter(pathLog+'test')
    
    no_of_batches = int(np.floor((numTrain)/batch_size)) 
    no_of_batchesTest = int(np.floor((len(test_input))/batch_size))
    tStart = time.clock()
    epoch =0
    NRMSETest = 10
    bestNRMSETest = 1    
    # train until the number of epochs or the training time is reached
    for epoch in range(num_epoch):
        tEpoch = time.clock()
        if (time.clock()-tStart < trainDuration) :
            ptr = 0
            if epoch % 20==0 : # each twenty epochs save the model
                tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myGraph.pb',as_text=False)
                save_path = saver.save(sess,os.path.join(pathTemp,'myModel.ckpt'))
            
            pMSETrain=0
            pEnergyTarget=0
            for j in range(no_of_batches):
                inp, out = train_input[ptr:ptr+batch_size],train_output[ptr:ptr+batch_size]
                ptr+=batch_size
                
                if j % np.floor(numTrain/len(test_input)) ==0 : # This is to have a train summary and a test summary of the same size
                    _,summary_str,pMSETrainTemp,pEnergyTargetTemp = sess.run([minimize,summary_op,MSE,EnergyTarget],{data: inp, target: out})
                    pMSETrain += pMSETrainTemp
                    pEnergyTarget += pEnergyTargetTemp
                    step = epoch*no_of_batches+j
                    # save the training RMSE for tensorboard
                    train_writer.add_summary(summary_str,step)                   

                else :
                    _,pMSETrainTemp,pEnergyTargetTemp = sess.run([minimize,MSE,EnergyTarget],{data: inp, target: out})
                    pMSETrain += pMSETrainTemp
                    pEnergyTarget += pEnergyTargetTemp
            # compute an estimation of the RMSE for this epoch       
            MSETrain = pMSETrain/no_of_batches
            EnergyTargetTrain = pEnergyTarget/no_of_batches
            NRMSETrain = np.sqrt(MSETrain/EnergyTargetTrain)
            print ("Epoch -{} calculated in {:5.2f} s ".format(epoch,time.clock()-tEpoch))
            
            # evaluate the model on the test set 
            pMSE = 0
            ptr2 = 0
            pEnergyTarget = 0
            for k in range(no_of_batchesTest):
                pMSETemp,pEnergyTargetTemp,summary_str = sess.run([MSE,EnergyTarget,summary_op],{data: test_input[ptr2:ptr2+batch_size] , target: test_output[ptr2:ptr2+batch_size]})
                pMSE += pMSETemp
                ptr2 += batch_size
                pEnergyTarget+=pEnergyTargetTemp
                step = epoch*no_of_batchesTest+k
                test_writer.add_summary(summary_str,step*np.floor(numTrain/len(test_input)))
            MSETest = pMSE/no_of_batchesTest
            EnergyTargetTest = pEnergyTarget/no_of_batchesTest
            NRMSETest = np.sqrt(MSETest/EnergyTargetTest)
            if NRMSETest<bestNRMSETest:
                bestNRMSETest=NRMSETest
                tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myBestGraph.pbtxt',as_text=True)
                save_path = saver.save(sess,os.path.join(pathTemp,'myBestModel.ckpt'))
            print("Epoch {}, NRMSE Test/best: {:.5f}/{:.5f}, Training NRMSE: {:.5f}, deviation of {:.2f}%".format(epoch,NRMSETest,bestNRMSETest,NRMSETrain,100*np.sqrt((NRMSETrain-NRMSETest)**2)/NRMSETrain))
        else : break # break the while loop if number of epoch is reached
    tStop = time.clock()
    trainTime = time.strftime("%d:%H:%M:%S ", time.gmtime(tStop-tStart))
   
    ################################################################
    # Save Graph variable and information about the running session
    ################################################################
    # save graph
    tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myFinalGraph.pbtxt',as_text=True)
    # Save checkpoint variables
    save_path = saver.save(sess,os.path.join(pathTemp,'myFinalModel.ckpt'))
    print ("Training duration {}".format(trainTime))
    totalParameters =np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.trainable_variables()])
    print("Number of training variable {}".format(totalParameters))
    # log
    infoLog={}
    infoLog["path"] = path
    infoLog["MSE"] = bestNRMSETest
    infoLog["num_step"] = num_step
    infoLog["num_hidden"] = num_hidden
    infoLog["num_epoch"] = epoch
    infoLog["batch_size"] = batch_size
    infoLog["maxSize"] = maxSize
    infoLog["duration"] = trainTime
    infoLog["totalParameters"] = totalParameters
    infoLog["version"] = version
    infoLog["n_layer"] = n_layer
    infoLog["trainDropout"] = 0
    infoLog["nameModel"] = modelName
    infoLog["conv_chan"] = conv_chan
    infoLog["strides"] = conv_strides
    infoLog["conv_size"] = conv_size
    infoLog["amplifierName"]=amplifierName
    logPerf(infoLog)
    input_nodes=["placeHolder/data"]
    output_nodes=["FCPred/Tanh"]
    optimizeGraph(pathTemp,input_nodes,output_nodes)
    
    
                                                 
    
    ###############################
    #  Validation
    ###############################
    restorePath = os.path.join(pathTemp,'myBestModel.ckpt') # restore the best model
    saver.restore(sess,restorePath)
    matrixVal = sio.loadmat(fileNameValidation)
    matrixVal = matrixVal['val']  
    valSize = 0
    if valSize == 0 :
        valSize = len(matrixVal)

    val_input,val_output = loadValidationSeq(matrixVal,num_step,valSize)
    lPrediction = []
    lTarget = []
    ptr3 = 0
    no_of_batchesVal = int(np.floor((len(val_input))/batch_size))
    for k in range(no_of_batchesVal):
        pPrediction,pTarget = sess.run([prediction,target],{data: val_input[ptr3:ptr3+batch_size], target: val_output[ptr3:ptr3+batch_size]}) 
        lPrediction.append(pPrediction)
        lTarget.append(pTarget)   
        ptr3+=batch_size

    predictionArray = np.array(lPrediction,dtype=np.float32).ravel()
    targetArray = np.array(lTarget,dtype=np.float32).ravel()
    scipy.io.wavfile.write(os.path.join(path,'prediction.wav'),44100,predictionArray)
    scipy.io.wavfile.write(os.path.join(path,'target.wav'),44100,targetArray)

    # save emulation in a pickle format
    ax = plt.subplot(111)
    ax.plot(predictionArray[6000+num_step:6700+num_step],label='prediction')
    ax.plot(targetArray[6000+num_step:6700+num_step],label='target')
    ax.legend()
    plt.xlabel('sample n')
    plt.ylabel('Amplitude y[n]')
    nameFigEstimation = os.path.join(path,"targetVsPrediction.pickle")
    pickle.dump(ax,open(nameFigEstimation, 'wb'))
print ("done, good job kids")
# Out:
# version 1.13.1 of tensorflow
# maxSize = 6726407
# shape input train (6726258, 150)
# Data loaded
# INFO:tensorflow:Scale of 0 disables regularizer.
# WARNING:tensorflow:From <ipython-input-1-a1ca03c2cb8d>:112: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.conv2d instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# Epoch -0 calculated in 23.54 s
# Epoch 0, NRMSE Test/best: 0.68159/0.68159, Training NRMSE: 0.52527, deviation of 29.76%
# Epoch -1 calculated in 22.58 s
# Epoch 1, NRMSE Test/best: 0.60938/0.60938, Training NRMSE: 0.45394, deviation of 34.24%
# Epoch -2 calculated in 22.93 s
# Epoch 2, NRMSE Test/best: 0.56893/0.56893, Training NRMSE: 0.42776, deviation of 33.00%
# Epoch -3 calculated in 22.96 s
# Epoch 3, NRMSE Test/best: 0.53572/0.53572, Training NRMSE: 0.42012, deviation of 27.52%
# Epoch -4 calculated in 22.79 s
# Epoch 4, NRMSE Test/best: 0.53741/0.53572, Training NRMSE: 0.40865, deviation of 31.51%
# Epoch -5 calculated in 22.80 s
# Epoch 5, NRMSE Test/best: 0.54954/0.53572, Training NRMSE: 0.40579, deviation of 35.42%
# Epoch -6 calculated in 22.89 s
# Epoch 6, NRMSE Test/best: 0.53707/0.53572, Training NRMSE: 0.39612, deviation of 35.58%
# Epoch -7 calculated in 22.95 s
# Epoch 7, NRMSE Test/best: 0.51629/0.51629, Training NRMSE: 0.39424, deviation of 30.96%
# Epoch -8 calculated in 22.86 s
# Epoch 8, NRMSE Test/best: 0.53027/0.51629, Training NRMSE: 0.38542, deviation of 37.58%
# Epoch -9 calculated in 22.05 s
# Epoch 9, NRMSE Test/best: 0.51008/0.51008, Training NRMSE: 0.38630, deviation of 32.04%
# Epoch -10 calculated in 22.42 s
# Epoch 10, NRMSE Test/best: 0.50933/0.50933, Training NRMSE: 0.38098, deviation of 33.69%
# Epoch -11 calculated in 22.58 s
# Epoch 11, NRMSE Test/best: 0.53279/0.50933, Training NRMSE: 0.37592, deviation of 41.73%
# Epoch -12 calculated in 22.29 s
# Epoch 12, NRMSE Test/best: 0.51362/0.50933, Training NRMSE: 0.37950, deviation of 35.34%
# Epoch -13 calculated in 22.24 s
# Epoch 13, NRMSE Test/best: 0.51440/0.50933, Training NRMSE: 0.37308, deviation of 37.88%
# Epoch -14 calculated in 21.26 s
# Epoch 14, NRMSE Test/best: 0.50370/0.50370, Training NRMSE: 0.36911, deviation of 36.46%
# Epoch -15 calculated in 22.34 s
# Epoch 15, NRMSE Test/best: 0.49995/0.49995, Training NRMSE: 0.36634, deviation of 36.47%
# Epoch -16 calculated in 22.34 s
# Epoch 16, NRMSE Test/best: 0.49160/0.49160, Training NRMSE: 0.36836, deviation of 33.45%
# Epoch -17 calculated in 21.30 s
# Epoch 17, NRMSE Test/best: 0.51953/0.49160, Training NRMSE: 0.36833, deviation of 41.05%
# Epoch -18 calculated in 22.32 s
# Epoch 18, NRMSE Test/best: 0.54706/0.49160, Training NRMSE: 0.36399, deviation of 50.30%
# Epoch -19 calculated in 22.37 s
# Epoch 19, NRMSE Test/best: 0.52686/0.49160, Training NRMSE: 0.36208, deviation of 45.51%
# Epoch -20 calculated in 22.34 s
# Epoch 20, NRMSE Test/best: 0.51434/0.49160, Training NRMSE: 0.35961, deviation of 43.02%
# Epoch -21 calculated in 22.28 s
# Epoch 21, NRMSE Test/best: 0.51893/0.49160, Training NRMSE: 0.35868, deviation of 44.68%
# Epoch -22 calculated in 22.49 s
# Epoch 22, NRMSE Test/best: 0.49622/0.49160, Training NRMSE: 0.35655, deviation of 39.17%
# Epoch -23 calculated in 22.20 s
# Epoch 23, NRMSE Test/best: 0.49928/0.49160, Training NRMSE: 0.35653, deviation of 40.04%
# Epoch -24 calculated in 22.38 s
# Epoch 24, NRMSE Test/best: 0.50135/0.49160, Training NRMSE: 0.35334, deviation of 41.89%
# Epoch -25 calculated in 22.38 s
# Epoch 25, NRMSE Test/best: 0.50062/0.49160, Training NRMSE: 0.35203, deviation of 42.21%
# Epoch -26 calculated in 22.45 s
# Epoch 26, NRMSE Test/best: 0.49620/0.49160, Training NRMSE: 0.34984, deviation of 41.83%
# Epoch -27 calculated in 22.45 s
# Epoch 27, NRMSE Test/best: 0.49595/0.49160, Training NRMSE: 0.35105, deviation of 41.28%
# Epoch -28 calculated in 22.46 s
# Epoch 28, NRMSE Test/best: 0.48714/0.48714, Training NRMSE: 0.34764, deviation of 40.13%
# Epoch -29 calculated in 22.13 s
# Epoch 29, NRMSE Test/best: 0.50522/0.48714, Training NRMSE: 0.34644, deviation of 45.83%
# Epoch -30 calculated in 22.32 s
# Epoch 30, NRMSE Test/best: 0.50277/0.48714, Training NRMSE: 0.34608, deviation of 45.28%
# Epoch -31 calculated in 22.28 s
# Epoch 31, NRMSE Test/best: 0.49909/0.48714, Training NRMSE: 0.34790, deviation of 43.46%
# Epoch -32 calculated in 22.23 s
# Epoch 32, NRMSE Test/best: 0.50305/0.48714, Training NRMSE: 0.34311, deviation of 46.62%
# Epoch -33 calculated in 22.14 s
# Epoch 33, NRMSE Test/best: 0.51507/0.48714, Training NRMSE: 0.34198, deviation of 50.61%
# Epoch -34 calculated in 22.40 s
# Epoch 34, NRMSE Test/best: 0.49648/0.48714, Training NRMSE: 0.34376, deviation of 44.43%
# Epoch -35 calculated in 22.43 s
# Epoch 35, NRMSE Test/best: 0.48937/0.48714, Training NRMSE: 0.34033, deviation of 43.79%
# Epoch -36 calculated in 22.24 s
# Epoch 36, NRMSE Test/best: 0.49515/0.48714, Training NRMSE: 0.34040, deviation of 45.46%
# Epoch -37 calculated in 22.42 s
# Epoch 37, NRMSE Test/best: 0.50699/0.48714, Training NRMSE: 0.33854, deviation of 49.76%
# Epoch -38 calculated in 22.39 s
# Epoch 38, NRMSE Test/best: 0.49510/0.48714, Training NRMSE: 0.33731, deviation of 46.78%
# Epoch -39 calculated in 22.30 s
# Epoch 39, NRMSE Test/best: 0.50917/0.48714, Training NRMSE: 0.33820, deviation of 50.55%
# Epoch -40 calculated in 22.44 s
# Epoch 40, NRMSE Test/best: 0.51044/0.48714, Training NRMSE: 0.33976, deviation of 50.24%
# Epoch -41 calculated in 22.39 s
# Epoch 41, NRMSE Test/best: 0.51567/0.48714, Training NRMSE: 0.33558, deviation of 53.66%
# Epoch -42 calculated in 22.20 s
# Epoch 42, NRMSE Test/best: 0.49154/0.48714, Training NRMSE: 0.33699, deviation of 45.86%
# Epoch -43 calculated in 22.34 s
# Epoch 43, NRMSE Test/best: 0.51897/0.48714, Training NRMSE: 0.33349, deviation of 55.62%
# Epoch -44 calculated in 22.32 s
# Epoch 44, NRMSE Test/best: 0.49465/0.48714, Training NRMSE: 0.33413, deviation of 48.04%
# Epoch -45 calculated in 22.51 s
# Epoch 45, NRMSE Test/best: 0.48867/0.48714, Training NRMSE: 0.33361, deviation of 46.48%
# Epoch -46 calculated in 22.30 s
# Epoch 46, NRMSE Test/best: 0.49064/0.48714, Training NRMSE: 0.33288, deviation of 47.39%
# Epoch -47 calculated in 22.31 s
# Epoch 47, NRMSE Test/best: 0.48470/0.48470, Training NRMSE: 0.33129, deviation of 46.31%
# Epoch -48 calculated in 22.38 s
# Epoch 48, NRMSE Test/best: 0.49522/0.48470, Training NRMSE: 0.33110, deviation of 49.57%
# Epoch -49 calculated in 22.30 s
# Epoch 49, NRMSE Test/best: 0.48786/0.48470, Training NRMSE: 0.33575, deviation of 45.31%
# Epoch -50 calculated in 22.45 s
# Epoch 50, NRMSE Test/best: 0.49051/0.48470, Training NRMSE: 0.32884, deviation of 49.16%
# Epoch -51 calculated in 22.34 s
# Epoch 51, NRMSE Test/best: 0.47243/0.47243, Training NRMSE: 0.33277, deviation of 41.97%
# Epoch -52 calculated in 22.19 s
# Epoch 52, NRMSE Test/best: 0.48220/0.47243, Training NRMSE: 0.32747, deviation of 47.25%
# Epoch -53 calculated in 22.35 s
# Epoch 53, NRMSE Test/best: 0.48141/0.47243, Training NRMSE: 0.32848, deviation of 46.56%
# Epoch -54 calculated in 22.30 s
# Epoch 54, NRMSE Test/best: 0.47985/0.47243, Training NRMSE: 0.32864, deviation of 46.01%
# Epoch -55 calculated in 22.30 s
# Epoch 55, NRMSE Test/best: 0.48482/0.47243, Training NRMSE: 0.32557, deviation of 48.91%
# Epoch -56 calculated in 22.41 s
# Epoch 56, NRMSE Test/best: 0.47171/0.47171, Training NRMSE: 0.32592, deviation of 44.73%
# Epoch -57 calculated in 22.34 s
# Epoch 57, NRMSE Test/best: 0.46346/0.46346, Training NRMSE: 0.32541, deviation of 42.42%
# Epoch -58 calculated in 22.41 s
# Epoch 58, NRMSE Test/best: 0.47485/0.46346, Training NRMSE: 0.32724, deviation of 45.11%
# Epoch -59 calculated in 22.15 s
# Epoch 59, NRMSE Test/best: 0.47016/0.46346, Training NRMSE: 0.32309, deviation of 45.52%
# Epoch -60 calculated in 22.35 s
# Epoch 60, NRMSE Test/best: 0.47466/0.46346, Training NRMSE: 0.32611, deviation of 45.55%
# Epoch -61 calculated in 22.41 s
# Epoch 61, NRMSE Test/best: 0.47637/0.46346, Training NRMSE: 0.32341, deviation of 47.29%
# Epoch -62 calculated in 22.38 s
# Epoch 62, NRMSE Test/best: 0.48116/0.46346, Training NRMSE: 0.32175, deviation of 49.55%
# Epoch -63 calculated in 22.25 s
# Epoch 63, NRMSE Test/best: 0.48453/0.46346, Training NRMSE: 0.32258, deviation of 50.21%
# Epoch -64 calculated in 22.13 s
# Epoch 64, NRMSE Test/best: 0.48725/0.46346, Training NRMSE: 0.32903, deviation of 48.09%
# Epoch -65 calculated in 22.27 s
# Epoch 65, NRMSE Test/best: 0.48807/0.46346, Training NRMSE: 0.32382, deviation of 50.72%
# Epoch -66 calculated in 22.26 s
# Epoch 66, NRMSE Test/best: 0.50012/0.46346, Training NRMSE: 0.32004, deviation of 56.27%
# Epoch -67 calculated in 22.38 s
# Epoch 67, NRMSE Test/best: 0.50339/0.46346, Training NRMSE: 0.32011, deviation of 57.25%
# Epoch -68 calculated in 22.26 s
# Epoch 68, NRMSE Test/best: 0.49026/0.46346, Training NRMSE: 0.32154, deviation of 52.47%
# Epoch -69 calculated in 22.39 s
# Epoch 69, NRMSE Test/best: 0.51063/0.46346, Training NRMSE: 0.32002, deviation of 59.56%
# Epoch -70 calculated in 22.21 s
# Epoch 70, NRMSE Test/best: 0.49976/0.46346, Training NRMSE: 0.31886, deviation of 56.73%
# Epoch -71 calculated in 22.19 s
# Epoch 71, NRMSE Test/best: 0.48604/0.46346, Training NRMSE: 0.31772, deviation of 52.98%
# Epoch -72 calculated in 22.17 s
# Epoch 72, NRMSE Test/best: 0.49438/0.46346, Training NRMSE: 0.31883, deviation of 55.06%
# Epoch -73 calculated in 22.22 s
# Epoch 73, NRMSE Test/best: 0.48395/0.46346, Training NRMSE: 0.31918, deviation of 51.62%
# Epoch -74 calculated in 22.38 s
# Epoch 74, NRMSE Test/best: 0.49754/0.46346, Training NRMSE: 0.31875, deviation of 56.09%
# Epoch -75 calculated in 22.22 s
# Epoch 75, NRMSE Test/best: 0.48556/0.46346, Training NRMSE: 0.31823, deviation of 52.58%
# Epoch -76 calculated in 22.37 s
# Epoch 76, NRMSE Test/best: 0.48197/0.46346, Training NRMSE: 0.31779, deviation of 51.66%
# Epoch -77 calculated in 22.27 s
# Epoch 77, NRMSE Test/best: 0.47691/0.46346, Training NRMSE: 0.31845, deviation of 49.76%
# Epoch -78 calculated in 22.37 s
# Epoch 78, NRMSE Test/best: 0.48077/0.46346, Training NRMSE: 0.31557, deviation of 52.35%
# Epoch -79 calculated in 22.29 s
# Epoch 79, NRMSE Test/best: 0.47625/0.46346, Training NRMSE: 0.31650, deviation of 50.48%
# Epoch -80 calculated in 22.46 s
# Epoch 80, NRMSE Test/best: 0.47196/0.46346, Training NRMSE: 0.31533, deviation of 49.67%
# Epoch -81 calculated in 22.40 s
# Epoch 81, NRMSE Test/best: 0.47551/0.46346, Training NRMSE: 0.31605, deviation of 50.45%
# Epoch -82 calculated in 22.24 s
# Epoch 82, NRMSE Test/best: 0.46786/0.46346, Training NRMSE: 0.31550, deviation of 48.29%
# Epoch -83 calculated in 22.47 s
# Epoch 83, NRMSE Test/best: 0.46561/0.46346, Training NRMSE: 0.31562, deviation of 47.52%
# Epoch -84 calculated in 22.17 s
# Epoch 84, NRMSE Test/best: 0.45833/0.45833, Training NRMSE: 0.31752, deviation of 44.35%
# Epoch -85 calculated in 22.44 s
# Epoch 85, NRMSE Test/best: 0.46774/0.45833, Training NRMSE: 0.31472, deviation of 48.62%
# Epoch -86 calculated in 22.37 s
# Epoch 86, NRMSE Test/best: 0.47779/0.45833, Training NRMSE: 0.31433, deviation of 52.00%
# Epoch -87 calculated in 22.24 s
# Epoch 87, NRMSE Test/best: 0.46548/0.45833, Training NRMSE: 0.31272, deviation of 48.85%
# Epoch -88 calculated in 22.28 s
# Epoch 88, NRMSE Test/best: 0.46315/0.45833, Training NRMSE: 0.31424, deviation of 47.39%
# Epoch -89 calculated in 22.26 s
# Epoch 89, NRMSE Test/best: 0.46856/0.45833, Training NRMSE: 0.31343, deviation of 49.49%
# Epoch -90 calculated in 22.56 s
# Epoch 90, NRMSE Test/best: 0.46081/0.45833, Training NRMSE: 0.31290, deviation of 47.27%
# Epoch -91 calculated in 22.19 s
# Epoch 91, NRMSE Test/best: 0.46909/0.45833, Training NRMSE: 0.31191, deviation of 50.39%
# Epoch -92 calculated in 22.39 s
# Epoch 92, NRMSE Test/best: 0.45841/0.45833, Training NRMSE: 0.31490, deviation of 45.57%
# Epoch -93 calculated in 22.27 s
# Epoch 93, NRMSE Test/best: 0.45951/0.45833, Training NRMSE: 0.31584, deviation of 45.49%
# Epoch -94 calculated in 22.34 s
# Epoch 94, NRMSE Test/best: 0.44710/0.44710, Training NRMSE: 0.31192, deviation of 43.34%
# Epoch -95 calculated in 22.27 s
# Epoch 95, NRMSE Test/best: 0.45090/0.44710, Training NRMSE: 0.31443, deviation of 43.40%
# Epoch -96 calculated in 22.42 s
# Epoch 96, NRMSE Test/best: 0.45078/0.44710, Training NRMSE: 0.31162, deviation of 44.66%
# Epoch -97 calculated in 22.37 s
# Epoch 97, NRMSE Test/best: 0.46129/0.44710, Training NRMSE: 0.30999, deviation of 48.81%
# Epoch -98 calculated in 22.27 s
# Epoch 98, NRMSE Test/best: 0.44926/0.44710, Training NRMSE: 0.31186, deviation of 44.06%
# Epoch -99 calculated in 22.39 s
# Epoch 99, NRMSE Test/best: 0.45695/0.44710, Training NRMSE: 0.31237, deviation of 46.28%
# Epoch -100 calculated in 22.34 s
# Epoch 100, NRMSE Test/best: 0.45181/0.44710, Training NRMSE: 0.31163, deviation of 44.98%
# Epoch -101 calculated in 22.25 s
# Epoch 101, NRMSE Test/best: 0.45401/0.44710, Training NRMSE: 0.31088, deviation of 46.04%
# Epoch -102 calculated in 22.29 s
# Epoch 102, NRMSE Test/best: 0.45033/0.44710, Training NRMSE: 0.31161, deviation of 44.52%
# Epoch -103 calculated in 22.17 s
# Epoch 103, NRMSE Test/best: 0.45605/0.44710, Training NRMSE: 0.31041, deviation of 46.92%
# Epoch -104 calculated in 22.11 s
# Epoch 104, NRMSE Test/best: 0.45424/0.44710, Training NRMSE: 0.30893, deviation of 47.04%
# Epoch -105 calculated in 22.55 s
# Epoch 105, NRMSE Test/best: 0.44859/0.44710, Training NRMSE: 0.31128, deviation of 44.11%
# Epoch -106 calculated in 22.05 s
# Epoch 106, NRMSE Test/best: 0.44462/0.44462, Training NRMSE: 0.31051, deviation of 43.19%
# Epoch -107 calculated in 22.20 s
# Epoch 107, NRMSE Test/best: 0.44615/0.44462, Training NRMSE: 0.30871, deviation of 44.52%
# Epoch -108 calculated in 22.48 s
# Epoch 108, NRMSE Test/best: 0.44478/0.44462, Training NRMSE: 0.30827, deviation of 44.28%
# Epoch -109 calculated in 22.27 s
# Epoch 109, NRMSE Test/best: 0.45272/0.44462, Training NRMSE: 0.31201, deviation of 45.10%
# Epoch -110 calculated in 22.27 s
# Epoch 110, NRMSE Test/best: 0.44756/0.44462, Training NRMSE: 0.30808, deviation of 45.27%
# Epoch -111 calculated in 22.35 s
# Epoch 111, NRMSE Test/best: 0.44307/0.44307, Training NRMSE: 0.30837, deviation of 43.68%
# Epoch -112 calculated in 22.29 s
# Epoch 112, NRMSE Test/best: 0.43730/0.43730, Training NRMSE: 0.30837, deviation of 41.81%
# Epoch -113 calculated in 22.38 s
# Epoch 113, NRMSE Test/best: 0.43858/0.43730, Training NRMSE: 0.31048, deviation of 41.26%
# Epoch -114 calculated in 22.36 s
# Epoch 114, NRMSE Test/best: 0.44323/0.43730, Training NRMSE: 0.30599, deviation of 44.85%
# Epoch -115 calculated in 22.39 s
# Epoch 115, NRMSE Test/best: 0.44124/0.43730, Training NRMSE: 0.30700, deviation of 43.73%
# Epoch -116 calculated in 22.34 s
# Epoch 116, NRMSE Test/best: 0.44274/0.43730, Training NRMSE: 0.30863, deviation of 43.45%
# Epoch -117 calculated in 22.27 s
# Epoch 117, NRMSE Test/best: 0.43203/0.43203, Training NRMSE: 0.30684, deviation of 40.80%
# Epoch -118 calculated in 22.30 s
# Epoch 118, NRMSE Test/best: 0.45292/0.43203, Training NRMSE: 0.30796, deviation of 47.07%
# Epoch -119 calculated in 22.40 s
# Epoch 119, NRMSE Test/best: 0.44822/0.43203, Training NRMSE: 0.30529, deviation of 46.82%
# Epoch -120 calculated in 22.47 s
# Epoch 120, NRMSE Test/best: 0.45032/0.43203, Training NRMSE: 0.30571, deviation of 47.30%
# Epoch -121 calculated in 22.55 s
# Epoch 121, NRMSE Test/best: 0.44930/0.43203, Training NRMSE: 0.30620, deviation of 46.73%
# Epoch -122 calculated in 22.57 s
# Epoch 122, NRMSE Test/best: 0.45168/0.43203, Training NRMSE: 0.30679, deviation of 47.23%
# Epoch -123 calculated in 22.30 s
# Epoch 123, NRMSE Test/best: 0.45611/0.43203, Training NRMSE: 0.30975, deviation of 47.25%
# Epoch -124 calculated in 22.45 s
# Epoch 124, NRMSE Test/best: 0.45380/0.43203, Training NRMSE: 0.30580, deviation of 48.40%
# Epoch -125 calculated in 22.23 s
# Epoch 125, NRMSE Test/best: 0.45301/0.43203, Training NRMSE: 0.30433, deviation of 48.86%
# Epoch -126 calculated in 22.31 s
# Epoch 126, NRMSE Test/best: 0.43857/0.43203, Training NRMSE: 0.31388, deviation of 39.73%
# Epoch -127 calculated in 22.44 s
# Epoch 127, NRMSE Test/best: 0.44407/0.43203, Training NRMSE: 0.30441, deviation of 45.88%
# Epoch -128 calculated in 22.00 s
# Epoch 128, NRMSE Test/best: 0.45447/0.43203, Training NRMSE: 0.30446, deviation of 49.27%
# Epoch -129 calculated in 22.46 s
# Epoch 129, NRMSE Test/best: 0.43991/0.43203, Training NRMSE: 0.30417, deviation of 44.63%
# Epoch -130 calculated in 22.18 s
# Epoch 130, NRMSE Test/best: 0.43363/0.43203, Training NRMSE: 0.30562, deviation of 41.89%
# Epoch -131 calculated in 22.47 s
# Epoch 131, NRMSE Test/best: 0.44036/0.43203, Training NRMSE: 0.30458, deviation of 44.58%
# Epoch -132 calculated in 22.26 s
# Epoch 132, NRMSE Test/best: 0.43410/0.43203, Training NRMSE: 0.30391, deviation of 42.84%
# Epoch -133 calculated in 22.26 s
# Epoch 133, NRMSE Test/best: 0.44388/0.43203, Training NRMSE: 0.30489, deviation of 45.58%
# Epoch -134 calculated in 22.36 s
# Epoch 134, NRMSE Test/best: 0.43660/0.43203, Training NRMSE: 0.30503, deviation of 43.13%
# Epoch -135 calculated in 22.42 s
# Epoch 135, NRMSE Test/best: 0.44171/0.43203, Training NRMSE: 0.30259, deviation of 45.98%
# Epoch -136 calculated in 22.31 s
# Epoch 136, NRMSE Test/best: 0.44360/0.43203, Training NRMSE: 0.30290, deviation of 46.45%
# Epoch -137 calculated in 22.25 s
# Epoch 137, NRMSE Test/best: 0.46931/0.43203, Training NRMSE: 0.30300, deviation of 54.89%
# Epoch -138 calculated in 22.36 s
# Epoch 138, NRMSE Test/best: 0.44010/0.43203, Training NRMSE: 0.30416, deviation of 44.70%
# Epoch -139 calculated in 22.08 s
# Epoch 139, NRMSE Test/best: 0.45303/0.43203, Training NRMSE: 0.30429, deviation of 48.88%
# Epoch -140 calculated in 22.41 s
# Epoch 140, NRMSE Test/best: 0.44656/0.43203, Training NRMSE: 0.30481, deviation of 46.50%
# Epoch -141 calculated in 22.47 s
# Epoch 141, NRMSE Test/best: 0.44597/0.43203, Training NRMSE: 0.30857, deviation of 44.53%
# Epoch -142 calculated in 22.29 s
# Epoch 142, NRMSE Test/best: 0.44129/0.43203, Training NRMSE: 0.30477, deviation of 44.79%
# Epoch -143 calculated in 22.02 s
# Epoch 143, NRMSE Test/best: 0.45020/0.43203, Training NRMSE: 0.30306, deviation of 48.55%
# Epoch -144 calculated in 22.21 s
# Epoch 144, NRMSE Test/best: 0.45415/0.43203, Training NRMSE: 0.30211, deviation of 50.33%
# Epoch -145 calculated in 22.32 s
# Epoch 145, NRMSE Test/best: 0.45300/0.43203, Training NRMSE: 0.30245, deviation of 49.78%
# Epoch -146 calculated in 22.28 s
# Epoch 146, NRMSE Test/best: 0.45023/0.43203, Training NRMSE: 0.30848, deviation of 45.95%
# Epoch -147 calculated in 22.48 s
# Epoch 147, NRMSE Test/best: 0.46055/0.43203, Training NRMSE: 0.30488, deviation of 51.06%
# Epoch -148 calculated in 22.36 s
# Epoch 148, NRMSE Test/best: 0.45280/0.43203, Training NRMSE: 0.30147, deviation of 50.20%
# Epoch -149 calculated in 22.31 s
# Epoch 149, NRMSE Test/best: 0.45841/0.43203, Training NRMSE: 0.30128, deviation of 52.15%
# Epoch -150 calculated in 22.13 s
# Epoch 150, NRMSE Test/best: 0.46292/0.43203, Training NRMSE: 0.30130, deviation of 53.64%
# Epoch -151 calculated in 22.37 s
# Epoch 151, NRMSE Test/best: 0.46044/0.43203, Training NRMSE: 0.29964, deviation of 53.67%
# Epoch -152 calculated in 22.35 s
# Epoch 152, NRMSE Test/best: 0.46998/0.43203, Training NRMSE: 0.30027, deviation of 56.52%
# Epoch -153 calculated in 22.31 s
# Epoch 153, NRMSE Test/best: 0.45662/0.43203, Training NRMSE: 0.30143, deviation of 51.49%
# Epoch -154 calculated in 22.31 s
# Epoch 154, NRMSE Test/best: 0.46124/0.43203, Training NRMSE: 0.30122, deviation of 53.12%
# Epoch -155 calculated in 22.31 s
# Epoch 155, NRMSE Test/best: 0.46303/0.43203, Training NRMSE: 0.30032, deviation of 54.18%
# Epoch -156 calculated in 22.21 s
# Epoch 156, NRMSE Test/best: 0.45921/0.43203, Training NRMSE: 0.29990, deviation of 53.12%
# Epoch -157 calculated in 22.40 s
# Epoch 157, NRMSE Test/best: 0.45203/0.43203, Training NRMSE: 0.30169, deviation of 49.84%
# Epoch -158 calculated in 22.44 s
# Epoch 158, NRMSE Test/best: 0.45965/0.43203, Training NRMSE: 0.29979, deviation of 53.32%
# Epoch -159 calculated in 22.41 s
# Epoch 159, NRMSE Test/best: 0.45206/0.43203, Training NRMSE: 0.30013, deviation of 50.62%
# Epoch -160 calculated in 22.46 s
# Epoch 160, NRMSE Test/best: 0.45111/0.43203, Training NRMSE: 0.30562, deviation of 47.61%
# Epoch -161 calculated in 22.14 s
# Epoch 161, NRMSE Test/best: 0.46065/0.43203, Training NRMSE: 0.30098, deviation of 53.05%
# Epoch -162 calculated in 22.22 s
# Epoch 162, NRMSE Test/best: 0.46433/0.43203, Training NRMSE: 0.30130, deviation of 54.11%
# Epoch -163 calculated in 22.05 s
# Epoch 163, NRMSE Test/best: 0.46362/0.43203, Training NRMSE: 0.30020, deviation of 54.44%
# Epoch -164 calculated in 22.58 s
# Epoch 164, NRMSE Test/best: 0.46288/0.43203, Training NRMSE: 0.29875, deviation of 54.94%
# Epoch -165 calculated in 22.20 s
# Epoch 165, NRMSE Test/best: 0.45082/0.43203, Training NRMSE: 0.29939, deviation of 50.58%
# Epoch -166 calculated in 22.48 s
# Epoch 166, NRMSE Test/best: 0.46196/0.43203, Training NRMSE: 0.30074, deviation of 53.60%
# Epoch -167 calculated in 22.21 s
# Epoch 167, NRMSE Test/best: 0.45315/0.43203, Training NRMSE: 0.30175, deviation of 50.17%
# Epoch -168 calculated in 22.31 s
# Epoch 168, NRMSE Test/best: 0.46801/0.43203, Training NRMSE: 0.29834, deviation of 56.87%
# Epoch -169 calculated in 22.41 s
# Epoch 169, NRMSE Test/best: 0.46627/0.43203, Training NRMSE: 0.29948, deviation of 55.69%
# Epoch -170 calculated in 22.27 s
# Epoch 170, NRMSE Test/best: 0.45919/0.43203, Training NRMSE: 0.29939, deviation of 53.38%
# Epoch -171 calculated in 22.40 s
# Epoch 171, NRMSE Test/best: 0.45853/0.43203, Training NRMSE: 0.29922, deviation of 53.24%
# Epoch -172 calculated in 22.47 s
# Epoch 172, NRMSE Test/best: 0.47518/0.43203, Training NRMSE: 0.29846, deviation of 59.21%
# Epoch -173 calculated in 22.39 s
# Epoch 173, NRMSE Test/best: 0.45823/0.43203, Training NRMSE: 0.29940, deviation of 53.05%
# Epoch -174 calculated in 22.22 s
# Epoch 174, NRMSE Test/best: 0.46076/0.43203, Training NRMSE: 0.29697, deviation of 55.15%
# Epoch -175 calculated in 22.35 s
# Epoch 175, NRMSE Test/best: 0.46119/0.43203, Training NRMSE: 0.29767, deviation of 54.93%
# Epoch -176 calculated in 22.35 s
# Epoch 176, NRMSE Test/best: 0.47011/0.43203, Training NRMSE: 0.29831, deviation of 57.59%
# Epoch -177 calculated in 22.21 s
# Epoch 177, NRMSE Test/best: 0.45446/0.43203, Training NRMSE: 0.29721, deviation of 52.91%
# Epoch -178 calculated in 22.43 s
# Epoch 178, NRMSE Test/best: 0.46309/0.43203, Training NRMSE: 0.29748, deviation of 55.67%
# Epoch -179 calculated in 22.37 s
# Epoch 179, NRMSE Test/best: 0.45326/0.43203, Training NRMSE: 0.29908, deviation of 51.55%
# Epoch -180 calculated in 22.37 s
# Epoch 180, NRMSE Test/best: 0.46213/0.43203, Training NRMSE: 0.29857, deviation of 54.78%
# Epoch -181 calculated in 22.25 s
# Epoch 181, NRMSE Test/best: 0.46825/0.43203, Training NRMSE: 0.29782, deviation of 57.23%
# Epoch -182 calculated in 22.29 s
# Epoch 182, NRMSE Test/best: 0.46671/0.43203, Training NRMSE: 0.29786, deviation of 56.69%
# Epoch -183 calculated in 22.23 s
# Epoch 183, NRMSE Test/best: 0.46236/0.43203, Training NRMSE: 0.29657, deviation of 55.90%
# Epoch -184 calculated in 22.54 s
# Epoch 184, NRMSE Test/best: 0.46448/0.43203, Training NRMSE: 0.30449, deviation of 52.54%
# Epoch -185 calculated in 22.14 s
# Epoch 185, NRMSE Test/best: 0.45785/0.43203, Training NRMSE: 0.29906, deviation of 53.10%
# Epoch -186 calculated in 22.40 s
# Epoch 186, NRMSE Test/best: 0.46702/0.43203, Training NRMSE: 0.29658, deviation of 57.47%
# Epoch -187 calculated in 22.30 s
# Epoch 187, NRMSE Test/best: 0.47245/0.43203, Training NRMSE: 0.29639, deviation of 59.40%
# Epoch -188 calculated in 22.50 s
# Epoch 188, NRMSE Test/best: 0.45703/0.43203, Training NRMSE: 0.29835, deviation of 53.19%
# Epoch -189 calculated in 22.20 s
# Epoch 189, NRMSE Test/best: 0.46436/0.43203, Training NRMSE: 0.29685, deviation of 56.43%
# Epoch -190 calculated in 22.28 s
# Epoch 190, NRMSE Test/best: 0.46910/0.43203, Training NRMSE: 0.29591, deviation of 58.53%
# Epoch -191 calculated in 22.33 s
# Epoch 191, NRMSE Test/best: 0.47407/0.43203, Training NRMSE: 0.29638, deviation of 59.95%
# Epoch -192 calculated in 22.30 s
# Epoch 192, NRMSE Test/best: 0.46607/0.43203, Training NRMSE: 0.29823, deviation of 56.28%
# Epoch -193 calculated in 22.36 s
# Epoch 193, NRMSE Test/best: 0.46951/0.43203, Training NRMSE: 0.29488, deviation of 59.22%
# Epoch -194 calculated in 22.32 s
# Epoch 194, NRMSE Test/best: 0.47166/0.43203, Training NRMSE: 0.29555, deviation of 59.59%
# Epoch -195 calculated in 22.44 s
# Epoch 195, NRMSE Test/best: 0.46020/0.43203, Training NRMSE: 0.29627, deviation of 55.33%
# Epoch -196 calculated in 22.17 s
# Epoch 196, NRMSE Test/best: 0.46452/0.43203, Training NRMSE: 0.29895, deviation of 55.39%
# Epoch -197 calculated in 22.32 s
# Epoch 197, NRMSE Test/best: 0.46611/0.43203, Training NRMSE: 0.29541, deviation of 57.78%
# Epoch -198 calculated in 22.40 s
# Epoch 198, NRMSE Test/best: 0.46901/0.43203, Training NRMSE: 0.29618, deviation of 58.35%
# Epoch -199 calculated in 22.48 s
# Epoch 199, NRMSE Test/best: 0.47861/0.43203, Training NRMSE: 0.29579, deviation of 61.81%
# Epoch -200 calculated in 22.51 s
# Epoch 200, NRMSE Test/best: 0.47618/0.43203, Training NRMSE: 0.29561, deviation of 61.09%
# Epoch -201 calculated in 22.37 s
# Epoch 201, NRMSE Test/best: 0.46894/0.43203, Training NRMSE: 0.29634, deviation of 58.24%
# Epoch -202 calculated in 22.32 s
# Epoch 202, NRMSE Test/best: 0.46514/0.43203, Training NRMSE: 0.29660, deviation of 56.83%
# Epoch -203 calculated in 22.32 s
# Epoch 203, NRMSE Test/best: 0.47028/0.43203, Training NRMSE: 0.29585, deviation of 58.96%
# Epoch -204 calculated in 22.37 s
# Epoch 204, NRMSE Test/best: 0.46611/0.43203, Training NRMSE: 0.29759, deviation of 56.63%
# Epoch -205 calculated in 22.45 s
# Epoch 205, NRMSE Test/best: 0.46730/0.43203, Training NRMSE: 0.29581, deviation of 57.97%
# Epoch -206 calculated in 22.18 s
# Epoch 206, NRMSE Test/best: 0.45775/0.43203, Training NRMSE: 0.29804, deviation of 53.59%
# Epoch -207 calculated in 22.22 s
# Epoch 207, NRMSE Test/best: 0.45624/0.43203, Training NRMSE: 0.29653, deviation of 53.86%
# Epoch -208 calculated in 22.41 s
# Epoch 208, NRMSE Test/best: 0.45566/0.43203, Training NRMSE: 0.29458, deviation of 54.68%
# Epoch -209 calculated in 22.54 s
# Epoch 209, NRMSE Test/best: 0.44861/0.43203, Training NRMSE: 0.29546, deviation of 51.83%
# Epoch -210 calculated in 22.51 s
# Epoch 210, NRMSE Test/best: 0.45043/0.43203, Training NRMSE: 0.29527, deviation of 52.55%
# Epoch -211 calculated in 22.28 s
# Epoch 211, NRMSE Test/best: 0.45354/0.43203, Training NRMSE: 0.29632, deviation of 53.06%
# Epoch -212 calculated in 22.38 s
# Epoch 212, NRMSE Test/best: 0.45168/0.43203, Training NRMSE: 0.29651, deviation of 52.34%
# Epoch -213 calculated in 22.27 s
# Epoch 213, NRMSE Test/best: 0.44333/0.43203, Training NRMSE: 0.29646, deviation of 49.54%
# Epoch -214 calculated in 22.43 s
# Epoch 214, NRMSE Test/best: 0.45764/0.43203, Training NRMSE: 0.29468, deviation of 55.30%
# Epoch -215 calculated in 22.39 s
# Epoch 215, NRMSE Test/best: 0.44726/0.43203, Training NRMSE: 0.29740, deviation of 50.39%
# Epoch -216 calculated in 22.66 s
# Epoch 216, NRMSE Test/best: 0.46056/0.43203, Training NRMSE: 0.29474, deviation of 56.26%
# Epoch -217 calculated in 22.35 s
# Epoch 217, NRMSE Test/best: 0.44937/0.43203, Training NRMSE: 0.29571, deviation of 51.96%
# Epoch -218 calculated in 22.32 s
# Epoch 218, NRMSE Test/best: 0.45203/0.43203, Training NRMSE: 0.29414, deviation of 53.68%
# Epoch -219 calculated in 22.18 s
# Epoch 219, NRMSE Test/best: 0.45657/0.43203, Training NRMSE: 0.29335, deviation of 55.64%
# Epoch -220 calculated in 22.28 s
# Epoch 220, NRMSE Test/best: 0.46107/0.43203, Training NRMSE: 0.29281, deviation of 57.46%
# Epoch -221 calculated in 22.54 s
# Epoch 221, NRMSE Test/best: 0.45913/0.43203, Training NRMSE: 0.29472, deviation of 55.78%
# Epoch -222 calculated in 22.34 s
# Epoch 222, NRMSE Test/best: 0.45021/0.43203, Training NRMSE: 0.29556, deviation of 52.33%
# Epoch -223 calculated in 22.24 s
# Epoch 223, NRMSE Test/best: 0.44974/0.43203, Training NRMSE: 0.29469, deviation of 52.62%
# Epoch -224 calculated in 22.42 s
# Epoch 224, NRMSE Test/best: 0.45153/0.43203, Training NRMSE: 0.29262, deviation of 54.30%
# Epoch -225 calculated in 22.56 s
# Epoch 225, NRMSE Test/best: 0.44900/0.43203, Training NRMSE: 0.29284, deviation of 53.33%
# Epoch -226 calculated in 22.41 s
# Epoch 226, NRMSE Test/best: 0.44855/0.43203, Training NRMSE: 0.29409, deviation of 52.52%
# Epoch -227 calculated in 22.27 s
# Epoch 227, NRMSE Test/best: 0.44935/0.43203, Training NRMSE: 0.29685, deviation of 51.37%
# Epoch -228 calculated in 22.34 s
# Epoch 228, NRMSE Test/best: 0.45424/0.43203, Training NRMSE: 0.29421, deviation of 54.39%
# Epoch -229 calculated in 22.52 s
# Epoch 229, NRMSE Test/best: 0.45241/0.43203, Training NRMSE: 0.29346, deviation of 54.16%
# Epoch -230 calculated in 22.17 s
# Epoch 230, NRMSE Test/best: 0.43996/0.43203, Training NRMSE: 0.29607, deviation of 48.60%
# Epoch -231 calculated in 22.21 s
# Epoch 231, NRMSE Test/best: 0.45116/0.43203, Training NRMSE: 0.29397, deviation of 53.47%
# Epoch -232 calculated in 22.22 s
# Epoch 232, NRMSE Test/best: 0.45397/0.43203, Training NRMSE: 0.29292, deviation of 54.98%
# Epoch -233 calculated in 22.33 s
# Epoch 233, NRMSE Test/best: 0.44980/0.43203, Training NRMSE: 0.29398, deviation of 53.01%
# Epoch -234 calculated in 22.26 s
# Epoch 234, NRMSE Test/best: 0.45130/0.43203, Training NRMSE: 0.29439, deviation of 53.30%
# Epoch -235 calculated in 22.49 s
# Epoch 235, NRMSE Test/best: 0.45099/0.43203, Training NRMSE: 0.29417, deviation of 53.31%
# Epoch -236 calculated in 22.31 s
# Epoch 236, NRMSE Test/best: 0.44637/0.43203, Training NRMSE: 0.29613, deviation of 50.73%
# Epoch -237 calculated in 22.27 s
# Epoch 237, NRMSE Test/best: 0.44901/0.43203, Training NRMSE: 0.29273, deviation of 53.39%
# Epoch -238 calculated in 22.38 s
# Epoch 238, NRMSE Test/best: 0.45212/0.43203, Training NRMSE: 0.29335, deviation of 54.13%
# Epoch -239 calculated in 22.43 s
# Epoch 239, NRMSE Test/best: 0.45109/0.43203, Training NRMSE: 0.29446, deviation of 53.19%
# Epoch -240 calculated in 22.51 s
# Epoch 240, NRMSE Test/best: 0.45126/0.43203, Training NRMSE: 0.29441, deviation of 53.28%
# Epoch -241 calculated in 22.18 s
# Epoch 241, NRMSE Test/best: 0.45534/0.43203, Training NRMSE: 0.29371, deviation of 55.03%
# Epoch -242 calculated in 22.26 s
# Epoch 242, NRMSE Test/best: 0.44766/0.43203, Training NRMSE: 0.29542, deviation of 51.53%
# Epoch -243 calculated in 22.30 s
# Epoch 243, NRMSE Test/best: 0.43717/0.43203, Training NRMSE: 0.29346, deviation of 48.97%
# Epoch -244 calculated in 22.19 s
# Epoch 244, NRMSE Test/best: 0.44765/0.43203, Training NRMSE: 0.29455, deviation of 51.98%
# Epoch -245 calculated in 22.50 s
# Epoch 245, NRMSE Test/best: 0.45115/0.43203, Training NRMSE: 0.29262, deviation of 54.18%
# Epoch -246 calculated in 22.31 s
# Epoch 246, NRMSE Test/best: 0.44528/0.43203, Training NRMSE: 0.29807, deviation of 49.39%
# Epoch -247 calculated in 22.34 s
# Epoch 247, NRMSE Test/best: 0.44586/0.43203, Training NRMSE: 0.29305, deviation of 52.14%
# Epoch -248 calculated in 22.42 s
# Epoch 248, NRMSE Test/best: 0.44946/0.43203, Training NRMSE: 0.29338, deviation of 53.20%
# Epoch -249 calculated in 22.42 s
# Epoch 249, NRMSE Test/best: 0.44522/0.43203, Training NRMSE: 0.29192, deviation of 52.51%
# Epoch -250 calculated in 22.46 s
# Epoch 250, NRMSE Test/best: 0.44328/0.43203, Training NRMSE: 0.29184, deviation of 51.89%
# Epoch -251 calculated in 22.40 s
# Epoch 251, NRMSE Test/best: 0.44279/0.43203, Training NRMSE: 0.29357, deviation of 50.83%
# Epoch -252 calculated in 22.30 s
# Epoch 252, NRMSE Test/best: 0.43911/0.43203, Training NRMSE: 0.29212, deviation of 50.32%
# Epoch -253 calculated in 22.38 s
# Epoch 253, NRMSE Test/best: 0.44140/0.43203, Training NRMSE: 0.29360, deviation of 50.34%
# Epoch -254 calculated in 22.44 s
# Epoch 254, NRMSE Test/best: 0.44000/0.43203, Training NRMSE: 0.29428, deviation of 49.52%
# Epoch -255 calculated in 22.52 s
# Epoch 255, NRMSE Test/best: 0.44518/0.43203, Training NRMSE: 0.29223, deviation of 52.34%
# Epoch -256 calculated in 22.21 s
# Epoch 256, NRMSE Test/best: 0.44355/0.43203, Training NRMSE: 0.29310, deviation of 51.33%
# Epoch -257 calculated in 22.30 s
# Epoch 257, NRMSE Test/best: 0.43374/0.43203, Training NRMSE: 0.29251, deviation of 48.28%
# Epoch -258 calculated in 22.21 s
# Epoch 258, NRMSE Test/best: 0.44437/0.43203, Training NRMSE: 0.29205, deviation of 52.16%
# Epoch -259 calculated in 22.47 s
# Epoch 259, NRMSE Test/best: 0.44809/0.43203, Training NRMSE: 0.29176, deviation of 53.58%
# Epoch -260 calculated in 22.52 s
# Epoch 260, NRMSE Test/best: 0.44361/0.43203, Training NRMSE: 0.29107, deviation of 52.41%
# Epoch -261 calculated in 22.46 s
# Epoch 261, NRMSE Test/best: 0.44997/0.43203, Training NRMSE: 0.29096, deviation of 54.65%
# Epoch -262 calculated in 22.39 s
# Epoch 262, NRMSE Test/best: 0.44625/0.43203, Training NRMSE: 0.29128, deviation of 53.20%
# Epoch -263 calculated in 22.54 s
# Epoch 263, NRMSE Test/best: 0.44297/0.43203, Training NRMSE: 0.29406, deviation of 50.64%
# Epoch -264 calculated in 22.40 s
# Epoch 264, NRMSE Test/best: 0.45093/0.43203, Training NRMSE: 0.29098, deviation of 54.97%
# Epoch -265 calculated in 22.24 s
# Epoch 265, NRMSE Test/best: 0.44361/0.43203, Training NRMSE: 0.29382, deviation of 50.98%
# Epoch -266 calculated in 22.39 s
# Epoch 266, NRMSE Test/best: 0.44503/0.43203, Training NRMSE: 0.29131, deviation of 52.77%
# Epoch -267 calculated in 22.24 s
# Epoch 267, NRMSE Test/best: 0.45429/0.43203, Training NRMSE: 0.29074, deviation of 56.25%
# Epoch -268 calculated in 22.49 s
# Epoch 268, NRMSE Test/best: 0.45942/0.43203, Training NRMSE: 0.29128, deviation of 57.73%
# Epoch -269 calculated in 22.30 s
# Epoch 269, NRMSE Test/best: 0.45184/0.43203, Training NRMSE: 0.29109, deviation of 55.22%
# Epoch -270 calculated in 22.31 s
# Epoch 270, NRMSE Test/best: 0.45046/0.43203, Training NRMSE: 0.29228, deviation of 54.12%
# Epoch -271 calculated in 22.33 s
# Epoch 271, NRMSE Test/best: 0.44671/0.43203, Training NRMSE: 0.28964, deviation of 54.23%
# Epoch -272 calculated in 22.45 s
# Epoch 272, NRMSE Test/best: 0.45724/0.43203, Training NRMSE: 0.29197, deviation of 56.61%
# Epoch -273 calculated in 22.45 s
# Epoch 273, NRMSE Test/best: 0.44762/0.43203, Training NRMSE: 0.29071, deviation of 53.97%
# Epoch -274 calculated in 22.30 s
# Epoch 274, NRMSE Test/best: 0.46509/0.43203, Training NRMSE: 0.29163, deviation of 59.48%
# Epoch -275 calculated in 22.34 s
# Epoch 275, NRMSE Test/best: 0.45396/0.43203, Training NRMSE: 0.29149, deviation of 55.74%
# Epoch -276 calculated in 22.36 s
# Epoch 276, NRMSE Test/best: 0.45338/0.43203, Training NRMSE: 0.29207, deviation of 55.23%
# Epoch -277 calculated in 22.33 s
# Epoch 277, NRMSE Test/best: 0.45272/0.43203, Training NRMSE: 0.29131, deviation of 55.41%
# Epoch -278 calculated in 22.34 s
# Epoch 278, NRMSE Test/best: 0.45562/0.43203, Training NRMSE: 0.29130, deviation of 56.41%
# Epoch -279 calculated in 22.49 s
# Epoch 279, NRMSE Test/best: 0.45155/0.43203, Training NRMSE: 0.29003, deviation of 55.69%
# Epoch -280 calculated in 22.43 s
# Epoch 280, NRMSE Test/best: 0.44942/0.43203, Training NRMSE: 0.29180, deviation of 54.01%
# Epoch -281 calculated in 22.33 s
# Epoch 281, NRMSE Test/best: 0.45123/0.43203, Training NRMSE: 0.29027, deviation of 55.45%
# Epoch -282 calculated in 22.44 s
# Epoch 282, NRMSE Test/best: 0.44881/0.43203, Training NRMSE: 0.29101, deviation of 54.23%
# Epoch -283 calculated in 22.40 s
# Epoch 283, NRMSE Test/best: 0.45497/0.43203, Training NRMSE: 0.29240, deviation of 55.60%
# Epoch -284 calculated in 22.47 s
# Epoch 284, NRMSE Test/best: 0.45350/0.43203, Training NRMSE: 0.29245, deviation of 55.07%
# Epoch -285 calculated in 22.25 s
# Epoch 285, NRMSE Test/best: 0.44905/0.43203, Training NRMSE: 0.29036, deviation of 54.65%
# Epoch -286 calculated in 22.30 s
# Epoch 286, NRMSE Test/best: 0.44868/0.43203, Training NRMSE: 0.29028, deviation of 54.57%
# Epoch -287 calculated in 22.47 s
# Epoch 287, NRMSE Test/best: 0.44785/0.43203, Training NRMSE: 0.29028, deviation of 54.28%
# Epoch -288 calculated in 22.50 s
# Epoch 288, NRMSE Test/best: 0.43992/0.43203, Training NRMSE: 0.29387, deviation of 49.70%
# Epoch -289 calculated in 22.40 s
# Epoch 289, NRMSE Test/best: 0.45103/0.43203, Training NRMSE: 0.29045, deviation of 55.29%
# Epoch -290 calculated in 22.32 s
# Epoch 290, NRMSE Test/best: 0.44780/0.43203, Training NRMSE: 0.29100, deviation of 53.88%
# Epoch -291 calculated in 22.30 s
# Epoch 291, NRMSE Test/best: 0.45205/0.43203, Training NRMSE: 0.28981, deviation of 55.98%
# Epoch -292 calculated in 22.22 s
# Epoch 292, NRMSE Test/best: 0.44872/0.43203, Training NRMSE: 0.29183, deviation of 53.76%
# Epoch -293 calculated in 22.43 s
# Epoch 293, NRMSE Test/best: 0.44561/0.43203, Training NRMSE: 0.29001, deviation of 53.65%
# Epoch -294 calculated in 22.32 s
# Epoch 294, NRMSE Test/best: 0.44810/0.43203, Training NRMSE: 0.29004, deviation of 54.50%
# Epoch -295 calculated in 22.43 s
# Epoch 295, NRMSE Test/best: 0.45092/0.43203, Training NRMSE: 0.29006, deviation of 55.46%
# Epoch -296 calculated in 22.20 s
# Epoch 296, NRMSE Test/best: 0.44871/0.43203, Training NRMSE: 0.28933, deviation of 55.08%
# Epoch -297 calculated in 22.28 s
# Epoch 297, NRMSE Test/best: 0.44977/0.43203, Training NRMSE: 0.28905, deviation of 55.61%
# Epoch -298 calculated in 22.35 s
# Epoch 298, NRMSE Test/best: 0.45340/0.43203, Training NRMSE: 0.29087, deviation of 55.88%
# Epoch -299 calculated in 22.36 s
# Epoch 299, NRMSE Test/best: 0.45069/0.43203, Training NRMSE: 0.29023, deviation of 55.29%
# Epoch -300 calculated in 22.38 s
# Epoch 300, NRMSE Test/best: 0.45257/0.43203, Training NRMSE: 0.28940, deviation of 56.38%
# Epoch -301 calculated in 22.16 s
# Epoch 301, NRMSE Test/best: 0.44913/0.43203, Training NRMSE: 0.29092, deviation of 54.38%
# Epoch -302 calculated in 22.55 s
# Epoch 302, NRMSE Test/best: 0.44899/0.43203, Training NRMSE: 0.28950, deviation of 55.09%
# Epoch -303 calculated in 22.39 s
# Epoch 303, NRMSE Test/best: 0.45274/0.43203, Training NRMSE: 0.29220, deviation of 54.94%
# Epoch -304 calculated in 22.33 s
# Epoch 304, NRMSE Test/best: 0.45050/0.43203, Training NRMSE: 0.29066, deviation of 54.99%
# Epoch -305 calculated in 22.41 s
# Epoch 305, NRMSE Test/best: 0.44831/0.43203, Training NRMSE: 0.28885, deviation of 55.21%
# Epoch -306 calculated in 22.31 s
# Epoch 306, NRMSE Test/best: 0.44985/0.43203, Training NRMSE: 0.29104, deviation of 54.57%
# Epoch -307 calculated in 22.39 s
# Epoch 307, NRMSE Test/best: 0.44773/0.43203, Training NRMSE: 0.28961, deviation of 54.60%
# Epoch -308 calculated in 22.45 s
# Epoch 308, NRMSE Test/best: 0.45067/0.43203, Training NRMSE: 0.28931, deviation of 55.77%
# Epoch -309 calculated in 22.35 s
# Epoch 309, NRMSE Test/best: 0.44582/0.43203, Training NRMSE: 0.28782, deviation of 54.89%
# Epoch -310 calculated in 22.57 s
# Epoch 310, NRMSE Test/best: 0.44972/0.43203, Training NRMSE: 0.29026, deviation of 54.94%
# Epoch -311 calculated in 22.30 s
# Epoch 311, NRMSE Test/best: 0.45531/0.43203, Training NRMSE: 0.29085, deviation of 56.54%
# Epoch -312 calculated in 22.29 s
# Epoch 312, NRMSE Test/best: 0.45512/0.43203, Training NRMSE: 0.28982, deviation of 57.04%
# Epoch -313 calculated in 22.18 s
# Epoch 313, NRMSE Test/best: 0.44828/0.43203, Training NRMSE: 0.28991, deviation of 54.63%
# Epoch -314 calculated in 22.29 s
# Epoch 314, NRMSE Test/best: 0.46018/0.43203, Training NRMSE: 0.29291, deviation of 57.10%
# Epoch -315 calculated in 22.37 s
# Epoch 315, NRMSE Test/best: 0.45021/0.43203, Training NRMSE: 0.28988, deviation of 55.31%
# Epoch -316 calculated in 22.40 s
# Epoch 316, NRMSE Test/best: 0.45733/0.43203, Training NRMSE: 0.28925, deviation of 58.11%
# Epoch -317 calculated in 22.26 s
# Epoch 317, NRMSE Test/best: 0.45316/0.43203, Training NRMSE: 0.28990, deviation of 56.31%
# Epoch -318 calculated in 22.63 s
# Epoch 318, NRMSE Test/best: 0.46163/0.43203, Training NRMSE: 0.29022, deviation of 59.06%
# Epoch -319 calculated in 22.29 s
# Epoch 319, NRMSE Test/best: 0.45141/0.43203, Training NRMSE: 0.28958, deviation of 55.89%
# Epoch -320 calculated in 22.35 s
# Epoch 320, NRMSE Test/best: 0.45492/0.43203, Training NRMSE: 0.28806, deviation of 57.92%
# Epoch -321 calculated in 22.54 s
# Epoch 321, NRMSE Test/best: 0.45444/0.43203, Training NRMSE: 0.28936, deviation of 57.05%
# Epoch -322 calculated in 22.27 s
# Epoch 322, NRMSE Test/best: 0.45413/0.43203, Training NRMSE: 0.28938, deviation of 56.93%
# Epoch -323 calculated in 22.37 s
# Epoch 323, NRMSE Test/best: 0.45358/0.43203, Training NRMSE: 0.28988, deviation of 56.47%
# Epoch -324 calculated in 22.37 s
# Epoch 324, NRMSE Test/best: 0.44345/0.43203, Training NRMSE: 0.28984, deviation of 53.00%
# Epoch -325 calculated in 22.29 s
# Epoch 325, NRMSE Test/best: 0.45926/0.43203, Training NRMSE: 0.28942, deviation of 58.68%
# Epoch -326 calculated in 22.30 s
# Epoch 326, NRMSE Test/best: 0.45506/0.43203, Training NRMSE: 0.28892, deviation of 57.50%
# Epoch -327 calculated in 22.03 s
# Epoch 327, NRMSE Test/best: 0.44193/0.43203, Training NRMSE: 0.29074, deviation of 52.00%
# Epoch -328 calculated in 22.30 s
# Epoch 328, NRMSE Test/best: 0.45727/0.43203, Training NRMSE: 0.28830, deviation of 58.61%
# Epoch -329 calculated in 22.24 s
# Epoch 329, NRMSE Test/best: 0.45037/0.43203, Training NRMSE: 0.28957, deviation of 55.53%
# Epoch -330 calculated in 22.45 s
# Epoch 330, NRMSE Test/best: 0.44971/0.43203, Training NRMSE: 0.28885, deviation of 55.69%
# Epoch -331 calculated in 22.34 s
# Epoch 331, NRMSE Test/best: 0.45378/0.43203, Training NRMSE: 0.28823, deviation of 57.44%
# Epoch -332 calculated in 21.99 s
# Epoch 332, NRMSE Test/best: 0.45593/0.43203, Training NRMSE: 0.28849, deviation of 58.04%
# Epoch -333 calculated in 22.14 s
# Epoch 333, NRMSE Test/best: 0.44715/0.43203, Training NRMSE: 0.28869, deviation of 54.89%
# Epoch -334 calculated in 22.22 s
# Epoch 334, NRMSE Test/best: 0.45514/0.43203, Training NRMSE: 0.28958, deviation of 57.17%
# Epoch -335 calculated in 22.41 s
# Epoch 335, NRMSE Test/best: 0.45095/0.43203, Training NRMSE: 0.29068, deviation of 55.13%
# Epoch -336 calculated in 22.11 s
# Epoch 336, NRMSE Test/best: 0.44686/0.43203, Training NRMSE: 0.28974, deviation of 54.23%
# Epoch -337 calculated in 22.34 s
# Epoch 337, NRMSE Test/best: 0.45423/0.43203, Training NRMSE: 0.28968, deviation of 56.81%
# Epoch -338 calculated in 22.24 s
# Epoch 338, NRMSE Test/best: 0.45353/0.43203, Training NRMSE: 0.28755, deviation of 57.72%
# Epoch -339 calculated in 22.27 s
# Epoch 339, NRMSE Test/best: 0.44983/0.43203, Training NRMSE: 0.28651, deviation of 57.00%
# Epoch -340 calculated in 22.47 s
# Epoch 340, NRMSE Test/best: 0.45588/0.43203, Training NRMSE: 0.28863, deviation of 57.95%
# Epoch -341 calculated in 22.41 s
# Epoch 341, NRMSE Test/best: 0.45662/0.43203, Training NRMSE: 0.28795, deviation of 58.57%
# Epoch -342 calculated in 22.25 s
# Epoch 342, NRMSE Test/best: 0.45427/0.43203, Training NRMSE: 0.28764, deviation of 57.93%
# Epoch -343 calculated in 22.45 s
# Epoch 343, NRMSE Test/best: 0.45849/0.43203, Training NRMSE: 0.28951, deviation of 58.37%
# Epoch -344 calculated in 22.23 s
# Epoch 344, NRMSE Test/best: 0.45569/0.43203, Training NRMSE: 0.29078, deviation of 56.71%
# Epoch -345 calculated in 22.29 s
# Epoch 345, NRMSE Test/best: 0.45655/0.43203, Training NRMSE: 0.28766, deviation of 58.71%
# Epoch -346 calculated in 22.24 s
# Epoch 346, NRMSE Test/best: 0.45593/0.43203, Training NRMSE: 0.29066, deviation of 56.86%
# Epoch -347 calculated in 22.35 s
# Epoch 347, NRMSE Test/best: 0.45668/0.43203, Training NRMSE: 0.28844, deviation of 58.33%
# Epoch -348 calculated in 22.43 s
# Epoch 348, NRMSE Test/best: 0.45218/0.43203, Training NRMSE: 0.28796, deviation of 57.03%
# Epoch -349 calculated in 22.44 s
# Epoch 349, NRMSE Test/best: 0.45452/0.43203, Training NRMSE: 0.28858, deviation of 57.51%
# Epoch -350 calculated in 22.49 s
# Epoch 350, NRMSE Test/best: 0.45701/0.43203, Training NRMSE: 0.28808, deviation of 58.64%
# Epoch -351 calculated in 22.38 s
# Epoch 351, NRMSE Test/best: 0.45923/0.43203, Training NRMSE: 0.28854, deviation of 59.16%
# Epoch -352 calculated in 22.12 s
# Epoch 352, NRMSE Test/best: 0.45577/0.43203, Training NRMSE: 0.28935, deviation of 57.51%
# Epoch -353 calculated in 22.40 s
# Epoch 353, NRMSE Test/best: 0.45529/0.43203, Training NRMSE: 0.28771, deviation of 58.25%
# Epoch -354 calculated in 22.38 s
# Epoch 354, NRMSE Test/best: 0.45829/0.43203, Training NRMSE: 0.28721, deviation of 59.57%
# Epoch -355 calculated in 22.55 s
# Epoch 355, NRMSE Test/best: 0.46201/0.43203, Training NRMSE: 0.28878, deviation of 59.99%
# Epoch -356 calculated in 22.47 s
# Epoch 356, NRMSE Test/best: 0.45844/0.43203, Training NRMSE: 0.28957, deviation of 58.32%
# Epoch -357 calculated in 22.26 s
# Epoch 357, NRMSE Test/best: 0.45922/0.43203, Training NRMSE: 0.28772, deviation of 59.60%
# Epoch -358 calculated in 22.11 s
# Epoch 358, NRMSE Test/best: 0.45816/0.43203, Training NRMSE: 0.29115, deviation of 57.36%
# Epoch -359 calculated in 22.19 s
# Epoch 359, NRMSE Test/best: 0.45766/0.43203, Training NRMSE: 0.28907, deviation of 58.32%
# Epoch -360 calculated in 22.23 s
# Epoch 360, NRMSE Test/best: 0.45825/0.43203, Training NRMSE: 0.28829, deviation of 58.95%
# Epoch -361 calculated in 22.41 s
# Epoch 361, NRMSE Test/best: 0.46109/0.43203, Training NRMSE: 0.29014, deviation of 58.92%
# Epoch -362 calculated in 22.16 s
# Epoch 362, NRMSE Test/best: 0.46010/0.43203, Training NRMSE: 0.28874, deviation of 59.35%
# Epoch -363 calculated in 22.45 s
# Epoch 363, NRMSE Test/best: 0.45970/0.43203, Training NRMSE: 0.28922, deviation of 58.95%
# Epoch -364 calculated in 22.50 s
# Epoch 364, NRMSE Test/best: 0.46410/0.43203, Training NRMSE: 0.28877, deviation of 60.71%
# Epoch -365 calculated in 22.35 s
# Epoch 365, NRMSE Test/best: 0.46012/0.43203, Training NRMSE: 0.28871, deviation of 59.37%
# Epoch -366 calculated in 22.61 s
# Epoch 366, NRMSE Test/best: 0.46426/0.43203, Training NRMSE: 0.28774, deviation of 61.34%
# Epoch -367 calculated in 22.33 s
# Epoch 367, NRMSE Test/best: 0.45763/0.43203, Training NRMSE: 0.29034, deviation of 57.62%
# Epoch -368 calculated in 22.46 s
# Epoch 368, NRMSE Test/best: 0.45567/0.43203, Training NRMSE: 0.28881, deviation of 57.77%
# Epoch -369 calculated in 22.38 s
# Epoch 369, NRMSE Test/best: 0.45487/0.43203, Training NRMSE: 0.29145, deviation of 56.07%
# Epoch -370 calculated in 22.54 s
# Epoch 370, NRMSE Test/best: 0.45294/0.43203, Training NRMSE: 0.28812, deviation of 57.21%
# Epoch -371 calculated in 22.16 s
# Epoch 371, NRMSE Test/best: 0.45853/0.43203, Training NRMSE: 0.28872, deviation of 58.81%
# Epoch -372 calculated in 22.47 s
# Epoch 372, NRMSE Test/best: 0.45595/0.43203, Training NRMSE: 0.29029, deviation of 57.07%
# Epoch -373 calculated in 22.29 s
# Epoch 373, NRMSE Test/best: 0.45759/0.43203, Training NRMSE: 0.28735, deviation of 59.24%
# Epoch -374 calculated in 22.43 s
# Epoch 374, NRMSE Test/best: 0.45692/0.43203, Training NRMSE: 0.28848, deviation of 58.39%
# Epoch -375 calculated in 22.39 s
# Epoch 375, NRMSE Test/best: 0.45317/0.43203, Training NRMSE: 0.28876, deviation of 56.94%
# Epoch -376 calculated in 22.34 s
# Epoch 376, NRMSE Test/best: 0.45864/0.43203, Training NRMSE: 0.28751, deviation of 59.52%
# Epoch -377 calculated in 22.22 s
# Epoch 377, NRMSE Test/best: 0.46203/0.43203, Training NRMSE: 0.28801, deviation of 60.42%
# Epoch -378 calculated in 22.40 s
# Epoch 378, NRMSE Test/best: 0.46780/0.43203, Training NRMSE: 0.29354, deviation of 59.36%
# Epoch -379 calculated in 22.37 s
# Epoch 379, NRMSE Test/best: 0.45377/0.43203, Training NRMSE: 0.28981, deviation of 56.58%
# Epoch -380 calculated in 22.32 s
# Epoch 380, NRMSE Test/best: 0.45985/0.43203, Training NRMSE: 0.28961, deviation of 58.78%
# Epoch -381 calculated in 22.42 s
# Epoch 381, NRMSE Test/best: 0.46155/0.43203, Training NRMSE: 0.28672, deviation of 60.98%
# Epoch -382 calculated in 22.35 s
# Epoch 382, NRMSE Test/best: 0.46590/0.43203, Training NRMSE: 0.28931, deviation of 61.04%
# ...
# Epoch -1968 calculated in 22.55 s
# Epoch 1968, NRMSE Test/best: 0.45450/0.42769, Training NRMSE: 0.27290, deviation of 66.55%
# Epoch -1969 calculated in 22.34 s
# Epoch 1969, NRMSE Test/best: 0.47184/0.42769, Training NRMSE: 0.27754, deviation of 70.01%
# Epoch -1970 calculated in 22.32 s
# Epoch 1970, NRMSE Test/best: 0.45360/0.42769, Training NRMSE: 0.27537, deviation of 64.72%
# Epoch -1971 calculated in 22.44 s
# Epoch 1971, NRMSE Test/best: 0.45506/0.42769, Training NRMSE: 0.27801, deviation of 63.69%
# Epoch -1972 calculated in 22.40 s
# Epoch 1972, NRMSE Test/best: 0.44978/0.42769, Training NRMSE: 0.27486, deviation of 63.64%
# Epoch -1973 calculated in 22.49 s
# Epoch 1973, NRMSE Test/best: 0.45161/0.42769, Training NRMSE: 0.27574, deviation of 63.78%
# Epoch -1974 calculated in 22.40 s
# Epoch 1974, NRMSE Test/best: 0.45607/0.42769, Training NRMSE: 0.27501, deviation of 65.84%
# Epoch -1975 calculated in 22.57 s
# Epoch 1975, NRMSE Test/best: 0.45415/0.42769, Training NRMSE: 0.27322, deviation of 66.22%
# Epoch -1976 calculated in 22.38 s
# Epoch 1976, NRMSE Test/best: 0.45818/0.42769, Training NRMSE: 0.27341, deviation of 67.58%
# Epoch -1977 calculated in 22.35 s
# Epoch 1977, NRMSE Test/best: 0.44598/0.42769, Training NRMSE: 0.27750, deviation of 60.71%
# Epoch -1978 calculated in 22.34 s
# Epoch 1978, NRMSE Test/best: 0.45379/0.42769, Training NRMSE: 0.27649, deviation of 64.12%
# Epoch -1979 calculated in 22.65 s
# Epoch 1979, NRMSE Test/best: 0.45563/0.42769, Training NRMSE: 0.27487, deviation of 65.76%
# Epoch -1980 calculated in 22.32 s
# Epoch 1980, NRMSE Test/best: 0.45398/0.42769, Training NRMSE: 0.27448, deviation of 65.40%
# Epoch -1981 calculated in 22.52 s
# Epoch 1981, NRMSE Test/best: 0.45723/0.42769, Training NRMSE: 0.27750, deviation of 64.77%
# Epoch -1982 calculated in 22.66 s
# Epoch 1982, NRMSE Test/best: 0.45671/0.42769, Training NRMSE: 0.27481, deviation of 66.20%
# Epoch -1983 calculated in 22.35 s
# Epoch 1983, NRMSE Test/best: 0.45603/0.42769, Training NRMSE: 0.27738, deviation of 64.41%
# Epoch -1984 calculated in 22.33 s
# Epoch 1984, NRMSE Test/best: 0.45237/0.42769, Training NRMSE: 0.27411, deviation of 65.03%
# Epoch -1985 calculated in 22.49 s
# Epoch 1985, NRMSE Test/best: 0.47179/0.42769, Training NRMSE: 0.27418, deviation of 72.07%
# Epoch -1986 calculated in 22.47 s
# Epoch 1986, NRMSE Test/best: 0.46027/0.42769, Training NRMSE: 0.27355, deviation of 68.26%
# Epoch -1987 calculated in 22.35 s
# Epoch 1987, NRMSE Test/best: 0.46672/0.42769, Training NRMSE: 0.27476, deviation of 69.86%
# Epoch -1988 calculated in 22.38 s
# Epoch 1988, NRMSE Test/best: 0.45123/0.42769, Training NRMSE: 0.27599, deviation of 63.50%
# Epoch -1989 calculated in 22.30 s
# Epoch 1989, NRMSE Test/best: 0.45172/0.42769, Training NRMSE: 0.27329, deviation of 65.29%
# Epoch -1990 calculated in 22.37 s
# Epoch 1990, NRMSE Test/best: 0.45664/0.42769, Training NRMSE: 0.27338, deviation of 67.04%
# Epoch -1991 calculated in 22.42 s
# Epoch 1991, NRMSE Test/best: 0.45331/0.42769, Training NRMSE: 0.27318, deviation of 65.94%
# Epoch -1992 calculated in 22.22 s
# Epoch 1992, NRMSE Test/best: 0.46929/0.42769, Training NRMSE: 0.27631, deviation of 69.84%
# Epoch -1993 calculated in 22.25 s
# Epoch 1993, NRMSE Test/best: 0.45500/0.42769, Training NRMSE: 0.27758, deviation of 63.91%
# Epoch -1994 calculated in 22.21 s
# Epoch 1994, NRMSE Test/best: 0.46243/0.42769, Training NRMSE: 0.27425, deviation of 68.62%
# Epoch -1995 calculated in 22.53 s
# Epoch 1995, NRMSE Test/best: 0.46149/0.42769, Training NRMSE: 0.27511, deviation of 67.75%
# Epoch -1996 calculated in 22.49 s
# Epoch 1996, NRMSE Test/best: 0.46134/0.42769, Training NRMSE: 0.27510, deviation of 67.70%
# Epoch -1997 calculated in 22.52 s
# Epoch 1997, NRMSE Test/best: 0.45348/0.42769, Training NRMSE: 0.27531, deviation of 64.72%
# Epoch -1998 calculated in 22.34 s
# Epoch 1998, NRMSE Test/best: 0.46234/0.42769, Training NRMSE: 0.27736, deviation of 66.70%
# Epoch -1999 calculated in 22.49 s
# Epoch 1999, NRMSE Test/best: 0.46042/0.42769, Training NRMSE: 0.27505, deviation of 67.39%
# Epoch -2000 calculated in 22.37 s
# Epoch 2000, NRMSE Test/best: 0.45614/0.42769, Training NRMSE: 0.27622, deviation of 65.13%
# Epoch -2001 calculated in 22.38 s
# Epoch 2001, NRMSE Test/best: 0.45784/0.42769, Training NRMSE: 0.27638, deviation of 65.66%
# Epoch -2002 calculated in 22.41 s
# Epoch 2002, NRMSE Test/best: 0.45993/0.42769, Training NRMSE: 0.27325, deviation of 68.32%
# Epoch -2003 calculated in 22.18 s
# Epoch 2003, NRMSE Test/best: 0.47093/0.42769, Training NRMSE: 0.27683, deviation of 70.11%
# Epoch -2004 calculated in 22.39 s
# Epoch 2004, NRMSE Test/best: 0.46260/0.42769, Training NRMSE: 0.27557, deviation of 67.87%
# Epoch -2005 calculated in 22.65 s
# Epoch 2005, NRMSE Test/best: 0.46003/0.42769, Training NRMSE: 0.27543, deviation of 67.03%
# Epoch -2006 calculated in 22.36 s
# Epoch 2006, NRMSE Test/best: 0.45975/0.42769, Training NRMSE: 0.27503, deviation of 67.16%
# Epoch -2007 calculated in 22.26 s
# Epoch 2007, NRMSE Test/best: 0.46865/0.42769, Training NRMSE: 0.27693, deviation of 69.23%
# Epoch -2008 calculated in 22.52 s
# Epoch 2008, NRMSE Test/best: 0.45979/0.42769, Training NRMSE: 0.27592, deviation of 66.64%
# Epoch -2009 calculated in 22.26 s
# Epoch 2009, NRMSE Test/best: 0.45637/0.42769, Training NRMSE: 0.27548, deviation of 65.66%
# Epoch -2010 calculated in 22.22 s
# Epoch 2010, NRMSE Test/best: 0.45905/0.42769, Training NRMSE: 0.27498, deviation of 66.94%
# Epoch -2011 calculated in 22.15 s
# Epoch 2011, NRMSE Test/best: 0.45237/0.42769, Training NRMSE: 0.27474, deviation of 64.65%
# Epoch -2012 calculated in 22.33 s
# Epoch 2012, NRMSE Test/best: 0.46498/0.42769, Training NRMSE: 0.27572, deviation of 68.64%
# Epoch -2013 calculated in 22.45 s
# Epoch 2013, NRMSE Test/best: 0.46375/0.42769, Training NRMSE: 0.27832, deviation of 66.63%
# Epoch -2014 calculated in 22.49 s
# Epoch 2014, NRMSE Test/best: 0.45778/0.42769, Training NRMSE: 0.27630, deviation of 65.69%
# Epoch -2015 calculated in 22.37 s
# Epoch 2015, NRMSE Test/best: 0.46394/0.42769, Training NRMSE: 0.27647, deviation of 67.81%
# Epoch -2016 calculated in 22.47 s
# Epoch 2016, NRMSE Test/best: 0.46261/0.42769, Training NRMSE: 0.27524, deviation of 68.08%
# Epoch -2017 calculated in 22.38 s
# Epoch 2017, NRMSE Test/best: 0.47634/0.42769, Training NRMSE: 0.27484, deviation of 73.31%
# Epoch -2018 calculated in 22.24 s
# Epoch 2018, NRMSE Test/best: 0.45978/0.42769, Training NRMSE: 0.27592, deviation of 66.64%
# Epoch -2019 calculated in 22.63 s
# Epoch 2019, NRMSE Test/best: 0.46717/0.42769, Training NRMSE: 0.27392, deviation of 70.55%
# Epoch -2020 calculated in 22.39 s
# Epoch 2020, NRMSE Test/best: 0.46141/0.42769, Training NRMSE: 0.27394, deviation of 68.44%
# Epoch -2021 calculated in 22.38 s
# Epoch 2021, NRMSE Test/best: 0.46737/0.42769, Training NRMSE: 0.27514, deviation of 69.86%
# Epoch -2022 calculated in 22.31 s
# Epoch 2022, NRMSE Test/best: 0.45961/0.42769, Training NRMSE: 0.27558, deviation of 66.78%
# Epoch -2023 calculated in 22.45 s
# Epoch 2023, NRMSE Test/best: 0.45590/0.42769, Training NRMSE: 0.27541, deviation of 65.54%
# Epoch -2024 calculated in 22.48 s
# Epoch 2024, NRMSE Test/best: 0.46498/0.42769, Training NRMSE: 0.27590, deviation of 68.53%
# Epoch -2025 calculated in 22.39 s
# Epoch 2025, NRMSE Test/best: 0.45862/0.42769, Training NRMSE: 0.27692, deviation of 65.61%
# Epoch -2026 calculated in 22.47 s
# Epoch 2026, NRMSE Test/best: 0.45537/0.42769, Training NRMSE: 0.27519, deviation of 65.48%
# Epoch -2027 calculated in 22.54 s
# Epoch 2027, NRMSE Test/best: 0.46867/0.42769, Training NRMSE: 0.27713, deviation of 69.12%
# Epoch -2028 calculated in 22.44 s
# Epoch 2028, NRMSE Test/best: 0.45458/0.42769, Training NRMSE: 0.27620, deviation of 64.58%
# Epoch -2029 calculated in 22.55 s
# Epoch 2029, NRMSE Test/best: 0.45465/0.42769, Training NRMSE: 0.27457, deviation of 65.58%
# Epoch -2030 calculated in 22.57 s
# Epoch 2030, NRMSE Test/best: 0.44738/0.42769, Training NRMSE: 0.27681, deviation of 61.62%
# Epoch -2031 calculated in 22.24 s
# Epoch 2031, NRMSE Test/best: 0.44595/0.42769, Training NRMSE: 0.27469, deviation of 62.35%
# Epoch -2032 calculated in 22.33 s
# Epoch 2032, NRMSE Test/best: 0.44373/0.42769, Training NRMSE: 0.27873, deviation of 59.20%
# Epoch -2033 calculated in 22.51 s
# Epoch 2033, NRMSE Test/best: 0.44345/0.42769, Training NRMSE: 0.27510, deviation of 61.20%
# Epoch -2034 calculated in 22.37 s
# Epoch 2034, NRMSE Test/best: 0.43381/0.42769, Training NRMSE: 0.27336, deviation of 58.69%
# Epoch -2035 calculated in 22.33 s
# Epoch 2035, NRMSE Test/best: 0.44060/0.42769, Training NRMSE: 0.27575, deviation of 59.78%
# Epoch -2036 calculated in 22.52 s
# Epoch 2036, NRMSE Test/best: 0.44490/0.42769, Training NRMSE: 0.27325, deviation of 62.82%
# Epoch -2037 calculated in 22.28 s
# Epoch 2037, NRMSE Test/best: 0.45073/0.42769, Training NRMSE: 0.27675, deviation of 62.87%
# Epoch -2038 calculated in 22.17 s
# Epoch 2038, NRMSE Test/best: 0.44568/0.42769, Training NRMSE: 0.27433, deviation of 62.46%
# Epoch -2039 calculated in 22.41 s
# Epoch 2039, NRMSE Test/best: 0.44167/0.42769, Training NRMSE: 0.27511, deviation of 60.54%
# Epoch -2040 calculated in 22.37 s
# Epoch 2040, NRMSE Test/best: 0.44614/0.42769, Training NRMSE: 0.27646, deviation of 61.38%
# Epoch -2041 calculated in 22.44 s
# Epoch 2041, NRMSE Test/best: 0.44448/0.42769, Training NRMSE: 0.27498, deviation of 61.64%
# Epoch -2042 calculated in 22.40 s
# Epoch 2042, NRMSE Test/best: 0.45160/0.42769, Training NRMSE: 0.27245, deviation of 65.76%
# Epoch -2043 calculated in 22.36 s
# Epoch 2043, NRMSE Test/best: 0.44280/0.42769, Training NRMSE: 0.27519, deviation of 60.91%
# Epoch -2044 calculated in 22.10 s
# Epoch 2044, NRMSE Test/best: 0.44762/0.42769, Training NRMSE: 0.27340, deviation of 63.73%
# Epoch -2045 calculated in 22.55 s
# Epoch 2045, NRMSE Test/best: 0.44966/0.42769, Training NRMSE: 0.27789, deviation of 61.82%
# Epoch -2046 calculated in 22.64 s
# Epoch 2046, NRMSE Test/best: 0.45193/0.42769, Training NRMSE: 0.27300, deviation of 65.54%
# Epoch -2047 calculated in 22.41 s
# Epoch 2047, NRMSE Test/best: 0.45164/0.42769, Training NRMSE: 0.27313, deviation of 65.35%
# Epoch -2048 calculated in 22.61 s
# Epoch 2048, NRMSE Test/best: 0.45041/0.42769, Training NRMSE: 0.27435, deviation of 64.18%
# Epoch -2049 calculated in 22.39 s
# Epoch 2049, NRMSE Test/best: 0.44701/0.42769, Training NRMSE: 0.27524, deviation of 62.41%
# Epoch -2050 calculated in 22.35 s
# Epoch 2050, NRMSE Test/best: 0.44876/0.42769, Training NRMSE: 0.27310, deviation of 64.32%
# Epoch -2051 calculated in 22.41 s
# Epoch 2051, NRMSE Test/best: 0.45542/0.42769, Training NRMSE: 0.27830, deviation of 63.64%
# Epoch -2052 calculated in 22.55 s
# Epoch 2052, NRMSE Test/best: 0.44938/0.42769, Training NRMSE: 0.27410, deviation of 63.95%
# Epoch -2053 calculated in 22.34 s
# Epoch 2053, NRMSE Test/best: 0.45563/0.42769, Training NRMSE: 0.27384, deviation of 66.39%
# Epoch -2054 calculated in 22.52 s
# Epoch 2054, NRMSE Test/best: 0.44823/0.42769, Training NRMSE: 0.27420, deviation of 63.47%
# Epoch -2055 calculated in 22.44 s
# Epoch 2055, NRMSE Test/best: 0.45835/0.42769, Training NRMSE: 0.27439, deviation of 67.04%
# Epoch -2056 calculated in 22.27 s
# Epoch 2056, NRMSE Test/best: 0.45754/0.42769, Training NRMSE: 0.27464, deviation of 66.60%
# Epoch -2057 calculated in 22.42 s
# Epoch 2057, NRMSE Test/best: 0.45847/0.42769, Training NRMSE: 0.27416, deviation of 67.23%
# Epoch -2058 calculated in 22.43 s
# Epoch 2058, NRMSE Test/best: 0.44394/0.42769, Training NRMSE: 0.27559, deviation of 61.08%
# Epoch -2059 calculated in 22.39 s
# Epoch 2059, NRMSE Test/best: 0.46135/0.42769, Training NRMSE: 0.27401, deviation of 68.37%
# Epoch -2060 calculated in 22.44 s
# Epoch 2060, NRMSE Test/best: 0.45398/0.42769, Training NRMSE: 0.27494, deviation of 65.12%
# Epoch -2061 calculated in 22.40 s
# Epoch 2061, NRMSE Test/best: 0.45704/0.42769, Training NRMSE: 0.28020, deviation of 63.11%
# Epoch -2062 calculated in 22.09 s
# Epoch 2062, NRMSE Test/best: 0.44630/0.42769, Training NRMSE: 0.28478, deviation of 56.72%
# Epoch -2063 calculated in 22.42 s
# Epoch 2063, NRMSE Test/best: 0.45867/0.42769, Training NRMSE: 0.27593, deviation of 66.23%
# Epoch -2064 calculated in 22.60 s
# Epoch 2064, NRMSE Test/best: 0.44920/0.42769, Training NRMSE: 0.27517, deviation of 63.24%
# Epoch -2065 calculated in 22.47 s
# Epoch 2065, NRMSE Test/best: 0.45940/0.42769, Training NRMSE: 0.27392, deviation of 67.71%
# Epoch -2066 calculated in 22.39 s
# Epoch 2066, NRMSE Test/best: 0.45487/0.42769, Training NRMSE: 0.27375, deviation of 66.16%
# Epoch -2067 calculated in 22.29 s
# Epoch 2067, NRMSE Test/best: 0.46099/0.42769, Training NRMSE: 0.27731, deviation of 66.23%
# Epoch -2068 calculated in 22.25 s
# Epoch 2068, NRMSE Test/best: 0.45066/0.42769, Training NRMSE: 0.27360, deviation of 64.71%
# Epoch -2069 calculated in 22.49 s
# Epoch 2069, NRMSE Test/best: 0.45898/0.42769, Training NRMSE: 0.27431, deviation of 67.32%
# Epoch -2070 calculated in 22.48 s
# Epoch 2070, NRMSE Test/best: 0.45114/0.42769, Training NRMSE: 0.27430, deviation of 64.47%
# Epoch -2071 calculated in 22.47 s
# Epoch 2071, NRMSE Test/best: 0.46034/0.42769, Training NRMSE: 0.27254, deviation of 68.90%
# Epoch -2072 calculated in 22.34 s
# Epoch 2072, NRMSE Test/best: 0.45510/0.42769, Training NRMSE: 0.27383, deviation of 66.20%
# Epoch -2073 calculated in 22.55 s
# Epoch 2073, NRMSE Test/best: 0.45212/0.42769, Training NRMSE: 0.27340, deviation of 65.37%
# Epoch -2074 calculated in 22.41 s
# Epoch 2074, NRMSE Test/best: 0.47027/0.42769, Training NRMSE: 0.27814, deviation of 69.08%
# Epoch -2075 calculated in 22.40 s
# Epoch 2075, NRMSE Test/best: 0.45543/0.42769, Training NRMSE: 0.27568, deviation of 65.20%
# Epoch -2076 calculated in 22.37 s
# Epoch 2076, NRMSE Test/best: 0.46337/0.42769, Training NRMSE: 0.27381, deviation of 69.23%
# Epoch -2077 calculated in 22.38 s
# Epoch 2077, NRMSE Test/best: 0.46325/0.42769, Training NRMSE: 0.27379, deviation of 69.20%
# Epoch -2078 calculated in 22.39 s
# Epoch 2078, NRMSE Test/best: 0.46160/0.42769, Training NRMSE: 0.27569, deviation of 67.43%
# Epoch -2079 calculated in 22.47 s
# Epoch 2079, NRMSE Test/best: 0.45743/0.42769, Training NRMSE: 0.28383, deviation of 61.16%
# Training duration 01:15:00:14
# Number of training variable 927226
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/freeze_graph.py:249: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from Experiments/2019-05-16-11-30/temp/myFinalModel.ckpt
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/freeze_graph.py:232: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.convert_variables_to_constants
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/graph_util_impl.py:245: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph
# INFO:tensorflow:Froze 8 variables.
# INFO:tensorflow:Converted 8 variables to const ops.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/optimize_for_inference_lib.py:113: remove_training_nodes (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.remove_training_nodes
# done, good job kids

# %%
from show import *
# %matplotlib notebook
showPickle(nameFigEstimation)
# Out:
# <img src="data:image/png;base64,..." width="640">
