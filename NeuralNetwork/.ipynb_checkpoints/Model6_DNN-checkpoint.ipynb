# %% [markdown]
# # Learn DNN model 6

# %% [markdown]
# DNN_model6 uses severals layers of feedforward neural network.
# Dataset can be downloaded in http://www.montefiore.ulg.ac.be/services/acous/STSI/downloads.php

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
import os
import sys
sys.path.append('Codes')
import tensorflow as tf
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import pickle
from dataShaping import *
from savePerf import *
from saveTransformedGraph import optimizeGraph
import scipy.io.wavfile
import time
from tensorflow.contrib.layers import fully_connected
from tensorflow.contrib.rnn import *


modelName = "DNN1"
# create directory experiment
date = time.strftime("%Y-%m-%d-%H-%M")
path = os.path.join("Experiments",date)
if not os.path.isdir(path):
    os.makedirs(path)
    #experiment/"date"/temp will contain the backuped model parameters
    pathTemp = os.path.join(path,'temp')
    os.makedirs(pathTemp)
    # if you run the file two time in a minute
else :
    date = date+'(2)'
    path = os.path.join("Experiments",date)
    os.makedirs(path)
    pathTemp = os.path.join(path,'temp')
    os.makedirs(pathTemp)

# directory that will contain tensorboard information
pathLog = 'Tf_logs'
if not os.path.isdir(pathLog):
    os.makedirs(pathLog)
pathLog = "{}/run-{}/".format(pathLog,date)

version = tf.__version__
print ("version {} of tensorflow".format(version))

#############################
# Model parameters
#############################
trainTestRatio = 0.8
#if you cannot load all the data set in Ram specify wich part you want to load (0 means all the dataset)
maxSize = 0
num_step = 150                                       
num_hidden = 1000                                      
num_out = 1                                         # size of the output
num_feature = 1                                     # size of the input
batch_size = 2500                                   
n_layer = 1                                         

#num_hidden = num_hidden/keep_prob
num_epoch = 10000                                    
trainDuration = 60*60*15                             
amplifierName = 'EnglDisto'
fileNameTrain = 'Datasets/training'+amplifierName+'.mat' # dataset train/test path
fileNameTest = 'Datasets/test'+amplifierName+'.mat'      # dataset validation path
fileNameValidation = 'Datasets/val'+amplifierName+'.mat'

#############################
# Loading data
#############################
matrix = sio.loadmat(fileNameTrain)
matrixTrain = matrix['train']
matrix = sio.loadmat(fileNameTest)
matrixTest = matrix['test']
if maxSize ==0:
    maxSize = len(matrixTrain)
    print("maxSize = {}".format(maxSize))

train_input,train_output,test_input,test_output = loadInputOutputSeq(matrixTrain,matrixTest,num_step,maxSize)


print("shape input train {}".format(np.shape(train_input)))
numTrain = len(train_output)
print ("Data loaded")
#######################
# Graph Construction
#######################

G = tf.Graph()
with G.as_default():
    with tf.name_scope("placeHolder"):
        data = tf.placeholder(tf.float32, [None, num_step], name ="data") 
        target = tf.placeholder(tf.float32, [None, num_out],name = "target") 
        
    with tf.variable_scope("DNNLayers"):
        FC1 = fully_connected(data,1000,activation_fn=tf.nn.relu,weights_regularizer=None,scope="FC1")
        FC2 = fully_connected(FC1,500,activation_fn=tf.nn.relu,weights_regularizer=None,scope="FC2")

        
    prediction = fully_connected(FC2,int(target.get_shape()[1]),activation_fn=tf.nn.tanh,weights_regularizer=None,scope="FCPred")

    #Compute the mean square error
    MSE = tf.reduce_mean(tf.square(prediction-target))
    EnergyTarget = tf.reduce_mean(tf.square(target)) 
    
    #get regularizer
    reg_losses = tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES)
    MSEReg = tf.add_n([MSE]+reg_losses,name="MSEReg")
    # create optimizer
    optimizer = tf.train.AdamOptimizer()
    #Compute gradient and apply backpropagation
    minimize = optimizer.minimize(MSEReg)

    # Create summary view for tensorboard
    mse_summary = tf.summary.scalar('RMSE',tf.sqrt(MSE))
    summary_op = tf.summary.merge_all()
    
    #Create an init op to initialize variable
    init_op = tf.global_variables_initializer()
    saver = tf.train.Saver() 
##############################
# Graph execution
##############################
    
with tf.Session(graph=G) as sess:

    sess.run(init_op)
    train_writer = tf.summary.FileWriter(pathLog+'train',graph =tf.get_default_graph())
    test_writer = tf.summary.FileWriter(pathLog+'test')
    
    no_of_batches = int(np.floor((numTrain)/batch_size)) 
    no_of_batchesTest = int(np.floor((len(test_input))/batch_size))
    tStart = time.clock()
    epoch =0
    NRMSETest = 10
    bestNRMSETest = 1    
    # train until the number of epochs or the training time is reached
    for epoch in range(num_epoch):
        tEpoch = time.clock()
        if (time.clock()-tStart < trainDuration) :
            ptr = 0
            if epoch % 20==0 : # each twenty epochs save the model
                tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myGraph.pb',as_text=False)
                save_path = saver.save(sess,os.path.join(pathTemp,'myModel.ckpt'))
            
            pMSETrain=0
            pEnergyTarget=0
            for j in range(no_of_batches):
                inp, out = train_input[ptr:ptr+batch_size],train_output[ptr:ptr+batch_size]
                ptr+=batch_size
                
                if j % np.floor(numTrain/len(test_input)) ==0 : # This is to have a train summary and a test summary of the same size
                    _,summary_str,pMSETrainTemp,pEnergyTargetTemp = sess.run([minimize,summary_op,MSE,EnergyTarget],{data: inp, target: out})
                    pMSETrain += pMSETrainTemp
                    pEnergyTarget += pEnergyTargetTemp
                    step = epoch*no_of_batches+j
                    # save the training RMSE for tensorboard
                    train_writer.add_summary(summary_str,step)                   

                else :
                    _,pMSETrainTemp,pEnergyTargetTemp = sess.run([minimize,MSE,EnergyTarget],{data: inp, target: out})
                    pMSETrain += pMSETrainTemp
                    pEnergyTarget += pEnergyTargetTemp
            # compute an estimation of the RMSE for this epoch       
            MSETrain = pMSETrain/no_of_batches
            EnergyTargetTrain = pEnergyTarget/no_of_batches
            NRMSETrain = np.sqrt(MSETrain/EnergyTargetTrain)
            print ("Epoch -{} calculated in {:5.2f} s ".format(epoch,time.clock()-tEpoch))
            # evaluate the model on the test set 
            pMSE = 0
            ptr2 = 0
            pEnergyTarget = 0
            for k in range(no_of_batchesTest):
                pMSETemp,pEnergyTargetTemp,summary_str = sess.run([MSE,EnergyTarget,summary_op],{data: test_input[ptr2:ptr2+batch_size] , target: test_output[ptr2:ptr2+batch_size]})
                pMSE += pMSETemp
                ptr2 += batch_size
                pEnergyTarget+=pEnergyTargetTemp
                step = epoch*no_of_batchesTest+k
                test_writer.add_summary(summary_str,step*np.floor(numTrain/len(test_input)))
            MSETest = pMSE/no_of_batchesTest
            EnergyTargetTest = pEnergyTarget/no_of_batchesTest
            NRMSETest = np.sqrt(MSETest/EnergyTargetTest)
            if NRMSETest<bestNRMSETest:
                bestNRMSETest=NRMSETest
                tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myBestGraph.pbtxt',as_text=True)
                save_path = saver.save(sess,os.path.join(pathTemp,'myBestModel.ckpt'))
            print("Epoch {}, NRMSE Test/best: {:.5f}/{:.5f}, Training NRMSE: {:.5f}, deviation of {:.2f}%".format(epoch,NRMSETest,bestNRMSETest,NRMSETrain,100*np.sqrt((NRMSETrain-NRMSETest)**2)/NRMSETrain))
        else : break # break the while loop if number of epoch is reached
    tStop = time.clock()
    trainTime = time.strftime("%d:%H:%M:%S ", time.gmtime(tStop-tStart))
    
    ################################################################
    # Save Graph variable and information about the running session
    ################################################################
    tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myFinalGraph.pbtxt',as_text=True)
    # Save checkpoint variables
    save_path = saver.save(sess,os.path.join(pathTemp,'myFinalModel.ckpt'))
    print ("Training duration {}".format(trainTime))
    totalParameters =np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.trainable_variables()])
    print("Number of training variable {}".format(totalParameters))
    # log
    infoLog={}
    infoLog["path"] = path
    infoLog["MSE"] =bestNRMSETest
    infoLog["num_step"] = num_step
    infoLog["num_hidden"] = num_hidden
    infoLog["num_epoch"] = epoch
    infoLog["batch_size"] = batch_size
    infoLog["maxSize"] = maxSize
    infoLog["duration"] = trainTime
    infoLog["totalParameters"] = totalParameters
    infoLog["version"] = version
    infoLog["n_layer"] = n_layer
    infoLog["trainDropout"] = 0
    infoLog["nameModel"] = modelName
    infoLog["conv_chan"] = conv_chan
    infoLog["strides"] = conv_strides
    infoLog["conv_size"] = conv_size
    infoLog["amplifierName"]=amplifierName
    logPerf(infoLog)
    input_nodes=["placeHolder/data"]
    output_nodes=["FCPred/Tanh"]
    optimizeGraph(pathTemp,input_nodes,output_nodes)
    
    
                                                 
    
    ###############################
    #   Validation
    ###############################
    restorePath = os.path.join(pathTemp,'myBestModel.ckpt') # restore best model
    saver.restore(sess,restorePath)
    matrixVal = sio.loadmat(fileNameValidation)
    matrixVal = matrixVal['val']  
    valSize = 0
    if valSize == 0 :
        valSize = len(matrixVal)

    val_input,val_output = loadValidationSeq(matrixVal,num_step,valSize)
    lPrediction = []
    lTarget = []
    ptr3 = 0
    no_of_batchesVal = int(np.floor((len(val_input))/batch_size))
    for k in range(no_of_batchesVal):
        pPrediction,pTarget = sess.run([prediction,target],{data: val_input[ptr3:ptr3+batch_size], target: val_output[ptr3:ptr3+batch_size]}) 
        lPrediction.append(pPrediction)
        lTarget.append(pTarget)   
        ptr3+=batch_size

    predictionArray = np.array(lPrediction,dtype=np.float32).ravel()
    targetArray = np.array(lTarget,dtype=np.float32).ravel()
    scipy.io.wavfile.write(os.path.join(path,'prediction.wav'),44100,predictionArray)
    scipy.io.wavfile.write(os.path.join(path,'target.wav'),44100,targetArray)

    # save emulation in a pickle format
    ax = plt.subplot(111)
    ax.plot(predictionArray[6000+num_step:6700+num_step],label='prediction')
    ax.plot(targetArray[6000+num_step:6700+num_step],label='target')
    ax.legend()
    plt.xlabel('sample n')
    plt.ylabel('Amplitude y[n]')
    nameFigEstimation = os.path.join(path,"targetVsPrediction.pickle")
    pickle.dump(ax,open(nameFigEstimation, 'wb'))
print ("done, good job kids")
# Out:
# version 1.13.1 of tensorflow
# maxSize = 6726407
# shape input train (6726258, 150)
# Data loaded
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Epoch -0 calculated in 13.50 s
# Epoch 0, NRMSE Test/best: 0.91180/0.91180, Training NRMSE: 0.55724, deviation of 63.63%
# Epoch -1 calculated in 13.59 s
# Epoch 1, NRMSE Test/best: 0.74511/0.74511, Training NRMSE: 0.49209, deviation of 51.42%
# Epoch -2 calculated in 13.26 s
# Epoch 2, NRMSE Test/best: 0.70033/0.70033, Training NRMSE: 0.45948, deviation of 52.42%
# Epoch -3 calculated in 13.47 s
# Epoch 3, NRMSE Test/best: 0.65866/0.65866, Training NRMSE: 0.43310, deviation of 52.08%
# Epoch -4 calculated in 13.26 s
# Epoch 4, NRMSE Test/best: 0.59485/0.59485, Training NRMSE: 0.42728, deviation of 39.22%
# Epoch -5 calculated in 13.38 s
# Epoch 5, NRMSE Test/best: 0.60607/0.59485, Training NRMSE: 0.41431, deviation of 46.28%
# Epoch -6 calculated in 13.45 s
# Epoch 6, NRMSE Test/best: 0.56785/0.56785, Training NRMSE: 0.41185, deviation of 37.88%
# Epoch -7 calculated in 13.76 s
# Epoch 7, NRMSE Test/best: 0.54068/0.54068, Training NRMSE: 0.40388, deviation of 33.87%
# Epoch -8 calculated in 13.49 s
# Epoch 8, NRMSE Test/best: 0.51686/0.51686, Training NRMSE: 0.39836, deviation of 29.75%
# Epoch -9 calculated in 13.80 s
# Epoch 9, NRMSE Test/best: 0.55140/0.51686, Training NRMSE: 0.39612, deviation of 39.20%
# Epoch -10 calculated in 13.91 s
# Epoch 10, NRMSE Test/best: 0.49912/0.49912, Training NRMSE: 0.39317, deviation of 26.95%
# Epoch -11 calculated in 13.13 s
# Epoch 11, NRMSE Test/best: 0.51158/0.49912, Training NRMSE: 0.38839, deviation of 31.72%
# Epoch -12 calculated in 13.45 s
# Epoch 12, NRMSE Test/best: 0.50294/0.49912, Training NRMSE: 0.38701, deviation of 29.96%
# Epoch -13 calculated in 13.02 s
# Epoch 13, NRMSE Test/best: 0.48302/0.48302, Training NRMSE: 0.38686, deviation of 24.86%
# Epoch -14 calculated in 13.78 s
# Epoch 14, NRMSE Test/best: 0.48477/0.48302, Training NRMSE: 0.38150, deviation of 27.07%
# Epoch -15 calculated in 13.65 s
# Epoch 15, NRMSE Test/best: 0.48419/0.48302, Training NRMSE: 0.38096, deviation of 27.10%
# Epoch -16 calculated in 13.52 s
# Epoch 16, NRMSE Test/best: 0.46650/0.46650, Training NRMSE: 0.38142, deviation of 22.31%
# Epoch -17 calculated in 13.85 s
# Epoch 17, NRMSE Test/best: 0.46761/0.46650, Training NRMSE: 0.37988, deviation of 23.10%
# Epoch -18 calculated in 13.95 s
# Epoch 18, NRMSE Test/best: 0.46499/0.46499, Training NRMSE: 0.37592, deviation of 23.69%
# Epoch -19 calculated in 13.54 s
# Epoch 19, NRMSE Test/best: 0.46403/0.46403, Training NRMSE: 0.37568, deviation of 23.52%
# Epoch -20 calculated in 14.17 s
# Epoch 20, NRMSE Test/best: 0.45448/0.45448, Training NRMSE: 0.37167, deviation of 22.28%
# Epoch -21 calculated in 13.68 s
# Epoch 21, NRMSE Test/best: 0.45367/0.45367, Training NRMSE: 0.37461, deviation of 21.10%
# Epoch -22 calculated in 14.01 s
# Epoch 22, NRMSE Test/best: 0.45188/0.45188, Training NRMSE: 0.37584, deviation of 20.23%
# Epoch -23 calculated in 13.65 s
# Epoch 23, NRMSE Test/best: 0.45625/0.45188, Training NRMSE: 0.37070, deviation of 23.08%
# Epoch -24 calculated in 14.03 s
# Epoch 24, NRMSE Test/best: 0.45551/0.45188, Training NRMSE: 0.36842, deviation of 23.64%
# Epoch -25 calculated in 14.18 s
# Epoch 25, NRMSE Test/best: 0.45406/0.45188, Training NRMSE: 0.36947, deviation of 22.89%
# Epoch -26 calculated in 13.72 s
# Epoch 26, NRMSE Test/best: 0.44669/0.44669, Training NRMSE: 0.36659, deviation of 21.85%
# Epoch -27 calculated in 14.05 s
# Epoch 27, NRMSE Test/best: 0.45159/0.44669, Training NRMSE: 0.36533, deviation of 23.61%
# Epoch -28 calculated in 13.57 s
# Epoch 28, NRMSE Test/best: 0.45203/0.44669, Training NRMSE: 0.36633, deviation of 23.40%
# Epoch -29 calculated in 13.85 s
# Epoch 29, NRMSE Test/best: 0.45276/0.44669, Training NRMSE: 0.36663, deviation of 23.49%
# Epoch -30 calculated in 14.25 s
# Epoch 30, NRMSE Test/best: 0.45934/0.44669, Training NRMSE: 0.36605, deviation of 25.49%
# Epoch -31 calculated in 13.96 s
# Epoch 31, NRMSE Test/best: 0.44975/0.44669, Training NRMSE: 0.36630, deviation of 22.78%
# Epoch -32 calculated in 14.13 s
# Epoch 32, NRMSE Test/best: 0.45250/0.44669, Training NRMSE: 0.36527, deviation of 23.88%
# Epoch -33 calculated in 13.80 s
# Epoch 33, NRMSE Test/best: 0.45010/0.44669, Training NRMSE: 0.36310, deviation of 23.96%
# Epoch -34 calculated in 13.57 s
# Epoch 34, NRMSE Test/best: 0.45647/0.44669, Training NRMSE: 0.36367, deviation of 25.52%
# Epoch -35 calculated in 14.18 s
# Epoch 35, NRMSE Test/best: 0.45092/0.44669, Training NRMSE: 0.36236, deviation of 24.44%
# Epoch -36 calculated in 13.48 s
# Epoch 36, NRMSE Test/best: 0.45616/0.44669, Training NRMSE: 0.36073, deviation of 26.46%
# Epoch -37 calculated in 13.84 s
# Epoch 37, NRMSE Test/best: 0.44934/0.44669, Training NRMSE: 0.36244, deviation of 23.97%
# Epoch -38 calculated in 13.96 s
# Epoch 38, NRMSE Test/best: 0.44377/0.44377, Training NRMSE: 0.35993, deviation of 23.29%
# Epoch -39 calculated in 13.94 s
# Epoch 39, NRMSE Test/best: 0.45168/0.44377, Training NRMSE: 0.36012, deviation of 25.43%
# Epoch -40 calculated in 14.21 s
# Epoch 40, NRMSE Test/best: 0.45615/0.44377, Training NRMSE: 0.35941, deviation of 26.92%
# Epoch -41 calculated in 13.80 s
# Epoch 41, NRMSE Test/best: 0.45791/0.44377, Training NRMSE: 0.36019, deviation of 27.13%
# Epoch -42 calculated in 13.88 s
# Epoch 42, NRMSE Test/best: 0.45314/0.44377, Training NRMSE: 0.35677, deviation of 27.01%
# Epoch -43 calculated in 14.02 s
# Epoch 43, NRMSE Test/best: 0.45675/0.44377, Training NRMSE: 0.35847, deviation of 27.42%
# Epoch -44 calculated in 13.66 s
# Epoch 44, NRMSE Test/best: 0.45036/0.44377, Training NRMSE: 0.35815, deviation of 25.75%
# Epoch -45 calculated in 13.51 s
# Epoch 45, NRMSE Test/best: 0.44918/0.44377, Training NRMSE: 0.35851, deviation of 25.29%
# Epoch -46 calculated in 13.69 s
# Epoch 46, NRMSE Test/best: 0.45500/0.44377, Training NRMSE: 0.35680, deviation of 27.52%
# Epoch -47 calculated in 13.84 s
# Epoch 47, NRMSE Test/best: 0.43893/0.43893, Training NRMSE: 0.35604, deviation of 23.28%
# Epoch -48 calculated in 13.76 s
# Epoch 48, NRMSE Test/best: 0.45931/0.43893, Training NRMSE: 0.35649, deviation of 28.84%
# Epoch -49 calculated in 13.84 s
# Epoch 49, NRMSE Test/best: 0.44852/0.43893, Training NRMSE: 0.35724, deviation of 25.55%
# Epoch -50 calculated in 13.94 s
# Epoch 50, NRMSE Test/best: 0.44859/0.43893, Training NRMSE: 0.35457, deviation of 26.52%
# Epoch -51 calculated in 13.93 s
# Epoch 51, NRMSE Test/best: 0.43537/0.43537, Training NRMSE: 0.35406, deviation of 22.97%
# Epoch -52 calculated in 13.62 s
# Epoch 52, NRMSE Test/best: 0.45542/0.43537, Training NRMSE: 0.35380, deviation of 28.72%
# Epoch -53 calculated in 13.91 s
# Epoch 53, NRMSE Test/best: 0.44385/0.43537, Training NRMSE: 0.35453, deviation of 25.19%
# Epoch -54 calculated in 13.76 s
# Epoch 54, NRMSE Test/best: 0.44123/0.43537, Training NRMSE: 0.35460, deviation of 24.43%
# Epoch -55 calculated in 13.86 s
# Epoch 55, NRMSE Test/best: 0.45147/0.43537, Training NRMSE: 0.35416, deviation of 27.48%
# Epoch -56 calculated in 13.85 s
# Epoch 56, NRMSE Test/best: 0.44113/0.43537, Training NRMSE: 0.35422, deviation of 24.53%
# Epoch -57 calculated in 13.99 s
# Epoch 57, NRMSE Test/best: 0.45014/0.43537, Training NRMSE: 0.35385, deviation of 27.21%
# Epoch -58 calculated in 13.42 s
# Epoch 58, NRMSE Test/best: 0.43459/0.43459, Training NRMSE: 0.35486, deviation of 22.47%
# Epoch -59 calculated in 13.83 s
# Epoch 59, NRMSE Test/best: 0.44768/0.43459, Training NRMSE: 0.35283, deviation of 26.88%
# Epoch -60 calculated in 13.70 s
# Epoch 60, NRMSE Test/best: 0.44476/0.43459, Training NRMSE: 0.35369, deviation of 25.75%
# Epoch -61 calculated in 13.80 s
# Epoch 61, NRMSE Test/best: 0.44963/0.43459, Training NRMSE: 0.35572, deviation of 26.40%
# Epoch -62 calculated in 13.98 s
# Epoch 62, NRMSE Test/best: 0.43488/0.43459, Training NRMSE: 0.35150, deviation of 23.72%
# Epoch -63 calculated in 13.88 s
# Epoch 63, NRMSE Test/best: 0.44041/0.43459, Training NRMSE: 0.35262, deviation of 24.90%
# Epoch -64 calculated in 13.83 s
# Epoch 64, NRMSE Test/best: 0.43625/0.43459, Training NRMSE: 0.35410, deviation of 23.20%
# Epoch -65 calculated in 13.96 s
# Epoch 65, NRMSE Test/best: 0.44356/0.43459, Training NRMSE: 0.34983, deviation of 26.79%
# Epoch -66 calculated in 14.14 s
# Epoch 66, NRMSE Test/best: 0.43479/0.43459, Training NRMSE: 0.35338, deviation of 23.04%
# Epoch -67 calculated in 14.19 s
# Epoch 67, NRMSE Test/best: 0.43474/0.43459, Training NRMSE: 0.35117, deviation of 23.80%
# Epoch -68 calculated in 14.28 s
# Epoch 68, NRMSE Test/best: 0.43992/0.43459, Training NRMSE: 0.35124, deviation of 25.25%
# Epoch -69 calculated in 13.79 s
# Epoch 69, NRMSE Test/best: 0.43382/0.43382, Training NRMSE: 0.35224, deviation of 23.16%
# Epoch -70 calculated in 13.81 s
# Epoch 70, NRMSE Test/best: 0.44624/0.43382, Training NRMSE: 0.34849, deviation of 28.05%
# Epoch -71 calculated in 14.08 s
# Epoch 71, NRMSE Test/best: 0.43250/0.43250, Training NRMSE: 0.35132, deviation of 23.11%
# Epoch -72 calculated in 14.12 s
# Epoch 72, NRMSE Test/best: 0.43569/0.43250, Training NRMSE: 0.34964, deviation of 24.61%
# Epoch -73 calculated in 13.85 s
# Epoch 73, NRMSE Test/best: 0.43234/0.43234, Training NRMSE: 0.34972, deviation of 23.62%
# Epoch -74 calculated in 13.88 s
# Epoch 74, NRMSE Test/best: 0.43537/0.43234, Training NRMSE: 0.35048, deviation of 24.22%
# Epoch -75 calculated in 14.24 s
# Epoch 75, NRMSE Test/best: 0.44254/0.43234, Training NRMSE: 0.34986, deviation of 26.49%
# Epoch -76 calculated in 13.99 s
# Epoch 76, NRMSE Test/best: 0.43408/0.43234, Training NRMSE: 0.34908, deviation of 24.35%
# Epoch -77 calculated in 13.93 s
# Epoch 77, NRMSE Test/best: 0.43817/0.43234, Training NRMSE: 0.35013, deviation of 25.15%
# Epoch -78 calculated in 13.85 s
# Epoch 78, NRMSE Test/best: 0.43156/0.43156, Training NRMSE: 0.34964, deviation of 23.43%
# Epoch -79 calculated in 13.88 s
# Epoch 79, NRMSE Test/best: 0.44586/0.43156, Training NRMSE: 0.34961, deviation of 27.53%
# Epoch -80 calculated in 14.20 s
# Epoch 80, NRMSE Test/best: 0.44267/0.43156, Training NRMSE: 0.34850, deviation of 27.02%
# Epoch -81 calculated in 13.70 s
# Epoch 81, NRMSE Test/best: 0.43328/0.43156, Training NRMSE: 0.35246, deviation of 22.93%
# Epoch -82 calculated in 13.89 s
# Epoch 82, NRMSE Test/best: 0.45454/0.43156, Training NRMSE: 0.34802, deviation of 30.61%
# Epoch -83 calculated in 14.21 s
# Epoch 83, NRMSE Test/best: 0.43598/0.43156, Training NRMSE: 0.34967, deviation of 24.68%
# Epoch -84 calculated in 13.90 s
# Epoch 84, NRMSE Test/best: 0.43704/0.43156, Training NRMSE: 0.35010, deviation of 24.83%
# Epoch -85 calculated in 14.19 s
# Epoch 85, NRMSE Test/best: 0.43533/0.43156, Training NRMSE: 0.34698, deviation of 25.46%
# Epoch -86 calculated in 14.33 s
# Epoch 86, NRMSE Test/best: 0.44580/0.43156, Training NRMSE: 0.34734, deviation of 28.35%
# Epoch -87 calculated in 13.83 s
# Epoch 87, NRMSE Test/best: 0.43414/0.43156, Training NRMSE: 0.35053, deviation of 23.85%
# Epoch -88 calculated in 14.06 s
# Epoch 88, NRMSE Test/best: 0.43569/0.43156, Training NRMSE: 0.34804, deviation of 25.18%
# Epoch -89 calculated in 13.75 s
# Epoch 89, NRMSE Test/best: 0.44187/0.43156, Training NRMSE: 0.34765, deviation of 27.10%
# Epoch -90 calculated in 14.25 s
# Epoch 90, NRMSE Test/best: 0.43927/0.43156, Training NRMSE: 0.34838, deviation of 26.09%
# Epoch -91 calculated in 14.08 s
# Epoch 91, NRMSE Test/best: 0.43621/0.43156, Training NRMSE: 0.34939, deviation of 24.85%
# Epoch -92 calculated in 13.63 s
# Epoch 92, NRMSE Test/best: 0.44067/0.43156, Training NRMSE: 0.34574, deviation of 27.46%
# Epoch -93 calculated in 14.07 s
# Epoch 93, NRMSE Test/best: 0.43181/0.43156, Training NRMSE: 0.34806, deviation of 24.06%
# Epoch -94 calculated in 13.23 s
# Epoch 94, NRMSE Test/best: 0.44236/0.43156, Training NRMSE: 0.34651, deviation of 27.66%
# Epoch -95 calculated in 14.00 s
# Epoch 95, NRMSE Test/best: 0.44764/0.43156, Training NRMSE: 0.34628, deviation of 29.27%
# Epoch -96 calculated in 13.56 s
# Epoch 96, NRMSE Test/best: 0.43223/0.43156, Training NRMSE: 0.34794, deviation of 24.23%
# Epoch -97 calculated in 13.84 s
# Epoch 97, NRMSE Test/best: 0.43386/0.43156, Training NRMSE: 0.34454, deviation of 25.93%
# Epoch -98 calculated in 13.57 s
# Epoch 98, NRMSE Test/best: 0.42861/0.42861, Training NRMSE: 0.34808, deviation of 23.13%
# Epoch -99 calculated in 13.43 s
# Epoch 99, NRMSE Test/best: 0.43548/0.42861, Training NRMSE: 0.34987, deviation of 24.47%
# Epoch -100 calculated in 13.73 s
# Epoch 100, NRMSE Test/best: 0.43251/0.42861, Training NRMSE: 0.34530, deviation of 25.26%
# Epoch -101 calculated in 13.61 s
# Epoch 101, NRMSE Test/best: 0.43846/0.42861, Training NRMSE: 0.34528, deviation of 26.98%
# Epoch -102 calculated in 13.38 s
# Epoch 102, NRMSE Test/best: 0.43467/0.42861, Training NRMSE: 0.34962, deviation of 24.33%
# Epoch -103 calculated in 13.67 s
# Epoch 103, NRMSE Test/best: 0.43678/0.42861, Training NRMSE: 0.34528, deviation of 26.50%
# Epoch -104 calculated in 13.76 s
# Epoch 104, NRMSE Test/best: 0.42759/0.42759, Training NRMSE: 0.34801, deviation of 22.87%
# Epoch -105 calculated in 13.95 s
# Epoch 105, NRMSE Test/best: 0.43830/0.42759, Training NRMSE: 0.34621, deviation of 26.60%
# Epoch -106 calculated in 14.07 s
# Epoch 106, NRMSE Test/best: 0.44682/0.42759, Training NRMSE: 0.34582, deviation of 29.21%
# Epoch -107 calculated in 13.66 s
# Epoch 107, NRMSE Test/best: 0.42961/0.42759, Training NRMSE: 0.34426, deviation of 24.79%
# Epoch -108 calculated in 13.72 s
# Epoch 108, NRMSE Test/best: 0.44519/0.42759, Training NRMSE: 0.34429, deviation of 29.31%
# Epoch -109 calculated in 13.77 s
# Epoch 109, NRMSE Test/best: 0.44359/0.42759, Training NRMSE: 0.34494, deviation of 28.60%
# Epoch -110 calculated in 13.82 s
# Epoch 110, NRMSE Test/best: 0.44070/0.42759, Training NRMSE: 0.34389, deviation of 28.15%
# Epoch -111 calculated in 13.64 s
# Epoch 111, NRMSE Test/best: 0.44784/0.42759, Training NRMSE: 0.34559, deviation of 29.59%
# Epoch -112 calculated in 13.52 s
# Epoch 112, NRMSE Test/best: 0.44409/0.42759, Training NRMSE: 0.34567, deviation of 28.47%
# Epoch -113 calculated in 13.91 s
# Epoch 113, NRMSE Test/best: 0.43526/0.42759, Training NRMSE: 0.34512, deviation of 26.12%
# Epoch -114 calculated in 13.99 s
# Epoch 114, NRMSE Test/best: 0.43792/0.42759, Training NRMSE: 0.34341, deviation of 27.52%
# Epoch -115 calculated in 13.83 s
# Epoch 115, NRMSE Test/best: 0.44338/0.42759, Training NRMSE: 0.34804, deviation of 27.39%
# Epoch -116 calculated in 14.15 s
# Epoch 116, NRMSE Test/best: 0.44056/0.42759, Training NRMSE: 0.34471, deviation of 27.81%
# Epoch -117 calculated in 13.79 s
# Epoch 117, NRMSE Test/best: 0.43867/0.42759, Training NRMSE: 0.34355, deviation of 27.69%
# Epoch -118 calculated in 13.89 s
# Epoch 118, NRMSE Test/best: 0.44996/0.42759, Training NRMSE: 0.34506, deviation of 30.40%
# Epoch -119 calculated in 14.09 s
# Epoch 119, NRMSE Test/best: 0.44960/0.42759, Training NRMSE: 0.34473, deviation of 30.42%
# Epoch -120 calculated in 13.99 s
# Epoch 120, NRMSE Test/best: 0.44365/0.42759, Training NRMSE: 0.34246, deviation of 29.55%
# Epoch -121 calculated in 14.19 s
# Epoch 121, NRMSE Test/best: 0.43636/0.42759, Training NRMSE: 0.34300, deviation of 27.22%
# Epoch -122 calculated in 14.07 s
# Epoch 122, NRMSE Test/best: 0.43492/0.42759, Training NRMSE: 0.34543, deviation of 25.91%
# Epoch -123 calculated in 14.31 s
# Epoch 123, NRMSE Test/best: 0.44574/0.42759, Training NRMSE: 0.34341, deviation of 29.80%
# Epoch -124 calculated in 13.85 s
# Epoch 124, NRMSE Test/best: 0.44152/0.42759, Training NRMSE: 0.34288, deviation of 28.77%
# Epoch -125 calculated in 13.88 s
# Epoch 125, NRMSE Test/best: 0.46254/0.42759, Training NRMSE: 0.34138, deviation of 35.49%
# Epoch -126 calculated in 14.09 s
# Epoch 126, NRMSE Test/best: 0.44405/0.42759, Training NRMSE: 0.34362, deviation of 29.23%
# Epoch -127 calculated in 13.90 s
# Epoch 127, NRMSE Test/best: 0.44102/0.42759, Training NRMSE: 0.34461, deviation of 27.98%
# Epoch -128 calculated in 14.05 s
# Epoch 128, NRMSE Test/best: 0.43595/0.42759, Training NRMSE: 0.34211, deviation of 27.43%
# Epoch -129 calculated in 14.22 s
# Epoch 129, NRMSE Test/best: 0.43974/0.42759, Training NRMSE: 0.34339, deviation of 28.06%
# Epoch -130 calculated in 13.90 s
# Epoch 130, NRMSE Test/best: 0.44742/0.42759, Training NRMSE: 0.34330, deviation of 30.33%
# Epoch -131 calculated in 13.59 s
# Epoch 131, NRMSE Test/best: 0.44140/0.42759, Training NRMSE: 0.34335, deviation of 28.56%
# Epoch -132 calculated in 13.99 s
# Epoch 132, NRMSE Test/best: 0.43854/0.42759, Training NRMSE: 0.34300, deviation of 27.86%
# Epoch -133 calculated in 13.91 s
# Epoch 133, NRMSE Test/best: 0.45220/0.42759, Training NRMSE: 0.34357, deviation of 31.62%
# Epoch -134 calculated in 13.91 s
# Epoch 134, NRMSE Test/best: 0.44710/0.42759, Training NRMSE: 0.34099, deviation of 31.12%
# Epoch -135 calculated in 13.68 s
# Epoch 135, NRMSE Test/best: 0.44598/0.42759, Training NRMSE: 0.34094, deviation of 30.81%
# Epoch -136 calculated in 13.43 s
# Epoch 136, NRMSE Test/best: 0.44389/0.42759, Training NRMSE: 0.34471, deviation of 28.77%
# Epoch -137 calculated in 14.07 s
# Epoch 137, NRMSE Test/best: 0.44083/0.42759, Training NRMSE: 0.34239, deviation of 28.75%
# Epoch -138 calculated in 13.77 s
# Epoch 138, NRMSE Test/best: 0.45094/0.42759, Training NRMSE: 0.34165, deviation of 31.99%
# Epoch -139 calculated in 13.85 s
# Epoch 139, NRMSE Test/best: 0.43626/0.42759, Training NRMSE: 0.34628, deviation of 25.99%
# Epoch -140 calculated in 13.29 s
# Epoch 140, NRMSE Test/best: 0.43808/0.42759, Training NRMSE: 0.34235, deviation of 27.96%
# Epoch -141 calculated in 13.44 s
# Epoch 141, NRMSE Test/best: 0.43541/0.42759, Training NRMSE: 0.34424, deviation of 26.48%
# Epoch -142 calculated in 13.83 s
# Epoch 142, NRMSE Test/best: 0.43714/0.42759, Training NRMSE: 0.34127, deviation of 28.09%
# Epoch -143 calculated in 13.04 s
# Epoch 143, NRMSE Test/best: 0.44186/0.42759, Training NRMSE: 0.34170, deviation of 29.31%
# Epoch -144 calculated in 13.68 s
# Epoch 144, NRMSE Test/best: 0.44488/0.42759, Training NRMSE: 0.34322, deviation of 29.62%
# Epoch -145 calculated in 13.79 s
# Epoch 145, NRMSE Test/best: 0.44677/0.42759, Training NRMSE: 0.34055, deviation of 31.19%
# Epoch -146 calculated in 13.85 s
# Epoch 146, NRMSE Test/best: 0.44311/0.42759, Training NRMSE: 0.34140, deviation of 29.79%
# Epoch -147 calculated in 13.72 s
# Epoch 147, NRMSE Test/best: 0.44698/0.42759, Training NRMSE: 0.34233, deviation of 30.57%
# Epoch -148 calculated in 13.29 s
# Epoch 148, NRMSE Test/best: 0.43853/0.42759, Training NRMSE: 0.34304, deviation of 27.84%
# Epoch -149 calculated in 13.68 s
# Epoch 149, NRMSE Test/best: 0.43801/0.42759, Training NRMSE: 0.34136, deviation of 28.31%
# Epoch -150 calculated in 13.91 s
# Epoch 150, NRMSE Test/best: 0.44580/0.42759, Training NRMSE: 0.34434, deviation of 29.46%
# Epoch -151 calculated in 13.43 s
# Epoch 151, NRMSE Test/best: 0.43430/0.42759, Training NRMSE: 0.34002, deviation of 27.73%
# Epoch -152 calculated in 14.17 s
# Epoch 152, NRMSE Test/best: 0.44550/0.42759, Training NRMSE: 0.34126, deviation of 30.54%
# Epoch -153 calculated in 13.60 s
# Epoch 153, NRMSE Test/best: 0.44393/0.42759, Training NRMSE: 0.34132, deviation of 30.06%
# Epoch -154 calculated in 13.88 s
# Epoch 154, NRMSE Test/best: 0.45019/0.42759, Training NRMSE: 0.34090, deviation of 32.06%
# Epoch -155 calculated in 13.93 s
# Epoch 155, NRMSE Test/best: 0.44258/0.42759, Training NRMSE: 0.34192, deviation of 29.44%
# Epoch -156 calculated in 13.54 s
# Epoch 156, NRMSE Test/best: 0.44582/0.42759, Training NRMSE: 0.34255, deviation of 30.15%
# Epoch -157 calculated in 13.59 s
# Epoch 157, NRMSE Test/best: 0.43681/0.42759, Training NRMSE: 0.34156, deviation of 27.89%
# Epoch -158 calculated in 13.70 s
# Epoch 158, NRMSE Test/best: 0.43589/0.42759, Training NRMSE: 0.34169, deviation of 27.57%
# Epoch -159 calculated in 13.82 s
# Epoch 159, NRMSE Test/best: 0.44376/0.42759, Training NRMSE: 0.34192, deviation of 29.79%
# Epoch -160 calculated in 13.88 s
# Epoch 160, NRMSE Test/best: 0.43521/0.42759, Training NRMSE: 0.34193, deviation of 27.28%
# Epoch -161 calculated in 13.61 s
# Epoch 161, NRMSE Test/best: 0.43376/0.42759, Training NRMSE: 0.34286, deviation of 26.51%
# Epoch -162 calculated in 13.93 s
# Epoch 162, NRMSE Test/best: 0.44247/0.42759, Training NRMSE: 0.33989, deviation of 30.18%
# Epoch -163 calculated in 13.66 s
# Epoch 163, NRMSE Test/best: 0.45042/0.42759, Training NRMSE: 0.33927, deviation of 32.76%
# Epoch -164 calculated in 13.35 s
# Epoch 164, NRMSE Test/best: 0.45075/0.42759, Training NRMSE: 0.34322, deviation of 31.33%
# Epoch -165 calculated in 13.50 s
# Epoch 165, NRMSE Test/best: 0.43923/0.42759, Training NRMSE: 0.33878, deviation of 29.65%
# Epoch -166 calculated in 13.50 s
# Epoch 166, NRMSE Test/best: 0.44026/0.42759, Training NRMSE: 0.34116, deviation of 29.05%
# Epoch -167 calculated in 13.93 s
# Epoch 167, NRMSE Test/best: 0.43658/0.42759, Training NRMSE: 0.34069, deviation of 28.15%
# Epoch -168 calculated in 13.85 s
# Epoch 168, NRMSE Test/best: 0.43488/0.42759, Training NRMSE: 0.34128, deviation of 27.43%
# Epoch -169 calculated in 13.51 s
# Epoch 169, NRMSE Test/best: 0.44237/0.42759, Training NRMSE: 0.33856, deviation of 30.66%
# Epoch -170 calculated in 13.85 s
# Epoch 170, NRMSE Test/best: 0.42671/0.42671, Training NRMSE: 0.34290, deviation of 24.44%
# Epoch -171 calculated in 13.73 s
# Epoch 171, NRMSE Test/best: 0.43673/0.42671, Training NRMSE: 0.34393, deviation of 26.98%
# Epoch -172 calculated in 13.87 s
# Epoch 172, NRMSE Test/best: 0.43911/0.42671, Training NRMSE: 0.33888, deviation of 29.58%
# Epoch -173 calculated in 13.96 s
# Epoch 173, NRMSE Test/best: 0.44318/0.42671, Training NRMSE: 0.33960, deviation of 30.50%
# Epoch -174 calculated in 13.40 s
# Epoch 174, NRMSE Test/best: 0.43049/0.42671, Training NRMSE: 0.34033, deviation of 26.49%
# Epoch -175 calculated in 13.81 s
# Epoch 175, NRMSE Test/best: 0.44065/0.42671, Training NRMSE: 0.34029, deviation of 29.49%
# Epoch -176 calculated in 13.74 s
# Epoch 176, NRMSE Test/best: 0.43432/0.42671, Training NRMSE: 0.34041, deviation of 27.59%
# Epoch -177 calculated in 13.88 s
# Epoch 177, NRMSE Test/best: 0.43208/0.42671, Training NRMSE: 0.34055, deviation of 26.88%
# Epoch -178 calculated in 13.67 s
# Epoch 178, NRMSE Test/best: 0.44201/0.42671, Training NRMSE: 0.33886, deviation of 30.44%
# Epoch -179 calculated in 13.68 s
# Epoch 179, NRMSE Test/best: 0.43376/0.42671, Training NRMSE: 0.33976, deviation of 27.66%
# Epoch -180 calculated in 13.60 s
# Epoch 180, NRMSE Test/best: 0.44011/0.42671, Training NRMSE: 0.33990, deviation of 29.48%
# Epoch -181 calculated in 13.54 s
# Epoch 181, NRMSE Test/best: 0.43580/0.42671, Training NRMSE: 0.34032, deviation of 28.05%
# Epoch -182 calculated in 13.78 s
# Epoch 182, NRMSE Test/best: 0.43298/0.42671, Training NRMSE: 0.33846, deviation of 27.93%
# Epoch -183 calculated in 13.83 s
# Epoch 183, NRMSE Test/best: 0.45509/0.42671, Training NRMSE: 0.33903, deviation of 34.23%
# Epoch -184 calculated in 13.79 s
# Epoch 184, NRMSE Test/best: 0.44217/0.42671, Training NRMSE: 0.33977, deviation of 30.14%
# Epoch -185 calculated in 13.87 s
# Epoch 185, NRMSE Test/best: 0.42793/0.42671, Training NRMSE: 0.33786, deviation of 26.66%
# Epoch -186 calculated in 14.24 s
# Epoch 186, NRMSE Test/best: 0.43754/0.42671, Training NRMSE: 0.33881, deviation of 29.14%
# Epoch -187 calculated in 14.10 s
# Epoch 187, NRMSE Test/best: 0.43767/0.42671, Training NRMSE: 0.33934, deviation of 28.98%
# Epoch -188 calculated in 13.90 s
# Epoch 188, NRMSE Test/best: 0.43546/0.42671, Training NRMSE: 0.33796, deviation of 28.85%
# Epoch -189 calculated in 14.11 s
# Epoch 189, NRMSE Test/best: 0.44073/0.42671, Training NRMSE: 0.33981, deviation of 29.70%
# Epoch -190 calculated in 13.63 s
# Epoch 190, NRMSE Test/best: 0.43726/0.42671, Training NRMSE: 0.33985, deviation of 28.66%
# Epoch -191 calculated in 13.90 s
# Epoch 191, NRMSE Test/best: 0.44356/0.42671, Training NRMSE: 0.33984, deviation of 30.52%
# Epoch -192 calculated in 14.10 s
# Epoch 192, NRMSE Test/best: 0.43763/0.42671, Training NRMSE: 0.33701, deviation of 29.85%
# Epoch -193 calculated in 13.81 s
# Epoch 193, NRMSE Test/best: 0.43978/0.42671, Training NRMSE: 0.33860, deviation of 29.88%
# Epoch -194 calculated in 13.98 s
# Epoch 194, NRMSE Test/best: 0.43911/0.42671, Training NRMSE: 0.33859, deviation of 29.69%
# Epoch -195 calculated in 13.91 s
# Epoch 195, NRMSE Test/best: 0.43759/0.42671, Training NRMSE: 0.33766, deviation of 29.59%
# Epoch -196 calculated in 14.05 s
# Epoch 196, NRMSE Test/best: 0.44570/0.42671, Training NRMSE: 0.33669, deviation of 32.38%
# Epoch -197 calculated in 13.52 s
# Epoch 197, NRMSE Test/best: 0.44000/0.42671, Training NRMSE: 0.33804, deviation of 30.16%
# Epoch -198 calculated in 13.75 s
# Epoch 198, NRMSE Test/best: 0.43686/0.42671, Training NRMSE: 0.33811, deviation of 29.21%
# Epoch -199 calculated in 13.67 s
# Epoch 199, NRMSE Test/best: 0.43646/0.42671, Training NRMSE: 0.33533, deviation of 30.16%
# Epoch -200 calculated in 13.65 s
# Epoch 200, NRMSE Test/best: 0.44140/0.42671, Training NRMSE: 0.33829, deviation of 30.48%
# Epoch -201 calculated in 14.25 s
# Epoch 201, NRMSE Test/best: 0.43526/0.42671, Training NRMSE: 0.33703, deviation of 29.15%
# Epoch -202 calculated in 13.66 s
# Epoch 202, NRMSE Test/best: 0.43714/0.42671, Training NRMSE: 0.33658, deviation of 29.88%
# Epoch -203 calculated in 13.55 s
# Epoch 203, NRMSE Test/best: 0.43713/0.42671, Training NRMSE: 0.33749, deviation of 29.52%
# Epoch -204 calculated in 13.65 s
# Epoch 204, NRMSE Test/best: 0.43354/0.42671, Training NRMSE: 0.33779, deviation of 28.34%
# Epoch -205 calculated in 13.82 s
# Epoch 205, NRMSE Test/best: 0.44237/0.42671, Training NRMSE: 0.33654, deviation of 31.45%
# Epoch -206 calculated in 13.95 s
# Epoch 206, NRMSE Test/best: 0.44252/0.42671, Training NRMSE: 0.33716, deviation of 31.25%
# Epoch -207 calculated in 13.66 s
# Epoch 207, NRMSE Test/best: 0.43093/0.42671, Training NRMSE: 0.33688, deviation of 27.92%
# Epoch -208 calculated in 13.90 s
# Epoch 208, NRMSE Test/best: 0.43526/0.42671, Training NRMSE: 0.33846, deviation of 28.60%
# Epoch -209 calculated in 13.66 s
# Epoch 209, NRMSE Test/best: 0.43460/0.42671, Training NRMSE: 0.33707, deviation of 28.93%
# Epoch -210 calculated in 13.93 s
# Epoch 210, NRMSE Test/best: 0.43364/0.42671, Training NRMSE: 0.33662, deviation of 28.82%
# Epoch -211 calculated in 13.80 s
# Epoch 211, NRMSE Test/best: 0.43196/0.42671, Training NRMSE: 0.33775, deviation of 27.89%
# Epoch -212 calculated in 13.26 s
# Epoch 212, NRMSE Test/best: 0.43326/0.42671, Training NRMSE: 0.33611, deviation of 28.90%
# Epoch -213 calculated in 13.54 s
# Epoch 213, NRMSE Test/best: 0.43316/0.42671, Training NRMSE: 0.33795, deviation of 28.17%
# Epoch -214 calculated in 13.68 s
# Epoch 214, NRMSE Test/best: 0.44479/0.42671, Training NRMSE: 0.33782, deviation of 31.66%
# Epoch -215 calculated in 13.65 s
# Epoch 215, NRMSE Test/best: 0.44430/0.42671, Training NRMSE: 0.33854, deviation of 31.24%
# Epoch -216 calculated in 13.98 s
# Epoch 216, NRMSE Test/best: 0.43908/0.42671, Training NRMSE: 0.33684, deviation of 30.35%
# Epoch -217 calculated in 13.73 s
# Epoch 217, NRMSE Test/best: 0.44350/0.42671, Training NRMSE: 0.33640, deviation of 31.84%
# Epoch -218 calculated in 13.85 s
# Epoch 218, NRMSE Test/best: 0.44021/0.42671, Training NRMSE: 0.33770, deviation of 30.36%
# Epoch -219 calculated in 13.98 s
# Epoch 219, NRMSE Test/best: 0.43794/0.42671, Training NRMSE: 0.33738, deviation of 29.81%
# Epoch -220 calculated in 13.94 s
# Epoch 220, NRMSE Test/best: 0.43541/0.42671, Training NRMSE: 0.33570, deviation of 29.70%
# Epoch -221 calculated in 14.11 s
# Epoch 221, NRMSE Test/best: 0.44053/0.42671, Training NRMSE: 0.33688, deviation of 30.77%
# Epoch -222 calculated in 13.69 s
# Epoch 222, NRMSE Test/best: 0.42923/0.42671, Training NRMSE: 0.33525, deviation of 28.03%
# Epoch -223 calculated in 14.01 s
# Epoch 223, NRMSE Test/best: 0.43711/0.42671, Training NRMSE: 0.33783, deviation of 29.39%
# Epoch -224 calculated in 14.07 s
# Epoch 224, NRMSE Test/best: 0.43556/0.42671, Training NRMSE: 0.34100, deviation of 27.73%
# Epoch -225 calculated in 13.77 s
# Epoch 225, NRMSE Test/best: 0.43678/0.42671, Training NRMSE: 0.33717, deviation of 29.54%
# Epoch -226 calculated in 14.15 s
# Epoch 226, NRMSE Test/best: 0.43769/0.42671, Training NRMSE: 0.33987, deviation of 28.78%
# Epoch -227 calculated in 13.81 s
# Epoch 227, NRMSE Test/best: 0.43686/0.42671, Training NRMSE: 0.33909, deviation of 28.83%
# Epoch -228 calculated in 14.05 s
# Epoch 228, NRMSE Test/best: 0.43899/0.42671, Training NRMSE: 0.33702, deviation of 30.26%
# Epoch -229 calculated in 13.95 s
# Epoch 229, NRMSE Test/best: 0.42878/0.42671, Training NRMSE: 0.33637, deviation of 27.47%
# Epoch -230 calculated in 14.11 s
# Epoch 230, NRMSE Test/best: 0.43436/0.42671, Training NRMSE: 0.33533, deviation of 29.54%
# Epoch -231 calculated in 14.00 s
# Epoch 231, NRMSE Test/best: 0.43547/0.42671, Training NRMSE: 0.33644, deviation of 29.43%
# Epoch -232 calculated in 13.70 s
# Epoch 232, NRMSE Test/best: 0.43943/0.42671, Training NRMSE: 0.33564, deviation of 30.92%
# Epoch -233 calculated in 13.83 s
# Epoch 233, NRMSE Test/best: 0.42779/0.42671, Training NRMSE: 0.33605, deviation of 27.30%
# Epoch -234 calculated in 14.13 s
# Epoch 234, NRMSE Test/best: 0.43552/0.42671, Training NRMSE: 0.33639, deviation of 29.47%
# Epoch -235 calculated in 14.12 s
# Epoch 235, NRMSE Test/best: 0.42937/0.42671, Training NRMSE: 0.34004, deviation of 26.27%
# Epoch -236 calculated in 14.01 s
# Epoch 236, NRMSE Test/best: 0.42663/0.42663, Training NRMSE: 0.33618, deviation of 26.91%
# Epoch -237 calculated in 13.79 s
# Epoch 237, NRMSE Test/best: 0.44249/0.42663, Training NRMSE: 0.33632, deviation of 31.57%
# Epoch -238 calculated in 14.14 s
# Epoch 238, NRMSE Test/best: 0.43889/0.42663, Training NRMSE: 0.33582, deviation of 30.69%
# Epoch -239 calculated in 13.85 s
# Epoch 239, NRMSE Test/best: 0.43535/0.42663, Training NRMSE: 0.33434, deviation of 30.21%
# Epoch -240 calculated in 14.21 s
# Epoch 240, NRMSE Test/best: 0.42964/0.42663, Training NRMSE: 0.33750, deviation of 27.30%
# Epoch -241 calculated in 14.28 s
# Epoch 241, NRMSE Test/best: 0.44487/0.42663, Training NRMSE: 0.33802, deviation of 31.61%
# Epoch -242 calculated in 14.20 s
# Epoch 242, NRMSE Test/best: 0.43869/0.42663, Training NRMSE: 0.33764, deviation of 29.93%
# Epoch -243 calculated in 14.07 s
# Epoch 243, NRMSE Test/best: 0.43707/0.42663, Training NRMSE: 0.33630, deviation of 29.96%
# Epoch -244 calculated in 13.86 s
# Epoch 244, NRMSE Test/best: 0.43667/0.42663, Training NRMSE: 0.34195, deviation of 27.70%
# Epoch -245 calculated in 14.27 s
# Epoch 245, NRMSE Test/best: 0.43912/0.42663, Training NRMSE: 0.33754, deviation of 30.09%
# Epoch -246 calculated in 13.75 s
# Epoch 246, NRMSE Test/best: 0.43528/0.42663, Training NRMSE: 0.33537, deviation of 29.79%
# Epoch -247 calculated in 13.95 s
# Epoch 247, NRMSE Test/best: 0.43802/0.42663, Training NRMSE: 0.33463, deviation of 30.90%
# Epoch -248 calculated in 14.11 s
# Epoch 248, NRMSE Test/best: 0.43411/0.42663, Training NRMSE: 0.33406, deviation of 29.95%
# Epoch -249 calculated in 13.60 s
# Epoch 249, NRMSE Test/best: 0.43860/0.42663, Training NRMSE: 0.33908, deviation of 29.35%
# Epoch -250 calculated in 13.46 s
# Epoch 250, NRMSE Test/best: 0.43848/0.42663, Training NRMSE: 0.33431, deviation of 31.16%
# Epoch -251 calculated in 14.01 s
# Epoch 251, NRMSE Test/best: 0.43051/0.42663, Training NRMSE: 0.33482, deviation of 28.58%
# Epoch -252 calculated in 13.42 s
# Epoch 252, NRMSE Test/best: 0.44246/0.42663, Training NRMSE: 0.33519, deviation of 32.00%
# Epoch -253 calculated in 13.83 s
# Epoch 253, NRMSE Test/best: 0.44499/0.42663, Training NRMSE: 0.33487, deviation of 32.89%
# Epoch -254 calculated in 13.87 s
# Epoch 254, NRMSE Test/best: 0.43106/0.42663, Training NRMSE: 0.33517, deviation of 28.61%
# Epoch -255 calculated in 13.51 s
# Epoch 255, NRMSE Test/best: 0.44050/0.42663, Training NRMSE: 0.33538, deviation of 31.34%
# Epoch -256 calculated in 13.81 s
# Epoch 256, NRMSE Test/best: 0.43027/0.42663, Training NRMSE: 0.33794, deviation of 27.32%
# Epoch -257 calculated in 13.76 s
# Epoch 257, NRMSE Test/best: 0.44361/0.42663, Training NRMSE: 0.33568, deviation of 32.15%
# Epoch -258 calculated in 13.95 s
# Epoch 258, NRMSE Test/best: 0.43660/0.42663, Training NRMSE: 0.33318, deviation of 31.04%
# Epoch -259 calculated in 13.60 s
# Epoch 259, NRMSE Test/best: 0.44331/0.42663, Training NRMSE: 0.33486, deviation of 32.38%
# Epoch -260 calculated in 13.55 s
# Epoch 260, NRMSE Test/best: 0.44133/0.42663, Training NRMSE: 0.33464, deviation of 31.88%
# Epoch -261 calculated in 13.85 s
# Epoch 261, NRMSE Test/best: 0.44016/0.42663, Training NRMSE: 0.33340, deviation of 32.02%
# Epoch -262 calculated in 13.83 s
# Epoch 262, NRMSE Test/best: 0.43031/0.42663, Training NRMSE: 0.33558, deviation of 28.23%
# Epoch -263 calculated in 13.61 s
# Epoch 263, NRMSE Test/best: 0.43156/0.42663, Training NRMSE: 0.33331, deviation of 29.48%
# Epoch -264 calculated in 14.04 s
# Epoch 264, NRMSE Test/best: 0.43152/0.42663, Training NRMSE: 0.33525, deviation of 28.72%
# Epoch -265 calculated in 13.78 s
# Epoch 265, NRMSE Test/best: 0.43366/0.42663, Training NRMSE: 0.33386, deviation of 29.89%
# Epoch -266 calculated in 13.88 s
# Epoch 266, NRMSE Test/best: 0.43346/0.42663, Training NRMSE: 0.33580, deviation of 29.08%
# Epoch -267 calculated in 14.24 s
# Epoch 267, NRMSE Test/best: 0.44330/0.42663, Training NRMSE: 0.33736, deviation of 31.40%
# Epoch -268 calculated in 14.12 s
# Epoch 268, NRMSE Test/best: 0.43779/0.42663, Training NRMSE: 0.33505, deviation of 30.67%
# Epoch -269 calculated in 13.99 s
# Epoch 269, NRMSE Test/best: 0.43494/0.42663, Training NRMSE: 0.33541, deviation of 29.67%
# Epoch -270 calculated in 14.20 s
# Epoch 270, NRMSE Test/best: 0.43661/0.42663, Training NRMSE: 0.33370, deviation of 30.84%
# Epoch -271 calculated in 14.14 s
# Epoch 271, NRMSE Test/best: 0.43312/0.42663, Training NRMSE: 0.33370, deviation of 29.79%
# Epoch -272 calculated in 14.26 s
# Epoch 272, NRMSE Test/best: 0.43782/0.42663, Training NRMSE: 0.33467, deviation of 30.82%
# Epoch -273 calculated in 13.73 s
# Epoch 273, NRMSE Test/best: 0.43242/0.42663, Training NRMSE: 0.33603, deviation of 28.68%
# Epoch -274 calculated in 14.05 s
# Epoch 274, NRMSE Test/best: 0.43894/0.42663, Training NRMSE: 0.33592, deviation of 30.67%
# Epoch -275 calculated in 13.58 s
# Epoch 275, NRMSE Test/best: 0.43059/0.42663, Training NRMSE: 0.33485, deviation of 28.59%
# Epoch -276 calculated in 13.99 s
# Epoch 276, NRMSE Test/best: 0.43707/0.42663, Training NRMSE: 0.33539, deviation of 30.32%
# Epoch -277 calculated in 13.99 s
# Epoch 277, NRMSE Test/best: 0.43577/0.42663, Training NRMSE: 0.33626, deviation of 29.59%
# Epoch -278 calculated in 13.84 s
# Epoch 278, NRMSE Test/best: 0.43241/0.42663, Training NRMSE: 0.33498, deviation of 29.09%
# Epoch -279 calculated in 14.05 s
# Epoch 279, NRMSE Test/best: 0.43805/0.42663, Training NRMSE: 0.33456, deviation of 30.93%
# Epoch -280 calculated in 13.88 s
# Epoch 280, NRMSE Test/best: 0.43119/0.42663, Training NRMSE: 0.33574, deviation of 28.43%
# Epoch -281 calculated in 13.71 s
# Epoch 281, NRMSE Test/best: 0.43152/0.42663, Training NRMSE: 0.33493, deviation of 28.84%
# Epoch -282 calculated in 13.95 s
# Epoch 282, NRMSE Test/best: 0.43859/0.42663, Training NRMSE: 0.33348, deviation of 31.52%
# Epoch -283 calculated in 13.57 s
# Epoch 283, NRMSE Test/best: 0.43374/0.42663, Training NRMSE: 0.33512, deviation of 29.43%
# Epoch -284 calculated in 13.68 s
# Epoch 284, NRMSE Test/best: 0.44200/0.42663, Training NRMSE: 0.33432, deviation of 32.21%
# Epoch -285 calculated in 13.83 s
# Epoch 285, NRMSE Test/best: 0.43551/0.42663, Training NRMSE: 0.33340, deviation of 30.62%
# Epoch -286 calculated in 13.56 s
# Epoch 286, NRMSE Test/best: 0.43399/0.42663, Training NRMSE: 0.33392, deviation of 29.97%
# Epoch -287 calculated in 13.97 s
# Epoch 287, NRMSE Test/best: 0.43244/0.42663, Training NRMSE: 0.33422, deviation of 29.39%
# Epoch -288 calculated in 13.53 s
# Epoch 288, NRMSE Test/best: 0.43187/0.42663, Training NRMSE: 0.33387, deviation of 29.35%
# Epoch -289 calculated in 13.46 s
# Epoch 289, NRMSE Test/best: 0.42788/0.42663, Training NRMSE: 0.33448, deviation of 27.92%
# Epoch -290 calculated in 13.66 s
# Epoch 290, NRMSE Test/best: 0.43434/0.42663, Training NRMSE: 0.33557, deviation of 29.43%
# Epoch -291 calculated in 13.59 s
# Epoch 291, NRMSE Test/best: 0.43221/0.42663, Training NRMSE: 0.33397, deviation of 29.42%
# Epoch -292 calculated in 13.78 s
# Epoch 292, NRMSE Test/best: 0.43040/0.42663, Training NRMSE: 0.33358, deviation of 29.03%
# Epoch -293 calculated in 13.75 s
# Epoch 293, NRMSE Test/best: 0.43368/0.42663, Training NRMSE: 0.33500, deviation of 29.46%
# Epoch -294 calculated in 13.29 s
# Epoch 294, NRMSE Test/best: 0.42894/0.42663, Training NRMSE: 0.33365, deviation of 28.56%
# Epoch -295 calculated in 13.93 s
# Epoch 295, NRMSE Test/best: 0.42986/0.42663, Training NRMSE: 0.33285, deviation of 29.14%
# Epoch -296 calculated in 13.45 s
# Epoch 296, NRMSE Test/best: 0.43375/0.42663, Training NRMSE: 0.33394, deviation of 29.89%
# Epoch -297 calculated in 13.96 s
# Epoch 297, NRMSE Test/best: 0.42777/0.42663, Training NRMSE: 0.33328, deviation of 28.35%
# Epoch -298 calculated in 13.84 s
# Epoch 298, NRMSE Test/best: 0.44026/0.42663, Training NRMSE: 0.33396, deviation of 31.83%
# Epoch -299 calculated in 13.65 s
# Epoch 299, NRMSE Test/best: 0.43231/0.42663, Training NRMSE: 0.33568, deviation of 28.78%
# Epoch -300 calculated in 13.73 s
# Epoch 300, NRMSE Test/best: 0.43012/0.42663, Training NRMSE: 0.33544, deviation of 28.23%
# Epoch -301 calculated in 13.40 s
# Epoch 301, NRMSE Test/best: 0.43844/0.42663, Training NRMSE: 0.33624, deviation of 30.40%
# Epoch -302 calculated in 13.52 s
# Epoch 302, NRMSE Test/best: 0.44004/0.42663, Training NRMSE: 0.33345, deviation of 31.97%
# Epoch -303 calculated in 14.13 s
# Epoch 303, NRMSE Test/best: 0.43237/0.42663, Training NRMSE: 0.33300, deviation of 29.84%
# Epoch -304 calculated in 13.24 s
# Epoch 304, NRMSE Test/best: 0.44064/0.42663, Training NRMSE: 0.33503, deviation of 31.52%
# Epoch -305 calculated in 14.01 s
# Epoch 305, NRMSE Test/best: 0.44091/0.42663, Training NRMSE: 0.33321, deviation of 32.32%
# Epoch -306 calculated in 13.33 s
# Epoch 306, NRMSE Test/best: 0.43812/0.42663, Training NRMSE: 0.33458, deviation of 30.95%
# Epoch -307 calculated in 13.92 s
# Epoch 307, NRMSE Test/best: 0.43270/0.42663, Training NRMSE: 0.33367, deviation of 29.68%
# Epoch -308 calculated in 13.90 s
# Epoch 308, NRMSE Test/best: 0.43131/0.42663, Training NRMSE: 0.33648, deviation of 28.18%
# Epoch -309 calculated in 13.53 s
# Epoch 309, NRMSE Test/best: 0.43658/0.42663, Training NRMSE: 0.33483, deviation of 30.39%
# Epoch -310 calculated in 14.02 s
# Epoch 310, NRMSE Test/best: 0.43423/0.42663, Training NRMSE: 0.33388, deviation of 30.06%
# Epoch -311 calculated in 12.69 s
# Epoch 311, NRMSE Test/best: 0.44225/0.42663, Training NRMSE: 0.33243, deviation of 33.03%
# Epoch -312 calculated in 13.53 s
# Epoch 312, NRMSE Test/best: 0.43602/0.42663, Training NRMSE: 0.33427, deviation of 30.44%
# Epoch -313 calculated in 13.84 s
# Epoch 313, NRMSE Test/best: 0.44179/0.42663, Training NRMSE: 0.33397, deviation of 32.29%
# Epoch -314 calculated in 13.81 s
# Epoch 314, NRMSE Test/best: 0.43395/0.42663, Training NRMSE: 0.33347, deviation of 30.13%
# Epoch -315 calculated in 13.81 s
# Epoch 315, NRMSE Test/best: 0.43594/0.42663, Training NRMSE: 0.33501, deviation of 30.13%
# Epoch -316 calculated in 13.93 s
# Epoch 316, NRMSE Test/best: 0.42049/0.42049, Training NRMSE: 0.33740, deviation of 24.63%
# Epoch -317 calculated in 13.61 s
# Epoch 317, NRMSE Test/best: 0.44015/0.42049, Training NRMSE: 0.33302, deviation of 32.17%
# Epoch -318 calculated in 13.68 s
# Epoch 318, NRMSE Test/best: 0.43538/0.42049, Training NRMSE: 0.33344, deviation of 30.57%
# Epoch -319 calculated in 13.41 s
# Epoch 319, NRMSE Test/best: 0.44380/0.42049, Training NRMSE: 0.33511, deviation of 32.43%
# Epoch -320 calculated in 13.57 s
# Epoch 320, NRMSE Test/best: 0.42355/0.42049, Training NRMSE: 0.33423, deviation of 26.73%
# Epoch -321 calculated in 13.87 s
# Epoch 321, NRMSE Test/best: 0.42745/0.42049, Training NRMSE: 0.33369, deviation of 28.10%
# Epoch -322 calculated in 13.74 s
# Epoch 322, NRMSE Test/best: 0.43421/0.42049, Training NRMSE: 0.33421, deviation of 29.92%
# Epoch -323 calculated in 13.68 s
# Epoch 323, NRMSE Test/best: 0.44706/0.42049, Training NRMSE: 0.33284, deviation of 34.32%
# Epoch -324 calculated in 13.88 s
# Epoch 324, NRMSE Test/best: 0.43353/0.42049, Training NRMSE: 0.33350, deviation of 30.00%
# Epoch -325 calculated in 13.71 s
# Epoch 325, NRMSE Test/best: 0.43642/0.42049, Training NRMSE: 0.33252, deviation of 31.25%
# Epoch -326 calculated in 13.48 s
# Epoch 326, NRMSE Test/best: 0.43234/0.42049, Training NRMSE: 0.33507, deviation of 29.03%
# Epoch -327 calculated in 13.86 s
# Epoch 327, NRMSE Test/best: 0.43458/0.42049, Training NRMSE: 0.33146, deviation of 31.11%
# Epoch -328 calculated in 13.82 s
# Epoch 328, NRMSE Test/best: 0.43354/0.42049, Training NRMSE: 0.33238, deviation of 30.44%
# Epoch -329 calculated in 13.93 s
# Epoch 329, NRMSE Test/best: 0.44732/0.42049, Training NRMSE: 0.33245, deviation of 34.55%
# Epoch -330 calculated in 13.63 s
# Epoch 330, NRMSE Test/best: 0.43294/0.42049, Training NRMSE: 0.33449, deviation of 29.43%
# Epoch -331 calculated in 13.86 s
# Epoch 331, NRMSE Test/best: 0.44991/0.42049, Training NRMSE: 0.33406, deviation of 34.68%
# Epoch -332 calculated in 13.88 s
# Epoch 332, NRMSE Test/best: 0.42949/0.42049, Training NRMSE: 0.33354, deviation of 28.77%
# Epoch -333 calculated in 14.02 s
# Epoch 333, NRMSE Test/best: 0.43048/0.42049, Training NRMSE: 0.33391, deviation of 28.92%
# Epoch -334 calculated in 13.97 s
# Epoch 334, NRMSE Test/best: 0.43649/0.42049, Training NRMSE: 0.33441, deviation of 30.52%
# Epoch -335 calculated in 14.16 s
# Epoch 335, NRMSE Test/best: 0.43149/0.42049, Training NRMSE: 0.33269, deviation of 29.70%
# Epoch -336 calculated in 14.15 s
# Epoch 336, NRMSE Test/best: 0.43583/0.42049, Training NRMSE: 0.33305, deviation of 30.86%
# Epoch -337 calculated in 13.67 s
# Epoch 337, NRMSE Test/best: 0.42921/0.42049, Training NRMSE: 0.33300, deviation of 28.89%
# Epoch -338 calculated in 13.88 s
# Epoch 338, NRMSE Test/best: 0.44502/0.42049, Training NRMSE: 0.33206, deviation of 34.02%
# Epoch -339 calculated in 14.12 s
# Epoch 339, NRMSE Test/best: 0.42800/0.42049, Training NRMSE: 0.33607, deviation of 27.35%
# Epoch -340 calculated in 14.04 s
# Epoch 340, NRMSE Test/best: 0.43557/0.42049, Training NRMSE: 0.33336, deviation of 30.66%
# Epoch -341 calculated in 13.91 s
# Epoch 341, NRMSE Test/best: 0.42040/0.42040, Training NRMSE: 0.33422, deviation of 25.79%
# Epoch -342 calculated in 14.07 s
# Epoch 342, NRMSE Test/best: 0.43110/0.42040, Training NRMSE: 0.33190, deviation of 29.89%
# Epoch -343 calculated in 13.93 s
# Epoch 343, NRMSE Test/best: 0.43441/0.42040, Training NRMSE: 0.33448, deviation of 29.88%
# Epoch -344 calculated in 13.88 s
# Epoch 344, NRMSE Test/best: 0.44259/0.42040, Training NRMSE: 0.33297, deviation of 32.92%
# Epoch -345 calculated in 13.21 s
# Epoch 345, NRMSE Test/best: 0.43752/0.42040, Training NRMSE: 0.33439, deviation of 30.84%
# Epoch -346 calculated in 13.82 s
# Epoch 346, NRMSE Test/best: 0.43118/0.42040, Training NRMSE: 0.33429, deviation of 28.98%
# Epoch -347 calculated in 13.41 s
# Epoch 347, NRMSE Test/best: 0.42766/0.42040, Training NRMSE: 0.33440, deviation of 27.89%
# Epoch -348 calculated in 13.60 s
# Epoch 348, NRMSE Test/best: 0.42894/0.42040, Training NRMSE: 0.33293, deviation of 28.84%
# Epoch -349 calculated in 14.01 s
# Epoch 349, NRMSE Test/best: 0.43015/0.42040, Training NRMSE: 0.33294, deviation of 29.20%
# Epoch -350 calculated in 13.46 s
# Epoch 350, NRMSE Test/best: 0.42419/0.42040, Training NRMSE: 0.33258, deviation of 27.55%
# Epoch -351 calculated in 13.84 s
# Epoch 351, NRMSE Test/best: 0.43468/0.42040, Training NRMSE: 0.33305, deviation of 30.52%
# Epoch -352 calculated in 13.51 s
# Epoch 352, NRMSE Test/best: 0.43147/0.42040, Training NRMSE: 0.33365, deviation of 29.32%
# Epoch -353 calculated in 13.58 s
# Epoch 353, NRMSE Test/best: 0.44133/0.42040, Training NRMSE: 0.33347, deviation of 32.34%
# Epoch -354 calculated in 13.73 s
# Epoch 354, NRMSE Test/best: 0.42167/0.42040, Training NRMSE: 0.33280, deviation of 26.71%
# Epoch -355 calculated in 13.70 s
# Epoch 355, NRMSE Test/best: 0.42962/0.42040, Training NRMSE: 0.33342, deviation of 28.85%
# Epoch -356 calculated in 13.74 s
# Epoch 356, NRMSE Test/best: 0.42334/0.42040, Training NRMSE: 0.33218, deviation of 27.44%
# Epoch -357 calculated in 13.86 s
# Epoch 357, NRMSE Test/best: 0.43152/0.42040, Training NRMSE: 0.33224, deviation of 29.88%
# Epoch -358 calculated in 13.56 s
# Epoch 358, NRMSE Test/best: 0.42951/0.42040, Training NRMSE: 0.33476, deviation of 28.31%
# Epoch -359 calculated in 13.72 s
# Epoch 359, NRMSE Test/best: 0.42930/0.42040, Training NRMSE: 0.33245, deviation of 29.13%
# Epoch -360 calculated in 13.30 s
# Epoch 360, NRMSE Test/best: 0.43061/0.42040, Training NRMSE: 0.33272, deviation of 29.42%
# Epoch -361 calculated in 13.62 s
# Epoch 361, NRMSE Test/best: 0.43249/0.42040, Training NRMSE: 0.33239, deviation of 30.11%
# Epoch -362 calculated in 13.61 s
# Epoch 362, NRMSE Test/best: 0.43224/0.42040, Training NRMSE: 0.33123, deviation of 30.49%
# Epoch -363 calculated in 13.49 s
# Epoch 363, NRMSE Test/best: 0.43134/0.42040, Training NRMSE: 0.33067, deviation of 30.44%
# Epoch -364 calculated in 13.68 s
# Epoch 364, NRMSE Test/best: 0.43722/0.42040, Training NRMSE: 0.33193, deviation of 31.72%
# Epoch -365 calculated in 13.78 s
# Epoch 365, NRMSE Test/best: 0.42072/0.42040, Training NRMSE: 0.33255, deviation of 26.51%
# Epoch -366 calculated in 13.76 s
# Epoch 366, NRMSE Test/best: 0.42773/0.42040, Training NRMSE: 0.33245, deviation of 28.66%
# Epoch -367 calculated in 14.19 s
# Epoch 367, NRMSE Test/best: 0.43800/0.42040, Training NRMSE: 0.33567, deviation of 30.48%
# Epoch -368 calculated in 13.63 s
# Epoch 368, NRMSE Test/best: 0.42651/0.42040, Training NRMSE: 0.33477, deviation of 27.41%
# Epoch -369 calculated in 14.40 s
# Epoch 369, NRMSE Test/best: 0.42862/0.42040, Training NRMSE: 0.33204, deviation of 29.09%
# Epoch -370 calculated in 13.87 s
# Epoch 370, NRMSE Test/best: 0.42385/0.42040, Training NRMSE: 0.33609, deviation of 26.11%
# Epoch -371 calculated in 13.83 s
# Epoch 371, NRMSE Test/best: 0.42849/0.42040, Training NRMSE: 0.33434, deviation of 28.16%
# Epoch -372 calculated in 13.94 s
# Epoch 372, NRMSE Test/best: 0.42730/0.42040, Training NRMSE: 0.33504, deviation of 27.54%
# Epoch -373 calculated in 13.96 s
# Epoch 373, NRMSE Test/best: 0.42776/0.42040, Training NRMSE: 0.33293, deviation of 28.48%
# Epoch -374 calculated in 13.88 s
# Epoch 374, NRMSE Test/best: 0.42434/0.42040, Training NRMSE: 0.33414, deviation of 26.99%
# Epoch -375 calculated in 13.84 s
# Epoch 375, NRMSE Test/best: 0.43289/0.42040, Training NRMSE: 0.33252, deviation of 30.18%
# Epoch -376 calculated in 13.86 s
# Epoch 376, NRMSE Test/best: 0.42512/0.42040, Training NRMSE: 0.33343, deviation of 27.50%
# Epoch -377 calculated in 14.01 s
# Epoch 377, NRMSE Test/best: 0.43968/0.42040, Training NRMSE: 0.33315, deviation of 31.98%
# Epoch -378 calculated in 13.83 s
# Epoch 378, NRMSE Test/best: 0.42320/0.42040, Training NRMSE: 0.33342, deviation of 26.93%
# Epoch -379 calculated in 13.56 s
# Epoch 379, NRMSE Test/best: 0.42969/0.42040, Training NRMSE: 0.33216, deviation of 29.36%
# Epoch -380 calculated in 14.20 s
# Epoch 380, NRMSE Test/best: 0.43098/0.42040, Training NRMSE: 0.33126, deviation of 30.10%
# Epoch -381 calculated in 14.56 s
# Epoch 381, NRMSE Test/best: 0.43464/0.42040, Training NRMSE: 0.33210, deviation of 30.88%
# Epoch -382 calculated in 13.96 s
# Epoch 382, NRMSE Test/best: 0.43017/0.42040, Training NRMSE: 0.33471, deviation of 28.52%
# Epoch -383 calculated in 13.84 s
# Epoch 383, NRMSE Test/best: 0.42425/0.42040, Training NRMSE: 0.33255, deviation of 27.58%
# Epoch -384 calculated in 13.63 s
# Epoch 384, NRMSE Test/best: 0.42651/0.42040, Training NRMSE: 0.33468, deviation of 27.44%
# Epoch -385 calculated in 13.74 s
# ...
# Epoch 3221, NRMSE Test/best: 0.43967/0.41522, Training NRMSE: 0.31929, deviation of 37.70%
# Epoch -3222 calculated in 13.77 s
# Epoch 3222, NRMSE Test/best: 0.43918/0.41522, Training NRMSE: 0.31900, deviation of 37.68%
# Epoch -3223 calculated in 13.39 s
# Epoch 3223, NRMSE Test/best: 0.43494/0.41522, Training NRMSE: 0.31781, deviation of 36.85%
# Epoch -3224 calculated in 14.05 s
# Epoch 3224, NRMSE Test/best: 0.44326/0.41522, Training NRMSE: 0.31912, deviation of 38.90%
# Epoch -3225 calculated in 13.75 s
# Epoch 3225, NRMSE Test/best: 0.44124/0.41522, Training NRMSE: 0.32084, deviation of 37.53%
# Epoch -3226 calculated in 14.20 s
# Epoch 3226, NRMSE Test/best: 0.42939/0.41522, Training NRMSE: 0.31789, deviation of 35.07%
# Epoch -3227 calculated in 13.99 s
# Epoch 3227, NRMSE Test/best: 0.43276/0.41522, Training NRMSE: 0.31836, deviation of 35.93%
# Epoch -3228 calculated in 13.73 s
# Epoch 3228, NRMSE Test/best: 0.43518/0.41522, Training NRMSE: 0.31729, deviation of 37.16%
# Epoch -3229 calculated in 13.91 s
# Epoch 3229, NRMSE Test/best: 0.44091/0.41522, Training NRMSE: 0.31936, deviation of 38.06%
# Epoch -3230 calculated in 14.12 s
# Epoch 3230, NRMSE Test/best: 0.43605/0.41522, Training NRMSE: 0.31753, deviation of 37.33%
# Epoch -3231 calculated in 14.36 s
# Epoch 3231, NRMSE Test/best: 0.44312/0.41522, Training NRMSE: 0.31825, deviation of 39.24%
# Epoch -3232 calculated in 13.81 s
# Epoch 3232, NRMSE Test/best: 0.43511/0.41522, Training NRMSE: 0.31631, deviation of 37.56%
# Epoch -3233 calculated in 13.76 s
# Epoch 3233, NRMSE Test/best: 0.43678/0.41522, Training NRMSE: 0.32042, deviation of 36.32%
# Epoch -3234 calculated in 14.32 s
# Epoch 3234, NRMSE Test/best: 0.43750/0.41522, Training NRMSE: 0.31719, deviation of 37.93%
# Epoch -3235 calculated in 13.91 s
# Epoch 3235, NRMSE Test/best: 0.42974/0.41522, Training NRMSE: 0.31814, deviation of 35.08%
# Epoch -3236 calculated in 14.07 s
# Epoch 3236, NRMSE Test/best: 0.44590/0.41522, Training NRMSE: 0.32055, deviation of 39.10%
# Epoch -3237 calculated in 13.98 s
# Epoch 3237, NRMSE Test/best: 0.43385/0.41522, Training NRMSE: 0.31773, deviation of 36.55%
# Epoch -3238 calculated in 13.56 s
# Epoch 3238, NRMSE Test/best: 0.43701/0.41522, Training NRMSE: 0.31758, deviation of 37.61%
# Epoch -3239 calculated in 14.18 s
# Epoch 3239, NRMSE Test/best: 0.43909/0.41522, Training NRMSE: 0.31829, deviation of 37.95%
# Epoch -3240 calculated in 14.52 s
# Epoch 3240, NRMSE Test/best: 0.42807/0.41522, Training NRMSE: 0.31693, deviation of 35.07%
# Epoch -3241 calculated in 14.24 s
# Epoch 3241, NRMSE Test/best: 0.43108/0.41522, Training NRMSE: 0.31989, deviation of 34.76%
# Epoch -3242 calculated in 14.17 s
# Epoch 3242, NRMSE Test/best: 0.44128/0.41522, Training NRMSE: 0.31874, deviation of 38.45%
# Epoch -3243 calculated in 13.65 s
# Epoch 3243, NRMSE Test/best: 0.44810/0.41522, Training NRMSE: 0.32127, deviation of 39.48%
# Epoch -3244 calculated in 13.88 s
# Epoch 3244, NRMSE Test/best: 0.43171/0.41522, Training NRMSE: 0.31693, deviation of 36.21%
# Epoch -3245 calculated in 14.12 s
# Epoch 3245, NRMSE Test/best: 0.44464/0.41522, Training NRMSE: 0.31737, deviation of 40.10%
# Epoch -3246 calculated in 13.94 s
# Epoch 3246, NRMSE Test/best: 0.44016/0.41522, Training NRMSE: 0.31888, deviation of 38.03%
# Epoch -3247 calculated in 13.86 s
# Epoch 3247, NRMSE Test/best: 0.43422/0.41522, Training NRMSE: 0.31819, deviation of 36.47%
# Epoch -3248 calculated in 13.77 s
# Epoch 3248, NRMSE Test/best: 0.43328/0.41522, Training NRMSE: 0.31794, deviation of 36.28%
# Epoch -3249 calculated in 13.66 s
# Epoch 3249, NRMSE Test/best: 0.43681/0.41522, Training NRMSE: 0.31937, deviation of 36.77%
# Epoch -3250 calculated in 13.70 s
# Epoch 3250, NRMSE Test/best: 0.43755/0.41522, Training NRMSE: 0.31863, deviation of 37.32%
# Epoch -3251 calculated in 13.87 s
# Epoch 3251, NRMSE Test/best: 0.43797/0.41522, Training NRMSE: 0.31831, deviation of 37.59%
# Epoch -3252 calculated in 13.81 s
# Epoch 3252, NRMSE Test/best: 0.44475/0.41522, Training NRMSE: 0.31727, deviation of 40.18%
# Epoch -3253 calculated in 13.55 s
# Epoch 3253, NRMSE Test/best: 0.42902/0.41522, Training NRMSE: 0.31815, deviation of 34.85%
# Epoch -3254 calculated in 14.13 s
# Epoch 3254, NRMSE Test/best: 0.43779/0.41522, Training NRMSE: 0.31808, deviation of 37.63%
# Epoch -3255 calculated in 13.71 s
# Epoch 3255, NRMSE Test/best: 0.44021/0.41522, Training NRMSE: 0.31732, deviation of 38.73%
# Epoch -3256 calculated in 13.53 s
# Epoch 3256, NRMSE Test/best: 0.44037/0.41522, Training NRMSE: 0.31835, deviation of 38.33%
# Epoch -3257 calculated in 13.70 s
# Epoch 3257, NRMSE Test/best: 0.44026/0.41522, Training NRMSE: 0.31689, deviation of 38.93%
# Epoch -3258 calculated in 13.26 s
# Epoch 3258, NRMSE Test/best: 0.43794/0.41522, Training NRMSE: 0.31790, deviation of 37.76%
# Epoch -3259 calculated in 13.99 s
# Epoch 3259, NRMSE Test/best: 0.42540/0.41522, Training NRMSE: 0.31794, deviation of 33.80%
# Epoch -3260 calculated in 13.77 s
# Epoch 3260, NRMSE Test/best: 0.44308/0.41522, Training NRMSE: 0.31969, deviation of 38.60%
# Epoch -3261 calculated in 13.71 s
# Epoch 3261, NRMSE Test/best: 0.43528/0.41522, Training NRMSE: 0.31970, deviation of 36.16%
# Epoch -3262 calculated in 14.10 s
# Epoch 3262, NRMSE Test/best: 0.43592/0.41522, Training NRMSE: 0.31895, deviation of 36.67%
# Epoch -3263 calculated in 13.77 s
# Epoch 3263, NRMSE Test/best: 0.43768/0.41522, Training NRMSE: 0.31653, deviation of 38.28%
# Epoch -3264 calculated in 13.56 s
# Epoch 3264, NRMSE Test/best: 0.42758/0.41522, Training NRMSE: 0.31739, deviation of 34.72%
# Epoch -3265 calculated in 13.90 s
# Epoch 3265, NRMSE Test/best: 0.43386/0.41522, Training NRMSE: 0.31845, deviation of 36.24%
# Epoch -3266 calculated in 13.94 s
# Epoch 3266, NRMSE Test/best: 0.42986/0.41522, Training NRMSE: 0.32014, deviation of 34.27%
# Epoch -3267 calculated in 13.88 s
# Epoch 3267, NRMSE Test/best: 0.43885/0.41522, Training NRMSE: 0.31959, deviation of 37.32%
# Epoch -3268 calculated in 13.63 s
# Epoch 3268, NRMSE Test/best: 0.44238/0.41522, Training NRMSE: 0.31678, deviation of 39.65%
# Epoch -3269 calculated in 14.18 s
# Epoch 3269, NRMSE Test/best: 0.43740/0.41522, Training NRMSE: 0.31700, deviation of 37.98%
# Epoch -3270 calculated in 14.10 s
# Epoch 3270, NRMSE Test/best: 0.43402/0.41522, Training NRMSE: 0.32046, deviation of 35.44%
# Epoch -3271 calculated in 13.84 s
# Epoch 3271, NRMSE Test/best: 0.43385/0.41522, Training NRMSE: 0.31906, deviation of 35.98%
# Epoch -3272 calculated in 13.99 s
# Epoch 3272, NRMSE Test/best: 0.43142/0.41522, Training NRMSE: 0.31926, deviation of 35.13%
# Epoch -3273 calculated in 13.89 s
# Epoch 3273, NRMSE Test/best: 0.44767/0.41522, Training NRMSE: 0.31677, deviation of 41.32%
# Epoch -3274 calculated in 13.47 s
# Epoch 3274, NRMSE Test/best: 0.43602/0.41522, Training NRMSE: 0.31993, deviation of 36.28%
# Epoch -3275 calculated in 14.03 s
# Epoch 3275, NRMSE Test/best: 0.43107/0.41522, Training NRMSE: 0.31819, deviation of 35.48%
# Epoch -3276 calculated in 13.65 s
# Epoch 3276, NRMSE Test/best: 0.43660/0.41522, Training NRMSE: 0.31889, deviation of 36.91%
# Epoch -3277 calculated in 14.20 s
# Epoch 3277, NRMSE Test/best: 0.44383/0.41522, Training NRMSE: 0.31728, deviation of 39.89%
# Epoch -3278 calculated in 14.17 s
# Epoch 3278, NRMSE Test/best: 0.43248/0.41522, Training NRMSE: 0.31690, deviation of 36.47%
# Epoch -3279 calculated in 13.68 s
# Epoch 3279, NRMSE Test/best: 0.43493/0.41522, Training NRMSE: 0.31843, deviation of 36.59%
# Epoch -3280 calculated in 14.41 s
# Epoch 3280, NRMSE Test/best: 0.43907/0.41522, Training NRMSE: 0.31724, deviation of 38.40%
# Epoch -3281 calculated in 13.55 s
# Epoch 3281, NRMSE Test/best: 0.43143/0.41522, Training NRMSE: 0.31995, deviation of 34.84%
# Epoch -3282 calculated in 13.85 s
# Epoch 3282, NRMSE Test/best: 0.43202/0.41522, Training NRMSE: 0.31910, deviation of 35.39%
# Epoch -3283 calculated in 13.53 s
# Epoch 3283, NRMSE Test/best: 0.43226/0.41522, Training NRMSE: 0.31854, deviation of 35.70%
# Epoch -3284 calculated in 13.60 s
# Epoch 3284, NRMSE Test/best: 0.43033/0.41522, Training NRMSE: 0.31705, deviation of 35.73%
# Epoch -3285 calculated in 13.93 s
# Epoch 3285, NRMSE Test/best: 0.43820/0.41522, Training NRMSE: 0.31738, deviation of 38.07%
# Epoch -3286 calculated in 13.46 s
# Epoch 3286, NRMSE Test/best: 0.44606/0.41522, Training NRMSE: 0.32059, deviation of 39.14%
# Epoch -3287 calculated in 13.73 s
# Epoch 3287, NRMSE Test/best: 0.43414/0.41522, Training NRMSE: 0.31727, deviation of 36.84%
# Epoch -3288 calculated in 13.77 s
# Epoch 3288, NRMSE Test/best: 0.44321/0.41522, Training NRMSE: 0.31690, deviation of 39.86%
# Epoch -3289 calculated in 13.66 s
# Epoch 3289, NRMSE Test/best: 0.43572/0.41522, Training NRMSE: 0.31681, deviation of 37.53%
# Epoch -3290 calculated in 13.64 s
# Epoch 3290, NRMSE Test/best: 0.44280/0.41522, Training NRMSE: 0.31699, deviation of 39.69%
# Epoch -3291 calculated in 13.69 s
# Epoch 3291, NRMSE Test/best: 0.44110/0.41522, Training NRMSE: 0.32035, deviation of 37.69%
# Epoch -3292 calculated in 13.65 s
# Epoch 3292, NRMSE Test/best: 0.44490/0.41522, Training NRMSE: 0.31939, deviation of 39.30%
# Epoch -3293 calculated in 14.12 s
# Epoch 3293, NRMSE Test/best: 0.43770/0.41522, Training NRMSE: 0.31970, deviation of 36.91%
# Epoch -3294 calculated in 13.75 s
# Epoch 3294, NRMSE Test/best: 0.44592/0.41522, Training NRMSE: 0.31704, deviation of 40.65%
# Epoch -3295 calculated in 13.93 s
# Epoch 3295, NRMSE Test/best: 0.43900/0.41522, Training NRMSE: 0.31824, deviation of 37.95%
# Epoch -3296 calculated in 13.44 s
# Epoch 3296, NRMSE Test/best: 0.43974/0.41522, Training NRMSE: 0.31687, deviation of 38.78%
# Epoch -3297 calculated in 13.52 s
# Epoch 3297, NRMSE Test/best: 0.43869/0.41522, Training NRMSE: 0.31850, deviation of 37.73%
# Epoch -3298 calculated in 13.95 s
# Epoch 3298, NRMSE Test/best: 0.43534/0.41522, Training NRMSE: 0.31910, deviation of 36.43%
# Epoch -3299 calculated in 13.62 s
# Epoch 3299, NRMSE Test/best: 0.44153/0.41522, Training NRMSE: 0.31940, deviation of 38.24%
# Epoch -3300 calculated in 13.83 s
# Epoch 3300, NRMSE Test/best: 0.44116/0.41522, Training NRMSE: 0.32047, deviation of 37.66%
# Epoch -3301 calculated in 13.88 s
# Epoch 3301, NRMSE Test/best: 0.43803/0.41522, Training NRMSE: 0.31831, deviation of 37.61%
# Epoch -3302 calculated in 13.17 s
# Epoch 3302, NRMSE Test/best: 0.44228/0.41522, Training NRMSE: 0.31812, deviation of 39.03%
# Epoch -3303 calculated in 14.02 s
# Epoch 3303, NRMSE Test/best: 0.43272/0.41522, Training NRMSE: 0.31837, deviation of 35.92%
# Epoch -3304 calculated in 13.86 s
# Epoch 3304, NRMSE Test/best: 0.43917/0.41522, Training NRMSE: 0.31861, deviation of 37.84%
# Epoch -3305 calculated in 13.66 s
# Epoch 3305, NRMSE Test/best: 0.45129/0.41522, Training NRMSE: 0.31923, deviation of 41.37%
# Epoch -3306 calculated in 13.82 s
# Epoch 3306, NRMSE Test/best: 0.44083/0.41522, Training NRMSE: 0.31812, deviation of 38.57%
# Epoch -3307 calculated in 13.78 s
# Epoch 3307, NRMSE Test/best: 0.44589/0.41522, Training NRMSE: 0.31880, deviation of 39.87%
# Epoch -3308 calculated in 13.87 s
# Epoch 3308, NRMSE Test/best: 0.44039/0.41522, Training NRMSE: 0.31820, deviation of 38.40%
# Epoch -3309 calculated in 13.60 s
# Epoch 3309, NRMSE Test/best: 0.43255/0.41522, Training NRMSE: 0.31952, deviation of 35.37%
# Epoch -3310 calculated in 13.77 s
# Epoch 3310, NRMSE Test/best: 0.43998/0.41522, Training NRMSE: 0.31845, deviation of 38.16%
# Epoch -3311 calculated in 14.10 s
# Epoch 3311, NRMSE Test/best: 0.43339/0.41522, Training NRMSE: 0.31762, deviation of 36.45%
# Epoch -3312 calculated in 13.70 s
# Epoch 3312, NRMSE Test/best: 0.43524/0.41522, Training NRMSE: 0.31801, deviation of 36.86%
# Epoch -3313 calculated in 13.79 s
# Epoch 3313, NRMSE Test/best: 0.44445/0.41522, Training NRMSE: 0.31935, deviation of 39.18%
# Epoch -3314 calculated in 13.83 s
# Epoch 3314, NRMSE Test/best: 0.44134/0.41522, Training NRMSE: 0.32032, deviation of 37.78%
# Epoch -3315 calculated in 13.91 s
# Epoch 3315, NRMSE Test/best: 0.42947/0.41522, Training NRMSE: 0.31945, deviation of 34.44%
# Epoch -3316 calculated in 14.09 s
# Epoch 3316, NRMSE Test/best: 0.43985/0.41522, Training NRMSE: 0.31652, deviation of 38.96%
# Epoch -3317 calculated in 13.99 s
# Epoch 3317, NRMSE Test/best: 0.43507/0.41522, Training NRMSE: 0.31763, deviation of 36.97%
# Epoch -3318 calculated in 14.11 s
# Epoch 3318, NRMSE Test/best: 0.44585/0.41522, Training NRMSE: 0.31737, deviation of 40.49%
# Epoch -3319 calculated in 14.01 s
# Epoch 3319, NRMSE Test/best: 0.44337/0.41522, Training NRMSE: 0.31746, deviation of 39.66%
# Epoch -3320 calculated in 14.12 s
# Epoch 3320, NRMSE Test/best: 0.44225/0.41522, Training NRMSE: 0.31790, deviation of 39.12%
# Epoch -3321 calculated in 14.37 s
# Epoch 3321, NRMSE Test/best: 0.44777/0.41522, Training NRMSE: 0.31968, deviation of 40.07%
# Epoch -3322 calculated in 14.22 s
# Epoch 3322, NRMSE Test/best: 0.44062/0.41522, Training NRMSE: 0.31654, deviation of 39.20%
# Epoch -3323 calculated in 14.21 s
# Epoch 3323, NRMSE Test/best: 0.43275/0.41522, Training NRMSE: 0.31655, deviation of 36.71%
# Epoch -3324 calculated in 14.32 s
# Epoch 3324, NRMSE Test/best: 0.44775/0.41522, Training NRMSE: 0.31738, deviation of 41.07%
# Epoch -3325 calculated in 13.83 s
# Epoch 3325, NRMSE Test/best: 0.43522/0.41522, Training NRMSE: 0.31768, deviation of 37.00%
# Epoch -3326 calculated in 14.40 s
# Epoch 3326, NRMSE Test/best: 0.43673/0.41522, Training NRMSE: 0.31824, deviation of 37.23%
# Epoch -3327 calculated in 13.85 s
# Epoch 3327, NRMSE Test/best: 0.45135/0.41522, Training NRMSE: 0.31850, deviation of 41.71%
# Epoch -3328 calculated in 14.00 s
# Epoch 3328, NRMSE Test/best: 0.43607/0.41522, Training NRMSE: 0.31904, deviation of 36.68%
# Epoch -3329 calculated in 14.12 s
# Epoch 3329, NRMSE Test/best: 0.44737/0.41522, Training NRMSE: 0.31663, deviation of 41.29%
# Epoch -3330 calculated in 13.56 s
# Epoch 3330, NRMSE Test/best: 0.43663/0.41522, Training NRMSE: 0.31764, deviation of 37.46%
# Epoch -3331 calculated in 13.69 s
# Epoch 3331, NRMSE Test/best: 0.44187/0.41522, Training NRMSE: 0.31843, deviation of 38.76%
# Epoch -3332 calculated in 13.56 s
# Epoch 3332, NRMSE Test/best: 0.44556/0.41522, Training NRMSE: 0.31733, deviation of 40.41%
# Training duration 01:15:00:02
# Number of training variable 652001
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/freeze_graph.py:249: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from Experiments/2019-05-15-10-42/temp/myFinalModel.ckpt
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/freeze_graph.py:232: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.convert_variables_to_constants
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/graph_util_impl.py:245: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph
# INFO:tensorflow:Froze 6 variables.
# INFO:tensorflow:Converted 6 variables to const ops.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/optimize_for_inference_lib.py:113: remove_training_nodes (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.remove_training_nodes
# INFO:tensorflow:Restoring parameters from Experiments/2019-05-15-10-42/temp/myBestModel.ckpt
# done, good job kids

# %%
from show import *
# %matplotlib notebook
showPickle(nameFigEstimation)
# Out:
# <img src="data:image/png;base64,..." width="640">
