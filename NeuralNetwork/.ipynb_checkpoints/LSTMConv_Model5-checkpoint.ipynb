# %% [markdown]
# # Learn simple layer of LSTM

# %% [markdown]
# smaller model parameters than in conv 10

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
import os
import sys
sys.path.append('Codes')
import tensorflow as tf
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import pickle
from dataShaping import *
from savePerf import *
from saveTransformedGraph import optimizeGraph
import scipy.io.wavfile
import time
from tensorflow.contrib.layers import fully_connected
from tensorflow.contrib.rnn import *




modelName = "LSTMConv_Model5"
# create directory experiment
date = time.strftime("%Y-%m-%d-%H-%M")
path = os.path.join("Experiments",date)
if not os.path.isdir(path):
    os.makedirs(path)
    #experiment/"date"/temp will contain the backuped model parameters
    pathTemp = os.path.join(path,'temp')
    os.makedirs(pathTemp)
    # if you run the file two time in a minute
else :
    date = date+'(2)'
    path = os.path.join("Experiments",date)
    os.makedirs(path)
    pathTemp = os.path.join(path,'temp')
    os.makedirs(pathTemp)

# directory that will contain tensorboard information
pathLog = 'Tf_logs'
if not os.path.isdir(pathLog):
    os.makedirs(pathLog)
pathLog = "{}/run-{}/".format(pathLog,date)

version = tf.__version__
print ("version {} of tensorflow".format(version))

#############################
# Model parameters
#############################
trainTestRatio = 0.8
#if you cannot load all the data set in Ram specify wich part you want to load (0 means all the dataset)
maxSize = 0
num_step = 150                                       # time step before reduction
#num_LSTM = 10                                         # num LSTM (time step after reduction)
conv_chan = [35]                                         #number of kernel for convolution
conv_strides = 3#int(np.ceil(num_step/num_LSTM))                  #decay between two convolution
conv_size = 12                                         #filter size for the convolution
size_poll = 4
reg_scale = 0
l1l2Prop = 0.4  # 1 =>l1, 0=> l2
reg_scale_l1 = l1l2Prop*reg_scale
reg_scale_l2 = ((1-l1l2Prop)/2)*reg_scale
num_hidden = 100                                      #num of hidden units
num_class = 1                                          #size of the output
num_feature = 1                                        # size of the input
batch_size = 2500                                   # number of sequence taken before to compute the gradient
n_layer = 1                                             #num_layer

#num_hidden = num_hidden/keep_prob
num_epoch = 10000                                      # process all the datas num_epoch times
trainDuration = 60*60*15                             # or during a determined duration(second)
                                      
amplifierName = 'EnglDisto'
fileNameTrain = 'Datasets/training'+amplifierName+'.mat'             #dataset train/test path
fileNameTest = 'Datasets/test'+amplifierName+'.mat' # dataset validation path
fileNameValidation = 'Datasets/val'+amplifierName+'.mat'

#############################
# Loading data
#############################
matrix = sio.loadmat(fileNameTrain)
matrixTrain = matrix['train']
matrix = sio.loadmat(fileNameTest)
matrixTest = matrix['test']
if maxSize ==0:
    maxSize = len(matrixTrain)
    print("maxSize = {}".format(maxSize))
# to do shuffle matrix by num_step length

#train_input,train_output,test_input,test_output = loadInputOutput(matrixTrain,matrixTest,num_step,maxSize)

#print("train input {}".format(matrixTrain[:10,0]))
#print("matrix output {}".format(matrixTrain[num_step-1:num_step-1+10,1]))
#print("1er method output {}".format(train_output[:10]))
train_input,train_output,test_input,test_output = loadInputOutputSeq(matrixTrain,matrixTest,num_step,maxSize)

#print("seq method output {}".format(train_output[:10]))
print("shape input train {}".format(np.shape(train_input)))
numTrain = len(train_output)
print ("Data loaded")
#######################
#Graph
#######################

G = tf.Graph()
with G.as_default():
    with tf.name_scope("placeHolder"):
        data = tf.placeholder(tf.float32, [None, num_step], name ="data") #Number of examples, number of input step (time step), dimension of each input
        target = tf.placeholder(tf.float32, [None, num_class],name = "target") # batchSize, nbClass

    dataShaped = tf.reshape(data,[tf.shape(data)[0],num_step,1,1]) # batchSize, num_step num_feature
    with tf.variable_scope("ConvLayers"):
        regularizerC1 = tf.contrib.layers.l1_l2_regularizer(scale_l1=reg_scale_l1,scale_l2=reg_scale_l2,scope="regC1")
        dataReduced = tf.layers.conv2d(inputs = dataShaped,filters = conv_chan[0],
                                       kernel_size = (conv_size,1),strides=(4,1),
                                       padding = "same",activation=tf.nn.elu,kernel_regularizer=regularizerC1,name="C1")#batch_size num_Lstm num_channel
        regularizerC2 = tf.contrib.layers.l1_l2_regularizer(scale_l1=reg_scale_l1,scale_l2=reg_scale_l2,scope="regC2")
        dataReduced = tf.layers.conv2d(inputs = dataReduced,filters = conv_chan[0],
                                       kernel_size = (conv_size,1),strides=(3,1),
                                       padding = "same",activation=tf.nn.elu,kernel_regularizer=regularizerC2,name="C2")#batch_size num_Lstm num_channel
        #regularizerC3 = tf.contrib.layers.l1_l2_regularizer(scale_l1=reg_scale_l1,scale_l2=reg_scale_l2,scope="regC3")
        #dataReduced = tf.layers.conv2d(inputs = dataReduced,filters = conv_chan,
        #                               kernel_size = (conv_size,1),strides=(2,1),
        #                               padding = "same",activation=tf.nn.elu,kernel_regularizer=regularizerC3,name="C3")#batch_size num_Lstm num_channel
    dataReduced = tf.reshape(dataReduced,[tf.shape(data)[0],tf.shape(dataReduced)[1],conv_chan[0]])
    
    fusedCell = tf.contrib.rnn.LSTMBlockFusedCell(num_hidden,use_peephole=False)
 
    dataReduced = tf.transpose(dataReduced,[1,0,2])

    with tf.name_scope("extractLastValueLSTM"):
        #val, state = fusedCell(dataReduced) #for cudnn_rnn.cudnnLSTM
        val, state = fusedCell(dataReduced,dtype=tf.float32) #for LSTMblockFusedCell
        #val, state = fusedCell(dataReduced,initial_state=None,dtype=tf.float32) # val dim is [num_step,batch_size, numhidden]
    # Let's first fetch the last index of seq length
    # last_index would have a scalar value
        last_index = tf.shape(val)[0] - 1
    # Then let's reshape the output to [sequence_length,batch_size,numhidden]
    # for convenience
        #val = tf.transpose(val,[1,0,2])
    # Last state of all batches
        #last = tf.nn.embedding_lookup(val,last_index) # tensor [batchsize,numhidden]
        last = tf.gather(val,last_index)

    prediction = fully_connected(last,int(target.get_shape()[1]),activation_fn=tf.nn.tanh,weights_regularizer=None,scope="FCPred")
    
    #Compute the mean square error
    MSE = tf.reduce_mean(tf.square(prediction-target))
    EnergyTarget = tf.reduce_mean(tf.square(target)) 
    
    #get regularizer
    reg_losses = tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES)
    MSEReg = tf.add_n([MSE]+reg_losses,name="MSEReg")
    # create optimizer
    optimizer = tf.train.AdamOptimizer()
    #Compute gradient and apply backpropagation
    minimize = optimizer.minimize(MSEReg)

    # Create summary view for tensorboard
    mse_summary = tf.summary.scalar('RMSE',tf.sqrt(MSE))
    #kernels = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES,'ConvLayers/C1/kernel')[0]
    #kernels1 = tf.reshape(tf.slice(kernels,[0,0,0,0],[12,1,1,1]),[-1])
    #kernels2 = tf.reshape(kernels,[1,12,30,1])
    #imag_summary=tf.summary.image('kernels',kernels2,max_outputs=1)
    #histogram_summary = tf.summary.histogram('kernelC1',kernels1)
    summary_op = tf.summary.merge_all()
    
    #Create an init op to initialize variable
    init_op = tf.global_variables_initializer()
    saver = tf.train.Saver() # save variable, use saver.restore(sess,"date/tmp/my_model.ckpt") instead of sess.run(init_op)

##############################
# Execution du graphe
##############################
    
with tf.Session(graph=G) as sess:
    #restorePath = os.path.join('2017-09-11-18-07','temp','my_model.ckpt')
    #saver.restore(sess,restorePath)
    sess.run(init_op)
    train_writer = tf.summary.FileWriter(pathLog+'train',graph =tf.get_default_graph())
    test_writer = tf.summary.FileWriter(pathLog+'test')
    
    no_of_batches = int(np.floor((numTrain)/batch_size)) # numtrain -numstep    no_of_batchesTest = int(np.floor((len(test_input)-num_step)/batch_size))
    no_of_batchesTest = int(np.floor((len(test_input))/batch_size))
    tStart = time.clock()
    epoch =0
    NRMSETest = 10
    bestNRMSETest = 1    
    # train until the number of epoch or the training time is reached
    for epoch in range(num_epoch):
        tEpoch = time.clock()
        if (time.clock()-tStart < trainDuration) :
            ptr = 0
            if epoch % 20==0 : # each twenty epochs save the model
                tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myGraph.pb',as_text=False)
                save_path = saver.save(sess,os.path.join(pathTemp,'myModel.ckpt'))
            
            pMSETrain=0
            pEnergyTarget=0
            for j in range(no_of_batches):
                inp, out = train_input[ptr:ptr+batch_size],train_output[ptr:ptr+batch_size]
                ptr+=batch_size
                
                if j % np.floor(numTrain/len(test_input)) ==0 : # This is to have a train summary and a test summary of the same size
                    _,summary_str,pMSETrainTemp,pEnergyTargetTemp = sess.run([minimize,summary_op,MSE,EnergyTarget],{data: inp, target: out})
                    #print("shape:{}".format(numTrain/len(test_input)))
                    pMSETrain += pMSETrainTemp
                    pEnergyTarget += pEnergyTargetTemp
                    step = epoch*no_of_batches+j
                    # save the training RMSE for tensorboard
                    train_writer.add_summary(summary_str,step)                   

                else :
                    _,pMSETrainTemp,pEnergyTargetTemp = sess.run([minimize,MSE,EnergyTarget],{data: inp, target: out})
                    pMSETrain += pMSETrainTemp
                    pEnergyTarget += pEnergyTargetTemp
                    #[print(n.name) for n in tf.get_default_graph().as_graph_def().node]
            # compute an estimation of the RMSE for this epoch       
            MSETrain = pMSETrain/no_of_batches
            EnergyTargetTrain = pEnergyTarget/no_of_batches
            NRMSETrain = np.sqrt(MSETrain/EnergyTargetTrain)
            print ("Epoch -{} calculated in {:5.2f} s ".format(epoch,time.clock()-tEpoch))
            # evaluate the model on the test set 
            pMSE = 0
            ptr2 = 0
            pEnergyTarget = 0
            for k in range(no_of_batchesTest):
                pMSETemp,pEnergyTargetTemp,summary_str = sess.run([MSE,EnergyTarget,summary_op],{data: test_input[ptr2:ptr2+batch_size] , target: test_output[ptr2:ptr2+batch_size]})
                pMSE += pMSETemp
                ptr2 += batch_size
                pEnergyTarget+=pEnergyTargetTemp
                step = epoch*no_of_batchesTest+k
                test_writer.add_summary(summary_str,step*np.floor(numTrain/len(test_input)))
            MSETest = pMSE/no_of_batchesTest
            EnergyTargetTest = pEnergyTarget/no_of_batchesTest
            NRMSETest = np.sqrt(MSETest/EnergyTargetTest)
            if NRMSETest<bestNRMSETest:
                bestNRMSETest=NRMSETest
                tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myBestGraph.pbtxt',as_text=True)
                save_path = saver.save(sess,os.path.join(pathTemp,'myBestModel.ckpt'))
            print("Epoch {}, NRMSE Test/best: {:.5f}/{:.5f}, Training NRMSE: {:.5f}, deviation of {:.2f}%".format(epoch,NRMSETest,bestNRMSETest,NRMSETrain,100*np.sqrt((NRMSETrain-NRMSETest)**2)/NRMSETrain))
        else : break # break the while loop if number of epoch is reached
    tStop = time.clock()
    trainTime = time.strftime("%d:%H:%M:%S ", time.gmtime(tStop-tStart))
    
    #######################
    # Save Graph variable and information about the running session
    #######################
    # save graph model
    tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myFinalGraph.pbtxt',as_text=True)
    # Save checkpoint variables
    save_path = saver.save(sess,os.path.join(pathTemp,'myFinalModel.ckpt'))
    print ("Training duration {}".format(trainTime))
    totalParameters =np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.trainable_variables()])
    print("Number of training variable {}".format(totalParameters))
    # log
    infoLog={}
    infoLog["path"] = path
    infoLog["MSE"] = bestNRMSETest
    infoLog["num_step"] = num_step
    infoLog["num_hidden"] = num_hidden
    infoLog["num_epoch"] = epoch
    infoLog["batch_size"] = batch_size
    infoLog["maxSize"] = maxSize
    infoLog["duration"] = trainTime
    infoLog["totalParameters"] = totalParameters
    infoLog["version"] = version
    infoLog["n_layer"] = n_layer
    infoLog["trainDropout"] = 0
    infoLog["nameModel"] = modelName
    infoLog["conv_chan"] = conv_chan
    infoLog["strides"] = conv_strides
    infoLog["conv_size"] = conv_size
    infoLog["amplifierName"]=amplifierName
    logPerf(infoLog)
    input_nodes=["placeHolder/data"]
    output_nodes=["FCPred/Tanh"]
    optimizeGraph(pathTemp,input_nodes,output_nodes)
    
    
                                                 
    
    ###############################
    #   validation dataset and emulate guitar signal
    ###############################
    restorePath = os.path.join(pathTemp,'myBestModel.ckpt') # example for restore a previous model
    saver.restore(sess,restorePath)
    matrixVal = sio.loadmat(fileNameValidation)
    matrixVal = matrixVal['val']  
    valSize = 0
    if valSize == 0 :
        valSize = len(matrixVal)
    # shape validation test
    val_input,val_output = loadValidationSeq(matrixVal,num_step,valSize)
    lPrediction = []
    lTarget = []
    ptr3 = 0
    no_of_batchesVal = int(np.floor((len(val_input))/batch_size))
    for k in range(no_of_batchesVal):
        pPrediction,pTarget = sess.run([prediction,target],{data: val_input[ptr3:ptr3+batch_size], target: val_output[ptr3:ptr3+batch_size]}) 
        lPrediction.append(pPrediction)
        lTarget.append(pTarget)   
        ptr3+=batch_size
    #plt.show()scree
    predictionArray = np.array(lPrediction,dtype=np.float32).ravel()
    targetArray = np.array(lTarget,dtype=np.float32).ravel()
    scipy.io.wavfile.write(os.path.join(path,'prediction.wav'),44100,predictionArray)
    scipy.io.wavfile.write(os.path.join(path,'target.wav'),44100,targetArray)

    # save emulation in a pickle format
    ax = plt.subplot(111)
    ax.plot(predictionArray[6000+num_step:6700+num_step],label='prediction')
    ax.plot(targetArray[6000+num_step:6700+num_step],label='target')
    ax.legend()
    plt.xlabel('sample n')
    plt.ylabel('Amplitude y[n]')
    nameFigEstimation = os.path.join(path,"targetVsPrediction.pickle")
    pickle.dump(ax,open(nameFigEstimation, 'wb'))
print ("done, good job kids")
# Out:
# version 1.13.1 of tensorflow
# maxSize = 6726407
# shape input train (6726258, 150)
# Data loaded
# INFO:tensorflow:Scale of 0 disables regularizer.
# WARNING:tensorflow:From <ipython-input-1-80ecc5a77804>:118: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.conv2d instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/rnn/python/ops/lstm_ops.py:694: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch -0 calculated in 35.28 s
# Epoch 0, NRMSE Test/best: 0.55132/0.55132, Training NRMSE: 0.59217, deviation of 6.90%
# Epoch -1 calculated in 34.51 s
# Epoch 1, NRMSE Test/best: 0.46243/0.46243, Training NRMSE: 0.40079, deviation of 15.38%
# Epoch -2 calculated in 34.33 s
# Epoch 2, NRMSE Test/best: 0.45417/0.45417, Training NRMSE: 0.36940, deviation of 22.95%
# Epoch -3 calculated in 34.41 s
# Epoch 3, NRMSE Test/best: 0.45511/0.45417, Training NRMSE: 0.35585, deviation of 27.90%
# Epoch -4 calculated in 34.51 s
# Epoch 4, NRMSE Test/best: 0.48410/0.45417, Training NRMSE: 0.34921, deviation of 38.63%
# Epoch -5 calculated in 34.54 s
# Epoch 5, NRMSE Test/best: 0.46954/0.45417, Training NRMSE: 0.34336, deviation of 36.75%
# Epoch -6 calculated in 34.41 s
# Epoch 6, NRMSE Test/best: 0.45301/0.45301, Training NRMSE: 0.33849, deviation of 33.83%
# Epoch -7 calculated in 34.48 s
# Epoch 7, NRMSE Test/best: 0.45097/0.45097, Training NRMSE: 0.33537, deviation of 34.47%
# Epoch -8 calculated in 34.35 s
# Epoch 8, NRMSE Test/best: 0.43527/0.43527, Training NRMSE: 0.33217, deviation of 31.04%
# Epoch -9 calculated in 34.63 s
# Epoch 9, NRMSE Test/best: 0.43414/0.43414, Training NRMSE: 0.32970, deviation of 31.68%
# Epoch -10 calculated in 34.75 s
# Epoch 10, NRMSE Test/best: 0.44949/0.43414, Training NRMSE: 0.32889, deviation of 36.67%
# Epoch -11 calculated in 34.58 s
# Epoch 11, NRMSE Test/best: 0.45513/0.43414, Training NRMSE: 0.32669, deviation of 39.31%
# Epoch -12 calculated in 34.62 s
# Epoch 12, NRMSE Test/best: 0.45768/0.43414, Training NRMSE: 0.32541, deviation of 40.65%
# Epoch -13 calculated in 34.44 s
# Epoch 13, NRMSE Test/best: 0.43783/0.43414, Training NRMSE: 0.32335, deviation of 35.40%
# Epoch -14 calculated in 34.63 s
# Epoch 14, NRMSE Test/best: 0.44186/0.43414, Training NRMSE: 0.32217, deviation of 37.15%
# Epoch -15 calculated in 34.54 s
# Epoch 15, NRMSE Test/best: 0.44509/0.43414, Training NRMSE: 0.32042, deviation of 38.91%
# Epoch -16 calculated in 34.48 s
# Epoch 16, NRMSE Test/best: 0.44182/0.43414, Training NRMSE: 0.31975, deviation of 38.18%
# Epoch -17 calculated in 34.47 s
# Epoch 17, NRMSE Test/best: 0.42303/0.42303, Training NRMSE: 0.31858, deviation of 32.79%
# Epoch -18 calculated in 34.48 s
# Epoch 18, NRMSE Test/best: 0.40783/0.40783, Training NRMSE: 0.31657, deviation of 28.83%
# Epoch -19 calculated in 34.36 s
# Epoch 19, NRMSE Test/best: 0.40655/0.40655, Training NRMSE: 0.31523, deviation of 28.97%
# Epoch -20 calculated in 34.48 s
# Epoch 20, NRMSE Test/best: 0.41066/0.40655, Training NRMSE: 0.31435, deviation of 30.64%
# Epoch -21 calculated in 34.48 s
# Epoch 21, NRMSE Test/best: 0.40168/0.40168, Training NRMSE: 0.31383, deviation of 28.00%
# Epoch -22 calculated in 34.61 s
# Epoch 22, NRMSE Test/best: 0.39966/0.39966, Training NRMSE: 0.31310, deviation of 27.65%
# Epoch -23 calculated in 34.43 s
# Epoch 23, NRMSE Test/best: 0.40948/0.39966, Training NRMSE: 0.31279, deviation of 30.91%
# Epoch -24 calculated in 34.50 s
# Epoch 24, NRMSE Test/best: 0.39966/0.39966, Training NRMSE: 0.31159, deviation of 28.27%
# Epoch -25 calculated in 34.43 s
# Epoch 25, NRMSE Test/best: 0.40783/0.39966, Training NRMSE: 0.31111, deviation of 31.09%
# Epoch -26 calculated in 34.31 s
# Epoch 26, NRMSE Test/best: 0.40766/0.39966, Training NRMSE: 0.31007, deviation of 31.47%
# Epoch -27 calculated in 34.44 s
# Epoch 27, NRMSE Test/best: 0.40556/0.39966, Training NRMSE: 0.31028, deviation of 30.71%
# Epoch -28 calculated in 34.59 s
# Epoch 28, NRMSE Test/best: 0.39728/0.39728, Training NRMSE: 0.30901, deviation of 28.57%
# Epoch -29 calculated in 34.39 s
# Epoch 29, NRMSE Test/best: 0.38639/0.38639, Training NRMSE: 0.30848, deviation of 25.26%
# Epoch -30 calculated in 34.36 s
# Epoch 30, NRMSE Test/best: 0.38522/0.38522, Training NRMSE: 0.30844, deviation of 24.90%
# Epoch -31 calculated in 34.43 s
# Epoch 31, NRMSE Test/best: 0.37060/0.37060, Training NRMSE: 0.30762, deviation of 20.47%
# Epoch -32 calculated in 34.50 s
# Epoch 32, NRMSE Test/best: 0.38037/0.37060, Training NRMSE: 0.30761, deviation of 23.65%
# Epoch -33 calculated in 34.34 s
# Epoch 33, NRMSE Test/best: 0.38834/0.37060, Training NRMSE: 0.30643, deviation of 26.73%
# Epoch -34 calculated in 34.57 s
# Epoch 34, NRMSE Test/best: 0.37430/0.37060, Training NRMSE: 0.30606, deviation of 22.30%
# Epoch -35 calculated in 34.64 s
# Epoch 35, NRMSE Test/best: 0.38341/0.37060, Training NRMSE: 0.30530, deviation of 25.59%
# Epoch -36 calculated in 34.62 s
# Epoch 36, NRMSE Test/best: 0.37531/0.37060, Training NRMSE: 0.30500, deviation of 23.05%
# Epoch -37 calculated in 34.47 s
# Epoch 37, NRMSE Test/best: 0.38216/0.37060, Training NRMSE: 0.30455, deviation of 25.48%
# Epoch -38 calculated in 34.37 s
# Epoch 38, NRMSE Test/best: 0.37199/0.37060, Training NRMSE: 0.30783, deviation of 20.84%
# Epoch -39 calculated in 34.60 s
# Epoch 39, NRMSE Test/best: 0.37103/0.37060, Training NRMSE: 0.30416, deviation of 21.99%
# Epoch -40 calculated in 34.68 s
# Epoch 40, NRMSE Test/best: 0.36379/0.36379, Training NRMSE: 0.30318, deviation of 19.99%
# Epoch -41 calculated in 34.50 s
# Epoch 41, NRMSE Test/best: 0.36369/0.36369, Training NRMSE: 0.30236, deviation of 20.28%
# Epoch -42 calculated in 34.71 s
# Epoch 42, NRMSE Test/best: 0.37515/0.36369, Training NRMSE: 0.30293, deviation of 23.84%
# Epoch -43 calculated in 34.35 s
# Epoch 43, NRMSE Test/best: 0.37235/0.36369, Training NRMSE: 0.30210, deviation of 23.25%
# Epoch -44 calculated in 34.74 s
# Epoch 44, NRMSE Test/best: 0.37400/0.36369, Training NRMSE: 0.30177, deviation of 23.94%
# Epoch -45 calculated in 34.47 s
# Epoch 45, NRMSE Test/best: 0.38502/0.36369, Training NRMSE: 0.30117, deviation of 27.84%
# Epoch -46 calculated in 34.63 s
# Epoch 46, NRMSE Test/best: 0.38814/0.36369, Training NRMSE: 0.30293, deviation of 28.13%
# Epoch -47 calculated in 34.57 s
# Epoch 47, NRMSE Test/best: 0.37691/0.36369, Training NRMSE: 0.30046, deviation of 25.44%
# Epoch -48 calculated in 34.56 s
# Epoch 48, NRMSE Test/best: 0.37529/0.36369, Training NRMSE: 0.30006, deviation of 25.07%
# Epoch -49 calculated in 34.44 s
# Epoch 49, NRMSE Test/best: 0.36305/0.36305, Training NRMSE: 0.30081, deviation of 20.69%
# Epoch -50 calculated in 34.51 s
# Epoch 50, NRMSE Test/best: 0.35961/0.35961, Training NRMSE: 0.30017, deviation of 19.80%
# Epoch -51 calculated in 34.39 s
# Epoch 51, NRMSE Test/best: 0.36628/0.35961, Training NRMSE: 0.30036, deviation of 21.95%
# Epoch -52 calculated in 34.56 s
# Epoch 52, NRMSE Test/best: 0.37193/0.35961, Training NRMSE: 0.29917, deviation of 24.32%
# Epoch -53 calculated in 34.36 s
# Epoch 53, NRMSE Test/best: 0.37348/0.35961, Training NRMSE: 0.29952, deviation of 24.69%
# Epoch -54 calculated in 34.53 s
# Epoch 54, NRMSE Test/best: 0.36612/0.35961, Training NRMSE: 0.29914, deviation of 22.39%
# Epoch -55 calculated in 34.62 s
# Epoch 55, NRMSE Test/best: 0.37546/0.35961, Training NRMSE: 0.29843, deviation of 25.81%
# Epoch -56 calculated in 34.53 s
# Epoch 56, NRMSE Test/best: 0.36554/0.35961, Training NRMSE: 0.29890, deviation of 22.29%
# Epoch -57 calculated in 34.53 s
# Epoch 57, NRMSE Test/best: 0.36411/0.35961, Training NRMSE: 0.29798, deviation of 22.19%
# Epoch -58 calculated in 34.54 s
# Epoch 58, NRMSE Test/best: 0.36507/0.35961, Training NRMSE: 0.29847, deviation of 22.31%
# Epoch -59 calculated in 34.26 s
# Epoch 59, NRMSE Test/best: 0.36302/0.35961, Training NRMSE: 0.29803, deviation of 21.81%
# Epoch -60 calculated in 34.56 s
# Epoch 60, NRMSE Test/best: 0.36743/0.35961, Training NRMSE: 0.29781, deviation of 23.38%
# Epoch -61 calculated in 34.08 s
# Epoch 61, NRMSE Test/best: 0.36933/0.35961, Training NRMSE: 0.29740, deviation of 24.19%
# Epoch -62 calculated in 34.46 s
# Epoch 62, NRMSE Test/best: 0.36908/0.35961, Training NRMSE: 0.29731, deviation of 24.14%
# Epoch -63 calculated in 34.50 s
# Epoch 63, NRMSE Test/best: 0.36391/0.35961, Training NRMSE: 0.29639, deviation of 22.78%
# Epoch -64 calculated in 34.60 s
# Epoch 64, NRMSE Test/best: 0.37581/0.35961, Training NRMSE: 0.29546, deviation of 27.19%
# Epoch -65 calculated in 34.55 s
# Epoch 65, NRMSE Test/best: 0.36340/0.35961, Training NRMSE: 0.29622, deviation of 22.68%
# Epoch -66 calculated in 34.54 s
# Epoch 66, NRMSE Test/best: 0.36415/0.35961, Training NRMSE: 0.29527, deviation of 23.33%
# Epoch -67 calculated in 34.54 s
# Epoch 67, NRMSE Test/best: 0.36354/0.35961, Training NRMSE: 0.29609, deviation of 22.78%
# Epoch -68 calculated in 34.45 s
# Epoch 68, NRMSE Test/best: 0.37446/0.35961, Training NRMSE: 0.29611, deviation of 26.46%
# Epoch -69 calculated in 34.59 s
# Epoch 69, NRMSE Test/best: 0.36475/0.35961, Training NRMSE: 0.29554, deviation of 23.42%
# Epoch -70 calculated in 34.67 s
# Epoch 70, NRMSE Test/best: 0.35892/0.35892, Training NRMSE: 0.29452, deviation of 21.86%
# Epoch -71 calculated in 34.62 s
# Epoch 71, NRMSE Test/best: 0.36364/0.35892, Training NRMSE: 0.29355, deviation of 23.88%
# Epoch -72 calculated in 34.41 s
# Epoch 72, NRMSE Test/best: 0.36861/0.35892, Training NRMSE: 0.29440, deviation of 25.21%
# Epoch -73 calculated in 34.65 s
# Epoch 73, NRMSE Test/best: 0.36968/0.35892, Training NRMSE: 0.29311, deviation of 26.12%
# Epoch -74 calculated in 34.43 s
# Epoch 74, NRMSE Test/best: 0.36001/0.35892, Training NRMSE: 0.29443, deviation of 22.27%
# Epoch -75 calculated in 34.50 s
# Epoch 75, NRMSE Test/best: 0.36512/0.35892, Training NRMSE: 0.29317, deviation of 24.54%
# Epoch -76 calculated in 34.48 s
# Epoch 76, NRMSE Test/best: 0.35590/0.35590, Training NRMSE: 0.29493, deviation of 20.67%
# Epoch -77 calculated in 34.71 s
# Epoch 77, NRMSE Test/best: 0.35225/0.35225, Training NRMSE: 0.29328, deviation of 20.11%
# Epoch -78 calculated in 34.70 s
# Epoch 78, NRMSE Test/best: 0.36597/0.35225, Training NRMSE: 0.29221, deviation of 25.24%
# Epoch -79 calculated in 34.51 s
# Epoch 79, NRMSE Test/best: 0.36200/0.35225, Training NRMSE: 0.29238, deviation of 23.81%
# Epoch -80 calculated in 34.73 s
# Epoch 80, NRMSE Test/best: 0.35393/0.35225, Training NRMSE: 0.29351, deviation of 20.58%
# Epoch -81 calculated in 34.54 s
# Epoch 81, NRMSE Test/best: 0.35365/0.35225, Training NRMSE: 0.29248, deviation of 20.91%
# Epoch -82 calculated in 34.58 s
# Epoch 82, NRMSE Test/best: 0.35275/0.35225, Training NRMSE: 0.29250, deviation of 20.60%
# Epoch -83 calculated in 34.63 s
# Epoch 83, NRMSE Test/best: 0.36279/0.35225, Training NRMSE: 0.29347, deviation of 23.62%
# Epoch -84 calculated in 34.52 s
# Epoch 84, NRMSE Test/best: 0.35710/0.35225, Training NRMSE: 0.29133, deviation of 22.57%
# Epoch -85 calculated in 34.51 s
# Epoch 85, NRMSE Test/best: 0.35555/0.35225, Training NRMSE: 0.29127, deviation of 22.07%
# Epoch -86 calculated in 34.62 s
# Epoch 86, NRMSE Test/best: 0.35684/0.35225, Training NRMSE: 0.29073, deviation of 22.74%
# Epoch -87 calculated in 34.39 s
# Epoch 87, NRMSE Test/best: 0.35528/0.35225, Training NRMSE: 0.29011, deviation of 22.46%
# Epoch -88 calculated in 34.42 s
# Epoch 88, NRMSE Test/best: 0.35244/0.35225, Training NRMSE: 0.29115, deviation of 21.05%
# Epoch -89 calculated in 34.61 s
# Epoch 89, NRMSE Test/best: 0.35683/0.35225, Training NRMSE: 0.29054, deviation of 22.82%
# Epoch -90 calculated in 34.67 s
# Epoch 90, NRMSE Test/best: 0.35837/0.35225, Training NRMSE: 0.28994, deviation of 23.60%
# Epoch -91 calculated in 34.69 s
# Epoch 91, NRMSE Test/best: 0.35748/0.35225, Training NRMSE: 0.29047, deviation of 23.07%
# Epoch -92 calculated in 34.75 s
# Epoch 92, NRMSE Test/best: 0.35447/0.35225, Training NRMSE: 0.28958, deviation of 22.41%
# Epoch -93 calculated in 34.51 s
# Epoch 93, NRMSE Test/best: 0.35655/0.35225, Training NRMSE: 0.28982, deviation of 23.02%
# Epoch -94 calculated in 34.67 s
# Epoch 94, NRMSE Test/best: 0.35896/0.35225, Training NRMSE: 0.29003, deviation of 23.77%
# Epoch -95 calculated in 34.47 s
# Epoch 95, NRMSE Test/best: 0.34975/0.34975, Training NRMSE: 0.28905, deviation of 21.00%
# Epoch -96 calculated in 34.55 s
# Epoch 96, NRMSE Test/best: 0.35008/0.34975, Training NRMSE: 0.28935, deviation of 20.99%
# Epoch -97 calculated in 34.50 s
# Epoch 97, NRMSE Test/best: 0.35614/0.34975, Training NRMSE: 0.28888, deviation of 23.28%
# Epoch -98 calculated in 34.39 s
# Epoch 98, NRMSE Test/best: 0.35997/0.34975, Training NRMSE: 0.28880, deviation of 24.64%
# Epoch -99 calculated in 34.63 s
# Epoch 99, NRMSE Test/best: 0.36678/0.34975, Training NRMSE: 0.28998, deviation of 26.49%
# Epoch -100 calculated in 34.55 s
# Epoch 100, NRMSE Test/best: 0.36111/0.34975, Training NRMSE: 0.28892, deviation of 24.98%
# Epoch -101 calculated in 34.43 s
# Epoch 101, NRMSE Test/best: 0.36238/0.34975, Training NRMSE: 0.28902, deviation of 25.38%
# Epoch -102 calculated in 34.53 s
# Epoch 102, NRMSE Test/best: 0.35438/0.34975, Training NRMSE: 0.28794, deviation of 23.08%
# Epoch -103 calculated in 34.45 s
# Epoch 103, NRMSE Test/best: 0.35350/0.34975, Training NRMSE: 0.28906, deviation of 22.29%
# Epoch -104 calculated in 34.40 s
# Epoch 104, NRMSE Test/best: 0.36054/0.34975, Training NRMSE: 0.28772, deviation of 25.31%
# Epoch -105 calculated in 34.44 s
# Epoch 105, NRMSE Test/best: 0.35761/0.34975, Training NRMSE: 0.28757, deviation of 24.36%
# Epoch -106 calculated in 34.58 s
# Epoch 106, NRMSE Test/best: 0.35537/0.34975, Training NRMSE: 0.28731, deviation of 23.69%
# Epoch -107 calculated in 34.67 s
# Epoch 107, NRMSE Test/best: 0.34932/0.34932, Training NRMSE: 0.28825, deviation of 21.19%
# Epoch -108 calculated in 34.53 s
# Epoch 108, NRMSE Test/best: 0.35694/0.34932, Training NRMSE: 0.28727, deviation of 24.25%
# Epoch -109 calculated in 34.51 s
# Epoch 109, NRMSE Test/best: 0.35278/0.34932, Training NRMSE: 0.28736, deviation of 22.77%
# Epoch -110 calculated in 34.44 s
# Epoch 110, NRMSE Test/best: 0.35862/0.34932, Training NRMSE: 0.28694, deviation of 24.98%
# Epoch -111 calculated in 34.40 s
# Epoch 111, NRMSE Test/best: 0.35566/0.34932, Training NRMSE: 0.28674, deviation of 24.03%
# Epoch -112 calculated in 34.57 s
# Epoch 112, NRMSE Test/best: 0.35850/0.34932, Training NRMSE: 0.28634, deviation of 25.20%
# Epoch -113 calculated in 34.54 s
# Epoch 113, NRMSE Test/best: 0.35044/0.34932, Training NRMSE: 0.28738, deviation of 21.94%
# Epoch -114 calculated in 34.19 s
# Epoch 114, NRMSE Test/best: 0.35409/0.34932, Training NRMSE: 0.28636, deviation of 23.65%
# Epoch -115 calculated in 34.66 s
# Epoch 115, NRMSE Test/best: 0.35034/0.34932, Training NRMSE: 0.28618, deviation of 22.42%
# Epoch -116 calculated in 34.58 s
# Epoch 116, NRMSE Test/best: 0.35122/0.34932, Training NRMSE: 0.28536, deviation of 23.08%
# Epoch -117 calculated in 34.58 s
# Epoch 117, NRMSE Test/best: 0.35040/0.34932, Training NRMSE: 0.28638, deviation of 22.36%
# Epoch -118 calculated in 34.71 s
# Epoch 118, NRMSE Test/best: 0.34777/0.34777, Training NRMSE: 0.28655, deviation of 21.36%
# Epoch -119 calculated in 34.60 s
# Epoch 119, NRMSE Test/best: 0.35720/0.34777, Training NRMSE: 0.28580, deviation of 24.98%
# Epoch -120 calculated in 34.55 s
# Epoch 120, NRMSE Test/best: 0.34882/0.34777, Training NRMSE: 0.28521, deviation of 22.30%
# Epoch -121 calculated in 34.58 s
# Epoch 121, NRMSE Test/best: 0.34980/0.34777, Training NRMSE: 0.28564, deviation of 22.46%
# Epoch -122 calculated in 34.45 s
# Epoch 122, NRMSE Test/best: 0.35762/0.34777, Training NRMSE: 0.28511, deviation of 25.43%
# Epoch -123 calculated in 34.26 s
# Epoch 123, NRMSE Test/best: 0.35675/0.34777, Training NRMSE: 0.28460, deviation of 25.35%
# Epoch -124 calculated in 34.57 s
# Epoch 124, NRMSE Test/best: 0.34790/0.34777, Training NRMSE: 0.28517, deviation of 22.00%
# Epoch -125 calculated in 34.64 s
# Epoch 125, NRMSE Test/best: 0.34872/0.34777, Training NRMSE: 0.28532, deviation of 22.22%
# Epoch -126 calculated in 34.44 s
# Epoch 126, NRMSE Test/best: 0.35012/0.34777, Training NRMSE: 0.28410, deviation of 23.24%
# Epoch -127 calculated in 34.33 s
# Epoch 127, NRMSE Test/best: 0.34706/0.34706, Training NRMSE: 0.28410, deviation of 22.16%
# Epoch -128 calculated in 34.48 s
# Epoch 128, NRMSE Test/best: 0.35272/0.34706, Training NRMSE: 0.28352, deviation of 24.41%
# Epoch -129 calculated in 34.53 s
# Epoch 129, NRMSE Test/best: 0.35432/0.34706, Training NRMSE: 0.28347, deviation of 25.00%
# Epoch -130 calculated in 34.59 s
# Epoch 130, NRMSE Test/best: 0.35742/0.34706, Training NRMSE: 0.28338, deviation of 26.13%
# Epoch -131 calculated in 34.71 s
# Epoch 131, NRMSE Test/best: 0.35562/0.34706, Training NRMSE: 0.28346, deviation of 25.45%
# Epoch -132 calculated in 34.65 s
# Epoch 132, NRMSE Test/best: 0.35470/0.34706, Training NRMSE: 0.28389, deviation of 24.94%
# Epoch -133 calculated in 34.47 s
# Epoch 133, NRMSE Test/best: 0.34959/0.34706, Training NRMSE: 0.28386, deviation of 23.16%
# Epoch -134 calculated in 33.75 s
# Epoch 134, NRMSE Test/best: 0.35306/0.34706, Training NRMSE: 0.28327, deviation of 24.64%
# Epoch -135 calculated in 34.47 s
# Epoch 135, NRMSE Test/best: 0.35494/0.34706, Training NRMSE: 0.28332, deviation of 25.28%
# Epoch -136 calculated in 34.57 s
# Epoch 136, NRMSE Test/best: 0.35421/0.34706, Training NRMSE: 0.28295, deviation of 25.19%
# Epoch -137 calculated in 34.67 s
# Epoch 137, NRMSE Test/best: 0.35015/0.34706, Training NRMSE: 0.28272, deviation of 23.85%
# Epoch -138 calculated in 34.45 s
# Epoch 138, NRMSE Test/best: 0.34981/0.34706, Training NRMSE: 0.28271, deviation of 23.73%
# Epoch -139 calculated in 34.64 s
# Epoch 139, NRMSE Test/best: 0.35658/0.34706, Training NRMSE: 0.28248, deviation of 26.23%
# Epoch -140 calculated in 34.78 s
# Epoch 140, NRMSE Test/best: 0.35481/0.34706, Training NRMSE: 0.28346, deviation of 25.17%
# Epoch -141 calculated in 34.52 s
# Epoch 141, NRMSE Test/best: 0.35543/0.34706, Training NRMSE: 0.28321, deviation of 25.50%
# Epoch -142 calculated in 34.57 s
# Epoch 142, NRMSE Test/best: 0.35060/0.34706, Training NRMSE: 0.28313, deviation of 23.83%
# Epoch -143 calculated in 34.42 s
# Epoch 143, NRMSE Test/best: 0.36078/0.34706, Training NRMSE: 0.28294, deviation of 27.51%
# Epoch -144 calculated in 34.34 s
# Epoch 144, NRMSE Test/best: 0.35197/0.34706, Training NRMSE: 0.28404, deviation of 23.91%
# Epoch -145 calculated in 34.45 s
# Epoch 145, NRMSE Test/best: 0.35253/0.34706, Training NRMSE: 0.28229, deviation of 24.88%
# Epoch -146 calculated in 34.49 s
# Epoch 146, NRMSE Test/best: 0.35245/0.34706, Training NRMSE: 0.28206, deviation of 24.95%
# Epoch -147 calculated in 34.61 s
# Epoch 147, NRMSE Test/best: 0.34896/0.34706, Training NRMSE: 0.28208, deviation of 23.71%
# Epoch -148 calculated in 34.57 s
# Epoch 148, NRMSE Test/best: 0.34748/0.34706, Training NRMSE: 0.28252, deviation of 22.99%
# Epoch -149 calculated in 34.36 s
# Epoch 149, NRMSE Test/best: 0.35091/0.34706, Training NRMSE: 0.28172, deviation of 24.56%
# Epoch -150 calculated in 34.37 s
# Epoch 150, NRMSE Test/best: 0.34881/0.34706, Training NRMSE: 0.28164, deviation of 23.85%
# Epoch -151 calculated in 34.76 s
# Epoch 151, NRMSE Test/best: 0.34918/0.34706, Training NRMSE: 0.28156, deviation of 24.02%
# Epoch -152 calculated in 34.81 s
# Epoch 152, NRMSE Test/best: 0.35272/0.34706, Training NRMSE: 0.28126, deviation of 25.41%
# Epoch -153 calculated in 34.42 s
# Epoch 153, NRMSE Test/best: 0.34860/0.34706, Training NRMSE: 0.28158, deviation of 23.80%
# Epoch -154 calculated in 34.53 s
# Epoch 154, NRMSE Test/best: 0.35074/0.34706, Training NRMSE: 0.28110, deviation of 24.78%
# Epoch -155 calculated in 34.58 s
# Epoch 155, NRMSE Test/best: 0.34740/0.34706, Training NRMSE: 0.28133, deviation of 23.48%
# Epoch -156 calculated in 34.35 s
# Epoch 156, NRMSE Test/best: 0.34921/0.34706, Training NRMSE: 0.28041, deviation of 24.53%
# Epoch -157 calculated in 34.27 s
# Epoch 157, NRMSE Test/best: 0.35042/0.34706, Training NRMSE: 0.28028, deviation of 25.02%
# Epoch -158 calculated in 34.37 s
# Epoch 158, NRMSE Test/best: 0.34711/0.34706, Training NRMSE: 0.27993, deviation of 24.00%
# Epoch -159 calculated in 34.60 s
# Epoch 159, NRMSE Test/best: 0.35029/0.34706, Training NRMSE: 0.28006, deviation of 25.08%
# Epoch -160 calculated in 34.72 s
# Epoch 160, NRMSE Test/best: 0.34867/0.34706, Training NRMSE: 0.28094, deviation of 24.11%
# Epoch -161 calculated in 34.63 s
# Epoch 161, NRMSE Test/best: 0.35262/0.34706, Training NRMSE: 0.28030, deviation of 25.80%
# Epoch -162 calculated in 34.45 s
# Epoch 162, NRMSE Test/best: 0.35268/0.34706, Training NRMSE: 0.28049, deviation of 25.74%
# Epoch -163 calculated in 34.38 s
# Epoch 163, NRMSE Test/best: 0.34688/0.34688, Training NRMSE: 0.27966, deviation of 24.03%
# Epoch -164 calculated in 34.54 s
# Epoch 164, NRMSE Test/best: 0.34877/0.34688, Training NRMSE: 0.28117, deviation of 24.04%
# Epoch -165 calculated in 34.57 s
# Epoch 165, NRMSE Test/best: 0.34990/0.34688, Training NRMSE: 0.28337, deviation of 23.48%
# Epoch -166 calculated in 34.69 s
# Epoch 166, NRMSE Test/best: 0.34728/0.34688, Training NRMSE: 0.28247, deviation of 22.94%
# Epoch -167 calculated in 34.75 s
# Epoch 167, NRMSE Test/best: 0.34786/0.34688, Training NRMSE: 0.27953, deviation of 24.45%
# Epoch -168 calculated in 34.43 s
# Epoch 168, NRMSE Test/best: 0.35034/0.34688, Training NRMSE: 0.28050, deviation of 24.90%
# Epoch -169 calculated in 34.44 s
# Epoch 169, NRMSE Test/best: 0.34941/0.34688, Training NRMSE: 0.27987, deviation of 24.85%
# Epoch -170 calculated in 34.60 s
# Epoch 170, NRMSE Test/best: 0.34605/0.34605, Training NRMSE: 0.27939, deviation of 23.86%
# Epoch -171 calculated in 34.64 s
# Epoch 171, NRMSE Test/best: 0.34736/0.34605, Training NRMSE: 0.28052, deviation of 23.83%
# Epoch -172 calculated in 34.57 s
# Epoch 172, NRMSE Test/best: 0.34747/0.34605, Training NRMSE: 0.27952, deviation of 24.31%
# Epoch -173 calculated in 34.34 s
# Epoch 173, NRMSE Test/best: 0.35140/0.34605, Training NRMSE: 0.27952, deviation of 25.72%
# Epoch -174 calculated in 34.45 s
# Epoch 174, NRMSE Test/best: 0.34518/0.34518, Training NRMSE: 0.27874, deviation of 23.84%
# Epoch -175 calculated in 34.45 s
# Epoch 175, NRMSE Test/best: 0.35070/0.34518, Training NRMSE: 0.27822, deviation of 26.05%
# Epoch -176 calculated in 34.64 s
# Epoch 176, NRMSE Test/best: 0.35033/0.34518, Training NRMSE: 0.27936, deviation of 25.41%
# Epoch -177 calculated in 34.46 s
# Epoch 177, NRMSE Test/best: 0.35194/0.34518, Training NRMSE: 0.27995, deviation of 25.71%
# Epoch -178 calculated in 34.40 s
# Epoch 178, NRMSE Test/best: 0.34697/0.34518, Training NRMSE: 0.27908, deviation of 24.33%
# Epoch -179 calculated in 34.46 s
# Epoch 179, NRMSE Test/best: 0.35373/0.34518, Training NRMSE: 0.27851, deviation of 27.01%
# Epoch -180 calculated in 34.66 s
# Epoch 180, NRMSE Test/best: 0.34844/0.34518, Training NRMSE: 0.27983, deviation of 24.52%
# Epoch -181 calculated in 34.52 s
# Epoch 181, NRMSE Test/best: 0.35137/0.34518, Training NRMSE: 0.27928, deviation of 25.81%
# Epoch -182 calculated in 34.62 s
# Epoch 182, NRMSE Test/best: 0.34811/0.34518, Training NRMSE: 0.27906, deviation of 24.74%
# Epoch -183 calculated in 34.31 s
# Epoch 183, NRMSE Test/best: 0.34907/0.34518, Training NRMSE: 0.27889, deviation of 25.16%
# Epoch -184 calculated in 34.73 s
# Epoch 184, NRMSE Test/best: 0.35317/0.34518, Training NRMSE: 0.27884, deviation of 26.66%
# Epoch -185 calculated in 34.53 s
# Epoch 185, NRMSE Test/best: 0.35338/0.34518, Training NRMSE: 0.27766, deviation of 27.27%
# Epoch -186 calculated in 34.27 s
# Epoch 186, NRMSE Test/best: 0.34908/0.34518, Training NRMSE: 0.27777, deviation of 25.67%
# Epoch -187 calculated in 34.51 s
# Epoch 187, NRMSE Test/best: 0.35163/0.34518, Training NRMSE: 0.27798, deviation of 26.50%
# Epoch -188 calculated in 34.46 s
# Epoch 188, NRMSE Test/best: 0.35346/0.34518, Training NRMSE: 0.27845, deviation of 26.94%
# Epoch -189 calculated in 34.40 s
# Epoch 189, NRMSE Test/best: 0.35800/0.34518, Training NRMSE: 0.27840, deviation of 28.59%
# Epoch -190 calculated in 34.55 s
# Epoch 190, NRMSE Test/best: 0.35863/0.34518, Training NRMSE: 0.27954, deviation of 28.29%
# Epoch -191 calculated in 34.69 s
# Epoch 191, NRMSE Test/best: 0.35388/0.34518, Training NRMSE: 0.27896, deviation of 26.85%
# Epoch -192 calculated in 34.60 s
# Epoch 192, NRMSE Test/best: 0.35967/0.34518, Training NRMSE: 0.27864, deviation of 29.08%
# Epoch -193 calculated in 34.36 s
# Epoch 193, NRMSE Test/best: 0.35497/0.34518, Training NRMSE: 0.27820, deviation of 27.60%
# Epoch -194 calculated in 34.59 s
# Epoch 194, NRMSE Test/best: 0.35131/0.34518, Training NRMSE: 0.27792, deviation of 26.41%
# Epoch -195 calculated in 34.37 s
# Epoch 195, NRMSE Test/best: 0.35321/0.34518, Training NRMSE: 0.27842, deviation of 26.86%
# Epoch -196 calculated in 34.46 s
# Epoch 196, NRMSE Test/best: 0.35151/0.34518, Training NRMSE: 0.27725, deviation of 26.78%
# Epoch -197 calculated in 34.51 s
# Epoch 197, NRMSE Test/best: 0.35073/0.34518, Training NRMSE: 0.27748, deviation of 26.40%
# Epoch -198 calculated in 34.60 s
# Epoch 198, NRMSE Test/best: 0.35559/0.34518, Training NRMSE: 0.27732, deviation of 28.22%
# Epoch -199 calculated in 34.63 s
# Epoch 199, NRMSE Test/best: 0.35213/0.34518, Training NRMSE: 0.27688, deviation of 27.18%
# Epoch -200 calculated in 34.70 s
# Epoch 200, NRMSE Test/best: 0.35221/0.34518, Training NRMSE: 0.27727, deviation of 27.03%
# Epoch -201 calculated in 34.27 s
# Epoch 201, NRMSE Test/best: 0.35251/0.34518, Training NRMSE: 0.27709, deviation of 27.22%
# Epoch -202 calculated in 34.72 s
# Epoch 202, NRMSE Test/best: 0.35524/0.34518, Training NRMSE: 0.27656, deviation of 28.45%
# Epoch -203 calculated in 34.51 s
# Epoch 203, NRMSE Test/best: 0.35199/0.34518, Training NRMSE: 0.27764, deviation of 26.78%
# Epoch -204 calculated in 34.60 s
# Epoch 204, NRMSE Test/best: 0.35226/0.34518, Training NRMSE: 0.27686, deviation of 27.24%
# Epoch -205 calculated in 34.50 s
# Epoch 205, NRMSE Test/best: 0.36104/0.34518, Training NRMSE: 0.27788, deviation of 29.93%
# Epoch -206 calculated in 34.69 s
# Epoch 206, NRMSE Test/best: 0.35356/0.34518, Training NRMSE: 0.27739, deviation of 27.46%
# Epoch -207 calculated in 34.51 s
# Epoch 207, NRMSE Test/best: 0.35398/0.34518, Training NRMSE: 0.27742, deviation of 27.60%
# Epoch -208 calculated in 34.59 s
# Epoch 208, NRMSE Test/best: 0.35429/0.34518, Training NRMSE: 0.27609, deviation of 28.33%
# Epoch -209 calculated in 34.54 s
# Epoch 209, NRMSE Test/best: 0.35093/0.34518, Training NRMSE: 0.27651, deviation of 26.91%
# Epoch -210 calculated in 34.48 s
# Epoch 210, NRMSE Test/best: 0.34846/0.34518, Training NRMSE: 0.27722, deviation of 25.70%
# Epoch -211 calculated in 34.68 s
# Epoch 211, NRMSE Test/best: 0.35144/0.34518, Training NRMSE: 0.27661, deviation of 27.05%
# Epoch -212 calculated in 34.57 s
# Epoch 212, NRMSE Test/best: 0.35510/0.34518, Training NRMSE: 0.27722, deviation of 28.09%
# Epoch -213 calculated in 34.25 s
# Epoch 213, NRMSE Test/best: 0.35899/0.34518, Training NRMSE: 0.27774, deviation of 29.25%
# Epoch -214 calculated in 34.44 s
# Epoch 214, NRMSE Test/best: 0.36169/0.34518, Training NRMSE: 0.27580, deviation of 31.14%
# Epoch -215 calculated in 34.52 s
# Epoch 215, NRMSE Test/best: 0.35715/0.34518, Training NRMSE: 0.27636, deviation of 29.24%
# Epoch -216 calculated in 34.45 s
# Epoch 216, NRMSE Test/best: 0.35274/0.34518, Training NRMSE: 0.27690, deviation of 27.39%
# Epoch -217 calculated in 34.47 s
# Epoch 217, NRMSE Test/best: 0.35691/0.34518, Training NRMSE: 0.27721, deviation of 28.75%
# Epoch -218 calculated in 34.54 s
# Epoch 218, NRMSE Test/best: 0.35264/0.34518, Training NRMSE: 0.27699, deviation of 27.31%
# Epoch -219 calculated in 34.48 s
# Epoch 219, NRMSE Test/best: 0.35013/0.34518, Training NRMSE: 0.27677, deviation of 26.51%
# Epoch -220 calculated in 34.25 s
# Epoch 220, NRMSE Test/best: 0.35582/0.34518, Training NRMSE: 0.27578, deviation of 29.02%
# Epoch -221 calculated in 34.50 s
# Epoch 221, NRMSE Test/best: 0.35357/0.34518, Training NRMSE: 0.27543, deviation of 28.37%
# Epoch -222 calculated in 34.31 s
# Epoch 222, NRMSE Test/best: 0.35292/0.34518, Training NRMSE: 0.27717, deviation of 27.33%
# Epoch -223 calculated in 34.41 s
# Epoch 223, NRMSE Test/best: 0.35623/0.34518, Training NRMSE: 0.27564, deviation of 29.24%
# Epoch -224 calculated in 34.57 s
# Epoch 224, NRMSE Test/best: 0.35764/0.34518, Training NRMSE: 0.27647, deviation of 29.36%
# Epoch -225 calculated in 34.49 s
# Epoch 225, NRMSE Test/best: 0.35630/0.34518, Training NRMSE: 0.27574, deviation of 29.22%
# Epoch -226 calculated in 34.60 s
# Epoch 226, NRMSE Test/best: 0.35390/0.34518, Training NRMSE: 0.27543, deviation of 28.49%
# Epoch -227 calculated in 34.47 s
# Epoch 227, NRMSE Test/best: 0.35237/0.34518, Training NRMSE: 0.27597, deviation of 27.68%
# Epoch -228 calculated in 34.53 s
# Epoch 228, NRMSE Test/best: 0.35448/0.34518, Training NRMSE: 0.27615, deviation of 28.36%
# Epoch -229 calculated in 34.38 s
# Epoch 229, NRMSE Test/best: 0.35458/0.34518, Training NRMSE: 0.27558, deviation of 28.67%
# Epoch -230 calculated in 34.54 s
# Epoch 230, NRMSE Test/best: 0.35296/0.34518, Training NRMSE: 0.27528, deviation of 28.22%
# Epoch -231 calculated in 34.64 s
# Epoch 231, NRMSE Test/best: 0.35520/0.34518, Training NRMSE: 0.27523, deviation of 29.06%
# Epoch -232 calculated in 34.59 s
# Epoch 232, NRMSE Test/best: 0.35825/0.34518, Training NRMSE: 0.27490, deviation of 30.32%
# Epoch -233 calculated in 34.35 s
# Epoch 233, NRMSE Test/best: 0.35688/0.34518, Training NRMSE: 0.27521, deviation of 29.68%
# Epoch -234 calculated in 34.44 s
# Epoch 234, NRMSE Test/best: 0.35469/0.34518, Training NRMSE: 0.27536, deviation of 28.81%
# Epoch -235 calculated in 34.54 s
# Epoch 235, NRMSE Test/best: 0.35507/0.34518, Training NRMSE: 0.27489, deviation of 29.17%
# Epoch -236 calculated in 34.56 s
# Epoch 236, NRMSE Test/best: 0.35708/0.34518, Training NRMSE: 0.27500, deviation of 29.85%
# Epoch -237 calculated in 34.65 s
# Epoch 237, NRMSE Test/best: 0.35581/0.34518, Training NRMSE: 0.27499, deviation of 29.39%
# Epoch -238 calculated in 34.49 s
# Epoch 238, NRMSE Test/best: 0.35500/0.34518, Training NRMSE: 0.27481, deviation of 29.18%
# Epoch -239 calculated in 34.67 s
# Epoch 239, NRMSE Test/best: 0.35958/0.34518, Training NRMSE: 0.27487, deviation of 30.82%
# Epoch -240 calculated in 34.54 s
# Epoch 240, NRMSE Test/best: 0.35220/0.34518, Training NRMSE: 0.27512, deviation of 28.02%
# Epoch -241 calculated in 34.64 s
# Epoch 241, NRMSE Test/best: 0.35591/0.34518, Training NRMSE: 0.27467, deviation of 29.58%
# Epoch -242 calculated in 34.59 s
# Epoch 242, NRMSE Test/best: 0.35477/0.34518, Training NRMSE: 0.27386, deviation of 29.54%
# Epoch -243 calculated in 34.53 s
# Epoch 243, NRMSE Test/best: 0.35941/0.34518, Training NRMSE: 0.27557, deviation of 30.42%
# Epoch -244 calculated in 34.53 s
# Epoch 244, NRMSE Test/best: 0.35728/0.34518, Training NRMSE: 0.27466, deviation of 30.08%
# Epoch -245 calculated in 34.27 s
# Epoch 245, NRMSE Test/best: 0.35539/0.34518, Training NRMSE: 0.27476, deviation of 29.34%
# Epoch -246 calculated in 34.50 s
# Epoch 246, NRMSE Test/best: 0.35372/0.34518, Training NRMSE: 0.27450, deviation of 28.86%
# Epoch -247 calculated in 34.40 s
# Epoch 247, NRMSE Test/best: 0.35483/0.34518, Training NRMSE: 0.27421, deviation of 29.40%
# Epoch -248 calculated in 34.49 s
# Epoch 248, NRMSE Test/best: 0.35454/0.34518, Training NRMSE: 0.27434, deviation of 29.23%
# Epoch -249 calculated in 34.43 s
# Epoch 249, NRMSE Test/best: 0.35836/0.34518, Training NRMSE: 0.27369, deviation of 30.94%
# Epoch -250 calculated in 34.46 s
# Epoch 250, NRMSE Test/best: 0.35522/0.34518, Training NRMSE: 0.27396, deviation of 29.66%
# Epoch -251 calculated in 34.45 s
# Epoch 251, NRMSE Test/best: 0.35845/0.34518, Training NRMSE: 0.27416, deviation of 30.74%
# Epoch -252 calculated in 34.49 s
# Epoch 252, NRMSE Test/best: 0.35650/0.34518, Training NRMSE: 0.27427, deviation of 29.98%
# Epoch -253 calculated in 34.54 s
# Epoch 253, NRMSE Test/best: 0.36213/0.34518, Training NRMSE: 0.27486, deviation of 31.75%
# Epoch -254 calculated in 34.46 s
# Epoch 254, NRMSE Test/best: 0.35729/0.34518, Training NRMSE: 0.27464, deviation of 30.09%
# Epoch -255 calculated in 34.43 s
# Epoch 255, NRMSE Test/best: 0.35524/0.34518, Training NRMSE: 0.27375, deviation of 29.77%
# Epoch -256 calculated in 34.48 s
# Epoch 256, NRMSE Test/best: 0.35818/0.34518, Training NRMSE: 0.27468, deviation of 30.40%
# Epoch -257 calculated in 34.33 s
# Epoch 257, NRMSE Test/best: 0.35571/0.34518, Training NRMSE: 0.27494, deviation of 29.38%
# Epoch -258 calculated in 34.26 s
# Epoch 258, NRMSE Test/best: 0.35670/0.34518, Training NRMSE: 0.27394, deviation of 30.21%
# Epoch -259 calculated in 34.52 s
# Epoch 259, NRMSE Test/best: 0.35484/0.34518, Training NRMSE: 0.27432, deviation of 29.35%
# Epoch -260 calculated in 34.42 s
# Epoch 260, NRMSE Test/best: 0.35135/0.34518, Training NRMSE: 0.27423, deviation of 28.12%
# Epoch -261 calculated in 34.58 s
# Epoch 261, NRMSE Test/best: 0.35267/0.34518, Training NRMSE: 0.27450, deviation of 28.48%
# Epoch -262 calculated in 34.39 s
# Epoch 262, NRMSE Test/best: 0.35244/0.34518, Training NRMSE: 0.27487, deviation of 28.22%
# Epoch -263 calculated in 34.74 s
# Epoch 263, NRMSE Test/best: 0.35976/0.34518, Training NRMSE: 0.27458, deviation of 31.02%
# Epoch -264 calculated in 34.29 s
# Epoch 264, NRMSE Test/best: 0.35367/0.34518, Training NRMSE: 0.27492, deviation of 28.65%
# Epoch -265 calculated in 34.54 s
# Epoch 265, NRMSE Test/best: 0.35100/0.34518, Training NRMSE: 0.27369, deviation of 28.25%
# Epoch -266 calculated in 34.48 s
# Epoch 266, NRMSE Test/best: 0.35225/0.34518, Training NRMSE: 0.27374, deviation of 28.68%
# Epoch -267 calculated in 34.41 s
# Epoch 267, NRMSE Test/best: 0.35220/0.34518, Training NRMSE: 0.27402, deviation of 28.53%
# Epoch -268 calculated in 34.43 s
# Epoch 268, NRMSE Test/best: 0.34910/0.34518, Training NRMSE: 0.27349, deviation of 27.65%
# Epoch -269 calculated in 34.52 s
# Epoch 269, NRMSE Test/best: 0.35824/0.34518, Training NRMSE: 0.27376, deviation of 30.86%
# Epoch -270 calculated in 34.46 s
# Epoch 270, NRMSE Test/best: 0.35899/0.34518, Training NRMSE: 0.27439, deviation of 30.83%
# Epoch -271 calculated in 34.53 s
# Epoch 271, NRMSE Test/best: 0.35627/0.34518, Training NRMSE: 0.27318, deviation of 30.42%
# Epoch -272 calculated in 34.49 s
# Epoch 272, NRMSE Test/best: 0.35369/0.34518, Training NRMSE: 0.27276, deviation of 29.67%
# Epoch -273 calculated in 34.43 s
# Epoch 273, NRMSE Test/best: 0.35356/0.34518, Training NRMSE: 0.27303, deviation of 29.50%
# Epoch -274 calculated in 34.45 s
# Epoch 274, NRMSE Test/best: 0.35481/0.34518, Training NRMSE: 0.27331, deviation of 29.82%
# Epoch -275 calculated in 34.53 s
# Epoch 275, NRMSE Test/best: 0.35680/0.34518, Training NRMSE: 0.27367, deviation of 30.38%
# Epoch -276 calculated in 34.53 s
# Epoch 276, NRMSE Test/best: 0.35740/0.34518, Training NRMSE: 0.27264, deviation of 31.09%
# Epoch -277 calculated in 34.61 s
# Epoch 277, NRMSE Test/best: 0.35692/0.34518, Training NRMSE: 0.27277, deviation of 30.85%
# Epoch -278 calculated in 34.45 s
# Epoch 278, NRMSE Test/best: 0.35872/0.34518, Training NRMSE: 0.27377, deviation of 31.03%
# Epoch -279 calculated in 34.53 s
# Epoch 279, NRMSE Test/best: 0.36213/0.34518, Training NRMSE: 0.27322, deviation of 32.54%
# Epoch -280 calculated in 34.57 s
# Epoch 280, NRMSE Test/best: 0.35541/0.34518, Training NRMSE: 0.27352, deviation of 29.94%
# Epoch -281 calculated in 34.54 s
# Epoch 281, NRMSE Test/best: 0.35982/0.34518, Training NRMSE: 0.27224, deviation of 32.17%
# Epoch -282 calculated in 34.63 s
# Epoch 282, NRMSE Test/best: 0.35759/0.34518, Training NRMSE: 0.27285, deviation of 31.06%
# Epoch -283 calculated in 34.75 s
# Epoch 283, NRMSE Test/best: 0.35798/0.34518, Training NRMSE: 0.27362, deviation of 30.83%
# Epoch -284 calculated in 34.38 s
# Epoch 284, NRMSE Test/best: 0.36051/0.34518, Training NRMSE: 0.27381, deviation of 31.66%
# Epoch -285 calculated in 34.52 s
# Epoch 285, NRMSE Test/best: 0.35800/0.34518, Training NRMSE: 0.27264, deviation of 31.31%
# Epoch -286 calculated in 34.54 s
# Epoch 286, NRMSE Test/best: 0.36089/0.34518, Training NRMSE: 0.27265, deviation of 32.37%
# Epoch -287 calculated in 34.32 s
# Epoch 287, NRMSE Test/best: 0.35886/0.34518, Training NRMSE: 0.27357, deviation of 31.18%
# Epoch -288 calculated in 34.51 s
# Epoch 288, NRMSE Test/best: 0.35508/0.34518, Training NRMSE: 0.27246, deviation of 30.32%
# Epoch -289 calculated in 34.59 s
# Epoch 289, NRMSE Test/best: 0.36038/0.34518, Training NRMSE: 0.27214, deviation of 32.42%
# Epoch -290 calculated in 34.53 s
# Epoch 290, NRMSE Test/best: 0.36570/0.34518, Training NRMSE: 0.27200, deviation of 34.45%
# Epoch -291 calculated in 34.39 s
# Epoch 291, NRMSE Test/best: 0.35980/0.34518, Training NRMSE: 0.27257, deviation of 32.00%
# Epoch -292 calculated in 34.50 s
# Epoch 292, NRMSE Test/best: 0.35283/0.34518, Training NRMSE: 0.27233, deviation of 29.56%
# Epoch -293 calculated in 34.45 s
# Epoch 293, NRMSE Test/best: 0.36072/0.34518, Training NRMSE: 0.27246, deviation of 32.39%
# Epoch -294 calculated in 34.24 s
# Epoch 294, NRMSE Test/best: 0.36079/0.34518, Training NRMSE: 0.27212, deviation of 32.59%
# Epoch -295 calculated in 34.82 s
# Epoch 295, NRMSE Test/best: 0.35858/0.34518, Training NRMSE: 0.27213, deviation of 31.77%
# Epoch -296 calculated in 34.55 s
# Epoch 296, NRMSE Test/best: 0.36239/0.34518, Training NRMSE: 0.27226, deviation of 33.11%
# Epoch -297 calculated in 34.63 s
# Epoch 297, NRMSE Test/best: 0.35870/0.34518, Training NRMSE: 0.27214, deviation of 31.81%
# Epoch -298 calculated in 34.66 s
# Epoch 298, NRMSE Test/best: 0.35994/0.34518, Training NRMSE: 0.27246, deviation of 32.11%
# Epoch -299 calculated in 34.55 s
# Epoch 299, NRMSE Test/best: 0.36598/0.34518, Training NRMSE: 0.27225, deviation of 34.43%
# Epoch -300 calculated in 34.45 s
# Epoch 300, NRMSE Test/best: 0.36723/0.34518, Training NRMSE: 0.27220, deviation of 34.91%
# Epoch -301 calculated in 34.52 s
# Epoch 301, NRMSE Test/best: 0.36228/0.34518, Training NRMSE: 0.27186, deviation of 33.26%
# Epoch -302 calculated in 34.59 s
# Epoch 302, NRMSE Test/best: 0.36607/0.34518, Training NRMSE: 0.27158, deviation of 34.80%
# Epoch -303 calculated in 34.53 s
# Epoch 303, NRMSE Test/best: 0.36417/0.34518, Training NRMSE: 0.27148, deviation of 34.15%
# Epoch -304 calculated in 34.59 s
# Epoch 304, NRMSE Test/best: 0.35973/0.34518, Training NRMSE: 0.27135, deviation of 32.57%
# Epoch -305 calculated in 34.49 s
# Epoch 305, NRMSE Test/best: 0.35766/0.34518, Training NRMSE: 0.27301, deviation of 31.01%
# Epoch -306 calculated in 34.56 s
# Epoch 306, NRMSE Test/best: 0.36735/0.34518, Training NRMSE: 0.27147, deviation of 35.32%
# Epoch -307 calculated in 34.56 s
# Epoch 307, NRMSE Test/best: 0.36154/0.34518, Training NRMSE: 0.27225, deviation of 32.79%
# Epoch -308 calculated in 34.36 s
# Epoch 308, NRMSE Test/best: 0.35913/0.34518, Training NRMSE: 0.27250, deviation of 31.79%
# Epoch -309 calculated in 34.30 s
# Epoch 309, NRMSE Test/best: 0.36247/0.34518, Training NRMSE: 0.27202, deviation of 33.25%
# Epoch -310 calculated in 34.31 s
# Epoch 310, NRMSE Test/best: 0.36008/0.34518, Training NRMSE: 0.27126, deviation of 32.74%
# Epoch -311 calculated in 34.71 s
# Epoch 311, NRMSE Test/best: 0.36323/0.34518, Training NRMSE: 0.27187, deviation of 33.60%
# Epoch -312 calculated in 34.35 s
# Epoch 312, NRMSE Test/best: 0.36497/0.34518, Training NRMSE: 0.27167, deviation of 34.34%
# Epoch -313 calculated in 34.57 s
# Epoch 313, NRMSE Test/best: 0.35923/0.34518, Training NRMSE: 0.27117, deviation of 32.48%
# Epoch -314 calculated in 34.47 s
# Epoch 314, NRMSE Test/best: 0.36933/0.34518, Training NRMSE: 0.27174, deviation of 35.92%
# Epoch -315 calculated in 34.49 s
# Epoch 315, NRMSE Test/best: 0.36113/0.34518, Training NRMSE: 0.27163, deviation of 32.95%
# Epoch -316 calculated in 34.27 s
# Epoch 316, NRMSE Test/best: 0.36802/0.34518, Training NRMSE: 0.27130, deviation of 35.65%
# Epoch -317 calculated in 34.61 s
# Epoch 317, NRMSE Test/best: 0.35873/0.34518, Training NRMSE: 0.27140, deviation of 32.18%
# Epoch -318 calculated in 34.30 s
# Epoch 318, NRMSE Test/best: 0.36433/0.34518, Training NRMSE: 0.27169, deviation of 34.09%
# Epoch -319 calculated in 34.63 s
# Epoch 319, NRMSE Test/best: 0.35820/0.34518, Training NRMSE: 0.27105, deviation of 32.15%
# Epoch -320 calculated in 34.60 s
# Epoch 320, NRMSE Test/best: 0.36643/0.34518, Training NRMSE: 0.27098, deviation of 35.23%
# Epoch -321 calculated in 34.46 s
# Epoch 321, NRMSE Test/best: 0.36404/0.34518, Training NRMSE: 0.27094, deviation of 34.36%
# Epoch -322 calculated in 34.71 s
# Epoch 322, NRMSE Test/best: 0.36254/0.34518, Training NRMSE: 0.27040, deviation of 34.08%
# Epoch -323 calculated in 34.60 s
# Epoch 323, NRMSE Test/best: 0.35460/0.34518, Training NRMSE: 0.27177, deviation of 30.48%
# Epoch -324 calculated in 34.42 s
# Epoch 324, NRMSE Test/best: 0.35092/0.34518, Training NRMSE: 0.27186, deviation of 29.08%
# Epoch -325 calculated in 34.68 s
# Epoch 325, NRMSE Test/best: 0.35643/0.34518, Training NRMSE: 0.27077, deviation of 31.63%
# Epoch -326 calculated in 34.45 s
# Epoch 326, NRMSE Test/best: 0.35749/0.34518, Training NRMSE: 0.27207, deviation of 31.40%
# Epoch -327 calculated in 34.59 s
# Epoch 327, NRMSE Test/best: 0.35237/0.34518, Training NRMSE: 0.27073, deviation of 30.15%
# Epoch -328 calculated in 34.35 s
# Epoch 328, NRMSE Test/best: 0.35759/0.34518, Training NRMSE: 0.27062, deviation of 32.14%
# Epoch -329 calculated in 34.44 s
# Epoch 329, NRMSE Test/best: 0.35517/0.34518, Training NRMSE: 0.27051, deviation of 31.30%
# Epoch -330 calculated in 34.37 s
# Epoch 330, NRMSE Test/best: 0.35883/0.34518, Training NRMSE: 0.27125, deviation of 32.29%
# Epoch -331 calculated in 34.47 s
# Epoch 331, NRMSE Test/best: 0.35463/0.34518, Training NRMSE: 0.27285, deviation of 29.98%
# Epoch -332 calculated in 34.64 s
# Epoch 332, NRMSE Test/best: 0.35994/0.34518, Training NRMSE: 0.27072, deviation of 32.96%
# Epoch -333 calculated in 34.52 s
# Epoch 333, NRMSE Test/best: 0.35210/0.34518, Training NRMSE: 0.27128, deviation of 29.79%
# Epoch -334 calculated in 34.61 s
# Epoch 334, NRMSE Test/best: 0.35445/0.34518, Training NRMSE: 0.27151, deviation of 30.55%
# Epoch -335 calculated in 34.26 s
# Epoch 335, NRMSE Test/best: 0.35553/0.34518, Training NRMSE: 0.27095, deviation of 31.22%
# Epoch -336 calculated in 34.55 s
# Epoch 336, NRMSE Test/best: 0.35101/0.34518, Training NRMSE: 0.27132, deviation of 29.37%
# Epoch -337 calculated in 34.69 s
# Epoch 337, NRMSE Test/best: 0.34962/0.34518, Training NRMSE: 0.27102, deviation of 29.00%
# Epoch -338 calculated in 34.45 s
# Epoch 338, NRMSE Test/best: 0.36010/0.34518, Training NRMSE: 0.27083, deviation of 32.96%
# Epoch -339 calculated in 34.71 s
# Epoch 339, NRMSE Test/best: 0.35108/0.34518, Training NRMSE: 0.27124, deviation of 29.43%
# Epoch -340 calculated in 34.53 s
# Epoch 340, NRMSE Test/best: 0.35646/0.34518, Training NRMSE: 0.27119, deviation of 31.44%
# Epoch -341 calculated in 34.42 s
# Epoch 341, NRMSE Test/best: 0.36098/0.34518, Training NRMSE: 0.27007, deviation of 33.66%
# Epoch -342 calculated in 34.56 s
# Epoch 342, NRMSE Test/best: 0.35841/0.34518, Training NRMSE: 0.27041, deviation of 32.55%
# Epoch -343 calculated in 34.55 s
# Epoch 343, NRMSE Test/best: 0.35230/0.34518, Training NRMSE: 0.26996, deviation of 30.50%
# Epoch -344 calculated in 34.74 s
# Epoch 344, NRMSE Test/best: 0.35952/0.34518, Training NRMSE: 0.27071, deviation of 32.81%
# Epoch -345 calculated in 34.43 s
# Epoch 345, NRMSE Test/best: 0.35430/0.34518, Training NRMSE: 0.26974, deviation of 31.35%
# Epoch -346 calculated in 34.76 s
# Epoch 346, NRMSE Test/best: 0.34917/0.34518, Training NRMSE: 0.27023, deviation of 29.21%
# Epoch -347 calculated in 34.53 s
# Epoch 347, NRMSE Test/best: 0.35076/0.34518, Training NRMSE: 0.27085, deviation of 29.50%
# Epoch -348 calculated in 34.39 s
# Epoch 348, NRMSE Test/best: 0.35676/0.34518, Training NRMSE: 0.27002, deviation of 32.12%
# Epoch -349 calculated in 34.62 s
# Epoch 349, NRMSE Test/best: 0.35363/0.34518, Training NRMSE: 0.26954, deviation of 31.20%
# Epoch -350 calculated in 34.79 s
# Epoch 350, NRMSE Test/best: 0.35169/0.34518, Training NRMSE: 0.27107, deviation of 29.74%
# Epoch -351 calculated in 34.50 s
# Epoch 351, NRMSE Test/best: 0.35142/0.34518, Training NRMSE: 0.26894, deviation of 30.67%
# Epoch -352 calculated in 34.46 s
# Epoch 352, NRMSE Test/best: 0.34925/0.34518, Training NRMSE: 0.26936, deviation of 29.66%
# Epoch -353 calculated in 34.62 s
# Epoch 353, NRMSE Test/best: 0.35149/0.34518, Training NRMSE: 0.26962, deviation of 30.37%
# Epoch -354 calculated in 34.77 s
# Epoch 354, NRMSE Test/best: 0.35012/0.34518, Training NRMSE: 0.27065, deviation of 29.36%
# Epoch -355 calculated in 34.47 s
# Epoch 355, NRMSE Test/best: 0.35685/0.34518, Training NRMSE: 0.27045, deviation of 31.95%
# Epoch -356 calculated in 34.69 s
# Epoch 356, NRMSE Test/best: 0.35035/0.34518, Training NRMSE: 0.26995, deviation of 29.78%
# Epoch -357 calculated in 34.53 s
# Epoch 357, NRMSE Test/best: 0.35820/0.34518, Training NRMSE: 0.26974, deviation of 32.79%
# Epoch -358 calculated in 34.56 s
# Epoch 358, NRMSE Test/best: 0.35294/0.34518, Training NRMSE: 0.27026, deviation of 30.59%
# Epoch -359 calculated in 34.47 s
# Epoch 359, NRMSE Test/best: 0.36039/0.34518, Training NRMSE: 0.26989, deviation of 33.53%
# Epoch -360 calculated in 34.75 s
# Epoch 360, NRMSE Test/best: 0.35902/0.34518, Training NRMSE: 0.27101, deviation of 32.47%
# Epoch -361 calculated in 34.45 s
# Epoch 361, NRMSE Test/best: 0.34948/0.34518, Training NRMSE: 0.26953, deviation of 29.66%
# Epoch -362 calculated in 34.38 s
# Epoch 362, NRMSE Test/best: 0.34982/0.34518, Training NRMSE: 0.26919, deviation of 29.95%
# Epoch -363 calculated in 34.52 s
# Epoch 363, NRMSE Test/best: 0.34865/0.34518, Training NRMSE: 0.27075, deviation of 28.77%
# Epoch -364 calculated in 34.77 s
# Epoch 364, NRMSE Test/best: 0.35520/0.34518, Training NRMSE: 0.26926, deviation of 31.92%
# Epoch -365 calculated in 34.66 s
# Epoch 365, NRMSE Test/best: 0.35178/0.34518, Training NRMSE: 0.26923, deviation of 30.66%
# Epoch -366 calculated in 34.44 s
# Epoch 366, NRMSE Test/best: 0.35572/0.34518, Training NRMSE: 0.27045, deviation of 31.53%
# Epoch -367 calculated in 34.65 s
# Epoch 367, NRMSE Test/best: 0.35098/0.34518, Training NRMSE: 0.26963, deviation of 30.17%
# Epoch -368 calculated in 34.41 s
# Epoch 368, NRMSE Test/best: 0.35677/0.34518, Training NRMSE: 0.26968, deviation of 32.30%
# Epoch -369 calculated in 34.44 s
# Epoch 369, NRMSE Test/best: 0.35200/0.34518, Training NRMSE: 0.26961, deviation of 30.56%
# Epoch -370 calculated in 34.49 s
# Epoch 370, NRMSE Test/best: 0.35088/0.34518, Training NRMSE: 0.26901, deviation of 30.43%
# Epoch -371 calculated in 34.30 s
# Epoch 371, NRMSE Test/best: 0.35403/0.34518, Training NRMSE: 0.26893, deviation of 31.64%
# Epoch -372 calculated in 34.56 s
# Epoch 372, NRMSE Test/best: 0.35391/0.34518, Training NRMSE: 0.26902, deviation of 31.55%
# Epoch -373 calculated in 34.47 s
# Epoch 373, NRMSE Test/best: 0.35480/0.34518, Training NRMSE: 0.26944, deviation of 31.68%
# Epoch -374 calculated in 34.63 s
# Epoch 374, NRMSE Test/best: 0.35274/0.34518, Training NRMSE: 0.26966, deviation of 30.81%
# Epoch -375 calculated in 34.49 s
# Epoch 375, NRMSE Test/best: 0.35700/0.34518, Training NRMSE: 0.27022, deviation of 32.11%
# Epoch -376 calculated in 34.59 s
# ...
# Epoch 1276, NRMSE Test/best: 0.35664/0.34518, Training NRMSE: 0.25909, deviation of 37.65%
# Epoch -1277 calculated in 34.70 s
# Epoch 1277, NRMSE Test/best: 0.35365/0.34518, Training NRMSE: 0.25736, deviation of 37.41%
# Epoch -1278 calculated in 34.43 s
# Epoch 1278, NRMSE Test/best: 0.35657/0.34518, Training NRMSE: 0.25852, deviation of 37.92%
# Epoch -1279 calculated in 34.61 s
# Epoch 1279, NRMSE Test/best: 0.35483/0.34518, Training NRMSE: 0.25857, deviation of 37.23%
# Epoch -1280 calculated in 34.70 s
# Epoch 1280, NRMSE Test/best: 0.35899/0.34518, Training NRMSE: 0.25727, deviation of 39.54%
# Epoch -1281 calculated in 34.50 s
# Epoch 1281, NRMSE Test/best: 0.35654/0.34518, Training NRMSE: 0.25693, deviation of 38.77%
# Epoch -1282 calculated in 34.43 s
# Epoch 1282, NRMSE Test/best: 0.35675/0.34518, Training NRMSE: 0.25820, deviation of 38.17%
# Epoch -1283 calculated in 34.51 s
# Epoch 1283, NRMSE Test/best: 0.35957/0.34518, Training NRMSE: 0.25637, deviation of 40.26%
# Epoch -1284 calculated in 34.64 s
# Epoch 1284, NRMSE Test/best: 0.35580/0.34518, Training NRMSE: 0.25713, deviation of 38.38%
# Epoch -1285 calculated in 34.57 s
# Epoch 1285, NRMSE Test/best: 0.35643/0.34518, Training NRMSE: 0.25671, deviation of 38.85%
# Epoch -1286 calculated in 34.60 s
# Epoch 1286, NRMSE Test/best: 0.35931/0.34518, Training NRMSE: 0.25751, deviation of 39.54%
# Epoch -1287 calculated in 34.51 s
# Epoch 1287, NRMSE Test/best: 0.35840/0.34518, Training NRMSE: 0.25668, deviation of 39.63%
# Epoch -1288 calculated in 34.51 s
# Epoch 1288, NRMSE Test/best: 0.35921/0.34518, Training NRMSE: 0.25646, deviation of 40.06%
# Epoch -1289 calculated in 34.56 s
# Epoch 1289, NRMSE Test/best: 0.36219/0.34518, Training NRMSE: 0.25629, deviation of 41.32%
# Epoch -1290 calculated in 34.30 s
# Epoch 1290, NRMSE Test/best: 0.35484/0.34518, Training NRMSE: 0.25743, deviation of 37.84%
# Epoch -1291 calculated in 34.47 s
# Epoch 1291, NRMSE Test/best: 0.36014/0.34518, Training NRMSE: 0.25793, deviation of 39.63%
# Epoch -1292 calculated in 34.47 s
# Epoch 1292, NRMSE Test/best: 0.35894/0.34518, Training NRMSE: 0.25654, deviation of 39.91%
# Epoch -1293 calculated in 34.64 s
# Epoch 1293, NRMSE Test/best: 0.35775/0.34518, Training NRMSE: 0.25780, deviation of 38.77%
# Epoch -1294 calculated in 34.38 s
# Epoch 1294, NRMSE Test/best: 0.35876/0.34518, Training NRMSE: 0.25732, deviation of 39.42%
# Epoch -1295 calculated in 34.42 s
# Epoch 1295, NRMSE Test/best: 0.36044/0.34518, Training NRMSE: 0.25781, deviation of 39.81%
# Epoch -1296 calculated in 34.68 s
# Epoch 1296, NRMSE Test/best: 0.36203/0.34518, Training NRMSE: 0.25931, deviation of 39.62%
# Epoch -1297 calculated in 34.45 s
# Epoch 1297, NRMSE Test/best: 0.35981/0.34518, Training NRMSE: 0.25665, deviation of 40.19%
# Epoch -1298 calculated in 34.51 s
# Epoch 1298, NRMSE Test/best: 0.35871/0.34518, Training NRMSE: 0.25658, deviation of 39.80%
# Epoch -1299 calculated in 34.42 s
# Epoch 1299, NRMSE Test/best: 0.35581/0.34518, Training NRMSE: 0.25821, deviation of 37.80%
# Epoch -1300 calculated in 34.61 s
# Epoch 1300, NRMSE Test/best: 0.35708/0.34518, Training NRMSE: 0.25688, deviation of 39.00%
# Epoch -1301 calculated in 34.60 s
# Epoch 1301, NRMSE Test/best: 0.35614/0.34518, Training NRMSE: 0.25769, deviation of 38.20%
# Epoch -1302 calculated in 34.60 s
# Epoch 1302, NRMSE Test/best: 0.35381/0.34518, Training NRMSE: 0.26416, deviation of 33.93%
# Epoch -1303 calculated in 34.48 s
# Epoch 1303, NRMSE Test/best: 0.35833/0.34518, Training NRMSE: 0.25850, deviation of 38.62%
# Epoch -1304 calculated in 34.62 s
# Epoch 1304, NRMSE Test/best: 0.35776/0.34518, Training NRMSE: 0.25752, deviation of 38.92%
# Epoch -1305 calculated in 34.55 s
# Epoch 1305, NRMSE Test/best: 0.35763/0.34518, Training NRMSE: 0.25822, deviation of 38.50%
# Epoch -1306 calculated in 34.57 s
# Epoch 1306, NRMSE Test/best: 0.35965/0.34518, Training NRMSE: 0.25691, deviation of 39.99%
# Epoch -1307 calculated in 34.53 s
# Epoch 1307, NRMSE Test/best: 0.35949/0.34518, Training NRMSE: 0.25599, deviation of 40.43%
# Epoch -1308 calculated in 34.60 s
# Epoch 1308, NRMSE Test/best: 0.35666/0.34518, Training NRMSE: 0.26015, deviation of 37.10%
# Epoch -1309 calculated in 34.66 s
# Epoch 1309, NRMSE Test/best: 0.35714/0.34518, Training NRMSE: 0.25894, deviation of 37.92%
# Epoch -1310 calculated in 34.62 s
# Epoch 1310, NRMSE Test/best: 0.35531/0.34518, Training NRMSE: 0.25721, deviation of 38.14%
# Epoch -1311 calculated in 34.59 s
# Epoch 1311, NRMSE Test/best: 0.36080/0.34518, Training NRMSE: 0.25718, deviation of 40.29%
# Epoch -1312 calculated in 34.58 s
# Epoch 1312, NRMSE Test/best: 0.35865/0.34518, Training NRMSE: 0.25770, deviation of 39.17%
# Epoch -1313 calculated in 34.46 s
# Epoch 1313, NRMSE Test/best: 0.35994/0.34518, Training NRMSE: 0.25681, deviation of 40.16%
# Epoch -1314 calculated in 34.22 s
# Epoch 1314, NRMSE Test/best: 0.35778/0.34518, Training NRMSE: 0.25675, deviation of 39.35%
# Epoch -1315 calculated in 34.42 s
# Epoch 1315, NRMSE Test/best: 0.36235/0.34518, Training NRMSE: 0.25655, deviation of 41.24%
# Epoch -1316 calculated in 34.72 s
# Epoch 1316, NRMSE Test/best: 0.36125/0.34518, Training NRMSE: 0.25703, deviation of 40.55%
# Epoch -1317 calculated in 34.44 s
# Epoch 1317, NRMSE Test/best: 0.36154/0.34518, Training NRMSE: 0.25722, deviation of 40.55%
# Epoch -1318 calculated in 34.42 s
# Epoch 1318, NRMSE Test/best: 0.35891/0.34518, Training NRMSE: 0.25656, deviation of 39.89%
# Epoch -1319 calculated in 34.48 s
# Epoch 1319, NRMSE Test/best: 0.36242/0.34518, Training NRMSE: 0.25809, deviation of 40.42%
# Epoch -1320 calculated in 34.56 s
# Epoch 1320, NRMSE Test/best: 0.35902/0.34518, Training NRMSE: 0.25855, deviation of 38.86%
# Epoch -1321 calculated in 34.45 s
# Epoch 1321, NRMSE Test/best: 0.35700/0.34518, Training NRMSE: 0.25725, deviation of 38.78%
# Epoch -1322 calculated in 34.49 s
# Epoch 1322, NRMSE Test/best: 0.36390/0.34518, Training NRMSE: 0.25619, deviation of 42.04%
# Epoch -1323 calculated in 34.36 s
# Epoch 1323, NRMSE Test/best: 0.35761/0.34518, Training NRMSE: 0.25752, deviation of 38.87%
# Epoch -1324 calculated in 34.51 s
# Epoch 1324, NRMSE Test/best: 0.35867/0.34518, Training NRMSE: 0.25627, deviation of 39.96%
# Epoch -1325 calculated in 34.62 s
# Epoch 1325, NRMSE Test/best: 0.36334/0.34518, Training NRMSE: 0.25618, deviation of 41.83%
# Epoch -1326 calculated in 34.68 s
# Epoch 1326, NRMSE Test/best: 0.36257/0.34518, Training NRMSE: 0.25814, deviation of 40.46%
# Epoch -1327 calculated in 34.34 s
# Epoch 1327, NRMSE Test/best: 0.36175/0.34518, Training NRMSE: 0.25764, deviation of 40.41%
# Epoch -1328 calculated in 34.59 s
# Epoch 1328, NRMSE Test/best: 0.36053/0.34518, Training NRMSE: 0.25644, deviation of 40.59%
# Epoch -1329 calculated in 34.55 s
# Epoch 1329, NRMSE Test/best: 0.35863/0.34518, Training NRMSE: 0.25762, deviation of 39.21%
# Epoch -1330 calculated in 34.54 s
# Epoch 1330, NRMSE Test/best: 0.35940/0.34518, Training NRMSE: 0.25882, deviation of 38.86%
# Epoch -1331 calculated in 34.49 s
# Epoch 1331, NRMSE Test/best: 0.36296/0.34518, Training NRMSE: 0.25747, deviation of 40.97%
# Epoch -1332 calculated in 34.75 s
# Epoch 1332, NRMSE Test/best: 0.35923/0.34518, Training NRMSE: 0.25656, deviation of 40.02%
# Epoch -1333 calculated in 34.60 s
# Epoch 1333, NRMSE Test/best: 0.36411/0.34518, Training NRMSE: 0.25687, deviation of 41.75%
# Epoch -1334 calculated in 34.41 s
# Epoch 1334, NRMSE Test/best: 0.35919/0.34518, Training NRMSE: 0.25706, deviation of 39.73%
# Epoch -1335 calculated in 34.50 s
# Epoch 1335, NRMSE Test/best: 0.36230/0.34518, Training NRMSE: 0.25772, deviation of 40.58%
# Epoch -1336 calculated in 34.56 s
# Epoch 1336, NRMSE Test/best: 0.36240/0.34518, Training NRMSE: 0.25600, deviation of 41.57%
# Epoch -1337 calculated in 34.45 s
# Epoch 1337, NRMSE Test/best: 0.35855/0.34518, Training NRMSE: 0.25849, deviation of 38.71%
# Epoch -1338 calculated in 34.65 s
# Epoch 1338, NRMSE Test/best: 0.35972/0.34518, Training NRMSE: 0.25870, deviation of 39.05%
# Epoch -1339 calculated in 34.37 s
# Epoch 1339, NRMSE Test/best: 0.36179/0.34518, Training NRMSE: 0.25693, deviation of 40.81%
# Epoch -1340 calculated in 34.35 s
# Epoch 1340, NRMSE Test/best: 0.36105/0.34518, Training NRMSE: 0.25579, deviation of 41.15%
# Epoch -1341 calculated in 34.45 s
# Epoch 1341, NRMSE Test/best: 0.36159/0.34518, Training NRMSE: 0.25738, deviation of 40.49%
# Epoch -1342 calculated in 34.58 s
# Epoch 1342, NRMSE Test/best: 0.35953/0.34518, Training NRMSE: 0.25588, deviation of 40.51%
# Epoch -1343 calculated in 34.60 s
# Epoch 1343, NRMSE Test/best: 0.35864/0.34518, Training NRMSE: 0.25737, deviation of 39.35%
# Epoch -1344 calculated in 34.33 s
# Epoch 1344, NRMSE Test/best: 0.35814/0.34518, Training NRMSE: 0.25692, deviation of 39.40%
# Epoch -1345 calculated in 34.58 s
# Epoch 1345, NRMSE Test/best: 0.35749/0.34518, Training NRMSE: 0.25618, deviation of 39.54%
# Epoch -1346 calculated in 34.53 s
# Epoch 1346, NRMSE Test/best: 0.36033/0.34518, Training NRMSE: 0.25683, deviation of 40.30%
# Epoch -1347 calculated in 34.44 s
# Epoch 1347, NRMSE Test/best: 0.35808/0.34518, Training NRMSE: 0.25858, deviation of 38.48%
# Epoch -1348 calculated in 34.59 s
# Epoch 1348, NRMSE Test/best: 0.35529/0.34518, Training NRMSE: 0.25824, deviation of 37.58%
# Epoch -1349 calculated in 34.52 s
# Epoch 1349, NRMSE Test/best: 0.35932/0.34518, Training NRMSE: 0.25860, deviation of 38.95%
# Epoch -1350 calculated in 34.44 s
# Epoch 1350, NRMSE Test/best: 0.35537/0.34518, Training NRMSE: 0.25656, deviation of 38.51%
# Epoch -1351 calculated in 34.56 s
# Epoch 1351, NRMSE Test/best: 0.35952/0.34518, Training NRMSE: 0.25784, deviation of 39.44%
# Epoch -1352 calculated in 34.37 s
# Epoch 1352, NRMSE Test/best: 0.36104/0.34518, Training NRMSE: 0.25634, deviation of 40.85%
# Epoch -1353 calculated in 34.53 s
# Epoch 1353, NRMSE Test/best: 0.35740/0.34518, Training NRMSE: 0.25754, deviation of 38.78%
# Epoch -1354 calculated in 34.62 s
# Epoch 1354, NRMSE Test/best: 0.35734/0.34518, Training NRMSE: 0.25790, deviation of 38.56%
# Epoch -1355 calculated in 34.69 s
# Epoch 1355, NRMSE Test/best: 0.36004/0.34518, Training NRMSE: 0.25735, deviation of 39.91%
# Epoch -1356 calculated in 34.57 s
# Epoch 1356, NRMSE Test/best: 0.36095/0.34518, Training NRMSE: 0.25710, deviation of 40.39%
# Epoch -1357 calculated in 34.47 s
# Epoch 1357, NRMSE Test/best: 0.35857/0.34518, Training NRMSE: 0.25662, deviation of 39.73%
# Epoch -1358 calculated in 34.60 s
# Epoch 1358, NRMSE Test/best: 0.36015/0.34518, Training NRMSE: 0.25724, deviation of 40.00%
# Epoch -1359 calculated in 34.36 s
# Epoch 1359, NRMSE Test/best: 0.36251/0.34518, Training NRMSE: 0.25656, deviation of 41.30%
# Epoch -1360 calculated in 34.88 s
# Epoch 1360, NRMSE Test/best: 0.36006/0.34518, Training NRMSE: 0.25812, deviation of 39.49%
# Epoch -1361 calculated in 34.53 s
# Epoch 1361, NRMSE Test/best: 0.35896/0.34518, Training NRMSE: 0.25624, deviation of 40.09%
# Epoch -1362 calculated in 34.45 s
# Epoch 1362, NRMSE Test/best: 0.35810/0.34518, Training NRMSE: 0.25697, deviation of 39.35%
# Epoch -1363 calculated in 34.43 s
# Epoch 1363, NRMSE Test/best: 0.35826/0.34518, Training NRMSE: 0.25612, deviation of 39.88%
# Epoch -1364 calculated in 34.61 s
# Epoch 1364, NRMSE Test/best: 0.35711/0.34518, Training NRMSE: 0.25540, deviation of 39.82%
# Epoch -1365 calculated in 34.45 s
# Epoch 1365, NRMSE Test/best: 0.35830/0.34518, Training NRMSE: 0.25581, deviation of 40.07%
# Epoch -1366 calculated in 34.55 s
# Epoch 1366, NRMSE Test/best: 0.36012/0.34518, Training NRMSE: 0.25696, deviation of 40.15%
# Epoch -1367 calculated in 34.31 s
# Epoch 1367, NRMSE Test/best: 0.35703/0.34518, Training NRMSE: 0.26156, deviation of 36.50%
# Epoch -1368 calculated in 34.59 s
# Epoch 1368, NRMSE Test/best: 0.36409/0.34518, Training NRMSE: 0.25641, deviation of 42.00%
# Epoch -1369 calculated in 34.46 s
# Epoch 1369, NRMSE Test/best: 0.36037/0.34518, Training NRMSE: 0.25613, deviation of 40.70%
# Epoch -1370 calculated in 34.59 s
# Epoch 1370, NRMSE Test/best: 0.36003/0.34518, Training NRMSE: 0.25601, deviation of 40.63%
# Epoch -1371 calculated in 34.27 s
# Epoch 1371, NRMSE Test/best: 0.36345/0.34518, Training NRMSE: 0.25568, deviation of 42.15%
# Epoch -1372 calculated in 34.66 s
# Epoch 1372, NRMSE Test/best: 0.36068/0.34518, Training NRMSE: 0.25576, deviation of 41.03%
# Epoch -1373 calculated in 34.48 s
# Epoch 1373, NRMSE Test/best: 0.36331/0.34518, Training NRMSE: 0.25606, deviation of 41.88%
# Epoch -1374 calculated in 34.20 s
# Epoch 1374, NRMSE Test/best: 0.36113/0.34518, Training NRMSE: 0.25581, deviation of 41.17%
# Epoch -1375 calculated in 34.43 s
# Epoch 1375, NRMSE Test/best: 0.36351/0.34518, Training NRMSE: 0.25773, deviation of 41.04%
# Epoch -1376 calculated in 34.45 s
# Epoch 1376, NRMSE Test/best: 0.35786/0.34518, Training NRMSE: 0.25758, deviation of 38.93%
# Epoch -1377 calculated in 34.64 s
# Epoch 1377, NRMSE Test/best: 0.36169/0.34518, Training NRMSE: 0.25661, deviation of 40.95%
# Epoch -1378 calculated in 34.56 s
# Epoch 1378, NRMSE Test/best: 0.36028/0.34518, Training NRMSE: 0.25636, deviation of 40.54%
# Epoch -1379 calculated in 34.52 s
# Epoch 1379, NRMSE Test/best: 0.36301/0.34518, Training NRMSE: 0.25533, deviation of 42.18%
# Epoch -1380 calculated in 34.73 s
# Epoch 1380, NRMSE Test/best: 0.35794/0.34518, Training NRMSE: 0.25677, deviation of 39.40%
# Epoch -1381 calculated in 34.51 s
# Epoch 1381, NRMSE Test/best: 0.35993/0.34518, Training NRMSE: 0.25714, deviation of 39.97%
# Epoch -1382 calculated in 34.41 s
# Epoch 1382, NRMSE Test/best: 0.36318/0.34518, Training NRMSE: 0.25583, deviation of 41.96%
# Epoch -1383 calculated in 34.58 s
# Epoch 1383, NRMSE Test/best: 0.36198/0.34518, Training NRMSE: 0.25645, deviation of 41.15%
# Epoch -1384 calculated in 34.47 s
# Epoch 1384, NRMSE Test/best: 0.35903/0.34518, Training NRMSE: 0.25463, deviation of 41.00%
# Epoch -1385 calculated in 34.48 s
# Epoch 1385, NRMSE Test/best: 0.36357/0.34518, Training NRMSE: 0.25549, deviation of 42.30%
# Epoch -1386 calculated in 34.50 s
# Epoch 1386, NRMSE Test/best: 0.36145/0.34518, Training NRMSE: 0.25655, deviation of 40.89%
# Epoch -1387 calculated in 34.44 s
# Epoch 1387, NRMSE Test/best: 0.35878/0.34518, Training NRMSE: 0.25509, deviation of 40.65%
# Training duration 01:15:00:35
# Number of training variable 69691
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/freeze_graph.py:249: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from Experiments/2019-05-14-16-41/temp/myFinalModel.ckpt
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/freeze_graph.py:232: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.convert_variables_to_constants
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/graph_util_impl.py:245: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph
# INFO:tensorflow:Froze 8 variables.
# INFO:tensorflow:Converted 8 variables to const ops.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/tools/optimize_for_inference_lib.py:113: remove_training_nodes (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.remove_training_nodes
# INFO:tensorflow:Restoring parameters from Experiments/2019-05-14-16-41/temp/myBestModel.ckpt
# done, good job kids

# %%
from show import *
# %matplotlib notebook
showPickle(nameFigEstimation)
# Out:
# <img src="data:image/png;base64,..." width="640">
